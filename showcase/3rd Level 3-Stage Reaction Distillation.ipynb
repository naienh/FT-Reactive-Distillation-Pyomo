# %% [markdown]
# # 3rd Level Model Structure: Single Stage Reactive Distillation

# %%
import sys
import os
import pickle
sys.path.append(os.path.abspath('..'))

import numpy as np
from matplotlib import pyplot as plt
import ipywidgets as widgets
from copy import deepcopy

# %%
from pyomo import environ as pe
from global_sets.component import m

from stages.reactive_stage import reactive_stage_rule
from stages.condenser_stage import condenser_stage_rule

from utility.display_utility import trans_product_mole, trans_product_mass, beautify2
from utility.model_utility import add_dual, update_dual, check_DOF
from utility.data_utility import cal_cnumber

model = pe.ConcreteModel()

# %% [markdown]
# # Global Set

# %%
model.TRAY = pe.RangeSet(1,3)

# %% [markdown]
# # Construct Reactive Stages

# %%
model.reactive = pe.Block(model.TRAY,rule=reactive_stage_rule)
# Out:
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[1].T_F
# | reactive[1].P
# | reactive[1].cat
# | reactive[1].Q_main
# | reactive[1].x_
# | reactive[1].y_
# | reactive[1].x
# | reactive[1].y
# | reactive[1].z
# | reactive[1].L
# | reactive[1].V
# | reactive[1].F
# | reactive[1].H_L_
# | reactive[1].H_V_
# | reactive[1].H_L
# | reactive[1].H_V
# | reactive[1].T
# | reactive[1].H_F
# | reactive[1].f_V
# | reactive[1].f_L
# | reactive[1].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].kinetics_block.k_FT
# | reactive[1].kinetics_block.r_FT_total
# | reactive[1].kinetics_block.g0_FT
# | reactive[1].kinetics_block.alpha
# | reactive[1].kinetics_block.r_FT_cnum
# | reactive[1].kinetics_block.r_FT_comp
# | reactive[1].kinetics_block.k_WGS
# | reactive[1].kinetics_block.Ke_WGS
# | reactive[1].kinetics_block.r_WGS
# | reactive[1].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].energy_block.dH_F
# | reactive[1].energy_block.dH_V
# | reactive[1].energy_block.dH_L
# | reactive[1].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].VLE_block.P_VLE
# | reactive[1].VLE_block.n_ave
# | reactive[1].VLE_block.n_ave_cal
# | reactive[1].VLE_block.Hen
# | reactive[1].VLE_block.Hen0
# | reactive[1].VLE_block.gamma
# | reactive[1].VLE_block.P_sat
# | reactive[1].VLE_block.P_sat_Y
# | reactive[1].VLE_block.P_sat_dY_inf
# | reactive[1].VLE_block.P_sat_dY0
# | reactive[1].VLE_block.Hen_ref
# | reactive[1].VLE_block.Hen0_ref
# | reactive[1].VLE_block.gamma_ref
# | reactive[1].VLE_block.V_L
# | reactive[1].VLE_block.V_L_dY_inf
# | reactive[1].VLE_block.V_L_dY0
# | reactive[1].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].MPCC.s_L
# | reactive[1].MPCC.s_V
# | reactive[1].MPCC.pf
# | reactive[1].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[2].T_F
# | reactive[2].P
# | reactive[2].cat
# | reactive[2].Q_main
# | reactive[2].x_
# | reactive[2].y_
# | reactive[2].x
# | reactive[2].y
# | reactive[2].z
# | reactive[2].L
# | reactive[2].V
# | reactive[2].F
# | reactive[2].H_L_
# | reactive[2].H_V_
# | reactive[2].H_L
# | reactive[2].H_V
# | reactive[2].T
# | reactive[2].H_F
# | reactive[2].f_V
# | reactive[2].f_L
# | reactive[2].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].kinetics_block.k_FT
# | reactive[2].kinetics_block.r_FT_total
# | reactive[2].kinetics_block.g0_FT
# | reactive[2].kinetics_block.alpha
# | reactive[2].kinetics_block.r_FT_cnum
# | reactive[2].kinetics_block.r_FT_comp
# | reactive[2].kinetics_block.k_WGS
# | reactive[2].kinetics_block.Ke_WGS
# | reactive[2].kinetics_block.r_WGS
# | reactive[2].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].energy_block.dH_F
# | reactive[2].energy_block.dH_V
# | reactive[2].energy_block.dH_L
# | reactive[2].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].VLE_block.P_VLE
# | reactive[2].VLE_block.n_ave
# | reactive[2].VLE_block.n_ave_cal
# | reactive[2].VLE_block.Hen
# | reactive[2].VLE_block.Hen0
# | reactive[2].VLE_block.gamma
# | reactive[2].VLE_block.P_sat
# | reactive[2].VLE_block.P_sat_Y
# | reactive[2].VLE_block.P_sat_dY_inf
# | reactive[2].VLE_block.P_sat_dY0
# | reactive[2].VLE_block.Hen_ref
# | reactive[2].VLE_block.Hen0_ref
# | reactive[2].VLE_block.gamma_ref
# | reactive[2].VLE_block.V_L
# | reactive[2].VLE_block.V_L_dY_inf
# | reactive[2].VLE_block.V_L_dY0
# | reactive[2].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].MPCC.s_L
# | reactive[2].MPCC.s_V
# | reactive[2].MPCC.pf
# | reactive[2].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[3].T_F
# | reactive[3].P
# | reactive[3].cat
# | reactive[3].Q_main
# | reactive[3].x_
# | reactive[3].y_
# | reactive[3].x
# | reactive[3].y
# | reactive[3].z
# | reactive[3].L
# | reactive[3].V
# | reactive[3].F
# | reactive[3].H_L_
# | reactive[3].H_V_
# | reactive[3].H_L
# | reactive[3].H_V
# | reactive[3].T
# | reactive[3].H_F
# | reactive[3].f_V
# | reactive[3].f_L
# | reactive[3].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].kinetics_block.k_FT
# | reactive[3].kinetics_block.r_FT_total
# | reactive[3].kinetics_block.g0_FT
# | reactive[3].kinetics_block.alpha
# | reactive[3].kinetics_block.r_FT_cnum
# | reactive[3].kinetics_block.r_FT_comp
# | reactive[3].kinetics_block.k_WGS
# | reactive[3].kinetics_block.Ke_WGS
# | reactive[3].kinetics_block.r_WGS
# | reactive[3].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].energy_block.dH_F
# | reactive[3].energy_block.dH_V
# | reactive[3].energy_block.dH_L
# | reactive[3].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].VLE_block.P_VLE
# | reactive[3].VLE_block.n_ave
# | reactive[3].VLE_block.n_ave_cal
# | reactive[3].VLE_block.Hen
# | reactive[3].VLE_block.Hen0
# | reactive[3].VLE_block.gamma
# | reactive[3].VLE_block.P_sat
# | reactive[3].VLE_block.P_sat_Y
# | reactive[3].VLE_block.P_sat_dY_inf
# | reactive[3].VLE_block.P_sat_dY0
# | reactive[3].VLE_block.Hen_ref
# | reactive[3].VLE_block.Hen0_ref
# | reactive[3].VLE_block.gamma_ref
# | reactive[3].VLE_block.V_L
# | reactive[3].VLE_block.V_L_dY_inf
# | reactive[3].VLE_block.V_L_dY0
# | reactive[3].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].MPCC.s_L
# | reactive[3].MPCC.s_V
# | reactive[3].MPCC.pf
# | reactive[3].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE

# %% [markdown]
# # Construct a single condenser

# %%
model.condenser = pe.Block(rule=condenser_stage_rule)
# Out:
# | Importing Condenser Stage......
# | Adding the following local variable:
# ------------------------------------
# | condenser.T
# | condenser.T_F
# | condenser.P
# | condenser.Q_main
# | condenser.x_
# | condenser.y_
# | condenser.x
# | condenser.y
# | condenser.z
# | condenser.L
# | condenser.W
# | condenser.V
# | condenser.F
# | condenser.H_L_
# | condenser.H_V_
# | condenser.H_L
# | condenser.H_V
# | condenser.H_F
# | condenser.f_V
# | condenser.f_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.energy_block.dH_F
# | condenser.energy_block.dH_V
# | condenser.energy_block.dH_L
# | condenser.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.VLE_block.n_ave
# | condenser.VLE_block.n_ave_cal
# | condenser.VLE_block.Hen
# | condenser.VLE_block.Hen0
# | condenser.VLE_block.gamma
# | condenser.VLE_block.P_sat
# | condenser.VLE_block.P_sat_Y
# | condenser.VLE_block.P_sat_dY_inf
# | condenser.VLE_block.P_sat_dY0
# | condenser.VLE_block.Hen_ref
# | condenser.VLE_block.Hen0_ref
# | condenser.VLE_block.gamma_ref
# | condenser.VLE_block.V_L
# | condenser.VLE_block.V_L_dY_inf
# | condenser.VLE_block.V_L_dY0
# | condenser.VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# # Linking Stage Variables

# %% [markdown]
# ### Vapor Between Reactive Stages

# %%
def V_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].V['in'] == model.reactive[j+1].V['out']
model.V_between_con = pe.Constraint(model.TRAY,rule=V_between_rule)

def Vy_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].y_['in',i] == model.reactive[j+1].y[i]
model.Vy_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Vy_between_rule)

def Vh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].H_V_['in'] == model.reactive[j+1].H_V
model.Vh_between_con = pe.Constraint(model.TRAY,rule=Vh_between_rule)

# %% [markdown]
# ### Liquid Between Reactive Stages

# %%
def L_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].L['in'] == model.reactive[j].L['out']
model.L_between_con = pe.Constraint(model.TRAY,rule=L_between_rule)

def Lx_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].x_['in',i] == model.reactive[j].x[i]
model.Ly_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Lx_between_rule)

def Lh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].H_L_['in'] == model.reactive[j].H_L
model.Lh_between_con = pe.Constraint(model.TRAY,rule=Lh_between_rule)

# %% [markdown]
# ### Condenser

# %%
def V_condenser_rule(model):
    return model.reactive[model.TRAY.first()].V['out'] == model.condenser.V['in']
model.V_condenser_con = pe.Constraint(rule=V_condenser_rule)

def Vy_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].y[i] == model.condenser.y_['in',i]
model.Vy_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_condenser_rule)

def Vh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_V == model.condenser.H_V_['in']
model.Vh_condenser_con = pe.Constraint(rule=Vh_condenser_rule)

# %%
def L_condenser_rule(model):
    return model.reactive[model.TRAY.first()].L['in'] == model.condenser.L['out']
model.L_condenser_con = pe.Constraint(rule=L_condenser_rule)

def Lx_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].x_['in',i] == model.condenser.x[i]
model.Lx_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_condenser_rule)

def Lh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_L_['in'] == model.condenser.H_L
model.Lh_condenser_con = pe.Constraint(rule=Lh_condenser_rule)

# %%
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.TRAY) ,sense=pe.maximize)

# %%
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# # Load from single stage solutions

# %%
# with open('../saved_solutions/reactive_flash_MPCC_P_pf.pickle', 'rb') as f:
#     results_imported = pickle.load(f)
# results_changed = deepcopy(results_imported)

# %% [markdown]
# ### Duplicate variable solution and bounds multiplier

# %%
# results_changed.Solution.Variable = {}
# for i in list(results_imported.Solution.Variable.keys()):
#     for j in model.TRAY:
#         results_changed.Solution.Variable['reactive[{}].{}'.format(j,i)] = \
#         results_imported.Solution.Variable[i]

# %% [markdown]
# ### Duplicate constraint multiplier

# %%
# results_changed.Solution.Constraint = {}
# for i in list(results_imported.Solution.Constraint.keys()):
#     for j in model.TRAY:
#         results_changed.Solution.Constraint['reactive[{}].{}'.format(j,i)] = \
#         results_imported.Solution.Constraint[i]

# %% [markdown]
# ### Load changed solution into current model

# %%
# model.solutions.load_from(results_changed)

# %% [markdown]
# # Fixing Redundent Stream Variables

# %%
# condenser
model.condenser.VLE_block.n_ave.fix(4)

model.condenser.F.fix(0)
model.condenser.T_F.fix(300+273.15)
model.condenser.z.fix(0)

model.condenser.V['P'].fix(0)
model.condenser.L['in'].fix(0)
for i in m.COMP_TOTAL: model.condenser.x_['in',i].fix(0)
model.condenser.H_L_['in'].fix(0)

# %%
# 'reboiler' fixing last stage V_in

model.reactive[model.TRAY.last()].V['in'].fix(0)
for i in m.COMP_TOTAL: model.reactive[model.TRAY.last()].y_['in',i].fix(0)
model.reactive[model.TRAY.last()].H_V_['in'].fix(0)

# %% [markdown]
# # Load Operating Parameters

# %%
# condenser
model.condenser.P.fix(19)
# model.condenser.T.fix(30+273.15)
model.condenser.T.fix(30+273.15)
model.condenser.L['out'].fix(0)

# reactive stage
for j in model.reactive:
    model.reactive[j].cat.fix(5000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2))
    model.reactive[j].z['H2'].fix(2/(1+2))
    model.reactive[j].z['C30H62'].fix(0)
    model.reactive[j].V['P'].fix(0)
    model.reactive[j].L['P'].fix(0)
    # model.reactive[j].Q_main.fix(0)
    model.reactive[j].T.setub(300+273.15)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 4989
# Active Inequality Constraints:	 3
# Active Variables:		 5203
# Fixed Variables:		 202
# DOF:				 12

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'

opt.options['linear_system_scaling '] = 'mc19'
opt.options['linear_scaling_on_demand '] = 'no'
# opt.options['recalc_y'] = 'yes'
# opt.options['bound_relax_factor'] = 0
# opt.options['halt_on_ampl_error'] = 'yes'

opt.options['max_iter'] = 7000
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    16780
# Number of nonzeros in inequality constraint Jacobian.:       15
# Number of nonzeros in Lagrangian Hessian.............:    17594
#
# Total number of variables............................:     5001
#                      variables with only lower bounds:      845
#                 variables with lower and upper bounds:     3553
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     4989
# Total number of inequality constraints...............:        3
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        3
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -1.4224200e+03 7.97e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1r-1.4224200e+03 7.97e+03 9.99e+02   3.8 0.00e+00    -  0.00e+00 4.57e-07R  4
#    2r-1.4224200e+03 7.97e+03 9.99e+02   3.8 5.59e+05    -  6.84e-07 4.01e-11f  1
#    3r-1.4244322e+03 7.85e+03 9.99e+02   1.7 5.78e+05    -  2.53e-04 1.70e-04f  1
#    4r-1.4380012e+03 6.87e+03 9.99e+02   1.7 2.28e+06    -  1.81e-04 3.49e-04f  1
#    5 -1.4380193e+03 6.87e+03 2.62e+01  -1.0 6.89e+04    -  9.15e-05 1.13e-04h  1
#    6 -1.4380271e+03 6.87e+03 2.57e+01  -1.0 6.37e+04    -  1.04e-04 4.63e-05h  1
#    7 -1.4380444e+03 6.87e+03 2.27e+01  -1.0 5.46e+04    -  7.30e-05 1.04e-04h  1
#    8 -1.4380486e+03 6.87e+03 2.39e+01  -1.0 1.68e+05    -  2.25e-05 2.19e-05h  1
#    9 -1.4380547e+03 6.87e+03 3.18e+01  -1.0 1.83e+05    -  7.46e-05 3.19e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-1.4380547e+03 6.87e+03 9.99e+02   3.8 0.00e+00    -  0.00e+00 2.14e-07R  2
#   11r-1.4380551e+03 6.87e+03 2.23e+03   3.8 5.26e+05    -  2.37e-04 9.29e-08f  1
#   12r-1.4743909e+03 4.67e+03 2.22e+03  -0.4 6.21e+05    -  1.44e-03 2.84e-03f  1
#   13r-1.4743909e+03 4.67e+03 9.99e+02   3.6 0.00e+00    -  0.00e+00 3.06e-07R  4
#   14r-1.4743909e+03 4.67e+03 1.25e+04   3.6 6.03e+05    -  2.00e-03 7.16e-12f  1
#   15r-1.5387058e+03 5.14e+02 1.24e+04  -1.3 6.37e+05    -  2.97e-03 5.25e-03f  1
#   16r-1.5387058e+03 5.14e+02 9.99e+02   2.7 0.00e+00    -  0.00e+00
-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  530 -1.7194473e+03 3.05e-10 5.74e+02  -3.8 1.95e-05    -  1.00e+00 1.00e+00H  1
#  531 -1.7194496e+03 7.17e-09 5.45e+04  -5.7 3.18e-02    -  1.00e+00 7.86e-01f  1
#  532 -1.7194500e+03 4.62e-10 9.17e+03  -5.7 6.37e-03    -  1.00e+00 1.00e+00f  1
#  533 -1.7194500e+03 1.53e-10 1.37e+02  -5.7 3.92e-06    -  1.00e+00 1.00e+00h  1
#  534 -1.7194500e+03 3.64e-12 5.85e-02  -5.7 1.04e-07    -  1.00e+00 1.00e+00h  1
#  535 -1.7194500e+03 3.00e-10 2.90e+01  -8.6 3.80e-04    -  1.00e+00 8.94e-01f  1
#  536 -1.7194500e+03 3.05e-10 5.53e+01  -8.6 4.04e-05    -  1.00e+00 3.11e-01f  1
#  537 -1.7194500e+03 1.91e-10 2.96e-02  -8.6 2.79e-05    -  1.00e+00 1.00e+00f  1
#  538 -1.7194500e+03 3.64e-12 3.55e-06  -8.6 4.11e-08    -  1.00e+00 1.00e+00h  1
#  539 -1.7194500e+03 3.64e-12 6.37e-11  -8.6 5.40e-10    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 539
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.7194500172094056e+03   -1.7194500172094056e+03
# Dual infeasibility......:   6.3683508523112499e-11    6.3683508523112499e-11
# Constraint violation....:   2.9897460212784098e-12    3.6379788070917130e-12
# Complementarity.........:   2.5059035859224436e-09    2.5059035859224436e-09
# Overall NLP error.......:   2.5059035859224436e-09    2.5059035859224436e-09
#
#
# Number of objective function evaluations             = 900
# Number of objective gradient evaluations             = 366
# Number of equality constraint evaluations            = 900
# Number of inequality constraint evaluations          = 900
# Number of equality constraint Jacobian evaluations   = 551
# Number of inequality constraint Jacobian evaluations = 551
# Number of Lagrangian Hessian evaluations             = 539
# Total CPU secs in IPOPT (w/o function evaluations)   =    229.583
# Total CPU secs in NLP function evaluations           =      5.509
#
# EXIT: Optimal Solution Found.

# %%
beautify2(pe,model)
# Out:
# Here comes the result:
# ----------------------------------------------------------------------------------------------------
# 		T		 Q			 V			 L
#                30.00 	       -52.1831200343 	         0.5552676251 	         0.0000000000
#               300.00 	       -47.0548743047 	         1.3704606254 	         0.0000000000
#               300.00 	       -47.0548743799 	         0.9136404142 	         0.0000000000
#               300.00 	       -47.0548743542 	         0.4568202080 	         0.0000000000
# ----------------------------------------------------------------------------------------------------
# Top
# V	 0.5552676250753587
# L	 0.03179527279199477
# W	 0.7833977275608544
# ----------------------------------------------------------------------------------------------------
# Bottom
# L	 0.0
# ----------------------------------------------------------------------------------------------------
# Condenser:	Vapor		Liquid		Last Stage	Vapor		Liquid
# H2 		0.526%		0.007%		 H2       	0.213%		0.070%
# CO 		0.008%		0.000%		 CO       	0.003%		0.001%
# CO2 		19.175%		3.726%		 CO2      	7.856%		5.354%
# H2O 		0.223%		0.000%		 H2O      	57.254%		59.714%
# C2H4 		13.612%		4.251%		 C2H4     	5.614%		4.663%
# C3H6 		7.271%		12.159%		 C3H6     	3.228%		4.801%
# C4H8 		2.702%		14.612%		 C4H8     	1.434%		1.940%
# C5H10 		0.665%		12.311%		 C5H10    	0.555%		1.395%
# C6H12 		0.143%		8.685%		 C6H12    	0.259%		1.088%
# C7H14 		0.025%		4.795%		 C7H14    	0.121%		0.792%
# C8H16 		0.004%		2.375%		 C8H16    	0.057%		0.551%
# C9H18 		0.001%		1.132%		 C9H18    	0.027%		0.370%
# C10H20 		0.000%		0.532%		 C10H20   	0.012%		0.242%
# C11H22 		0.000%		0.159%		 C11H22   	0.004%		0.099%
# C12H24 		0.000%		0.074%		 C12H24   	0.002%		0.062%
# C13H26 		0.000%		0.035%		 C13H26   	0.001%		0.039%
# C14H28 		0.000%		0.016%		 C14H28   	0.000%		0.024%
# C15H30 		0.000%		0.008%		 C15H30   	0.000%		0.015%
# C16H32 		0.000%		0.004%		 C16H32   	0.000%		0.009%
# C17H34 		0.000%		0.002%		 C17H34   	0.000%		0.005%
# C1H4 		45.356%		3.828%		 C1H4     	18.466%		11.044%
# C2H6 		7.226%		3.890%		 C2H6     	3.018%		2.667%
# C3H8 		1.811%		3.156%		 C3H8     	0.807%		1.128%
# C4H10 		0.811%		5.340%		 C4H10    	0.452%		0.685%
# C5H12 		0.353%		7.903%		 C5H12    	0.327%		0.900%
# C6H14 		0.073%		5.308%		 C6H14    	0.153%		0.693%
# C7H16 		0.012%		2.860%		 C7H16    	0.071%		0.501%
# C8H18 		0.002%		1.404%		 C8H18    	0.033%		0.346%
# C9H20 		0.000%		0.667%		 C9H20    	0.016%		0.232%
# C10H22 		0.000%		0.313%		 C10H22   	0.007%		0.151%
# C11H24 		0.000%		0.237%		 C11H24   	0.006%		0.156%
# C12H26 		0.000%		0.111%		 C12H26   	0.003%		0.098%
# C13H28 		0.000%		0.052%		 C13H28   	0.001%		0.061%
# C14H30 		0.000%		0.024%		 C14H30   	0.001%		0.038%
# C15H32 		0.000%		0.011%		 C15H32   	0.000%		0.023%
# C16H34 		0.000%		0.005%		 C16H34   	0.000%		0.014%
# C17H36 		0.000%		0.002%		 C17H36   	0.000%		0.008%
# C18H38 		0.000%		0.001%		 C18H38   	0.000%		0.005%

# %%
model.reactive[1].kinetics_block.r_FT_total.value
# Out:
# 0.29743176486952727

# %%
# model.solutions.store_to(results)
# with open('../saved_solutions/3_stage_condenser_240C.pickle','wb') as f:
#     pickle.dump(results,f)

# %% [markdown]
# # So, what exactly does adding a reflux do?

# %%
opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6

# %%
results_anchor = results
update_dual(pe,model)
model.solutions.store_to(results_anchor)

# %%
Refluxrange = np.linspace(0,2,41)
Trange = np.linspace(300+273.15,200+273.15,21)

# %%
cd_data_master = {}
rf_data_master = {}

for t in Trange:
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.TRAY) ,sense=pe.maximize)
    model.solutions.load_from(results_anchor)
    update_dual(pe,model)
    
    for j in model.reactive:
        model.reactive[j].T.fixed = False
        model.reactive[j].T.setub(t)
        model.reactive[j].T = t
    model.condenser.L['out'].fix(0)
    
    results_anchor = opt.solve(model,tee=False)
    model.solutions.store_to(results_anchor)
    
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = model.condenser.L['out'] - sum(model.reactive[j].MPCC.pf for j in model.TRAY),sense=pe.maximize)
    model.condenser.L['out'].fixed = False
    for j in model.reactive:
        model.reactive[j].T.fixed=True
    
    print('\nWorking on T = {} K'.format(model.reactive[1].T.value))
    print('-'*108)
    
    cd_data = {};
    cd_data['Re'] = []; cd_data['D'] = []; cd_data['V'] = []
    cd_data['x'] = {}; cd_data['y'] = {}; cd_data['g'] = {}; cd_data['d'] = {}; cd_data['b'] = {}
    for i in m.COMP_TOTAL:
        cd_data['x'][i] = []
        cd_data['y'][i] = []
        cd_data['g'][i] = []
        cd_data['d'][i] = []
        cd_data['b'][i] = []

    rf_data = {}
    for j in model.reactive:
        rf_data[j] = {}
        rf_data[j]['r'] = {}; rf_data[j]['b'] = {}; rf_data[j]['x'] = {};rf_data[j]['y'] = {};
        rf_data[j]['T'] = []; rf_data[j]['Q'] = []; rf_data[j]['V'] = []; rf_data[j]['L'] = []; 
        rf_data[j]['r_WGS'] = []; rf_data[j]['r_FT'] = []; rf_data[j]['pf'] = []
        for i in m.COMP_TOTAL:
            rf_data[j]['r'][i] = []
            rf_data[j]['b'][i] = []
            rf_data[j]['x'][i] = []
            rf_data[j]['y'][i] = []       

    for re in Refluxrange:
        model.condenser.L['out'].setub(re)
        results = opt.solve(model,tee=False)
        update_dual(pe,model)
        print('Solved\t|Reflux = {:.3f} kmol/s\t|Vapor = {:.3f} kmol/s\t|Distillate = {:.3f} kmol/s\t|Bottom = {:.3f} kmol/s'.\
              format(model.condenser.L['out'].value,model.condenser.V['out'].value,model.condenser.L['P'].value,model.reactive[3].L['out'].value))

        cd_data['V'].append(model.condenser.V['out'].value)
        cd_data['D'].append(model.condenser.L['P'].value)
        cd_data['Re'].append(model.condenser.L['out'].value)

        for i in model.reactive[1].r_total_comp:
            cd_data['x'][i].append(model.condenser.x[i].value)
            cd_data['y'][i].append(model.condenser.y[i].value)
            cd_data['g'][i].append(model.condenser.y[i].value*model.condenser.V['out'].value)
            cd_data['d'][i].append(model.condenser.x[i].value*model.condenser.L['P'].value)
            cd_data['b'][i].append(model.condenser.x[i].value*model.condenser.L['out'].value)

        for j in model.reactive:      
            rf_data[j]['T'].append(model.reactive[j].T.value)
            rf_data[j]['Q'].append(model.reactive[j].Q_main.value)
            rf_data[j]['V'].append(model.reactive[j].V['out'].value)
            rf_data[j]['L'].append(model.reactive[j].L['out'].value)
            rf_data[j]['r_WGS'].append(model.reactive[j].kinetics_block.r_WGS.value)
            rf_data[j]['r_FT'].append(model.reactive[j].kinetics_block.r_FT_total.value)
            rf_data[j]['pf'].append(model.reactive[j].MPCC.pf.value)

            for i in model.reactive[1].r_total_comp:
                rf_data[j]['r'][i].append(model.reactive[j].r_total_comp[i].value)
                rf_data[j]['b'][i].append(model.reactive[j].x[i].value*model.reactive[j].L['out'].value)
                rf_data[j]['x'][i].append(model.reactive[j].x[i].value)
                rf_data[j]['y'][i].append(model.reactive[j].y[i].value)
        
    cd_data_master[t] = cd_data
    rf_data_master[t] = rf_data
# Out:
# Working on T = 573.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.555 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.050 kmol/s	|Vapor = 0.556 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.556 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.150 kmol/s	|Vapor = 0.556 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.557 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.250 kmol/s	|Vapor = 0.557 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.558 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.350 kmol/s	|Vapor = 0.558 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.558 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.450 kmol/s	|Vapor = 0.559 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.559 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.550 kmol/s	|Vapor = 0.559 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.560 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.650 kmol/s	|Vapor = 0.560 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.560 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.750 kmol/s	|Vapor = 0.561 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.561 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.850 kmol/s	|Vapor = 0.561 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.562 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.950 kmol/s	|Vapor = 0.562 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.562 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.050 kmol/s	|Vapor = 0.562 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.563 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.150 kmol/s	|Vapor = 0.563 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.563 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.250 kmol/s	|Vapor = 0.564 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.564 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.350 kmol/s	|Vapor = 0.564 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.564 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.450 kmol/s	|Vapor = 0.565 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.565 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.550 kmol/s	|Vapor = 0.565 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.565 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.650 kmol/s	|Vapor = 0.566 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.566 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.750 kmol/s	|Vapor = 0.566 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.566 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.850 kmol/s	|Vapor = 0.567 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.567 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.950 kmol/s	|Vapor = 0.567 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.567 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.000 kmol/s
#
# Working on T = 568.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.521 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.050 kmol/s	|Vapor = 0.521 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.522 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.150 kmol/s	|Vapor = 0.522 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.523 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.250 kmol/s	|Vapor = 0.523 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.524 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.350 kmol/s	|Vapor = 0.524 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.525 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.450 kmol/s	|Vapor = 0.525 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.525 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.550 kmol/s	|Vapor = 0.526 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.526 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.650 kmol/s	|Vapor = 0.527 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.527 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.750 kmol/s	|Vapor = 0.528 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.528 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.850 kmol/s	|Vapor = 0.528 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.529 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.950 kmol/s	|Vapor = 0.529 kmol/s	|Distillate = 0.042 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.530 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.050 kmol/s	|Vapor = 0.530 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.530 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.150 kmol/s	|Vapor = 0.531 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.531 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.250 kmol/s	|Vapor = 0.531 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.532 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.350 kmol/s	|Vapor = 0.532 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.532 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.450 kmol/s	|Vapor = 0.533 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.533 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.550 kmol/s	|Vapor = 0.533 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.534 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.650 kmol/s	|Vapor = 0.534 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.534 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.750 kmol/s	|Vapor = 0.535 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.535 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.850 kmol/s	|Vapor = 0.535 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.536 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.950 kmol/s	|Vapor = 0.536 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.536 kmol/s	|Distillate = 0.041 kmol/s	|Bottom = 0.000 kmol/s
#
# Working on T = 563.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.484 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.050 kmol/s	|Vapor = 0.485 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.485 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.150 kmol/s	|Vapor = 0.486 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.487 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.250 kmol/s	|Vapor = 0.487 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.488 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.350 kmol/s	|Vapor = 0.489 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.489 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.450 kmol/s	|Vapor = 0.490 kmol/s	|Distillate = 0.054 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.491 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.550 kmol/s	|Vapor = 0.491 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.492 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.650 kmol/s	|Vapor = 0.492 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.493 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.750 kmol/s	|Vapor = 0.493 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.494 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.850 kmol/s	|Vapor = 0.495 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.495 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.950 kmol/s	|Vapor = 0.496 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.496 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.050 kmol/s	|Vapor = 0.497 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.497 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.150 kmol/s	|Vapor = 0.498 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.498 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.250 kmol/s	|Vapor = 0.498 kmol/s	|Distillate = 0.053 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.499 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.350 kmol/s	|Vapor = 0.499 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.500 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.450 kmol/s	|Vapor = 0.500 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.501 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.550 kmol/s	|Vapor = 0.501 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.502 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.650 kmol/s	|Vapor = 0.502 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.502 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.750 kmol/s	|Vapor = 0.503 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.503 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.850 kmol/s	|Vapor = 0.504 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.504 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.950 kmol/s	|Vapor = 0.504 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.505 kmol/s	|Distillate = 0.052 kmol/s	|Bottom = 0.000 kmol/s
#
# Working on T = 558.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.446 kmol/s	|Distillate = 0.067 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.050 kmol/s	|Vapor = 0.447 kmol/s	|Distillate = 0.067 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.448 kmol/s	|Distillate = 0.067 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.150 kmol/s	|Vapor = 0.449 kmol/s	|Distillate = 0.067 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.450 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.250 kmol/s	|Vapor = 0.451 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.452 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.350 kmol/s	|Vapor = 0.453 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.453 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.450 kmol/s	|Vapor = 0.454 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.455 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.550 kmol/s	|Vapor = 0.456 kmol/s	|Distillate = 0.066 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.457 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.650 kmol/s	|Vapor = 0.458 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.458 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.750 kmol/s	|Vapor = 0.459 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.460 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.850 kmol/s	|Vapor = 0.461 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.461 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.950 kmol/s	|Vapor = 0.462 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.463 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.050 kmol/s	|Vapor = 0.463 kmol/s	|Distillate = 0.065 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.464 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.150 kmol/s	|Vapor = 0.465 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.465 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.250 kmol/s	|Vapor = 0.466 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.467 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.350 kmol/s	|Vapor = 0.467 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.468 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.450 kmol/s	|Vapor = 0.469 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.469 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.550 kmol/s	|Vapor = 0.470 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.470 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.650 kmol/s	|Vapor = 0.471 kmol/s	|Distillate = 0.064 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.471 kmol/s	|Distillate = 0.063 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.750 kmol/s	|Vapor = 0.472 kmol/s	|Distillate = 0.063 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.472 kmol/s	|Distillate = 0.063 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.850 kmol/s	|Vapor = 0.473 kmol/s	|Distillate = 0.063 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.474 kmol/s	|Distillate = 0.063 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 1.950 kmol/s	|Vapor = 0.474 kmol/s	|Distillate = 0.063 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.475 kmol/s	|Distillate = 0.063 kmol/s	|Bottom = 0.000 kmol/s
#
# Working on T = 553.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.407 kmol/s	|Distillate = 0.080 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.050 kmol/s	|Vapor = 0.409 kmol/s	|Distillate = 0.080 kmol/s	|Bottom = 0.000 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.410 kmol/s	|Distillate = 0.079 kmol/s	|Bottom = 0.000 kmol/s

# %%
cnumber_range = range(1,57)

# %%
def trans_cnumber(dic):
    molefraction = {}
    for i in range(1,57):
        molefraction[i] = []
    for i in m.COMP_ORG:
        molefraction[cal_cnumber(i)].append(np.array(dic[i]))
    for i in range(1,57):
        molefraction[i] = np.sum(molefraction[i],0)
    length = len(molefraction[1])
    tmp = {}
    for j in range(length):
        tmp[j] = []
        for i in range(1,57):
            tmp[j].append(molefraction[i][j])
    return tmp

# %%
g_data = {}
d_data = {}
lr_data = {}
l1_data = {}
l2_data = {}
l3_data = {}

cd_x_data = {}
rf_x_data = {}

for t in Trange:

    g_data[t] = trans_cnumber(cd_data_master[t]['g'])
    d_data[t] = trans_cnumber(cd_data_master[t]['d'])
    lr_data[t] = trans_cnumber(cd_data_master[t]['d'])
    l1_data[t] = trans_cnumber(rf_data_master[t][1]['b'])
    l2_data[t] = trans_cnumber(rf_data_master[t][2]['b'])
    l3_data[t] = trans_cnumber(rf_data_master[t][3]['b'])
    
    cd_x_data[t] = trans_cnumber(cd_data_master[t]['x'])
    rf_x_data[t] = {}
    for j in model.reactive:
        rf_x_data[t][j] = trans_cnumber(rf_data_master[t][j]['x'])

# %%
 def plot_distribution(index,temperature):
    fig, (ax,ax2) = plt.subplots(2,1,figsize=(16,12))
    ax.plot(cnumber_range,g_data[temperature][index],'co-')
    ax.plot(cnumber_range,d_data[temperature][index],'go-')
    ax.plot(cnumber_range,lr_data[temperature][index],'ro-',alpha=0.1)
    ax.plot(cnumber_range,l1_data[temperature][index],'ro-',alpha=0.3)
    ax.plot(cnumber_range,l2_data[temperature][index],'ro-',alpha=0.5)
    ax.plot(cnumber_range,l3_data[temperature][index],'ro-')
    ax.set_yscale("log")
    ax.set_ylim(1e-12, 1)
    ax.legend(['Vapor','Distillate','Reflux','L1','L2','Bottom'],fontsize=18)
    ax.set_title('T, Reflux {:.2f} kmol/s'.format(cd_data_master[temperature]['Re'][index]),fontsize=18)

    ax.set_ylabel('Molar Flow (kmol/s)', color='K',fontsize=18)
    ax.set_xlabel('Carbon Number', color='K',fontsize=18)
    # ax.tick_params('y', colors='k',labelsize=18)
    # ax.tick_params('x', colors='k',labelsize=18)

    ax2.plot(cnumber_range,cd_x_data[temperature][index],'go-')
    ax2.plot(cnumber_range,rf_x_data[temperature][1][index],'co-')
    ax2.plot(cnumber_range,rf_x_data[temperature][2][index],'bo-')
    ax2.plot(cnumber_range,rf_x_data[temperature][3][index],'ro-')

    ax2.set_ylim(0, 0.2)
    ax2.legend(['Condenser','Stage 1','Stage 2','Stage 3'],fontsize=18)
    ax2.set_title('Liquid Composition (Mole)',fontsize=18)

    ax2.set_ylabel('Molar Fraction', color='K',fontsize=18)
    ax2.set_xlabel('Carbon Number', color='K',fontsize=18)

    ax.grid()
    ax2.grid()
    plt.show()

# %%
widgets.interact(plot_distribution, index = widgets.IntSlider(
    value=0,
    min=0,
    max=20,
    step=1,
    description='Reflux:'),temperature=widgets.SelectionSlider(
    options=Trange,
    value=Trange[0],
    description='Temperature',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True)
);

# %%
plot_distribution(20,523.15)
