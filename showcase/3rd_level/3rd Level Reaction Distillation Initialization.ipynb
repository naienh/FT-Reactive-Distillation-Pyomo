# %% [markdown]
# # 3rd Level Model Structure: Initialize Procedure (20+ stages)

# %%
# system imports
import sys
import os
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../..'))

import numpy as np
from matplotlib import pyplot as plt

import ipywidgets as widgets
from IPython.display import display, clear_output

import pickle
from copy import deepcopy

# %%
# pyomo imports
from pyomo import environ as pe
from global_sets.component import m

from stages.reactive_stage import reactive_stage_rule
from stages.condenser_stage import condenser_stage_rule
from stages.reboiler_stage import reboiler_stage_rule

from utility.display_utility import trans_product_mole, trans_product_mass, beautify, beautify_reactive
from utility.model_utility import add_dual, update_dual, delete_dual, check_DOF, check_violate_constraint
from utility.data_utility import cal_cnumber

model = pe.ConcreteModel(name='reactive_distillation')

# %% [markdown]
# # Global Set

# %%
model.TRAY = pe.RangeSet(1,10)

# %% [markdown]
# # Construct reactive stages and Initialization separately

# %%
model.reactive = pe.Block(model.TRAY,rule=reactive_stage_rule)
add_dual(pe,model)
# Out:
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[1].x_
# | reactive[1].y_
# | reactive[1].x
# | reactive[1].y
# | reactive[1].z
# | reactive[1].L
# | reactive[1].V
# | reactive[1].F
# | reactive[1].H_L_
# | reactive[1].H_V_
# | reactive[1].H_L
# | reactive[1].H_V
# | reactive[1].H_F
# | reactive[1].T
# | reactive[1].T_F
# | reactive[1].P
# | reactive[1].f_V
# | reactive[1].f_L
# | reactive[1].cat
# | reactive[1].Q_main
# | reactive[1].r_total_comp
# | reactive[1].PR_L
# | reactive[1].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].kinetics_block.k_FT
# | reactive[1].kinetics_block.r_FT_total
# | reactive[1].kinetics_block.g0_FT
# | reactive[1].kinetics_block.alpha
# | reactive[1].kinetics_block.r_FT_cnum
# | reactive[1].kinetics_block.r_FT_comp
# | reactive[1].kinetics_block.k_WGS
# | reactive[1].kinetics_block.Ke_WGS
# | reactive[1].kinetics_block.r_WGS
# | reactive[1].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].energy_block.dH_F
# | reactive[1].energy_block.dH_V
# | reactive[1].energy_block.dH_L
# | reactive[1].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].VLE_block.P_VLE
# | reactive[1].VLE_block.n_ave
# | reactive[1].VLE_block.n_ave_cal
# | reactive[1].VLE_block.Hen
# | reactive[1].VLE_block.Hen0
# | reactive[1].VLE_block.gamma
# | reactive[1].VLE_block.P_sat
# | reactive[1].VLE_block.P_sat_Y
# | reactive[1].VLE_block.P_sat_dY_inf
# | reactive[1].VLE_block.P_sat_dY0
# | reactive[1].VLE_block.Hen_ref
# | reactive[1].VLE_block.Hen0_ref
# | reactive[1].VLE_block.gamma_ref
# | reactive[1].VLE_block.V_L
# | reactive[1].VLE_block.V_L_dY_inf
# | reactive[1].VLE_block.V_L_dY0
# | reactive[1].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].MPCC.s_L
# | reactive[1].MPCC.s_V
# | reactive[1].MPCC.pf
# | reactive[1].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[2].x_
# | reactive[2].y_
# | reactive[2].x
# | reactive[2].y
# | reactive[2].z
# | reactive[2].L
# | reactive[2].V
# | reactive[2].F
# | reactive[2].H_L_
# | reactive[2].H_V_
# | reactive[2].H_L
# | reactive[2].H_V
# | reactive[2].H_F
# | reactive[2].T
# | reactive[2].T_F
# | reactive[2].P
# | reactive[2].f_V
# | reactive[2].f_L
# | reactive[2].cat
# | reactive[2].Q_main
# | reactive[2].r_total_comp
# | reactive[2].PR_L
# | reactive[2].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].kinetics_block.k_FT
# | reactive[2].kinetics_block.r_FT_total
# | reactive[2].kinetics_block.g0_FT
# | reactive[2].kinetics_block.alpha
# | reactive[2].kinetics_block.r_FT_cnum
# | reactive[2].kinetics_block.r_FT_comp
# | reactive[2].kinetics_block.k_WGS
# | reactive[2].kinetics_block.Ke_WGS
# | reactive[2].kinetics_block.r_WGS
# | reactive[2].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].energy_block.dH_F
# | reactive[2].energy_block.dH_V
# | reactive[2].energy_block.dH_L
# | reactive[2].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].VLE_block.P_VLE
# | reactive[2].VLE_block.n_ave
# | reactive[2].VLE_block.n_ave_cal
# | reactive[2].VLE_block.Hen
# | reactive[2].VLE_block.Hen0
# | reactive[2].VLE_block.gamma
# | reactive[2].VLE_block.P_sat
# | reactive[2].VLE_block.P_sat_Y
# | reactive[2].VLE_block.P_sat_dY_inf
# | reactive[2].VLE_block.P_sat_dY0
# | reactive[2].VLE_block.Hen_ref
# | reactive[2].VLE_block.Hen0_ref
# | reactive[2].VLE_block.gamma_ref
# | reactive[2].VLE_block.V_L
# | reactive[2].VLE_block.V_L_dY_inf
# | reactive[2].VLE_block.V_L_dY0
# | reactive[2].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].MPCC.s_L
# | reactive[2].MPCC.s_V
# | reactive[2].MPCC.pf
# | reactive[2].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[3].x_
# | reactive[3].y_
# | reactive[3].x
# | reactive[3].y
# | reactive[3].z
# | reactive[3].L
# | reactive[3].V
# | reactive[3].F
# | reactive[3].H_L_
# | reactive[3].H_V_
# | reactive[3].H_L
# | reactive[3].H_V
# | reactive[3].H_F
# | reactive[3].T
# | reactive[3].T_F
# | reactive[3].P
# | reactive[3].f_V
# | reactive[3].f_L
# | reactive[3].cat
# | reactive[3].Q_main
# | reactive[3].r_total_comp
# | reactive[3].PR_L
# | reactive[3].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].kinetics_block.k_FT
# | reactive[3].kinetics_block.r_FT_total
# | reactive[3].kinetics_block.g0_FT
# | reactive[3].kinetics_block.alpha
# | reactive[3].kinetics_block.r_FT_cnum
# | reactive[3].kinetics_block.r_FT_comp
# | reactive[3].kinetics_block.k_WGS
# | reactive[3].kinetics_block.Ke_WGS
# | reactive[3].kinetics_block.r_WGS
# | reactive[3].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].energy_block.dH_F
# | reactive[3].energy_block.dH_V
# | reactive[3].energy_block.dH_L
# | reactive[3].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].VLE_block.P_VLE
# | reactive[3].VLE_block.n_ave
# | reactive[3].VLE_block.n_ave_cal
# | reactive[3].VLE_block.Hen
# | reactive[3].VLE_block.Hen0
# | reactive[3].VLE_block.gamma
# | reactive[3].VLE_block.P_sat
# | reactive[3].VLE_block.P_sat_Y
# | reactive[3].VLE_block.P_sat_dY_inf
# | reactive[3].VLE_block.P_sat_dY0
# | reactive[3].VLE_block.Hen_ref
# | reactive[3].VLE_block.Hen0_ref
# | reactive[3].VLE_block.gamma_ref
# | reactive[3].VLE_block.V_L
# | reactive[3].VLE_block.V_L_dY_inf
# | reactive[3].VLE_block.V_L_dY0
# | reactive[3].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].MPCC.s_L
# | reactive[3].MPCC.s_V
# | reactive[3].MPCC.pf
# | reactive[3].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[4].x_
# | reactive[4].y_
# | reactive[4].x
# | reactive[4].y
# | reactive[4].z
# | reactive[4].L
# | reactive[4].V
# | reactive[4].F
# | reactive[4].H_L_
# | reactive[4].H_V_
# | reactive[4].H_L
# | reactive[4].H_V
# | reactive[4].H_F
# | reactive[4].T
# | reactive[4].T_F
# | reactive[4].P
# | reactive[4].f_V
# | reactive[4].f_L
# | reactive[4].cat
# | reactive[4].Q_main
# | reactive[4].r_total_comp
# | reactive[4].PR_L
# | reactive[4].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].kinetics_block.k_FT
# | reactive[4].kinetics_block.r_FT_total
# | reactive[4].kinetics_block.g0_FT
# | reactive[4].kinetics_block.alpha
# | reactive[4].kinetics_block.r_FT_cnum
# | reactive[4].kinetics_block.r_FT_comp
# | reactive[4].kinetics_block.k_WGS
# | reactive[4].kinetics_block.Ke_WGS
# | reactive[4].kinetics_block.r_WGS
# | reactive[4].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].energy_block.dH_F
# | reactive[4].energy_block.dH_V
# | reactive[4].energy_block.dH_L
# | reactive[4].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].VLE_block.P_VLE
# | reactive[4].VLE_block.n_ave
# | reactive[4].VLE_block.n_ave_cal
# | reactive[4].VLE_block.Hen
# | reactive[4].VLE_block.Hen0
# | reactive[4].VLE_block.gamma
# | reactive[4].VLE_block.P_sat
# | reactive[4].VLE_block.P_sat_Y
# | reactive[4].VLE_block.P_sat_dY_inf
# | reactive[4].VLE_block.P_sat_dY0
# | reactive[4].VLE_block.Hen_ref
# | reactive[4].VLE_block.Hen0_ref
# | reactive[4].VLE_block.gamma_ref
# | reactive[4].VLE_block.V_L
# | reactive[4].VLE_block.V_L_dY_inf
# | reactive[4].VLE_block.V_L_dY0
# | reactive[4].VLE_block.poynting
# --------------------------------------------------
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].MPCC.s_L
# | reactive[4].MPCC.s_V
# | reactive[4].MPCC.pf
# | reactive[4].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[5].x_
# | reactive[5].y_
# | reactive[5].x
# | reactive[5].y
# | reactive[5].z
# | reactive[5].L
# | reactive[5].V
# | reactive[5].F
# | reactive[5].H_L_
# | reactive[5].H_V_
# | reactive[5].H_L
# | reactive[5].H_V
# | reactive[5].H_F
# | reactive[5].T
# | reactive[5].T_F
# | reactive[5].P
# | reactive[5].f_V
# | reactive[5].f_L
# | reactive[5].cat
# | reactive[5].Q_main
# | reactive[5].r_total_comp
# | reactive[5].PR_L
# | reactive[5].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].kinetics_block.k_FT
# | reactive[5].kinetics_block.r_FT_total
# | reactive[5].kinetics_block.g0_FT
# | reactive[5].kinetics_block.alpha
# | reactive[5].kinetics_block.r_FT_cnum
# | reactive[5].kinetics_block.r_FT_comp
# | reactive[5].kinetics_block.k_WGS
# | reactive[5].kinetics_block.Ke_WGS
# | reactive[5].kinetics_block.r_WGS
# | reactive[5].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].energy_block.dH_F
# | reactive[5].energy_block.dH_V
# | reactive[5].energy_block.dH_L
# | reactive[5].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].VLE_block.P_VLE
# | reactive[5].VLE_block.n_ave
# | reactive[5].VLE_block.n_ave_cal
# | reactive[5].VLE_block.Hen
# | reactive[5].VLE_block.Hen0
# | reactive[5].VLE_block.gamma
# | reactive[5].VLE_block.P_sat
# | reactive[5].VLE_block.P_sat_Y
# | reactive[5].VLE_block.P_sat_dY_inf
# | reactive[5].VLE_block.P_sat_dY0
# | reactive[5].VLE_block.Hen_ref
# | reactive[5].VLE_block.Hen0_ref
# | reactive[5].VLE_block.gamma_ref
# | reactive[5].VLE_block.V_L
# | reactive[5].VLE_block.V_L_dY_inf
# | reactive[5].VLE_block.V_L_dY0
# | reactive[5].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].MPCC.s_L
# | reactive[5].MPCC.s_V
# | reactive[5].MPCC.pf
# | reactive[5].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[6].x_
# | reactive[6].y_
# | reactive[6].x
# | reactive[6].y
# | reactive[6].z
# | reactive[6].L
# | reactive[6].V
# | reactive[6].F
# | reactive[6].H_L_
# | reactive[6].H_V_
# | reactive[6].H_L
# | reactive[6].H_V
# | reactive[6].H_F
# | reactive[6].T
# | reactive[6].T_F
# | reactive[6].P
# | reactive[6].f_V
# | reactive[6].f_L
# | reactive[6].cat
# | reactive[6].Q_main
# | reactive[6].r_total_comp
# | reactive[6].PR_L
# | reactive[6].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].kinetics_block.k_FT
# | reactive[6].kinetics_block.r_FT_total
# | reactive[6].kinetics_block.g0_FT
# | reactive[6].kinetics_block.alpha
# | reactive[6].kinetics_block.r_FT_cnum
# | reactive[6].kinetics_block.r_FT_comp
# | reactive[6].kinetics_block.k_WGS
# | reactive[6].kinetics_block.Ke_WGS
# | reactive[6].kinetics_block.r_WGS
# | reactive[6].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].energy_block.dH_F
# | reactive[6].energy_block.dH_V
# | reactive[6].energy_block.dH_L
# | reactive[6].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].VLE_block.P_VLE
# | reactive[6].VLE_block.n_ave
# | reactive[6].VLE_block.n_ave_cal
# | reactive[6].VLE_block.Hen
# | reactive[6].VLE_block.Hen0
# | reactive[6].VLE_block.gamma
# | reactive[6].VLE_block.P_sat
# | reactive[6].VLE_block.P_sat_Y
# | reactive[6].VLE_block.P_sat_dY_inf
# | reactive[6].VLE_block.P_sat_dY0
# | reactive[6].VLE_block.Hen_ref
# | reactive[6].VLE_block.Hen0_ref
# | reactive[6].VLE_block.gamma_ref
# | reactive[6].VLE_block.V_L
# | reactive[6].VLE_block.V_L_dY_inf
# | reactive[6].VLE_block.V_L_dY0
# | reactive[6].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].MPCC.s_L
# | reactive[6].MPCC.s_V
# | reactive[6].MPCC.pf
# | reactive[6].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[7].x_
# | reactive[7].y_
# | reactive[7].x
# | reactive[7].y
# | reactive[7].z
# | reactive[7].L
# | reactive[7].V
# | reactive[7].F
# | reactive[7].H_L_
# | reactive[7].H_V_
# | reactive[7].H_L
# | reactive[7].H_V
# | reactive[7].H_F
# | reactive[7].T
# | reactive[7].T_F
# | reactive[7].P
# | reactive[7].f_V
# | reactive[7].f_L
# | reactive[7].cat
# | reactive[7].Q_main
# | reactive[7].r_total_comp
# | reactive[7].PR_L
# | reactive[7].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].kinetics_block.k_FT
# | reactive[7].kinetics_block.r_FT_total
# | reactive[7].kinetics_block.g0_FT
# | reactive[7].kinetics_block.alpha
# | reactive[7].kinetics_block.r_FT_cnum
# | reactive[7].kinetics_block.r_FT_comp
# | reactive[7].kinetics_block.k_WGS
# | reactive[7].kinetics_block.Ke_WGS
# | reactive[7].kinetics_block.r_WGS
# | reactive[7].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].energy_block.dH_F
# | reactive[7].energy_block.dH_V
# | reactive[7].energy_block.dH_L
# | reactive[7].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].VLE_block.P_VLE
# | reactive[7].VLE_block.n_ave
# | reactive[7].VLE_block.n_ave_cal
# | reactive[7].VLE_block.Hen
# | reactive[7].VLE_block.Hen0
# | reactive[7].VLE_block.gamma
# | reactive[7].VLE_block.P_sat
# | reactive[7].VLE_block.P_sat_Y
# | reactive[7].VLE_block.P_sat_dY_inf
# | reactive[7].VLE_block.P_sat_dY0
# | reactive[7].VLE_block.Hen_ref
# | reactive[7].VLE_block.Hen0_ref
# | reactive[7].VLE_block.gamma_ref
# | reactive[7].VLE_block.V_L
# | reactive[7].VLE_block.V_L_dY_inf
# | reactive[7].VLE_block.V_L_dY0
# | reactive[7].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].MPCC.s_L
# | reactive[7].MPCC.s_V
# | reactive[7].MPCC.pf
# | reactive[7].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[8].x_
# | reactive[8].y_
# | reactive[8].x
# | reactive[8].y
# | reactive[8].z
# | reactive[8].L
# | reactive[8].V
# | reactive[8].F
# | reactive[8].H_L_
# | reactive[8].H_V_
# | reactive[8].H_L
# | reactive[8].H_V
# | reactive[8].H_F
# | reactive[8].T
# | reactive[8].T_F
# | reactive[8].P
# | reactive[8].f_V
# | reactive[8].f_L
# | reactive[8].cat
# | reactive[8].Q_main
# | reactive[8].r_total_comp
# | reactive[8].PR_L
# | reactive[8].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].kinetics_block.k_FT
# | reactive[8].kinetics_block.r_FT_total
# | reactive[8].kinetics_block.g0_FT
# | reactive[8].kinetics_block.alpha
# | reactive[8].kinetics_block.r_FT_cnum
# | reactive[8].kinetics_block.r_FT_comp
# | reactive[8].kinetics_block.k_WGS
# | reactive[8].kinetics_block.Ke_WGS
# | reactive[8].kinetics_block.r_WGS
# | reactive[8].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].energy_block.dH_F
# | reactive[8].energy_block.dH_V
# | reactive[8].energy_block.dH_L
# | reactive[8].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].VLE_block.P_VLE
# | reactive[8].VLE_block.n_ave
# | reactive[8].VLE_block.n_ave_cal
# | reactive[8].VLE_block.Hen
# | reactive[8].VLE_block.Hen0
# | reactive[8].VLE_block.gamma
# | reactive[8].VLE_block.P_sat
# | reactive[8].VLE_block.P_sat_Y
# | reactive[8].VLE_block.P_sat_dY_inf
# | reactive[8].VLE_block.P_sat_dY0
# | reactive[8].VLE_block.Hen_ref
# | reactive[8].VLE_block.Hen0_ref
# | reactive[8].VLE_block.gamma_ref
# | reactive[8].VLE_block.V_L
# | reactive[8].VLE_block.V_L_dY_inf
# | reactive[8].VLE_block.V_L_dY0
# | reactive[8].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].MPCC.s_L
# | reactive[8].MPCC.s_V
# | reactive[8].MPCC.pf
# | reactive[8].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[9].x_
# | reactive[9].y_
# | reactive[9].x
# | reactive[9].y
# | reactive[9].z
# | reactive[9].L
# | reactive[9].V
# | reactive[9].F
# | reactive[9].H_L_
# | reactive[9].H_V_
# | reactive[9].H_L
# | reactive[9].H_V
# | reactive[9].H_F
# | reactive[9].T
# | reactive[9].T_F
# | reactive[9].P
# | reactive[9].f_V
# | reactive[9].f_L
# | reactive[9].cat
# | reactive[9].Q_main
# | reactive[9].r_total_comp
# | reactive[9].PR_L
# | reactive[9].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].kinetics_block.k_FT
# | reactive[9].kinetics_block.r_FT_total
# | reactive[9].kinetics_block.g0_FT
# | reactive[9].kinetics_block.alpha
# | reactive[9].kinetics_block.r_FT_cnum
# | reactive[9].kinetics_block.r_FT_comp
# | reactive[9].kinetics_block.k_WGS
# | reactive[9].kinetics_block.Ke_WGS
# | reactive[9].kinetics_block.r_WGS
# | reactive[9].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].energy_block.dH_F
# | reactive[9].energy_block.dH_V
# | reactive[9].energy_block.dH_L
# | reactive[9].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].VLE_block.P_VLE
# | reactive[9].VLE_block.n_ave
# | reactive[9].VLE_block.n_ave_cal
# | reactive[9].VLE_block.Hen
# | reactive[9].VLE_block.Hen0
# | reactive[9].VLE_block.gamma
# | reactive[9].VLE_block.P_sat
# | reactive[9].VLE_block.P_sat_Y
# | reactive[9].VLE_block.P_sat_dY_inf
# | reactive[9].VLE_block.P_sat_dY0
# | reactive[9].VLE_block.Hen_ref
# | reactive[9].VLE_block.Hen0_ref
# | reactive[9].VLE_block.gamma_ref
# | reactive[9].VLE_block.V_L
# | reactive[9].VLE_block.V_L_dY_inf
# | reactive[9].VLE_block.V_L_dY0
# | reactive[9].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].MPCC.s_L
# | reactive[9].MPCC.s_V
# | reactive[9].MPCC.pf
# | reactive[9].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[10].x_
# | reactive[10].y_
# | reactive[10].x
# | reactive[10].y
# | reactive[10].z
# | reactive[10].L
# | reactive[10].V
# | reactive[10].F
# | reactive[10].H_L_
# | reactive[10].H_V_
# | reactive[10].H_L
# | reactive[10].H_V
# | reactive[10].H_F
# | reactive[10].T
# | reactive[10].T_F
# | reactive[10].P
# | reactive[10].f_V
# | reactive[10].f_L
# | reactive[10].cat
# | reactive[10].Q_main
# | reactive[10].r_total_comp
# | reactive[10].PR_L
# | reactive[10].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].kinetics_block.k_FT
# | reactive[10].kinetics_block.r_FT_total
# | reactive[10].kinetics_block.g0_FT
# | reactive[10].kinetics_block.alpha
# | reactive[10].kinetics_block.r_FT_cnum
# | reactive[10].kinetics_block.r_FT_comp
# | reactive[10].kinetics_block.k_WGS
# | reactive[10].kinetics_block.Ke_WGS
# | reactive[10].kinetics_block.r_WGS
# | reactive[10].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].energy_block.dH_F
# | reactive[10].energy_block.dH_V
# | reactive[10].energy_block.dH_L
# | reactive[10].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].VLE_block.P_VLE
# | reactive[10].VLE_block.n_ave
# | reactive[10].VLE_block.n_ave_cal
# | reactive[10].VLE_block.Hen
# | reactive[10].VLE_block.Hen0
# | reactive[10].VLE_block.gamma
# | reactive[10].VLE_block.P_sat
# | reactive[10].VLE_block.P_sat_Y
# | reactive[10].VLE_block.P_sat_dY_inf
# | reactive[10].VLE_block.P_sat_dY0
# | reactive[10].VLE_block.Hen_ref
# | reactive[10].VLE_block.Hen0_ref
# | reactive[10].VLE_block.gamma_ref
# | reactive[10].VLE_block.V_L
# | reactive[10].VLE_block.V_L_dY_inf
# | reactive[10].VLE_block.V_L_dY0
# | reactive[10].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].MPCC.s_L
# | reactive[10].MPCC.s_V
# | reactive[10].MPCC.pf
# | reactive[10].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
# in/out variable
for j in model.reactive:
    model.reactive[j].x_.fix(0)
    model.reactive[j].y_.fix(0)
    model.reactive[j].L['in'].fix(0)
    model.reactive[j].V['in'].fix(0)
    model.reactive[j].H_L_.fix(0)
    model.reactive[j].H_V_.fix(0)

# operating parameters
for j in model.reactive:
    model.reactive[j].cat.fix(3000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
    model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
    model.reactive[j].z['C30H62'].fix(0)
    
    model.reactive[j].PR_L.fix(1)
    model.reactive[j].PR_V.fix(1)
    
    # model.reactive[j].Q_main.fix(0)
    model.reactive[j].T.setub(220+273.15)
    model.reactive[j].T.setlb(200+273.15)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 11840
# Active Inequality Constraints:	 10
# Active Variables:		 13600
# Fixed Variables:		 1720
# DOF:				 40

# %%
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.reactive),sense=pe.maximize)

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'

opt.options['linear_system_scaling '] = 'mc19'
opt.options['linear_scaling_on_demand '] = 'no'

# opt.options['warm_start_init_point'] = 'yes'
# opt.options['warm_start_bound_push'] = 1e-20
# opt.options['warm_start_mult_bound_push'] = 1e-20
# opt.options['mu_init'] = 1e-6

# opt.options['halt_on_ampl_error'] = 'yes'

opt.options['max_iter'] = 7000

# %%
# %%time

results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    41760
# Number of nonzeros in inequality constraint Jacobian.:       70
# Number of nonzeros in Lagrangian Hessian.............:    45570
#
# Total number of variables............................:    11880
#                      variables with only lower bounds:     3850
#                 variables with lower and upper bounds:     6330
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:
-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -4.9272460e+03 4.61e+00 6.76e+05  -1.0 1.29e+01    -  7.66e-01 9.90e-01h  1
#   51 -4.9277045e+03 1.93e-01 2.49e+05  -1.0 6.45e+00    -  1.00e+00 9.93e-01h  1
#   52 -4.9274008e+03 1.18e-02 1.18e+04  -1.0 3.63e+00    -  1.00e+00 1.00e+00h  1
#   53 -4.9271748e+03 1.04e-04 2.85e+02  -1.0 5.88e-01    -  1.00e+00 1.00e+00h  1
#   54 -4.9305834e+03 1.25e-03 2.72e+06  -2.5 5.30e+00    -  9.87e-01 7.07e-01f  1
#   55 -4.9313658e+03 4.33e-04 2.24e+04  -2.5 4.59e+00    -  1.00e+00 1.00e+00f  1
#   56 -4.9313705e+03 1.40e-04 1.42e+02  -2.5 7.74e-01    -  1.00e+00 1.00e+00h  1
#   57 -4.9313720e+03 3.73e-06 2.06e-01  -2.5 1.28e-01    -  1.00e+00 1.00e+00h  1
#   58 -4.9314863e+03 1.59e-04 2.02e+03  -3.8 8.23e-01    -  1.00e+00 1.00e+00f  1
#   59 -4.9314927e+03 1.16e-04 1.23e+01  -3.8 7.11e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -4.9314926e+03 4.23e-09 6.99e-04  -3.8 3.22e-03    -  1.00e+00 1.00e+00h  1
#   61 -4.9314999e+03 5.35e-06 2.07e+01  -5.7 1.53e-01    -  1.00e+00 1.00e+00f  1
#   62 -4.9315000e+03 9.82e-09 1.22e-03  -5.7 6.61e-03    -  1.00e+00 1.00e+00h  1
#   63 -4.9315000e+03 1.38e-10 1.85e-11  -5.7 2.99e-07    -  1.00e+00 1.00e+00h  1
#   64 -4.9315000e+03 9.73e-10 3.46e-03  -8.6 2.06e-03    -  1.00e+00 1.00e+00f  1
#   65 -4.9315000e+03 4.24e-11 1.57e-08  -8.6 8.41e-07    -  1.00e+00 1.00e+00h  1
#   66 -4.9315000e+03 4.24e-11 2.76e-08  -9.0 1.77e-06    -  1.00e+00 1.00e+00h  1
#   67 -4.9315000e+03 2.27e-13 6.51e-09  -9.0 2.14e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 67
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.9315000493886910e+03   -4.9315000493886910e+03
# Dual infeasibility......:   6.5107696257913101e-09    6.5107696257913101e-09
# Constraint violation....:   2.2737367544323206e-13    2.2737367544323206e-13
# Complementarity.........:   1.0404302700175745e-09    1.0404302700175745e-09
# Overall NLP error.......:   6.5107696257913101e-09    6.5107696257913101e-09
#
#
# Number of objective function evaluations             = 96
# Number of objective gradient evaluations             = 54
# Number of equality constraint evaluations            = 96
# Number of inequality constraint evaluations          = 96
# Number of equality constraint Jacobian evaluations   = 73
# Number of inequality constraint Jacobian evaluations = 73
# Number of Lagrangian Hessian evaluations             = 67
# Total CPU secs in IPOPT (w/o function evaluations)   =     31.512
# Total CPU secs in NLP function evaluations           =      1.719
#
# EXIT: Optimal Solution Found.
# CPU times: user 1.52 s, sys: 89.2 ms, total: 1.61 s
# Wall time: 12.6 s

# %%
beautify_reactive(pe,model)
# Out:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[2]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[3]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[4]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[5]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000

# %% [markdown]
# # Connect reactive stages and Initialize connectively

# %% [markdown]
# ### Vapor Between Reactive Stages

# %%
def V_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].V['in'] == model.reactive[j+1].V['out']
model.V_between_con = pe.Constraint(model.TRAY,rule=V_between_rule)

def Vy_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].y_['in',i] == model.reactive[j+1].y[i]
model.Vy_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Vy_between_rule)

def Vh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].H_V_['in'] == model.reactive[j+1].H_V
model.Vh_between_con = pe.Constraint(model.TRAY,rule=Vh_between_rule)

# %% [markdown]
# ### Liquid Between Reactive Stages

# %%
def L_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].L['in'] == model.reactive[j].L['out']
model.L_between_con = pe.Constraint(model.TRAY,rule=L_between_rule)

def Lx_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].x_['in',i] == model.reactive[j].x[i]
model.Ly_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Lx_between_rule)

def Lh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].H_L_['in'] == model.reactive[j].H_L
model.Lh_between_con = pe.Constraint(model.TRAY,rule=Lh_between_rule)

# %% [markdown]
# ### Unlock liquid and vapor in-flow

# %%
for j in model.reactive:
    if j != model.TRAY.first():
        model.reactive[j].x_.unfix()
        model.reactive[j].H_L_.unfix()
        model.reactive[j].L['in'].unfix()
    if j != model.TRAY.last():
        model.reactive[j].y_.unfix()
        model.reactive[j].V['in'].unfix()
        model.reactive[j].H_V_.unfix()

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 13298
# Active Inequality Constraints:	 10
# Active Variables:		 13600
# Fixed Variables:		 262
# DOF:				 40

# %%
opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6

results = opt.solve(model,tee=False)
update_dual(pe,model)

# %% [markdown]
# ### Iteratively reduce stage product draw ratio

# %%
# %%time

PR_range = np.linspace(1,0,11)
for r in PR_range:
    for j in model.reactive:
        model.reactive[j].PR_L.fix(r)
        model.reactive[j].PR_V.fix(r)
        
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    print('\nWorking on PR ratio = {:.2f}'.format(r))
    beautify_reactive(pe,model)
# Out:
# Working on PR ratio = 1.00
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[2]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[3]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[4]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[5]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
#
# Working on PR ratio = 0.90
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.0531		0.00064		0.00578		20.00000
# Reactive[2]	220.00		-43.29		 0.0531		0.00071		0.00636		20.00000
# Reactive[3]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[4]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[5]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.0530		0.00071		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.0525		0.00071		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.0478		0.00071		0.00642		20.00000
#
# Working on PR ratio = 0.80
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.1194		0.00128		0.00514		20.00000
# Reactive[2]	220.00		-43.29		 0.1194		0.00154		0.00617		20.00000
# Reactive[3]	220.00		-43.29		 0.1194		0.00159		0.00637		20.00000
# Reactive[4]	220.00		-43.29		 0.1194		0.00160		0.00641		20.00000
# Reactive[5]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.1192		0.00161		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.1184		0.00161		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.1146		0.00161		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.0955		0.00161		0.00642		20.00000
#
# Working on PR ratio = 0.70
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.2047		0.00193		0.00450		20.00000
# Reactive[2]	220.00		-43.29		 0.2047		0.00251		0.00585		20.00000
# Reactive[3]	220.00		-43.29		 0.2047		0.00268		0.00625		20.00000
# Reactive[4]	220.00		-43.29		 0.2046		0.00273		0.00637		20.00000
# Reactive[5]	220.00		-43.29		 0.2045		0.00275		0.00641		20.00000
# Reactive[6]	220.00		-43.29		 0.2042		0.00275		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.2030		0.00275		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.1992		0.00275		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.1863		0.00275		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.1433		0.00275		0.00642		20.00000
#
# Working on PR ratio = 0.60
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.3184		0.00257		0.00385		20.00000
# Reactive[2]	220.00		-43.29		 0.3183		0.00360		0.00540		20.00000
# Reactive[3]	220.00		-43.29		 0.3182		0.00401		0.00601		20.00000
# Reactive[4]	220.00		-43.29		 0.3179		0.00417		0.00626		20.00000
# Reactive[5]	220.00		-43.29		 0.3171		0.00424		0.00636		20.00000
# Reactive[6]	220.00		-43.29		 0.3151		0.00426		0.00640		20.00000
# Reactive[7]	220.00		-43.29		 0.3103		0.00428		0.00641		20.00000
# Reactive[8]	220.00		-43.29		 0.2980		0.00428		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.2675		0.00428		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.1910		0.00428		0.00642		20.00000
#
# Working on PR ratio = 0.50
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.4771		0.00321		0.00321		20.00000
# Reactive[2]	220.00		-43.29		 0.4767		0.00482		0.00482		20.00000
# Reactive[3]	220.00		-43.29		 0.4757		0.00562		0.00562		20.00000
# Reactive[4]	220.00		-43.29		 0.4739		0.00602		0.00602		20.00000
# Reactive[5]	220.00		-43.29		 0.4701		0.00622		0.00622		20.00000
# Reactive[6]	220.00		-43.29		 0.4627		0.00632		0.00632		20.00000
# Reactive[7]	220.00		-43.29		 0.4478		0.00637		0.00637		20.00000
# Reactive[8]	220.00		-43.29		 0.4179		0.00640		0.00640		20.00000
# Reactive[9]	220.00		-43.29		 0.3582		0.00641		0.00641		20.00000
# Reactive[10]	220.00		-43.29		 0.2388		0.00642		0.00642		20.00000
#
# Working on PR ratio = 0.40
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.7121		0.00385		0.00257		20.00000
# Reactive[2]	220.00		-43.29		 0.7092		0.00617		0.00411		20.00000
# Reactive[3]	220.00		-43.29		 0.7044		0.00755		0.00504		20.00000
# Reactive[4]	220.00		-43.29		 0.6964		0.00839		0.00559		20.00000
# Reactive[5]	220.00		-43.29		 0.6830		0.00889		0.00592		20.00000
# Reactive[6]	220.00		-43.29		 0.6607		0.00919		0.00612		20.00000
# Reactive[7]	220.00		-43.29		 0.6236		0.00937		0.00624		20.00000
# Reactive[8]	220.00		-43.29		 0.5617		0.00947		0.00632		20.00000
# Reactive[9]	220.00		-43.29		 0.4585		0.00954		0.00636		20.00000
# Reactive[10]	220.00		-43.29		 0.2866		0.00958		0.00638		20.00000
#
# Working on PR ratio = 0.30
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 1.0829		0.00450		0.00193		20.00000
# Reactive[2]	220.00		-43.29		 1.0695		0.00764		0.00328		20.00000
# Reactive[3]	220.00		-43.29		 1.0502		0.00985		0.00422		20.00000
# Reactive[4]	220.00		-43.29		 1.0227		0.01139		0.00488		20.00000
# Reactive[5]	220.00		-43.29		 0.9833		0.01247		0.00534		20.00000
# Reactive[6]	220.00		-43.29		 0.9271		0.01323		0.00567		20.00000
# Reactive[7]	220.00		-43.29		 0.8469		0.01375		0.00589		20.00000
# Reactive[8]	220.00		-43.29		 0.7322		0.01412		0.00605		20.00000
# Reactive[9]	220.00		-43.29		 0.5684		0.01438		0.00616		20.00000
# Reactive[10]	220.00		-43.29		 0.3343		0.01457		0.00624		20.00000
#
# Working on PR ratio = 0.20
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 1.7053		0.00514		0.00128		20.00000
# Reactive[2]	220.00		-43.29		 1.6540		0.00925		0.00231		20.00000
# Reactive[3]	220.00		-43.29		 1.5899		0.01254		0.00313		20.00000
# Reactive[4]	220.00		-43.29		 1.5098		0.01517		0.00379		20.00000
# Reactive[5]	220.00		-43.29		 1.4096		0.01728		0.00432		20.00000
# Reactive[6]	220.00		-43.29		 1.2844		0.01896		0.00474		20.00000
# Reactive[7]	220.00		-43.29		 1.1279		0.02031		0.00508		20.00000
# Reactive[8]	220.00		-43.29		 0.9323		0.02138		0.00535		20.00000
# Reactive[9]	220.00		-43.29		 0.6878		0.02225		0.00556		20.00000
# Reactive[10]	220.00		-43.29		 0.3821		0.02294		0.00573		20.00000
#
# Working on PR ratio = 0.10
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 2.7997		0.00578		0.00064		20.00000
# Reactive[2]	220.00		-43.29		 2.6332		0.01098		0.00122		20.00000
# Reactive[3]	220.00		-43.29		 2.4481		0.01567		0.00174		20.00000
# Reactive[4]	220.00		-43.29		 2.2425		0.01988		0.00221		20.00000
# Reactive[5]	220.00		-43.29		 2.0141		0.02368		0.00263		20.00000
# Reactive[6]	220.00		-43.29		 1.7603		0.02709		0.00301		20.00000
# Reactive[7]	220.00		-43.29		 1.4783		0.03016		0.00335		20.00000
# Reactive[8]	220.00		-43.29		 1.1649		0.03293		0.00366		20.00000
# Reactive[9]	220.00		-43.29		 0.8167		0.03542		0.00394		20.00000
# Reactive[10]	220.00		-43.29		 0.4299		0.03766		0.00418		20.00000
#
# Working on PR ratio = 0.00
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 4.7761		0.00642		0.00000		20.00000
# Reactive[2]	220.00		-43.29		 4.2985		0.01285		0.00000		20.00000
# Reactive[3]	220.00		-43.29		 3.8209		0.01927		0.00000		20.00000
# Reactive[4]	220.00		-43.29		 3.3433		0.02570		0.00000		20.00000
# Reactive[5]	220.00		-43.29		 2.8657		0.03212		0.00000		20.00000
# Reactive[6]	220.00		-43.29		 2.3881		0.03854		0.00000		20.00000
# Reactive[7]	220.00		-43.29		 1.9104		0.04497		0.00000		20.00000
# Reactive[8]	220.00		-43.29		 1.4328		0.05139		0.00000		20.00000
# Reactive[9]	220.00		-43.29		 0.9552		0.05781		0.00000		20.00000
# Reactive[10]	220.00		-43.29		 0.4776		0.06424		0.00000		20.00000
# CPU times: user 16.9 s, sys: 365 ms, total: 17.3 s
# Wall time: 47.3 s

# %% [markdown]
# # Construct a single condenser and Initialize

# %% [markdown]
# ### Deactivate the reactive part first

# %%
for i in model.block_data_objects():
    if i.name != 'reactive_distillation':
        i.deactivate()
for i in model.component_objects(pe.Constraint, active=True):
    i.deactivate()
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 0
# Active Inequality Constraints:	 0
# Active Variables:		 0
# Fixed Variables:		 0
# DOF:				 0

# %%
model.condenser = pe.Block(rule=condenser_stage_rule)
# Out:
# | Importing Condenser Stage......
# | Adding the following local variable:
# ------------------------------------
# | condenser.T
# | condenser.T_F
# | condenser.P
# | condenser.Q_main
# | condenser.x_
# | condenser.y_
# | condenser.x
# | condenser.y
# | condenser.z
# | condenser.L
# | condenser.W
# | condenser.V
# | condenser.F
# | condenser.H_L_
# | condenser.H_V_
# | condenser.H_L
# | condenser.H_V
# | condenser.H_F
# | condenser.f_V
# | condenser.f_L
# | condenser.PR_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.energy_block.dH_F
# | condenser.energy_block.dH_V
# | condenser.energy_block.dH_L
# | condenser.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.VLE_block.n_ave
# | condenser.VLE_block.n_ave_cal
# | condenser.VLE_block.Hen
# | condenser.VLE_block.Hen0
# | condenser.VLE_block.gamma
# | condenser.VLE_block.P_sat
# | condenser.VLE_block.P_sat_Y
# | condenser.VLE_block.P_sat_dY_inf
# | condenser.VLE_block.P_sat_dY0
# | condenser.VLE_block.Hen_ref
# | condenser.VLE_block.Hen0_ref
# | condenser.VLE_block.gamma_ref
# | condenser.VLE_block.V_L
# | condenser.VLE_block.V_L_dY_inf
# | condenser.VLE_block.V_L_dY0
# | condenser.VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# ### Use the reactive sections vapor output as input to condenser

# %%
# in/out variables
model.condenser.x_.fix(0)
for i in m.COMP_TOTAL:
    model.condenser.y_['in',i].fix(model.reactive[model.TRAY.first()].y[i].value)
model.condenser.V['in'].fix(model.reactive[model.TRAY.first()].V['out'].value)
model.condenser.L['in'].fix(0)
model.condenser.V['P'].fix(0)
model.condenser.H_L_.fix(0)
model.condenser.H_V_.fix(model.reactive[model.TRAY.first()].H_V.value)

# operating parameters
model.condenser.P.fix(19)
model.condenser.T_F.fix(200+273.15)
model.condenser.F.fix(0)
model.condenser.z.fix(0)
model.condenser.VLE_block.n_ave.fix(4)
model.condenser.PR_L.fix(1)

model.condenser.T.setub(30+273.15)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = model.condenser.T, sense = pe.maximize)

delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 958
# Active Inequality Constraints:	 0
# Active Variables:		 1130
# Fixed Variables:		 171
# DOF:				 1

# %%
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     3146
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4089
#
# Total number of variables............................:      959
#                      variables with only lower bounds:      165
#                 variables with lower and upper bounds:      707
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      958
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -2.9315000e+02 9.57e+02 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1r-2.9315000e+02 9.57e+02 9.99e+02   3.0 0.00e+00    -  0.00e+00 7.41e-09R  6
#    2r-2.9315000e+02 9.57e+02 4.30e+06   3.0 2.00e+06    -  3.25e-10 2.77e-10f  1
#    3r-2.9315000e+02 9.57e+02 4.30e+06   3.0 1.65e+05    -  2.40e-08 8.90e-10f  1
#    4r-2.9315006e+02 9.57e+02 4.87e+06   3.0 1.43e+05    -  4.07e-08 5.79e-08f  1
#    5r-2.9315018e+02 9.57e+02 4.87e+06   3.0 1.43e+05    -  3.72e-07 1.25e-07f  1
#    6r-2.9315165e+02 9.57e+02 6.48e+06   3.0 1.43e+05    -  1.35e-07 1.54e-06f  1
#    7r-2.9315274e+02 9.56e+02 6.48e+06   3.0 1.43e+05    -  3.68e-06 1.15e-06f  1
#    8r-2.9316179e+02 9.55e+02 6.48e+06   3.0 1.43e+05    -  7.35e-06 9.86e-06f  1
#    9r-2.9318770e+02 9.51e+02 6.48e+06   3.0 1.43e+05    -  1.59e-04 3.07e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-2.9333929e+02 8.21e+02 6.48e+06   2.3 1.44e+05    -  1.29e-04 8.98e-04f  1
#   11 -2.9333977e+02 8.21e+02 7.27e+01  -6.0 4.31e+03    -  1.25e-05 2.44e-04h  1
#   12r-2.9333977e+02 8.21e+02 9.99e+02   2.9 0.00e+00    -  0.00e+00 1.11e-10R  2
#   13r-2.9333977e+02 8.21e+02 1.29e+03   2.9 2.84e+05    -  3.57e-05 7.66e-11f  2
#   14r-2.9545998e+02 5.14e+02 1.26e+03  -0.6 2.87e+05    -  2.50e-04 2.82e-03f  1
#   15r-2.9545998e+02 5.14e+02 9.99e+02   2.7 0.00e+00    -  0.00e+00 3.22e-07R  2
#   16r-2.9545998e+02 5.14e+02 1.16e+03   2.7 5.58e+04    -  5.13e-05 3.38e-11f  2
#   17r-2.9597585e+02 5.14e+02 1.28e+03  -0.1 2.20e+04    -  5.78e-03 1.85e-03f  1
#   18r-2.9598440e+02 5.12e+02 1.29e+03  -0.8 8.92e+03    -  4.92e-03 1.11e-03f  1
#   19r-2.9598914e+02 5.12e+02 1.23e+03  -0.8 7.22e+03    -  3.79e-05 3.53e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r
#   96 -2.9315009e+02 6.77e-02 8.68e+04  -6.0 6.36e+01    -  1.65e-06 9.39e-01h  1
#   97 -2.9315142e+02 7.78e-05 2.28e+05  -6.0 3.88e+00    -  6.50e-02 1.00e+00h  1
#   98 -2.9428562e+02 1.47e-01 9.00e+03  -6.0 4.20e+01    -  3.07e-01 1.00e+00f  1
#   99 -2.9626149e+02 4.55e-01 6.91e+03  -6.0 7.38e+01    -  3.66e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100 -2.9992648e+02 1.61e+00 3.63e+03  -6.0 1.39e+02    -  4.76e-01 1.00e+00f  1
#  101 -3.0315000e+02 2.20e+00 2.15e+03  -6.0 2.87e+02    -  4.08e-01 4.36e-01f  1
#  102 -3.0315000e+02 2.09e+00 3.38e+02  -6.0 2.21e+00    -  8.46e-01 5.26e-02h  1
#  103 -3.0315000e+02 5.93e-03 3.09e+01  -6.0 2.09e+00    -  9.06e-01 1.00e+00h  1
#  104 -3.0315000e+02 1.18e-05 1.35e-04  -6.0 8.51e-03    -  1.00e+00 1.00e+00h  1
#  105 -3.0315000e+02 4.97e-11 6.77e-11  -6.0 1.46e-05    -  1.00e+00 1.00e+00h  1
#  106 -3.0315000e+02 1.50e-10 9.05e-07  -9.0 3.94e-05    -  1.00e+00 1.00e+00h  1
#  107 -3.0315000e+02 9.94e-11 1.00e-14  -9.0 4.16e-10    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 107
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.0315000303049999e+02   -3.0315000303049999e+02
# Dual infeasibility......:   1.0019762797242038e-14    1.0019762797242038e-14
# Constraint violation....:   9.9373484809851809e-11    9.9373484809851809e-11
# Complementarity.........:   1.0000000000000491e-09    1.0000000000000491e-09
# Overall NLP error.......:   1.0000000000000491e-09    1.0000000000000491e-09
#
#
# Number of objective function evaluations             = 151
# Number of objective gradient evaluations             = 41
# Number of equality constraint evaluations            = 151
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 116
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 107
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.054
# Total CPU secs in NLP function evaluations           =      0.073
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# # Construct a single reboiler and Initialize

# %% [markdown]
# ### Deactivate the condenser part first

# %%
model.condenser.deactivate()
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 0
# Active Inequality Constraints:	 0
# Active Variables:		 0
# Fixed Variables:		 0
# DOF:				 0

# %%
model.reboiler = pe.Block(rule=reboiler_stage_rule)
# Out:
# > Importing Non Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reboiler.T_F
# | reboiler.P
# | reboiler.Q_main
# | reboiler.x_
# | reboiler.y_
# | reboiler.x
# | reboiler.y
# | reboiler.z
# | reboiler.L
# | reboiler.V
# | reboiler.F
# | reboiler.H_L_
# | reboiler.H_V_
# | reboiler.H_L
# | reboiler.H_V
# | reboiler.T
# | reboiler.H_F
# | reboiler.f_V
# | reboiler.f_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.energy_block.dH_F
# | reboiler.energy_block.dH_V
# | reboiler.energy_block.dH_L
# | reboiler.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.VLE_block.P_VLE
# | reboiler.VLE_block.n_ave
# | reboiler.VLE_block.n_ave_cal
# | reboiler.VLE_block.Hen
# | reboiler.VLE_block.Hen0
# | reboiler.VLE_block.gamma
# | reboiler.VLE_block.P_sat
# | reboiler.VLE_block.P_sat_Y
# | reboiler.VLE_block.P_sat_dY_inf
# | reboiler.VLE_block.P_sat_dY0
# | reboiler.VLE_block.Hen_ref
# | reboiler.VLE_block.Hen0_ref
# | reboiler.VLE_block.gamma_ref
# | reboiler.VLE_block.V_L
# | reboiler.VLE_block.V_L_dY_inf
# | reboiler.VLE_block.V_L_dY0
# | reboiler.VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.MPCC.s_L
# | reboiler.MPCC.s_V
# | reboiler.MPCC.pf
# | reboiler.MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE

# %% [markdown]
# ### Use the reactive sections liquid output as input to reboiler

# %%
# in/out variables
model.reboiler.y_.fix(0)
for i in m.COMP_TOTAL:
    model.reboiler.x_['in',i].fix(model.reactive[model.TRAY.last()].x[i].value)
model.reboiler.L['in'].fix(model.reactive[model.TRAY.last()].L['out'].value)
model.reboiler.V['in'].fix(0)
model.reboiler.L['P'].fix(0)
model.reboiler.V['P'].fix(0)
model.reboiler.H_L_.fix(model.reactive[model.TRAY.last()].H_L.value)
model.reboiler.H_V_.fix(0)

# operating parameters
model.reboiler.P.fix(20)
model.reboiler.T_F.fix(200+273.15)
model.reboiler.F.fix(0)
model.reboiler.z.fix(0)
model.reboiler.VLE_block.n_ave.fix(20)

model.reboiler.T.setub(model.reactive[model.TRAY.last()].T.value)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = model.reboiler.T - model.reboiler.MPCC.pf, sense = pe.maximize)

delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 957
# Active Inequality Constraints:	 1
# Active Variables:		 1132
# Fixed Variables:		 171
# DOF:				 4

# %%
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     3224
# Number of nonzeros in inequality constraint Jacobian.:        5
# Number of nonzeros in Lagrangian Hessian.............:     4317
#
# Total number of variables............................:      961
#                      variables with only lower bounds:      167
#                 variables with lower and upper bounds:      786
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      957
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        1
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.7315000e+02 9.36e+03 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.7315000e+02 9.36e+03 2.24e+02  -6.0 2.10e+04    -  6.75e-12 1.52e-09f  1
#    2r-4.7315000e+02 9.36e+03 9.99e+02   3.9 0.00e+00    -  0.00e+00 1.33e-10R  4
#    3r-4.7315000e+02 9.36e+03 1.35e+04   3.9 5.99e+09    -  2.56e-15 2.40e-09f  1
#    4r-4.7314997e+02 9.36e+03 1.34e+04   2.5 1.62e+04   2.0 5.75e-07 9.78e-08f  1
#    5r-4.7314955e+02 9.36e+03 1.34e+04   2.5 8.69e+03   2.4 1.79e-06 1.48e-06f  1
-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -4.9315000e+02 4.70e-07 5.84e-06  -6.0 2.36e-02    -  1.00e+00 1.00e+00h  1
#   61 -4.9315000e+02 2.92e-05 7.45e-01  -9.0 1.88e-01    -  9.97e-01 9.89e-01h  1
#   62 -4.9315000e+02 6.50e-06 7.83e-04  -9.0 8.77e-02    -  1.00e+00 1.00e+00h  1
#   63 -4.9315000e+02 1.59e-06 6.10e-05  -9.0 4.34e-02    -  1.00e+00 1.00e+00h  1
#   64 -4.9315000e+02 3.73e-07 4.80e-05  -9.0 2.10e-02    -  1.00e+00 1.00e+00h  1
#   65 -4.9315000e+02 7.53e-08 1.91e-05  -9.0 9.44e-03    -  1.00e+00 1.00e+00h  1
#   66 -4.9315000e+02 8.21e-09 1.35e-06  -9.0 3.11e-03    -  1.00e+00 1.00e+00h  1
#   67 -4.9315000e+02 1.43e-10 7.10e-09  -9.0 4.11e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 67
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.9315000493696596e+02   -4.9315000493696596e+02
# Dual infeasibility......:   7.0982461115517981e-09    7.0982461115517981e-09
# Constraint violation....:   1.4297896200332616e-10    1.4297896200332616e-10
# Complementarity.........:   1.0013787684185202e-09    1.0013787684185202e-09
# Overall NLP error.......:   7.0982461115517981e-09    7.0982461115517981e-09
#
#
# Number of objective function evaluations             = 81
# Number of objective gradient evaluations             = 44
# Number of equality constraint evaluations            = 81
# Number of inequality constraint evaluations          = 82
# Number of equality constraint Jacobian evaluations   = 72
# Number of inequality constraint Jacobian evaluations = 72
# Number of Lagrangian Hessian evaluations             = 67
# Total CPU secs in IPOPT (w/o function evaluations)   =      2.594
# Total CPU secs in NLP function evaluations           =      0.133
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# # Initialization is complete

# %%
beautify(pe,model)
# Out:
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		W
# Condenser	30.00		-134.95		2.54837		0.00000		0.13822		2.08954
#
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		4.77612		0.00642		0.00000		20.00000
# Reactive[2]	220.00		-43.29		4.29851		0.01285		0.00000		20.00000
# Reactive[3]	220.00		-43.29		3.82090		0.01927		0.00000		20.00000
# Reactive[4]	220.00		-43.29		3.34329		0.02570		0.00000		20.00000
# Reactive[5]	220.00		-43.29		2.86567		0.03212		0.00000		20.00000
# Reactive[6]	220.00		-43.29		2.38806		0.03854		0.00000		20.00000
# Reactive[7]	220.00		-43.29		1.91045		0.04497		0.00000		20.00000
# Reactive[8]	220.00		-43.29		1.43284		0.05139		0.00000		20.00000
# Reactive[9]	220.00		-43.29		0.95522		0.05781		0.00000		20.00000
# Reactive[10]	220.00		-43.29		0.47761		0.06424		0.00000		20.00000
# Reboiler	220.00		0.00		0.00000		0.06424				19.99770
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Linking Condenser and Reboiler

# %% [markdown]
# ### Activate previously disabled constraint and variables

# %%
for i in model.block_data_objects():
    if i.name != 'reactive_distillation':
        i.activate()
for i in model.component_objects(pe.Constraint):
    i.activate()

# %% [markdown]
# ### Condenser Vapor

# %%
def V_condenser_rule(model):
    return model.reactive[model.TRAY.first()].V['out'] == model.condenser.V['in']
model.V_condenser_con = pe.Constraint(rule=V_condenser_rule)

def Vy_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].y[i] == model.condenser.y_['in',i]
model.Vy_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_condenser_rule)

def Vh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_V == model.condenser.H_V_['in']
model.Vh_condenser_con = pe.Constraint(rule=Vh_condenser_rule)

# %% [markdown]
# ### Condenser Liquid

# %%
def L_condenser_rule(model):
    return model.reactive[model.TRAY.first()].L['in'] == model.condenser.L['out']
model.L_condenser_con = pe.Constraint(rule=L_condenser_rule)

def Lx_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].x_['in',i] == model.condenser.x[i]
model.Lx_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_condenser_rule)

def Lh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_L_['in'] == model.condenser.H_L
model.Lh_condenser_con = pe.Constraint(rule=Lh_condenser_rule)

# %% [markdown]
# ### Reboiler Vapor

# %%
def V_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].V['in'] == model.reboiler.V['out']
model.V_reboiler_con = pe.Constraint(rule=V_reboiler_rule)

def Vy_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].y_['in',i] == model.reboiler.y[i]
model.Vy_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_reboiler_rule)

def Vh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_V_['in'] == model.reboiler.H_V
model.Vh_reboiler_con = pe.Constraint(rule=Vh_reboiler_rule)

# %% [markdown]
# ### Reboiler Liquid

# %%
def L_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].L['out'] + 1e-6 == model.reboiler.L['in']
model.L_reboiler_con = pe.Constraint(rule=L_reboiler_rule)

def Lx_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].x[i] == model.reboiler.x_['in',i]
model.Lx_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_reboiler_rule)

def Lh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_L == model.reboiler.H_L_['in']
model.Lh_reboiler_con = pe.Constraint(rule=Lh_reboiler_rule)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.reactive)\
                         - model.reboiler.MPCC.pf ,sense=pe.maximize)

# %%
delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# # Fixing Redundent Stream Variables

# %% [markdown]
# ### Condenser

# %%
# in/out variables
model.condenser.x_.fix(0)
for i in m.COMP_TOTAL:
    model.condenser.y_['in',i].unfix()
model.condenser.V['in'].unfix()
model.condenser.L['in'].fix(0)
model.condenser.V['P'].fix(0)
model.condenser.H_L_.fix(0)
model.condenser.H_V_.unfix()

# operating parameters
model.condenser.P.fix(19)
model.condenser.T_F.fix(200+273.15)
model.condenser.F.fix(0)
model.condenser.z.fix(0)
model.condenser.VLE_block.n_ave.fix(4)
model.condenser.PR_L.fix(1)

model.condenser.T.fix(30+273.15)

# %% [markdown]
# ### Reboiler

# %%
# in/out variables
model.reboiler.y_.fix(0)
for i in m.COMP_TOTAL:
    model.reboiler.x_['in',i].unfix()
model.reboiler.L['in'].unfix()
model.reboiler.V['in'].fix(0)
model.reboiler.L['P'].fix(0)
model.reboiler.V['P'].fix(0)
model.reboiler.H_L_.unfix()
model.reboiler.H_V_.fix(0)

# operating parameters
model.reboiler.P.fix(20)
model.reboiler.T_F.fix(200+273.15)
model.reboiler.F.fix(0)
model.reboiler.z.fix(0)
model.reboiler.VLE_block.n_ave.fix(20)

model.reboiler.T.fix(model.reactive[model.TRAY.last()].T.value)

# %% [markdown]
# ### Reactive

# %%
# unlock reflux and reboiler vapor
for j in model.reactive:
    model.reactive[j].x_.unfix()
    model.reactive[j].H_L_.unfix()
    model.reactive[j].L['in'].unfix()
    model.reactive[j].y_.unfix()
    model.reactive[j].V['in'].unfix()
    model.reactive[j].H_V_.unfix()

for j in model.reactive:
    model.reactive[j].cat.fix(3000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
    model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
    model.reactive[j].z['C30H62'].fix(0)
    
    model.reactive[j].PR_L.fix(0)
    model.reactive[j].PR_V.fix(0)
    
    # model.reactive[j].Q_main.fix(0)
    model.reactive[j].T.setub(220+273.15)
    model.reactive[j].T.setlb(200+273.15)

# %% [markdown]
# # Connected Solve

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 15537
# Active Inequality Constraints:	 11
# Active Variables:		 15862
# Fixed Variables:		 282
# DOF:				 43

# %%
# %%time

results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    54722
# Number of nonzeros in inequality constraint Jacobian.:       75
# Number of nonzeros in Lagrangian Hessian.............:    55576
#
# Total number of variables............................:    15580
#                      variables with only lower bounds:     5784
#                 variables with lower and upper bounds:     7979
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    15537
# Total number of inequality constraints...............:       11
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       11
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.9315000e+03 2.03e+02 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.9315000e+03 2.03e+02 3.53e+02  -6.0 2.03e+02    -  2.28e-08 8.04e-06h  1
#    2 -4.9315000e+03 2.03e+02 3.52e+02  -6.0 2.03e+02    -  8.09e-06 2.45e-03h  1
#    3 -4.9315000e+03 7.75e-02 6.33e+02  -6.0 2.03e+02    -  2.41e-03 1.00e+00f  1
#    4 -4.9315000e+03 7.74e-02 6.32e+02  -6.0 7.73e-02    -  9.98e-03 2.09e-03h  1
#    5 -4.9315000e+03 5.84e-02 4.78e+02  -6.0 7.74e-02    -  7.93e-01 2.45e-01h  1
#    6 -4.9315000e+03 7.06e-03 5.78e+01  -6.0 5.84e-02    -  9.94e-01 8.79e-01h  1
#    7 -4.9315000e+03 2.36e-03 1.93e+01  -6.0 1.80e-02    -  6.64e-01 6.66e-01f  1
#    8 -4.9315000e+03 1.13e-06 6.65e-01  -6.0 3.84e-02    -  4.08e-01 1.00e+00f  1
#    9 -4.9315000e+03 3.17e-06 1.81e-01  -6.0 6.12e-02    -  7.28e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -4.9315000e+03 3.02e-05 9.24e-02  -6.0 1.89e-01    -  4.98e-01 1.00e+00h  1
#   11 -4.9315000e+03 1.38e-05 2.39e-03  -6.0 1.28e-01    -  1.00e+00 1.00e+00h  1
#   12 -4.9315000e+03 2.46e-07 1.11e-05  -6.0 1.71e-02    -  1.00e+00 1.00e+00h  1
#   13 -4.9315000e+03 2.86e-10 1.21e-08  -6.0 5.81e-04    -  1.00e+00 1.00e+00h  1
#   14 -4.9315000e+03 4.56e-05 2.27e+00  -9.0 2.39e-01    -  9.96e-01 9.74e-01f  1
#   15 -4.9315000e+03 1.71e-05 6.87e-01  -9.0 1.07e-01    -  1.00e+00 7.45e-01h  1
#   16 -4.9315000e+03 8.72e-06 1.36e+00  -9.0 6.80e-02    -  1.00e+00 5.61e-01f  1
#   17 -4.9315000e+03 2.91e-06 2.25e-01  -9.0 4.94e-02    -  1.00e+00 8.28e-01f  1
#   18 -4.9315000e+03 6.96e-07 3.42e-04  -9.0 2.87e-02    -  1.00e+00 1.00e+00f  1
#   19 -4.9315000e+03 1.35e-07 2.69e-04  -9.0 1.26e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -4.9315000e+03 2.19e-09 2.98e-05  -9.0 1.61e-03    -  1.00e+00 1.00e+00h  1
#   21 -4.9315000e+03 1.53e-11 3.87e-07  -9.0 1.35e-04    -  1.00e+00 1.00e+00h  1
#   22 -4.9315000e+03 2.27e-13 1.47e-10  -9.0 1.50e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 22
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.9315000493989510e+03   -4.9315000493989510e+03
# Dual infeasibility......:   1.4715877431556446e-10    1.4715877431556446e-10
# Constraint violation....:   2.2737367544323206e-13    2.2737367544323206e-13
# Complementarity.........:   1.0000002365356600e-09    1.0000002365356600e-09
# Overall NLP error.......:   1.0000002365356600e-09    1.0000002365356600e-09
#
#
# Number of objective function evaluations             = 23
# Number of objective gradient evaluations             = 23
# Number of equality constraint evaluations            = 23
# Number of inequality constraint evaluations          = 23
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 23
# Number of Lagrangian Hessian evaluations             = 22
# Total CPU secs in IPOPT (w/o function evaluations)   =     22.461
# Total CPU secs in NLP function evaluations           =      0.659
#
# EXIT: Optimal Solution Found.
# CPU times: user 1.75 s, sys: 62.4 ms, total: 1.82 s
# Wall time: 9 s

# %%
beautify(pe,model)
# Out:
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		W
# Condenser	30.00		-134.95		2.54837		0.00000		0.13822		2.08954
#
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		4.77612		0.00642		0.00000		20.00000
# Reactive[2]	220.00		-43.29		4.29851		0.01285		0.00000		20.00000
# Reactive[3]	220.00		-43.29		3.82090		0.01927		0.00000		20.00000
# Reactive[4]	220.00		-43.29		3.34329		0.02570		0.00000		20.00000
# Reactive[5]	220.00		-43.29		2.86567		0.03212		0.00000		20.00000
# Reactive[6]	220.00		-43.29		2.38806		0.03854		0.00000		20.00000
# Reactive[7]	220.00		-43.29		1.91045		0.04497		0.00000		20.00000
# Reactive[8]	220.00		-43.29		1.43284		0.05139		0.00000		20.00000
# Reactive[9]	220.00		-43.29		0.95523		0.05781		0.00000		20.00000
# Reactive[10]	220.00		-43.29		0.47761		0.06424		0.00000		20.00000
# Reboiler	220.00		0.00		0.00000		0.06424				19.99724
# ------------------------------------------------------------------------------------------------------------

# %%
def beautify_reactive(pyomo,model):
    print('-'*108)
    print('stages\t\tT\t\tQ\t\tV_out\t\tL_out\t\tL_P\t\tP_VLE')
    for j in model.reactive:
        temp_num = model.reactive[j].T.value - 273.15, model.reactive[j].Q_main.value,model.reactive[j].V['out'].value,\
            model.reactive[j].L['out'].value,model.reactive[j].L['P'].value,model.reactive[j].VLE_block.P_VLE.value
        temp_string = ['{:.5f}'.format(i) for i in temp_num]
        print('Reactive[{}]\t{:.5s}\t\t{:.5s}\t\t{:.6s}\t\t{:.6s}\t\t{:.6s}\t\t{:.6s}'.format(j,*temp_string))

# %%
beautify_reactive(pe,model)
# Out:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.0		-43.2		4.7761		0.0064		0.0000		20.000
# Reactive[2]	220.0		-43.2		4.2985		0.0128		0.0000		20.000
# Reactive[3]	220.0		-43.2		3.8209		0.0192		0.0000		20.000
# Reactive[4]	220.0		-43.2		3.3432		0.0257		0.0000		20.000
# Reactive[5]	220.0		-43.2		2.8656		0.0321		0.0000		20.000
# Reactive[6]	220.0		-43.2		2.3880		0.0385		0.0000		20.000
# Reactive[7]	220.0		-43.2		1.9104		0.0449		0.0000		20.000
# Reactive[8]	220.0		-43.2		1.4328		0.0513		0.0000		20.000
# Reactive[9]	220.0		-43.2		0.9552		0.0578		0.0000		20.000
# Reactive[10]	220.0		-43.2		0.4776		0.0642		0.0000		20.000

# %%
model.reactive[1].VLE_block.P_sat_Y.pprint()
# Out:
# P_sat_Y : Size=70, Index=reactive[1].VLE_block.COMP_NONHENRY
#     Key     : Lower               : Value               : Upper                : Fixed : Stale : Domain
#      C10H20 : -2.4614099080125302 :  1.1263884445865826 :    3.474028484362643 : False : False :  Reals
#      C10H22 : -2.5955361701142494 :  1.0500355364861729 :   3.4128464550154303 : False : False :  Reals
#      C11H22 : -3.3207367315668512 :  0.6408656964256351 :    3.089238578836299 : False : False :  Reals
#      C11H24 :  -3.453088045682415 :  0.5668133923450308 :   3.0314030121743656 : False : False :  Reals
#      C12H24 :  -4.169583339226395 :  0.1689269107266949 :   2.7242079291862407 : False : False :  Reals
#      C12H26 :  -4.300492592965126 : 0.09674373741815773 :   2.6690912034585947 : False : False :  Reals
#      C13H26 : -5.0098534409819875 : -0.2918954117787228 :   2.3753473066026216 : False : False :  Reals
#      C13H28 : -5.1395707941622035 : -0.3625336996948365 :   2.3224777739052733 : False : False :  Reals
