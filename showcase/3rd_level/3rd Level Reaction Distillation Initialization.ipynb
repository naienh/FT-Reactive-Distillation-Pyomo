# %% [markdown]
# # 3rd Level Model Structure: Initialize Procedure (20+ stages)

# %%
# system imports
import sys
import os
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../..'))

import numpy as np
from matplotlib import pyplot as plt

import ipywidgets as widgets
from IPython.display import display, clear_output

import pickle
from copy import deepcopy

# %%
# pyomo imports
from pyomo import environ as pe
from global_sets.component import m

from stages.reactive_stage import reactive_stage_rule
from stages.condenser_stage import condenser_stage_rule
from stages.reboiler_stage import reboiler_stage_rule

from utility.display_utility import trans_product_mole, trans_product_mass, beautify, beautify_reactive
from utility.model_utility import add_dual, update_dual, delete_dual, check_DOF, check_violate_constraint
from utility.data_utility import cal_cnumber

model = pe.ConcreteModel(name='reactive_distillation')

# %% [markdown]
# # Global Set

# %%
model.TRAY = pe.RangeSet(1,20)

# %% [markdown]
# # Construct reactive stages and Initialization separately

# %%
model.reactive = pe.Block(model.TRAY,rule=reactive_stage_rule)
add_dual(pe,model)
# Out:
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[1].x_
# | reactive[1].y_
# | reactive[1].x
# | reactive[1].y
# | reactive[1].z
# | reactive[1].L
# | reactive[1].V
# | reactive[1].F
# | reactive[1].H_L_
# | reactive[1].H_V_
# | reactive[1].H_L
# | reactive[1].H_V
# | reactive[1].H_F
# | reactive[1].T
# | reactive[1].T_F
# | reactive[1].P
# | reactive[1].f_V
# | reactive[1].f_L
# | reactive[1].cat
# | reactive[1].Q_main
# | reactive[1].r_total_comp
# | reactive[1].PR_L
# | reactive[1].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].kinetics_block.k_FT
# | reactive[1].kinetics_block.r_FT_total
# | reactive[1].kinetics_block.g0_FT
# | reactive[1].kinetics_block.alpha
# | reactive[1].kinetics_block.r_FT_cnum
# | reactive[1].kinetics_block.r_FT_comp
# | reactive[1].kinetics_block.k_WGS
# | reactive[1].kinetics_block.Ke_WGS
# | reactive[1].kinetics_block.r_WGS
# | reactive[1].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].energy_block.dH_F
# | reactive[1].energy_block.dH_V
# | reactive[1].energy_block.dH_L
# | reactive[1].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].VLE_block.P_VLE
# | reactive[1].VLE_block.n_ave
# | reactive[1].VLE_block.n_ave_cal
# | reactive[1].VLE_block.Hen
# | reactive[1].VLE_block.Hen0
# | reactive[1].VLE_block.gamma
# | reactive[1].VLE_block.P_sat
# | reactive[1].VLE_block.P_sat_Y
# | reactive[1].VLE_block.P_sat_dY_inf
# | reactive[1].VLE_block.P_sat_dY0
# | reactive[1].VLE_block.Hen_ref
# | reactive[1].VLE_block.Hen0_ref
# | reactive[1].VLE_block.gamma_ref
# | reactive[1].VLE_block.V_L
# | reactive[1].VLE_block.V_L_dY_inf
# | reactive[1].VLE_block.V_L_dY0
# | reactive[1].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].MPCC.s_L
# | reactive[1].MPCC.s_V
# | reactive[1].MPCC.pf
# | reactive[1].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[2].x_
# | reactive[2].y_
# | reactive[2].x
# | reactive[2].y
# | reactive[2].z
# | reactive[2].L
# | reactive[2].V
# | reactive[2].F
# | reactive[2].H_L_
# | reactive[2].H_V_
# | reactive[2].H_L
# | reactive[2].H_V
# | reactive[2].H_F
# | reactive[2].T
# | reactive[2].T_F
# | reactive[2].P
# | reactive[2].f_V
# | reactive[2].f_L
# | reactive[2].cat
# | reactive[2].Q_main
# | reactive[2].r_total_comp
# | reactive[2].PR_L
# | reactive[2].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].kinetics_block.k_FT
# | reactive[2].kinetics_block.r_FT_total
# | reactive[2].kinetics_block.g0_FT
# | reactive[2].kinetics_block.alpha
# | reactive[2].kinetics_block.r_FT_cnum
# | reactive[2].kinetics_block.r_FT_comp
# | reactive[2].kinetics_block.k_WGS
# | reactive[2].kinetics_block.Ke_WGS
# | reactive[2].kinetics_block.r_WGS
# | reactive[2].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].energy_block.dH_F
# | reactive[2].energy_block.dH_V
# | reactive[2].energy_block.dH_L
# | reactive[2].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].VLE_block.P_VLE
# | reactive[2].VLE_block.n_ave
# | reactive[2].VLE_block.n_ave_cal
# | reactive[2].VLE_block.Hen
# | reactive[2].VLE_block.Hen0
# | reactive[2].VLE_block.gamma
# | reactive[2].VLE_block.P_sat
# | reactive[2].VLE_block.P_sat_Y
# | reactive[2].VLE_block.P_sat_dY_inf
# | reactive[2].VLE_block.P_sat_dY0
# | reactive[2].VLE_block.Hen_ref
# | reactive[2].VLE_block.Hen0_ref
# | reactive[2].VLE_block.gamma_ref
# | reactive[2].VLE_block.V_L
# | reactive[2].VLE_block.V_L_dY_inf
# | reactive[2].VLE_block.V_L_dY0
# | reactive[2].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].MPCC.s_L
# | reactive[2].MPCC.s_V
# | reactive[2].MPCC.pf
# | reactive[2].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[3].x_
# | reactive[3].y_
# | reactive[3].x
# | reactive[3].y
# | reactive[3].z
# | reactive[3].L
# | reactive[3].V
# | reactive[3].F
# | reactive[3].H_L_
# | reactive[3].H_V_
# | reactive[3].H_L
# | reactive[3].H_V
# | reactive[3].H_F
# | reactive[3].T
# | reactive[3].T_F
# | reactive[3].P
# | reactive[3].f_V
# | reactive[3].f_L
# | reactive[3].cat
# | reactive[3].Q_main
# | reactive[3].r_total_comp
# | reactive[3].PR_L
# | reactive[3].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].kinetics_block.k_FT
# | reactive[3].kinetics_block.r_FT_total
# | reactive[3].kinetics_block.g0_FT
# | reactive[3].kinetics_block.alpha
# | reactive[3].kinetics_block.r_FT_cnum
# | reactive[3].kinetics_block.r_FT_comp
# | reactive[3].kinetics_block.k_WGS
# | reactive[3].kinetics_block.Ke_WGS
# | reactive[3].kinetics_block.r_WGS
# | reactive[3].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].energy_block.dH_F
# | reactive[3].energy_block.dH_V
# | reactive[3].energy_block.dH_L
# | reactive[3].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].VLE_block.P_VLE
# | reactive[3].VLE_block.n_ave
# | reactive[3].VLE_block.n_ave_cal
# | reactive[3].VLE_block.Hen
# | reactive[3].VLE_block.Hen0
# | reactive[3].VLE_block.gamma
# | reactive[3].VLE_block.P_sat
# | reactive[3].VLE_block.P_sat_Y
# | reactive[3].VLE_block.P_sat_dY_inf
# | reactive[3].VLE_block.P_sat_dY0
# | reactive[3].VLE_block.Hen_ref
# | reactive[3].VLE_block.Hen0_ref
# | reactive[3].VLE_block.gamma_ref
# | reactive[3].VLE_block.V_L
# | reactive[3].VLE_block.V_L_dY_inf
# | reactive[3].VLE_block.V_L_dY0
# | reactive[3].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].MPCC.s_L
# | reactive[3].MPCC.s_V
# | reactive[3].MPCC.pf
# | reactive[3].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[4].x_
# | reactive[4].y_
# | reactive[4].x
# | reactive[4].y
# | reactive[4].z
# | reactive[4].L
# | reactive[4].V
# | reactive[4].F
# | reactive[4].H_L_
# | reactive[4].H_V_
# | reactive[4].H_L
# | reactive[4].H_V
# | reactive[4].H_F
# | reactive[4].T
# | reactive[4].T_F
# | reactive[4].P
# | reactive[4].f_V
# | reactive[4].f_L
# | reactive[4].cat
# | reactive[4].Q_main
# | reactive[4].r_total_comp
# | reactive[4].PR_L
# | reactive[4].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].kinetics_block.k_FT
# | reactive[4].kinetics_block.r_FT_total
# | reactive[4].kinetics_block.g0_FT
# | reactive[4].kinetics_block.alpha
# | reactive[4].kinetics_block.r_FT_cnum
# | reactive[4].kinetics_block.r_FT_comp
# | reactive[4].kinetics_block.k_WGS
# | reactive[4].kinetics_block.Ke_WGS
# | reactive[4].kinetics_block.r_WGS
# | reactive[4].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].energy_block.dH_F
# | reactive[4].energy_block.dH_V
# | reactive[4].energy_block.dH_L
# | reactive[4].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].VLE_block.P_VLE
# | reactive[4].VLE_block.n_ave
# | reactive[4].VLE_block.n_ave_cal
# | reactive[4].VLE_block.Hen
# | reactive[4].VLE_block.Hen0
# | reactive[4].VLE_block.gamma
# | reactive[4].VLE_block.P_sat
# | reactive[4].VLE_block.P_sat_Y
# | reactive[4].VLE_block.P_sat_dY_inf
# | reactive[4].VLE_block.P_sat_dY0
# | reactive[4].VLE_block.Hen_ref
# | reactive[4].VLE_block.Hen0_ref
# | reactive[4].VLE_block.gamma_ref
# | reactive[4].VLE_block.V_L
# | reactive[4].VLE_block.V_L_dY_inf
# | reactive[4].VLE_block.V_L_dY0
# | reactive[4].VLE_block.poynting
# --------------------------------------------------
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].MPCC.s_L
# | reactive[4].MPCC.s_V
# | reactive[4].MPCC.pf
# | reactive[4].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[5].x_
# | reactive[5].y_
# | reactive[5].x
# | reactive[5].y
# | reactive[5].z
# | reactive[5].L
# | reactive[5].V
# | reactive[5].F
# | reactive[5].H_L_
# | reactive[5].H_V_
# | reactive[5].H_L
# | reactive[5].H_V
# | reactive[5].H_F
# | reactive[5].T
# | reactive[5].T_F
# | reactive[5].P
# | reactive[5].f_V
# | reactive[5].f_L
# | reactive[5].cat
# | reactive[5].Q_main
# | reactive[5].r_total_comp
# | reactive[5].PR_L
# | reactive[5].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].kinetics_block.k_FT
# | reactive[5].kinetics_block.r_FT_total
# | reactive[5].kinetics_block.g0_FT
# | reactive[5].kinetics_block.alpha
# | reactive[5].kinetics_block.r_FT_cnum
# | reactive[5].kinetics_block.r_FT_comp
# | reactive[5].kinetics_block.k_WGS
# | reactive[5].kinetics_block.Ke_WGS
# | reactive[5].kinetics_block.r_WGS
# | reactive[5].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].energy_block.dH_F
# | reactive[5].energy_block.dH_V
# | reactive[5].energy_block.dH_L
# | reactive[5].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].VLE_block.P_VLE
# | reactive[5].VLE_block.n_ave
# | reactive[5].VLE_block.n_ave_cal
# | reactive[5].VLE_block.Hen
# | reactive[5].VLE_block.Hen0
# | reactive[5].VLE_block.gamma
# | reactive[5].VLE_block.P_sat
# | reactive[5].VLE_block.P_sat_Y
# | reactive[5].VLE_block.P_sat_dY_inf
# | reactive[5].VLE_block.P_sat_dY0
# | reactive[5].VLE_block.Hen_ref
# | reactive[5].VLE_block.Hen0_ref
# | reactive[5].VLE_block.gamma_ref
# | reactive[5].VLE_block.V_L
# | reactive[5].VLE_block.V_L_dY_inf
# | reactive[5].VLE_block.V_L_dY0
# | reactive[5].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].MPCC.s_L
# | reactive[5].MPCC.s_V
# | reactive[5].MPCC.pf
# | reactive[5].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[6].x_
# | reactive[6].y_
# | reactive[6].x
# | reactive[6].y
# | reactive[6].z
# | reactive[6].L
# | reactive[6].V
# | reactive[6].F
# | reactive[6].H_L_
# | reactive[6].H_V_
# | reactive[6].H_L
# | reactive[6].H_V
# | reactive[6].H_F
# | reactive[6].T
# | reactive[6].T_F
# | reactive[6].P
# | reactive[6].f_V
# | reactive[6].f_L
# | reactive[6].cat
# | reactive[6].Q_main
# | reactive[6].r_total_comp
# | reactive[6].PR_L
# | reactive[6].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].kinetics_block.k_FT
# | reactive[6].kinetics_block.r_FT_total
# | reactive[6].kinetics_block.g0_FT
# | reactive[6].kinetics_block.alpha
# | reactive[6].kinetics_block.r_FT_cnum
# | reactive[6].kinetics_block.r_FT_comp
# | reactive[6].kinetics_block.k_WGS
# | reactive[6].kinetics_block.Ke_WGS
# | reactive[6].kinetics_block.r_WGS
# | reactive[6].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].energy_block.dH_F
# | reactive[6].energy_block.dH_V
# | reactive[6].energy_block.dH_L
# | reactive[6].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].VLE_block.P_VLE
# | reactive[6].VLE_block.n_ave
# | reactive[6].VLE_block.n_ave_cal
# | reactive[6].VLE_block.Hen
# | reactive[6].VLE_block.Hen0
# | reactive[6].VLE_block.gamma
# | reactive[6].VLE_block.P_sat
# | reactive[6].VLE_block.P_sat_Y
# | reactive[6].VLE_block.P_sat_dY_inf
# | reactive[6].VLE_block.P_sat_dY0
# | reactive[6].VLE_block.Hen_ref
# | reactive[6].VLE_block.Hen0_ref
# | reactive[6].VLE_block.gamma_ref
# | reactive[6].VLE_block.V_L
# | reactive[6].VLE_block.V_L_dY_inf
# | reactive[6].VLE_block.V_L_dY0
# | reactive[6].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].MPCC.s_L
# | reactive[6].MPCC.s_V
# | reactive[6].MPCC.pf
# | reactive[6].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[7].x_
# | reactive[7].y_
# | reactive[7].x
# | reactive[7].y
# | reactive[7].z
# | reactive[7].L
# | reactive[7].V
# | reactive[7].F
# | reactive[7].H_L_
# | reactive[7].H_V_
# | reactive[7].H_L
# | reactive[7].H_V
# | reactive[7].H_F
# | reactive[7].T
# | reactive[7].T_F
# | reactive[7].P
# | reactive[7].f_V
# | reactive[7].f_L
# | reactive[7].cat
# | reactive[7].Q_main
# | reactive[7].r_total_comp
# | reactive[7].PR_L
# | reactive[7].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].kinetics_block.k_FT
# | reactive[7].kinetics_block.r_FT_total
# | reactive[7].kinetics_block.g0_FT
# | reactive[7].kinetics_block.alpha
# | reactive[7].kinetics_block.r_FT_cnum
# | reactive[7].kinetics_block.r_FT_comp
# | reactive[7].kinetics_block.k_WGS
# | reactive[7].kinetics_block.Ke_WGS
# | reactive[7].kinetics_block.r_WGS
# | reactive[7].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].energy_block.dH_F
# | reactive[7].energy_block.dH_V
# | reactive[7].energy_block.dH_L
# | reactive[7].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].VLE_block.P_VLE
# | reactive[7].VLE_block.n_ave
# | reactive[7].VLE_block.n_ave_cal
# | reactive[7].VLE_block.Hen
# | reactive[7].VLE_block.Hen0
# | reactive[7].VLE_block.gamma
# | reactive[7].VLE_block.P_sat
# | reactive[7].VLE_block.P_sat_Y
# | reactive[7].VLE_block.P_sat_dY_inf
# | reactive[7].VLE_block.P_sat_dY0
# | reactive[7].VLE_block.Hen_ref
# | reactive[7].VLE_block.Hen0_ref
# | reactive[7].VLE_block.gamma_ref
# | reactive[7].VLE_block.V_L
# | reactive[7].VLE_block.V_L_dY_inf
# | reactive[7].VLE_block.V_L_dY0
# | reactive[7].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].MPCC.s_L
# | reactive[7].MPCC.s_V
# | reactive[7].MPCC.pf
# | reactive[7].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[8].x_
# | reactive[8].y_
# | reactive[8].x
# | reactive[8].y
# | reactive[8].z
# | reactive[8].L
# | reactive[8].V
# | reactive[8].F
# | reactive[8].H_L_
# | reactive[8].H_V_
# | reactive[8].H_L
# | reactive[8].H_V
# | reactive[8].H_F
# | reactive[8].T
# | reactive[8].T_F
# | reactive[8].P
# | reactive[8].f_V
# | reactive[8].f_L
# | reactive[8].cat
# | reactive[8].Q_main
# | reactive[8].r_total_comp
# | reactive[8].PR_L
# | reactive[8].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].kinetics_block.k_FT
# | reactive[8].kinetics_block.r_FT_total
# | reactive[8].kinetics_block.g0_FT
# | reactive[8].kinetics_block.alpha
# | reactive[8].kinetics_block.r_FT_cnum
# | reactive[8].kinetics_block.r_FT_comp
# | reactive[8].kinetics_block.k_WGS
# | reactive[8].kinetics_block.Ke_WGS
# | reactive[8].kinetics_block.r_WGS
# | reactive[8].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].energy_block.dH_F
# | reactive[8].energy_block.dH_V
# | reactive[8].energy_block.dH_L
# | reactive[8].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].VLE_block.P_VLE
# | reactive[8].VLE_block.n_ave
# | reactive[8].VLE_block.n_ave_cal
# | reactive[8].VLE_block.Hen
# | reactive[8].VLE_block.Hen0
# | reactive[8].VLE_block.gamma
# | reactive[8].VLE_block.P_sat
# | reactive[8].VLE_block.P_sat_Y
# | reactive[8].VLE_block.P_sat_dY_inf
# | reactive[8].VLE_block.P_sat_dY0
# | reactive[8].VLE_block.Hen_ref
# | reactive[8].VLE_block.Hen0_ref
# | reactive[8].VLE_block.gamma_ref
# | reactive[8].VLE_block.V_L
# | reactive[8].VLE_block.V_L_dY_inf
# | reactive[8].VLE_block.V_L_dY0
# | reactive[8].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].MPCC.s_L
# | reactive[8].MPCC.s_V
# | reactive[8].MPCC.pf
# | reactive[8].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[9].x_
# | reactive[9].y_
# | reactive[9].x
# | reactive[9].y
# | reactive[9].z
# | reactive[9].L
# | reactive[9].V
# | reactive[9].F
# | reactive[9].H_L_
# | reactive[9].H_V_
# | reactive[9].H_L
# | reactive[9].H_V
# | reactive[9].H_F
# | reactive[9].T
# | reactive[9].T_F
# | reactive[9].P
# | reactive[9].f_V
# | reactive[9].f_L
# | reactive[9].cat
# | reactive[9].Q_main
# | reactive[9].r_total_comp
# | reactive[9].PR_L
# | reactive[9].PR_V
# ------------------------------------
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].kinetics_block.k_FT
# | reactive[9].kinetics_block.r_FT_total
# | reactive[9].kinetics_block.g0_FT
# | reactive[9].kinetics_block.alpha
# | reactive[9].kinetics_block.r_FT_cnum
# | reactive[9].kinetics_block.r_FT_comp
# | reactive[9].kinetics_block.k_WGS
# | reactive[9].kinetics_block.Ke_WGS
# | reactive[9].kinetics_block.r_WGS
# | reactive[9].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].energy_block.dH_F
# | reactive[9].energy_block.dH_V
# | reactive[9].energy_block.dH_L
# | reactive[9].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].VLE_block.P_VLE
# | reactive[9].VLE_block.n_ave
# | reactive[9].VLE_block.n_ave_cal
# | reactive[9].VLE_block.Hen
# | reactive[9].VLE_block.Hen0
# | reactive[9].VLE_block.gamma
# | reactive[9].VLE_block.P_sat
# | reactive[9].VLE_block.P_sat_Y
# | reactive[9].VLE_block.P_sat_dY_inf
# | reactive[9].VLE_block.P_sat_dY0
# | reactive[9].VLE_block.Hen_ref
# | reactive[9].VLE_block.Hen0_ref
# | reactive[9].VLE_block.gamma_ref
# | reactive[9].VLE_block.V_L
# | reactive[9].VLE_block.V_L_dY_inf
# | reactive[9].VLE_block.V_L_dY0
# | reactive[9].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].MPCC.s_L
# | reactive[9].MPCC.s_V
# | reactive[9].MPCC.pf
# | reactive[9].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[10].x_
# | reactive[10].y_
# | reactive[10].x
# | reactive[10].y
# | reactive[10].z
# | reactive[10].L
# | reactive[10].V
# | reactive[10].F
# | reactive[10].H_L_
# | reactive[10].H_V_
# | reactive[10].H_L
# | reactive[10].H_V
# | reactive[10].H_F
# | reactive[10].T
# | reactive[10].T_F
# | reactive[10].P
# | reactive[10].f_V
# | reactive[10].f_L
# | reactive[10].cat
# | reactive[10].Q_main
# | reactive[10].r_total_comp
# | reactive[10].PR_L
# | reactive[10].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].kinetics_block.k_FT
# | reactive[10].kinetics_block.r_FT_total
# | reactive[10].kinetics_block.g0_FT
# | reactive[10].kinetics_block.alpha
# | reactive[10].kinetics_block.r_FT_cnum
# | reactive[10].kinetics_block.r_FT_comp
# | reactive[10].kinetics_block.k_WGS
# | reactive[10].kinetics_block.Ke_WGS
# | reactive[10].kinetics_block.r_WGS
# | reactive[10].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].energy_block.dH_F
# | reactive[10].energy_block.dH_V
# | reactive[10].energy_block.dH_L
# | reactive[10].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].VLE_block.P_VLE
# | reactive[10].VLE_block.n_ave
# | reactive[10].VLE_block.n_ave_cal
# | reactive[10].VLE_block.Hen
# | reactive[10].VLE_block.Hen0
# | reactive[10].VLE_block.gamma
# | reactive[10].VLE_block.P_sat
# | reactive[10].VLE_block.P_sat_Y
# | reactive[10].VLE_block.P_sat_dY_inf
# | reactive[10].VLE_block.P_sat_dY0
# | reactive[10].VLE_block.Hen_ref
# | reactive[10].VLE_block.Hen0_ref
# | reactive[10].VLE_block.gamma_ref
# | reactive[10].VLE_block.V_L
# | reactive[10].VLE_block.V_L_dY_inf
# | reactive[10].VLE_block.V_L_dY0
# | reactive[10].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].MPCC.s_L
# | reactive[10].MPCC.s_V
# | reactive[10].MPCC.pf
# | reactive[10].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[11].x_
# | reactive[11].y_
# | reactive[11].x
# | reactive[11].y
# | reactive[11].z
# | reactive[11].L
# | reactive[11].V
# | reactive[11].F
# | reactive[11].H_L_
# | reactive[11].H_V_
# | reactive[11].H_L
# | reactive[11].H_V
# | reactive[11].H_F
# | reactive[11].T
# | reactive[11].T_F
# | reactive[11].P
# | reactive[11].f_V
# | reactive[11].f_L
# | reactive[11].cat
# | reactive[11].Q_main
# | reactive[11].r_total_comp
# | reactive[11].PR_L
# | reactive[11].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].kinetics_block.k_FT
# | reactive[11].kinetics_block.r_FT_total
# | reactive[11].kinetics_block.g0_FT
# | reactive[11].kinetics_block.alpha
# | reactive[11].kinetics_block.r_FT_cnum
# | reactive[11].kinetics_block.r_FT_comp
# | reactive[11].kinetics_block.k_WGS
# | reactive[11].kinetics_block.Ke_WGS
# | reactive[11].kinetics_block.r_WGS
# | reactive[11].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].energy_block.dH_F
# | reactive[11].energy_block.dH_V
# | reactive[11].energy_block.dH_L
# | reactive[11].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].VLE_block.P_VLE
# | reactive[11].VLE_block.n_ave
# | reactive[11].VLE_block.n_ave_cal
# | reactive[11].VLE_block.Hen
# | reactive[11].VLE_block.Hen0
# | reactive[11].VLE_block.gamma
# | reactive[11].VLE_block.P_sat
# | reactive[11].VLE_block.P_sat_Y
# | reactive[11].VLE_block.P_sat_dY_inf
# | reactive[11].VLE_block.P_sat_dY0
# | reactive[11].VLE_block.Hen_ref
# | reactive[11].VLE_block.Hen0_ref
# | reactive[11].VLE_block.gamma_ref
# | reactive[11].VLE_block.V_L
# | reactive[11].VLE_block.V_L_dY_inf
# | reactive[11].VLE_block.V_L_dY0
# | reactive[11].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].MPCC.s_L
# | reactive[11].MPCC.s_V
# | reactive[11].MPCC.pf
# | reactive[11].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[12].x_
# | reactive[12].y_
# | reactive[12].x
# | reactive[12].y
# | reactive[12].z
# | reactive[12].L
# | reactive[12].V
# | reactive[12].F
# | reactive[12].H_L_
# | reactive[12].H_V_
# | reactive[12].H_L
# | reactive[12].H_V
# | reactive[12].H_F
# | reactive[12].T
# | reactive[12].T_F
# | reactive[12].P
# | reactive[12].f_V
# | reactive[12].f_L
# | reactive[12].cat
# | reactive[12].Q_main
# | reactive[12].r_total_comp
# | reactive[12].PR_L
# | reactive[12].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].kinetics_block.k_FT
# | reactive[12].kinetics_block.r_FT_total
# | reactive[12].kinetics_block.g0_FT
# | reactive[12].kinetics_block.alpha
# | reactive[12].kinetics_block.r_FT_cnum
# | reactive[12].kinetics_block.r_FT_comp
# | reactive[12].kinetics_block.k_WGS
# | reactive[12].kinetics_block.Ke_WGS
# | reactive[12].kinetics_block.r_WGS
# | reactive[12].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].energy_block.dH_F
# | reactive[12].energy_block.dH_V
# | reactive[12].energy_block.dH_L
# | reactive[12].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].VLE_block.P_VLE
# | reactive[12].VLE_block.n_ave
# | reactive[12].VLE_block.n_ave_cal
# | reactive[12].VLE_block.Hen
# | reactive[12].VLE_block.Hen0
# | reactive[12].VLE_block.gamma
# | reactive[12].VLE_block.P_sat
# | reactive[12].VLE_block.P_sat_Y
# | reactive[12].VLE_block.P_sat_dY_inf
# | reactive[12].VLE_block.P_sat_dY0
# | reactive[12].VLE_block.Hen_ref
# | reactive[12].VLE_block.Hen0_ref
# | reactive[12].VLE_block.gamma_ref
# | reactive[12].VLE_block.V_L
# | reactive[12].VLE_block.V_L_dY_inf
# | reactive[12].VLE_block.V_L_dY0
# | reactive[12].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].MPCC.s_L
# | reactive[12].MPCC.s_V
# | reactive[12].MPCC.pf
# | reactive[12].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[13].x_
# | reactive[13].y_
# | reactive[13].x
# | reactive[13].y
# | reactive[13].z
# | reactive[13].L
# | reactive[13].V
# | reactive[13].F
# | reactive[13].H_L_
# | reactive[13].H_V_
# | reactive[13].H_L
# | reactive[13].H_V
# | reactive[13].H_F
# | reactive[13].T
# | reactive[13].T_F
# | reactive[13].P
# | reactive[13].f_V
# | reactive[13].f_L
# | reactive[13].cat
# | reactive[13].Q_main
# | reactive[13].r_total_comp
# | reactive[13].PR_L
# | reactive[13].PR_V
# ------------------------------------
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].kinetics_block.k_FT
# | reactive[13].kinetics_block.r_FT_total
# | reactive[13].kinetics_block.g0_FT
# | reactive[13].kinetics_block.alpha
# | reactive[13].kinetics_block.r_FT_cnum
# | reactive[13].kinetics_block.r_FT_comp
# | reactive[13].kinetics_block.k_WGS
# | reactive[13].kinetics_block.Ke_WGS
# | reactive[13].kinetics_block.r_WGS
# | reactive[13].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].energy_block.dH_F
# | reactive[13].energy_block.dH_V
# | reactive[13].energy_block.dH_L
# | reactive[13].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].VLE_block.P_VLE
# | reactive[13].VLE_block.n_ave
# | reactive[13].VLE_block.n_ave_cal
# | reactive[13].VLE_block.Hen
# | reactive[13].VLE_block.Hen0
# | reactive[13].VLE_block.gamma
# | reactive[13].VLE_block.P_sat
# | reactive[13].VLE_block.P_sat_Y
# | reactive[13].VLE_block.P_sat_dY_inf
# | reactive[13].VLE_block.P_sat_dY0
# | reactive[13].VLE_block.Hen_ref
# | reactive[13].VLE_block.Hen0_ref
# | reactive[13].VLE_block.gamma_ref
# | reactive[13].VLE_block.V_L
# | reactive[13].VLE_block.V_L_dY_inf
# | reactive[13].VLE_block.V_L_dY0
# | reactive[13].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].MPCC.s_L
# | reactive[13].MPCC.s_V
# | reactive[13].MPCC.pf
# | reactive[13].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[14].x_
# | reactive[14].y_
# | reactive[14].x
# | reactive[14].y
# | reactive[14].z
# | reactive[14].L
# | reactive[14].V
# | reactive[14].F
# | reactive[14].H_L_
# | reactive[14].H_V_
# | reactive[14].H_L
# | reactive[14].H_V
# | reactive[14].H_F
# | reactive[14].T
# | reactive[14].T_F
# | reactive[14].P
# | reactive[14].f_V
# | reactive[14].f_L
# | reactive[14].cat
# | reactive[14].Q_main
# | reactive[14].r_total_comp
# | reactive[14].PR_L
# | reactive[14].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].kinetics_block.k_FT
# | reactive[14].kinetics_block.r_FT_total
# | reactive[14].kinetics_block.g0_FT
# | reactive[14].kinetics_block.alpha
# | reactive[14].kinetics_block.r_FT_cnum
# | reactive[14].kinetics_block.r_FT_comp
# | reactive[14].kinetics_block.k_WGS
# | reactive[14].kinetics_block.Ke_WGS
# | reactive[14].kinetics_block.r_WGS
# | reactive[14].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].energy_block.dH_F
# | reactive[14].energy_block.dH_V
# | reactive[14].energy_block.dH_L
# | reactive[14].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].VLE_block.P_VLE
# | reactive[14].VLE_block.n_ave
# | reactive[14].VLE_block.n_ave_cal
# | reactive[14].VLE_block.Hen
# | reactive[14].VLE_block.Hen0
# | reactive[14].VLE_block.gamma
# | reactive[14].VLE_block.P_sat
# | reactive[14].VLE_block.P_sat_Y
# | reactive[14].VLE_block.P_sat_dY_inf
# | reactive[14].VLE_block.P_sat_dY0
# | reactive[14].VLE_block.Hen_ref
# | reactive[14].VLE_block.Hen0_ref
# | reactive[14].VLE_block.gamma_ref
# | reactive[14].VLE_block.V_L
# | reactive[14].VLE_block.V_L_dY_inf
# | reactive[14].VLE_block.V_L_dY0
# | reactive[14].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].MPCC.s_L
# | reactive[14].MPCC.s_V
# | reactive[14].MPCC.pf
# | reactive[14].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[15].x_
# | reactive[15].y_
# | reactive[15].x
# | reactive[15].y
# | reactive[15].z
# | reactive[15].L
# | reactive[15].V
# | reactive[15].F
# | reactive[15].H_L_
# | reactive[15].H_V_
# | reactive[15].H_L
# | reactive[15].H_V
# | reactive[15].H_F
# | reactive[15].T
# | reactive[15].T_F
# | reactive[15].P
# | reactive[15].f_V
# | reactive[15].f_L
# | reactive[15].cat
# | reactive[15].Q_main
# | reactive[15].r_total_comp
# | reactive[15].PR_L
# | reactive[15].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].kinetics_block.k_FT
# | reactive[15].kinetics_block.r_FT_total
# | reactive[15].kinetics_block.g0_FT
# | reactive[15].kinetics_block.alpha
# | reactive[15].kinetics_block.r_FT_cnum
# | reactive[15].kinetics_block.r_FT_comp
# | reactive[15].kinetics_block.k_WGS
# | reactive[15].kinetics_block.Ke_WGS
# | reactive[15].kinetics_block.r_WGS
# | reactive[15].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].energy_block.dH_F
# | reactive[15].energy_block.dH_V
# | reactive[15].energy_block.dH_L
# | reactive[15].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].VLE_block.P_VLE
# | reactive[15].VLE_block.n_ave
# | reactive[15].VLE_block.n_ave_cal
# | reactive[15].VLE_block.Hen
# | reactive[15].VLE_block.Hen0
# | reactive[15].VLE_block.gamma
# | reactive[15].VLE_block.P_sat
# | reactive[15].VLE_block.P_sat_Y
# | reactive[15].VLE_block.P_sat_dY_inf
# | reactive[15].VLE_block.P_sat_dY0
# | reactive[15].VLE_block.Hen_ref
# | reactive[15].VLE_block.Hen0_ref
# | reactive[15].VLE_block.gamma_ref
# | reactive[15].VLE_block.V_L
# | reactive[15].VLE_block.V_L_dY_inf
# | reactive[15].VLE_block.V_L_dY0
# | reactive[15].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].MPCC.s_L
# | reactive[15].MPCC.s_V
# | reactive[15].MPCC.pf
# | reactive[15].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[16].x_
# | reactive[16].y_
# | reactive[16].x
# | reactive[16].y
# | reactive[16].z
# | reactive[16].L
# | reactive[16].V
# | reactive[16].F
# | reactive[16].H_L_
# | reactive[16].H_V_
# | reactive[16].H_L
# | reactive[16].H_V
# | reactive[16].H_F
# | reactive[16].T
# | reactive[16].T_F
# | reactive[16].P
# | reactive[16].f_V
# | reactive[16].f_L
# | reactive[16].cat
# | reactive[16].Q_main
# | reactive[16].r_total_comp
# | reactive[16].PR_L
# | reactive[16].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].kinetics_block.k_FT
# | reactive[16].kinetics_block.r_FT_total
# | reactive[16].kinetics_block.g0_FT
# | reactive[16].kinetics_block.alpha
# | reactive[16].kinetics_block.r_FT_cnum
# | reactive[16].kinetics_block.r_FT_comp
# | reactive[16].kinetics_block.k_WGS
# | reactive[16].kinetics_block.Ke_WGS
# | reactive[16].kinetics_block.r_WGS
# | reactive[16].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].energy_block.dH_F
# | reactive[16].energy_block.dH_V
# | reactive[16].energy_block.dH_L
# | reactive[16].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].VLE_block.P_VLE
# | reactive[16].VLE_block.n_ave
# | reactive[16].VLE_block.n_ave_cal
# | reactive[16].VLE_block.Hen
# | reactive[16].VLE_block.Hen0
# | reactive[16].VLE_block.gamma
# | reactive[16].VLE_block.P_sat
# | reactive[16].VLE_block.P_sat_Y
# | reactive[16].VLE_block.P_sat_dY_inf
# | reactive[16].VLE_block.P_sat_dY0
# | reactive[16].VLE_block.Hen_ref
# | reactive[16].VLE_block.Hen0_ref
# | reactive[16].VLE_block.gamma_ref
# | reactive[16].VLE_block.V_L
# | reactive[16].VLE_block.V_L_dY_inf
# | reactive[16].VLE_block.V_L_dY0
# | reactive[16].VLE_block.poynting
# --------------------------------------------------
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].MPCC.s_L
# | reactive[16].MPCC.s_V
# | reactive[16].MPCC.pf
# | reactive[16].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[17].x_
# | reactive[17].y_
# | reactive[17].x
# | reactive[17].y
# | reactive[17].z
# | reactive[17].L
# | reactive[17].V
# | reactive[17].F
# | reactive[17].H_L_
# | reactive[17].H_V_
# | reactive[17].H_L
# | reactive[17].H_V
# | reactive[17].H_F
# | reactive[17].T
# | reactive[17].T_F
# | reactive[17].P
# | reactive[17].f_V
# | reactive[17].f_L
# | reactive[17].cat
# | reactive[17].Q_main
# | reactive[17].r_total_comp
# | reactive[17].PR_L
# | reactive[17].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].kinetics_block.k_FT
# | reactive[17].kinetics_block.r_FT_total
# | reactive[17].kinetics_block.g0_FT
# | reactive[17].kinetics_block.alpha
# | reactive[17].kinetics_block.r_FT_cnum
# | reactive[17].kinetics_block.r_FT_comp
# | reactive[17].kinetics_block.k_WGS
# | reactive[17].kinetics_block.Ke_WGS
# | reactive[17].kinetics_block.r_WGS
# | reactive[17].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].energy_block.dH_F
# | reactive[17].energy_block.dH_V
# | reactive[17].energy_block.dH_L
# | reactive[17].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].VLE_block.P_VLE
# | reactive[17].VLE_block.n_ave
# | reactive[17].VLE_block.n_ave_cal
# | reactive[17].VLE_block.Hen
# | reactive[17].VLE_block.Hen0
# | reactive[17].VLE_block.gamma
# | reactive[17].VLE_block.P_sat
# | reactive[17].VLE_block.P_sat_Y
# | reactive[17].VLE_block.P_sat_dY_inf
# | reactive[17].VLE_block.P_sat_dY0
# | reactive[17].VLE_block.Hen_ref
# | reactive[17].VLE_block.Hen0_ref
# | reactive[17].VLE_block.gamma_ref
# | reactive[17].VLE_block.V_L
# | reactive[17].VLE_block.V_L_dY_inf
# | reactive[17].VLE_block.V_L_dY0
# | reactive[17].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].MPCC.s_L
# | reactive[17].MPCC.s_V
# | reactive[17].MPCC.pf
# | reactive[17].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[18].x_
# | reactive[18].y_
# | reactive[18].x
# | reactive[18].y
# | reactive[18].z
# | reactive[18].L
# | reactive[18].V
# | reactive[18].F
# | reactive[18].H_L_
# | reactive[18].H_V_
# | reactive[18].H_L
# | reactive[18].H_V
# | reactive[18].H_F
# | reactive[18].T
# | reactive[18].T_F
# | reactive[18].P
# | reactive[18].f_V
# | reactive[18].f_L
# | reactive[18].cat
# | reactive[18].Q_main
# | reactive[18].r_total_comp
# | reactive[18].PR_L
# | reactive[18].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].kinetics_block.k_FT
# | reactive[18].kinetics_block.r_FT_total
# | reactive[18].kinetics_block.g0_FT
# | reactive[18].kinetics_block.alpha
# | reactive[18].kinetics_block.r_FT_cnum
# | reactive[18].kinetics_block.r_FT_comp
# | reactive[18].kinetics_block.k_WGS
# | reactive[18].kinetics_block.Ke_WGS
# | reactive[18].kinetics_block.r_WGS
# | reactive[18].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].energy_block.dH_F
# | reactive[18].energy_block.dH_V
# | reactive[18].energy_block.dH_L
# | reactive[18].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].VLE_block.P_VLE
# | reactive[18].VLE_block.n_ave
# | reactive[18].VLE_block.n_ave_cal
# | reactive[18].VLE_block.Hen
# | reactive[18].VLE_block.Hen0
# | reactive[18].VLE_block.gamma
# | reactive[18].VLE_block.P_sat
# | reactive[18].VLE_block.P_sat_Y
# | reactive[18].VLE_block.P_sat_dY_inf
# | reactive[18].VLE_block.P_sat_dY0
# | reactive[18].VLE_block.Hen_ref
# | reactive[18].VLE_block.Hen0_ref
# | reactive[18].VLE_block.gamma_ref
# | reactive[18].VLE_block.V_L
# | reactive[18].VLE_block.V_L_dY_inf
# | reactive[18].VLE_block.V_L_dY0
# | reactive[18].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].MPCC.s_L
# | reactive[18].MPCC.s_V
# | reactive[18].MPCC.pf
# | reactive[18].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[19].x_
# | reactive[19].y_
# | reactive[19].x
# | reactive[19].y
# | reactive[19].z
# | reactive[19].L
# | reactive[19].V
# | reactive[19].F
# | reactive[19].H_L_
# | reactive[19].H_V_
# | reactive[19].H_L
# | reactive[19].H_V
# | reactive[19].H_F
# | reactive[19].T
# | reactive[19].T_F
# | reactive[19].P
# | reactive[19].f_V
# | reactive[19].f_L
# | reactive[19].cat
# | reactive[19].Q_main
# | reactive[19].r_total_comp
# | reactive[19].PR_L
# | reactive[19].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].kinetics_block.k_FT
# | reactive[19].kinetics_block.r_FT_total
# | reactive[19].kinetics_block.g0_FT
# | reactive[19].kinetics_block.alpha
# | reactive[19].kinetics_block.r_FT_cnum
# | reactive[19].kinetics_block.r_FT_comp
# | reactive[19].kinetics_block.k_WGS
# | reactive[19].kinetics_block.Ke_WGS
# | reactive[19].kinetics_block.r_WGS
# | reactive[19].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].energy_block.dH_F
# | reactive[19].energy_block.dH_V
# | reactive[19].energy_block.dH_L
# | reactive[19].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].VLE_block.P_VLE
# | reactive[19].VLE_block.n_ave
# | reactive[19].VLE_block.n_ave_cal
# | reactive[19].VLE_block.Hen
# | reactive[19].VLE_block.Hen0
# | reactive[19].VLE_block.gamma
# | reactive[19].VLE_block.P_sat
# | reactive[19].VLE_block.P_sat_Y
# | reactive[19].VLE_block.P_sat_dY_inf
# | reactive[19].VLE_block.P_sat_dY0
# | reactive[19].VLE_block.Hen_ref
# | reactive[19].VLE_block.Hen0_ref
# | reactive[19].VLE_block.gamma_ref
# | reactive[19].VLE_block.V_L
# | reactive[19].VLE_block.V_L_dY_inf
# | reactive[19].VLE_block.V_L_dY0
# | reactive[19].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].MPCC.s_L
# | reactive[19].MPCC.s_V
# | reactive[19].MPCC.pf
# | reactive[19].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[20].x_
# | reactive[20].y_
# | reactive[20].x
# | reactive[20].y
# | reactive[20].z
# | reactive[20].L
# | reactive[20].V
# | reactive[20].F
# | reactive[20].H_L_
# | reactive[20].H_V_
# | reactive[20].H_L
# | reactive[20].H_V
# | reactive[20].H_F
# | reactive[20].T
# | reactive[20].T_F
# | reactive[20].P
# | reactive[20].f_V
# | reactive[20].f_L
# | reactive[20].cat
# | reactive[20].Q_main
# | reactive[20].r_total_comp
# | reactive[20].PR_L
# | reactive[20].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].kinetics_block.k_FT
# | reactive[20].kinetics_block.r_FT_total
# | reactive[20].kinetics_block.g0_FT
# | reactive[20].kinetics_block.alpha
# | reactive[20].kinetics_block.r_FT_cnum
# | reactive[20].kinetics_block.r_FT_comp
# | reactive[20].kinetics_block.k_WGS
# | reactive[20].kinetics_block.Ke_WGS
# | reactive[20].kinetics_block.r_WGS
# | reactive[20].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].energy_block.dH_F
# | reactive[20].energy_block.dH_V
# | reactive[20].energy_block.dH_L
# | reactive[20].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].VLE_block.P_VLE
# | reactive[20].VLE_block.n_ave
# | reactive[20].VLE_block.n_ave_cal
# | reactive[20].VLE_block.Hen
# | reactive[20].VLE_block.Hen0
# | reactive[20].VLE_block.gamma
# | reactive[20].VLE_block.P_sat
# | reactive[20].VLE_block.P_sat_Y
# | reactive[20].VLE_block.P_sat_dY_inf
# | reactive[20].VLE_block.P_sat_dY0
# | reactive[20].VLE_block.Hen_ref
# | reactive[20].VLE_block.Hen0_ref
# | reactive[20].VLE_block.gamma_ref
# | reactive[20].VLE_block.V_L
# | reactive[20].VLE_block.V_L_dY_inf
# | reactive[20].VLE_block.V_L_dY0
# | reactive[20].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].MPCC.s_L
# | reactive[20].MPCC.s_V
# | reactive[20].MPCC.pf
# | reactive[20].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
# in/out variable
for j in model.reactive:
    model.reactive[j].x_.fix(0)
    model.reactive[j].y_.fix(0)
    model.reactive[j].L['in'].fix(0)
    model.reactive[j].V['in'].fix(0)
    model.reactive[j].H_L_.fix(0)
    model.reactive[j].H_V_.fix(0)

# operating parameters
for j in model.reactive:
    model.reactive[j].cat.fix(3000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
    model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
    model.reactive[j].z['C30H62'].fix(0)
    
    model.reactive[j].PR_L.fix(1)
    model.reactive[j].PR_V.fix(1)
    
    # model.reactive[j].Q_main.fix(0)
    model.reactive[j].T.setub(220+273.15)
    model.reactive[j].T.setlb(200+273.15)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 23680
# Active Inequality Constraints:	 20
# Active Variables:		 27200
# Fixed Variables:		 3440
# DOF:				 80

# %%
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.reactive),sense=pe.maximize)

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'

opt.options['linear_system_scaling '] = 'mc19'
opt.options['linear_scaling_on_demand '] = 'no'

# opt.options['warm_start_init_point'] = 'yes'
# opt.options['warm_start_bound_push'] = 1e-20
# opt.options['warm_start_mult_bound_push'] = 1e-20
# opt.options['mu_init'] = 1e-6

# opt.options['halt_on_ampl_error'] = 'yes'

opt.options['max_iter'] = 7000

# %%
# %%time

results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    83520
# Number of nonzeros in inequality constraint Jacobian.:      140
# Number of nonzeros in Lagrangian Hessian.............:    91140
#
# Total number of variables............................:    23760
#                      variables with only lower bounds:     7700
#                 variables with lower and upper bounds:    12660
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    23680
# Total number of inequality constraints...............:       20
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       20
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -9.4667999e+03 9.34e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -9.4668899e+03 9.34e+03 5.24e+00  -1.0 2.15e+04    -  3.22e-04 1.47e-04h  1
#    2r-9.4668899e+03 9.34e+03 9.99e+02   3.9 0.00e+00    -  0.00e+00 3.24e-07R  4
#    3r-9.4668854e+03 9.34e+03 9.99e+02   3.9 5.85e+05    -  3.19e-05 4.85e-07f  1
#    4r-9.5205640e+03 8.81e+03 9.98e+02   2.5 4.80e+05    -  7.33e-05 9.06e-04f  1
#    5r-9.7580188e+03 6.46e+03 9.97e+02   2.5 1.78e+06    -  4.02e-04 1.06e-03f  1
#    6 -9.7579550e+03 6.45e+03 1.12e+01  -1.0 2.93e+04    -  3.48e-04 2.18e-04h  1
#    7 -9.7580123e+03 6.45e+03 4.80e+01  -1.0 3.09e+03    -  6.31e-04 6.92e-05h  1
#    8 -9.7583047e+03 6.45e+03 1.50e+02  -1.0 3.96e+03    -  8.69e-04 3.38e-04h  1
#    9 -9.7583245e+03 6.45e+03 8.28e+03  -1.0 3.30e+03    -  1.78e-03 2.33e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-9.7583245e+03 6.45e+03 1.00e+03   3.7 0.00e+00    -  0.00e+00 2.44e-07R  2
#   11r-9.7583664e+03 6.45e+03 1.38e+03   3.7 5.87e+05    -  1.14e-03 7.80e-07f  1
#   12r-9.8604130e+03 5.46e+03 1.50e+03   2.3 6.16e+05    -  3.97e-03 1.31e-03f  1
#   13r-9.8604130e+03 5.46e+03 9.99e+02   3.7 0.00e+00    -  0.00e+00 4.05e-07R  4
#   14r-9.8604114e+03 5.46e+03 9.99e+02   3.7 2.60e+05    -  3.71e-04 1.37e-07f  1
#   15r-9.8613657e+03 5.35e+03 9.98e+02   2.3 2.74e+05    -  8.69e-03 3.48e-04f  1
#   16r-9.8607314e+03 2.47e+03 9.95e+02   2.3 9.15e+05    -  3.13e-03 3.15e-03f  1
#   17 -9.8607226e+03 2.47e+03 1.58e+00  -1.0 1.94e+04    -  6.26e-05 3.93e-05h  1
#   18 -9.8607375e+03 2.47e+03 9.86e+00  -1.0 3.31e+03    -  7.45e-05 1.78e-05h  1
#   19 -9.8607503e+03 2.47e+03 3.09e+02  -1.0 3.46e+03    -  5.71e-04 1.47e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r-9.8607503e+03 2.47e+03 9.99e+02   3.3 0.00e+00    -  0.00e+00 1.35e-07R  2
#   21r-9.8607454e+03 2.47e+03 9.99e+02   3.3 2.14e+05    -  1.33e-03 4.12e-07f  1
#   22r-9.8573880e+03 5.13e+02 9.91e+02   2.6 3.20e+05    -  8.44e-03 7.33e-03f  1
#   23 -9.8573547e+03 5.13e+02 1.34e+02  -1.0 1.70e+04    -  3.70e-04 8.23e-05h  1
#   24 -9.8573880e+03 5.13e+02 5.10e+02  -1.0 5.54e+03    -  1.19e-03 4.03e-05h  1
#   25 -9.8577110e+03 5.13e+02 3.05e+03  -1.0 5.72e+03    -  2.43e-03 3.80e-04h  1
#   26r-9.8577110e+03 5.13e+02 1.00e+03   2.7 0.00e+00    -  0.00e+00 4.99e-07R  4
#   27r-9.8576884e+03 5.13e+02 1.05e+03   2.7 2.71e+04    -  5.91e-03 8.80e-06f  1
#   28r-9.8483110e+03 5.12e+02 2.99e+03   2.7 1.28e+04    -  3.93e-03 1.03e-02f  1
#   29r-9.8383798e+03 5.11e+02 1.16e+04   2.7 1.38e+03    -  4.88e-03 1.60e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30r-9.8264387e+03 5.10e+02 1.97e+04   2.7 8.12e+02    -  1.49e-02 2.48e-02f  1
#   31r-9.8240377e+03 5.08e+02 2.37e+04   2.0 1.02e+03    -  7.21e-03 3.54e-02f  1
#   32r-9.8208046e+03 5.05e+02 1.75e+04   2.0 7.82e+02    -  6.04e-02 3.07e-02f  1
#   33r-9.8119285e+03 4.96e+02 1.66e+04   2.0 1.10e+02    -  8.33e-02 8.27e-02f  1
#   34r-9.8029330e+03 4.85e+02 2.15e+04   2.0 1.01e+02    -  3.47e-01 1.07e-01f  1
#   35r-9.7829534e+03 4.61e+02 1.70e+04   2.0 9.02e+01    -  3.13e-01 2.65e-01f  1
#   36 -9.7807257e+03 4.53e+02 3.44e+00  -1.0 8.66e+02    -  1.06e-02 1.70e-02h  4
#   37 -9.7745008e+03 4.40e+02 3.94e+00  -1.0 1.45e+03    -  2.40e-02 2.84e-02h  3
#   38 -9.7617886e+03 4.22e+02 3.72e+01  -1.0 2.09e+03    -  7.50e-02 4.05e-02h  2
#   39 -9.7459983e+03 3.97e+02 1.17e+02  -1.0 1.78e+03    -  1.40e-01 6.03e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 -9.7459405e+03 3.95e+02 8.54e+02  -1.0 3.97e+02    -  3.15e-01 4.76e-03h  1
#   41 -9.7753557e+03 1.97e+02 3.91e+03  -1.0 3.95e+02    -  3.65e-01 5.78e-01H  1
#   42 -9.7555729e+03 1.22e+02 3.63e+03  -1.0 3.91e+02    -  4.28e-01 5.16e-01h  1
#   43 -9.7506994e+03 1.17e+02 4.46e+03  -1.0 9.30e+02    -  2.72e-01 4.41e-02h  1
#   44 -9.7607484e+03 6.85e+01 1.99e+04  -1.0 1.43e+02    -  8.04e-02 4.65e-01h  1
#   45 -9.7637732e+03 6.41e+01 9.80e+05  -1.0 2.50e+02    -  4.65e-01 7.13e-02h  1
#   46 -9.8300361e+03 1.43e+01 1.23e+06  -1.0 3.04e+02    -  5.54e-01 9.52e-01h  1
#   47 -9.8521590e+03 1.25e+01 3.14e+05  -1.0 1.21e+03    -  1.86e-01 1.20e-01h  1
#   48 -9.8492461e+03 9.94e+00 1.47e+06  -1.0 1.04e+02    -  5.97e-02 2.42e-01h  1
#   49 -9.8545680e+03 6.76e+00 3.47e+06  -1.0 5.99e+01    -  9.87e-01 4.60e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -9.8544920e+03 4.61e+00 6.76e+05  -1.0 1.29e+01    -  7.66e-01 9.90e-01h  1
#   51 -9.8554091e+03 1.93e-01 2.49e+05  -1.0 6.45e+00    -  1.00e+00 9.93e-01h  1
#   52 -9.8548017e+03 1.18e-02 1.18e+04  -1.0 3.63e+00    -  1.00e+00 1.00e+00h  1
#   53 -9.8543495e+03 1.04e-04 2.85e+02  -1.0 5.88e-01    -  1.00e+00 1.00e+00h  1
#   54 -9.8611668e+03 1.25e-03 2.72e+06  -2.5 5.30e+00    -  9.87e-01 7.07e-01f  1
#   55 -9.8627316e+03 4.33e-04 2.24e+04  -2.5 4.59e+00    -  1.00e+00 1.00e+00f  1
#   56 -9.8627411e+03 1.40e-04 1.42e+02  -2.5 7.74e-01    -  1.00e+00 1.00e+00h  1
#   57 -9.8627439e+03 3.73e-06 2.06e-01  -2.5 1.28e-01    -  1.00e+00 1.00e+00h  1
#   58 -9.8629725e+03 1.59e-04 2.02e+03  -3.8 8.23e-01    -  1.00e+00 1.00e+00f  1
#   59 -9.8629853e+03 1.16e-04 1.23e+01  -3.8 7.11e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -9.8629852e+03 4.23e-09 6.99e-04  -3.8 3.22e-03    -  1.00e+00 1.00e+00h  1
#   61 -9.8629998e+03 5.35e-06 2.07e+01  -5.7 1.53e-01    -  1.00e+00 1.00e+00f  1
#   62 -9.8629999e+03 9.82e-09 1.22e-03  -5.7 6.61e-03    -  1.00e+00 1.00e+00h  1
#   63 -9.8629999e+03 1.38e-10 1.85e-11  -5.7 2.99e-07    -  1.00e+00 1.00e+00h  1
#   64 -9.8630001e+03 9.73e-10 3.46e-03  -8.6 2.06e-03    -  1.00e+00 1.00e+00f  1
#   65 -9.8630001e+03 4.24e-11 1.57e-08  -8.6 8.41e-07    -  1.00e+00 1.00e+00h  1
#   66 -9.8630001e+03 4.24e-11 2.76e-08  -9.0 1.77e-06    -  1.00e+00 1.00e+00h  1
#   67 -9.8630001e+03 2.27e-13 6.51e-09  -9.0 2.14e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 67
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -9.8630000987773783e+03   -9.8630000987773783e+03
# Dual infeasibility......:   6.5107696317623365e-09    6.5107696317623365e-09
# Constraint violation....:   2.2737367544323206e-13    2.2737367544323206e-13
# Complementarity.........:   1.0404302700175669e-09    1.0404302700175669e-09
# Overall NLP error.......:   6.5107696317623365e-09    6.5107696317623365e-09
#
#
# Number of objective function evaluations             = 96
# Number of objective gradient evaluations             = 54
# Number of equality constraint evaluations            = 96
# Number of inequality constraint evaluations          = 96
# Number of equality constraint Jacobian evaluations   = 73
# Number of inequality constraint Jacobian evaluations = 73
# Number of Lagrangian Hessian evaluations             = 67
# Total CPU secs in IPOPT (w/o function evaluations)   =     49.637
# Total CPU secs in NLP function evaluations           =      3.369
#
# EXIT: Optimal Solution Found.
# CPU times: user 2.75 s, sys: 109 ms, total: 2.86 s
# Wall time: 23.9 s

# %%
beautify_reactive(pe,model)
# Out:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[2]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[3]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[4]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[5]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[11]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[12]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[13]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000

# %% [markdown]
# # Connect reactive stages and Initialize connectively

# %% [markdown]
# ### Vapor Between Reactive Stages

# %%
def V_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].V['in'] == model.reactive[j+1].V['out']
model.V_between_con = pe.Constraint(model.TRAY,rule=V_between_rule)

def Vy_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].y_['in',i] == model.reactive[j+1].y[i]
model.Vy_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Vy_between_rule)

def Vh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].H_V_['in'] == model.reactive[j+1].H_V
model.Vh_between_con = pe.Constraint(model.TRAY,rule=Vh_between_rule)

# %% [markdown]
# ### Liquid Between Reactive Stages

# %%
def L_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].L['in'] == model.reactive[j].L['out']
model.L_between_con = pe.Constraint(model.TRAY,rule=L_between_rule)

def Lx_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].x_['in',i] == model.reactive[j].x[i]
model.Ly_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Lx_between_rule)

def Lh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].H_L_['in'] == model.reactive[j].H_L
model.Lh_between_con = pe.Constraint(model.TRAY,rule=Lh_between_rule)

# %% [markdown]
# ### Unlock liquid and vapor in-flow

# %%
for j in model.reactive:
    if j != model.TRAY.first():
        model.reactive[j].x_.unfix()
        model.reactive[j].H_L_.unfix()
        model.reactive[j].L['in'].unfix()
    if j != model.TRAY.last():
        model.reactive[j].y_.unfix()
        model.reactive[j].V['in'].unfix()
        model.reactive[j].H_V_.unfix()

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 26758
# Active Inequality Constraints:	 20
# Active Variables:		 27200
# Fixed Variables:		 362
# DOF:				 80

# %%
opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6

results = opt.solve(model,tee=False)
update_dual(pe,model)

# %% [markdown]
# ### Iteratively reduce stage product draw ratio

# %%
# %%time

PR_range = np.linspace(1,0,11)
for r in PR_range:
    for j in model.reactive:
        model.reactive[j].PR_L.fix(r)
        model.reactive[j].PR_V.fix(r)
        
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    print('\nWorking on PR ratio = {:.2f}'.format(r))
    beautify_reactive(pe,model)
# Out:
# Working on PR ratio = 1.00
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[2]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[3]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[4]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[5]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[11]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[12]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[13]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.0000		0.00000		0.00642		20.00000
#
# Working on PR ratio = 0.90
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.0531		0.00064		0.00578		20.00000
# Reactive[2]	220.00		-43.29		 0.0531		0.00071		0.00636		20.00000
# Reactive[3]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[4]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[5]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[11]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[12]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[13]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.0531		0.00071		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.0530		0.00071		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.0525		0.00071		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.0478		0.00071		0.00642		20.00000
#
# Working on PR ratio = 0.80
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.1194		0.00128		0.00514		20.00000
# Reactive[2]	220.00		-43.29		 0.1194		0.00154		0.00617		20.00000
# Reactive[3]	220.00		-43.29		 0.1194		0.00159		0.00637		20.00000
# Reactive[4]	220.00		-43.29		 0.1194		0.00160		0.00641		20.00000
# Reactive[5]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[6]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[11]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[12]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[13]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.1194		0.00161		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.1192		0.00161		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.1184		0.00161		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.1146		0.00161		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.0955		0.00161		0.00642		20.00000
#
# Working on PR ratio = 0.70
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.2047		0.00193		0.00450		20.00000
# Reactive[2]	220.00		-43.29		 0.2047		0.00251		0.00585		20.00000
# Reactive[3]	220.00		-43.29		 0.2047		0.00268		0.00625		20.00000
# Reactive[4]	220.00		-43.29		 0.2047		0.00273		0.00637		20.00000
# Reactive[5]	220.00		-43.29		 0.2047		0.00275		0.00641		20.00000
# Reactive[6]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[7]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[8]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[11]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[12]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[13]	220.00		-43.29		 0.2047		0.00275		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.2046		0.00275		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.2045		0.00275		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.2042		0.00275		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.2030		0.00275		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.1992		0.00275		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.1863		0.00275		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.1433		0.00275		0.00642		20.00000
#
# Working on PR ratio = 0.60
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.3184		0.00257		0.00385		20.00000
# Reactive[2]	220.00		-43.29		 0.3184		0.00360		0.00540		20.00000
# Reactive[3]	220.00		-43.29		 0.3184		0.00401		0.00601		20.00000
# Reactive[4]	220.00		-43.29		 0.3184		0.00417		0.00626		20.00000
# Reactive[5]	220.00		-43.29		 0.3184		0.00424		0.00636		20.00000
# Reactive[6]	220.00		-43.29		 0.3184		0.00426		0.00640		20.00000
# Reactive[7]	220.00		-43.29		 0.3184		0.00428		0.00641		20.00000
# Reactive[8]	220.00		-43.29		 0.3184		0.00428		0.00642		20.00000
# Reactive[9]	220.00		-43.29		 0.3184		0.00428		0.00642		20.00000
# Reactive[10]	220.00		-43.29		 0.3184		0.00428		0.00642		20.00000
# Reactive[11]	220.00		-43.29		 0.3184		0.00428		0.00642		20.00000
# Reactive[12]	220.00		-43.29		 0.3183		0.00428		0.00642		20.00000
# Reactive[13]	220.00		-43.29		 0.3182		0.00428		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.3179		0.00428		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.3171		0.00428		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.3151		0.00428		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.3103		0.00428		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.2980		0.00428		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.2675		0.00428		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.1910		0.00428		0.00642		20.00000
#
# Working on PR ratio = 0.50
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.4776		0.00321		0.00321		20.00000
# Reactive[2]	220.00		-43.29		 0.4776		0.00482		0.00482		20.00000
# Reactive[3]	220.00		-43.29		 0.4776		0.00562		0.00562		20.00000
# Reactive[4]	220.00		-43.29		 0.4776		0.00602		0.00602		20.00000
# Reactive[5]	220.00		-43.29		 0.4776		0.00622		0.00622		20.00000
# Reactive[6]	220.00		-43.29		 0.4776		0.00632		0.00632		20.00000
# Reactive[7]	220.00		-43.29		 0.4776		0.00637		0.00637		20.00000
# Reactive[8]	220.00		-43.29		 0.4776		0.00640		0.00640		20.00000
# Reactive[9]	220.00		-43.29		 0.4775		0.00641		0.00641		20.00000
# Reactive[10]	220.00		-43.29		 0.4774		0.00642		0.00642		20.00000
# Reactive[11]	220.00		-43.29		 0.4771		0.00642		0.00642		20.00000
# Reactive[12]	220.00		-43.29		 0.4767		0.00642		0.00642		20.00000
# Reactive[13]	220.00		-43.29		 0.4757		0.00642		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.4739		0.00642		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.4701		0.00642		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.4627		0.00642		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.4478		0.00642		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.4179		0.00642		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.3582		0.00642		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.2388		0.00642		0.00642		20.00000
# Working on PR ratio = 0.40
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 0.7164		0.00385		0.00257		20.00000
# Reactive[2]	220.00		-43.29		 0.7164		0.00617		0.00411		20.00000
# Reactive[3]	220.00		-43.29		 0.7163		0.00755		0.00504		20.00000
# Reactive[4]	220.00		-43.29		 0.7163		0.00839		0.00559		20.00000
# Reactive[5]	220.00		-43.29		 0.7162		0.00889		0.00592		20.00000
# Reactive[6]	220.00		-43.29		 0.7161		0.00919		0.00612		20.00000
# Reactive[7]	220.00		-43.29		 0.7159		0.00937		0.00624		20.00000
# Reactive[8]	220.00		-43.29		 0.7155		0.00947		0.00632		20.00000
# Reactive[9]	220.00		-43.29		 0.7149		0.00954		0.00636		20.00000
# Reactive[10]	220.00		-43.29		 0.7138		0.00958		0.00638		20.00000
# Reactive[11]	220.00		-43.29		 0.7121		0.00960		0.00640		20.00000
# Reactive[12]	220.00		-43.29		 0.7092		0.00961		0.00641		20.00000
# Reactive[13]	220.00		-43.29		 0.7044		0.00962		0.00642		20.00000
# Reactive[14]	220.00		-43.29		 0.6964		0.00963		0.00642		20.00000
# Reactive[15]	220.00		-43.29		 0.6830		0.00963		0.00642		20.00000
# Reactive[16]	220.00		-43.29		 0.6607		0.00963		0.00642		20.00000
# Reactive[17]	220.00		-43.29		 0.6236		0.00963		0.00642		20.00000
# Reactive[18]	220.00		-43.29		 0.5617		0.00963		0.00642		20.00000
# Reactive[19]	220.00		-43.29		 0.4585		0.00964		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.2866		0.00964		0.00642		20.00000
#
# Working on PR ratio = 0.30
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 1.1135		0.00450		0.00193		20.00000
# Reactive[2]	220.00		-43.29		 1.1132		0.00764		0.00328		20.00000
# Reactive[3]	220.00		-43.29		 1.1126		0.00985		0.00422		20.00000
# Reactive[4]	220.00		-43.29		 1.1118		0.01139		0.00488		20.00000
# Reactive[5]	220.00		-43.29		 1.1107		0.01247		0.00534		20.00000
# Reactive[6]	220.00		-43.29		 1.1091		0.01323		0.00567		20.00000
# Reactive[7]	220.00		-43.29		 1.1069		0.01375		0.00589		20.00000
# Reactive[8]	220.00		-43.29		 1.1036		0.01412		0.00605		20.00000
# Reactive[9]	220.00		-43.29		 1.0990		0.01438		0.00616		20.00000
# Reactive[10]	220.00		-43.29		 1.0924		0.01457		0.00624		20.00000
# Reactive[11]	220.00		-43.29		 1.0829		0.01469		0.00630		20.00000
# Reactive[12]	220.00		-43.29		 1.0695		0.01478		0.00633		20.00000
# Reactive[13]	220.00		-43.29		 1.0502		0.01484		0.00636		20.00000
# Reactive[14]	220.00		-43.29		 1.0227		0.01489		0.00638		20.00000
# Reactive[15]	220.00		-43.29		 0.9833		0.01492		0.00639		20.00000
# Reactive[16]	220.00		-43.29		 0.9271		0.01494		0.00640		20.00000
# Reactive[17]	220.00		-43.29		 0.8469		0.01495		0.00641		20.00000
# Reactive[18]	220.00		-43.29		 0.7322		0.01496		0.00641		20.00000
# Reactive[19]	220.00		-43.29		 0.5684		0.01497		0.00642		20.00000
# Reactive[20]	220.00		-43.29		 0.3343		0.01498		0.00642		20.00000
#
# Working on PR ratio = 0.20
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 1.8884		0.00514		0.00128		20.00000
# Reactive[2]	220.00		-43.29		 1.8829		0.00925		0.00231		20.00000
# Reactive[3]	220.00		-43.29		 1.8760		0.01254		0.00313		20.00000
# Reactive[4]	220.00		-43.29		 1.8674		0.01517		0.00379		20.00000
# Reactive[5]	220.00		-43.29		 1.8567		0.01728		0.00432		20.00000
# Reactive[6]	220.00		-43.29		 1.8432		0.01896		0.00474		20.00000
# Reactive[7]	220.00		-43.29		 1.8264		0.02031		0.00508		20.00000
# Reactive[8]	220.00		-43.29		 1.8054		0.02138		0.00535		20.00000
# Reactive[9]	220.00		-43.29		 1.7792		0.02225		0.00556		20.00000
# Reactive[10]	220.00		-43.29		 1.7463		0.02294		0.00573		20.00000
# Reactive[11]	220.00		-43.29		 1.7053		0.02349		0.00587		20.00000
# Reactive[12]	220.00		-43.29		 1.6540		0.02393		0.00598		20.00000
# Reactive[13]	220.00		-43.29		 1.5899		0.02428		0.00607		20.00000
# Reactive[14]	220.00		-43.29		 1.5098		0.02457		0.00614		20.00000
# Reactive[15]	220.00		-43.29		 1.4096		0.02479		0.00620		20.00000
# Reactive[16]	220.00		-43.29		 1.2844		0.02497		0.00624		20.00000
# Reactive[17]	220.00		-43.29		 1.1279		0.02512		0.00628		20.00000
# Reactive[18]	220.00		-43.29		 0.9323		0.02523		0.00631		20.00000
# Reactive[19]	220.00		-43.29		 0.6878		0.02532		0.00633		20.00000
# Reactive[20]	220.00		-43.29		 0.3821		0.02540		0.00635		20.00000
#
# Working on PR ratio = 0.10
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 3.7759		0.00578		0.00064		20.00000
# Reactive[2]	220.00		-43.29		 3.7178		0.01098		0.00122		20.00000
# Reactive[3]	220.00		-43.29		 3.6533		0.01567		0.00174		20.00000
# Reactive[4]	220.00		-43.29		 3.5816		0.01988		0.00221		20.00000
# Reactive[5]	220.00		-43.29		 3.5020		0.02368		0.00263		20.00000
# Reactive[6]	220.00		-43.29		 3.4135		0.02709		0.00301		20.00000
# Reactive[7]	220.00		-43.29		 3.3151		0.03016		0.00335		20.00000
# Reactive[8]	220.00		-43.29		 3.2059		0.03293		0.00366		20.00000
# Reactive[9]	220.00		-43.29		 3.0845		0.03542		0.00394		20.00000
# Reactive[10]	220.00		-43.29		 2.9496		0.03766		0.00418		20.00000
# Reactive[11]	220.00		-43.29		 2.7997		0.03967		0.00441		20.00000
# Reactive[12]	220.00		-43.29		 2.6332		0.04149		0.00461		20.00000
# Reactive[13]	220.00		-43.29		 2.4481		0.04312		0.00479		20.00000
# Reactive[14]	220.00		-43.29		 2.2425		0.04459		0.00495		20.00000
# Reactive[15]	220.00		-43.29		 2.0141		0.04591		0.00510		20.00000
# Reactive[16]	220.00		-43.29		 1.7603		0.04710		0.00523		20.00000
# Reactive[17]	220.00		-43.29		 1.4783		0.04817		0.00535		20.00000
# Reactive[18]	220.00		-43.29		 1.1649		0.04914		0.00546		20.00000
# Reactive[19]	220.00		-43.29		 0.8167		0.05000		0.00556		20.00000
# Reactive[20]	220.00		-43.29		 0.4299		0.05079		0.00564		20.00000
#
# Working on PR ratio = 0.00
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		 9.5522		0.00642		0.00000		20.00001
# Reactive[2]	220.00		-43.29		 9.0746		0.01285		0.00000		20.00000
# Reactive[3]	220.00		-43.29		 8.5970		0.01927		0.00000		20.00000
# Reactive[4]	220.00		-43.29		 8.1194		0.02570		0.00000		20.00000
# Reactive[5]	220.00		-43.29		 7.6418		0.03212		0.00000		20.00000
# Reactive[6]	220.00		-43.29		 7.1642		0.03854		0.00000		20.00000
# Reactive[7]	220.00		-43.29		 6.6866		0.04497		0.00000		20.00000
# Reactive[8]	220.00		-43.29		 6.2090		0.05139		0.00000		20.00000
# Reactive[9]	220.00		-43.29		 5.7313		0.05781		0.00000		20.00000
# Reactive[10]	220.00		-43.29		 5.2537		0.06424		0.00000		20.00000
# Reactive[11]	220.00		-43.29		 4.7761		0.07066		0.00000		20.00000
# Reactive[12]	220.00		-43.29		 4.2985		0.07709		0.00000		20.00000
# Reactive[13]	220.00		-43.29		 3.8209		0.08351		0.00000		20.00000
# Reactive[14]	220.00		-43.29		 3.3433		0.08993		0.00000		20.00000
# Reactive[15]	220.00		-43.29		 2.8657		0.09636		0.00000		20.00000
# Reactive[16]	220.00		-43.29		 2.3881		0.10278		0.00000		20.00000
# Reactive[17]	220.00		-43.29		 1.9104		0.10920		0.00000		20.00000
# Reactive[18]	220.00		-43.29		 1.4328		0.11563		0.00000		20.00000
# Reactive[19]	220.00		-43.29		 0.9552		0.12205		0.00000		20.00000
# Reactive[20]	220.00		-43.29		 0.4776		0.12848		0.00000		20.00000
# CPU times: user 40 s, sys: 839 ms, total: 40.8 s
# Wall time: 1min 59s

# %% [markdown]
# # Construct a single condenser and Initialize

# %% [markdown]
# ### Deactivate the reactive part first

# %%
for i in model.block_data_objects():
    if i.name != 'reactive_distillation':
        i.deactivate()
for i in model.component_objects(pe.Constraint, active=True):
    i.deactivate()
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 0
# Active Inequality Constraints:	 0
# Active Variables:		 0
# Fixed Variables:		 0
# DOF:				 0

# %%
model.condenser = pe.Block(rule=condenser_stage_rule)
# Out:
# | Importing Condenser Stage......
# | Adding the following local variable:
# ------------------------------------
# | condenser.T
# | condenser.T_F
# | condenser.P
# | condenser.Q_main
# | condenser.x_
# | condenser.y_
# | condenser.x
# | condenser.y
# | condenser.z
# | condenser.L
# | condenser.W
# | condenser.V
# | condenser.F
# | condenser.H_L_
# | condenser.H_V_
# | condenser.H_L
# | condenser.H_V
# | condenser.H_F
# | condenser.f_V
# | condenser.f_L
# | condenser.PR_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.energy_block.dH_F
# | condenser.energy_block.dH_V
# | condenser.energy_block.dH_L
# | condenser.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.VLE_block.n_ave
# | condenser.VLE_block.n_ave_cal
# | condenser.VLE_block.Hen
# | condenser.VLE_block.Hen0
# | condenser.VLE_block.gamma
# | condenser.VLE_block.P_sat
# | condenser.VLE_block.P_sat_Y
# | condenser.VLE_block.P_sat_dY_inf
# | condenser.VLE_block.P_sat_dY0
# | condenser.VLE_block.Hen_ref
# | condenser.VLE_block.Hen0_ref
# | condenser.VLE_block.gamma_ref
# | condenser.VLE_block.V_L
# | condenser.VLE_block.V_L_dY_inf
# | condenser.VLE_block.V_L_dY0
# | condenser.VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# ### Use the reactive sections vapor output as input to condenser

# %%
# in/out variables
model.condenser.x_.fix(0)
for i in m.COMP_TOTAL:
    model.condenser.y_['in',i].fix(model.reactive[model.TRAY.first()].y[i].value)
model.condenser.V['in'].fix(model.reactive[model.TRAY.first()].V['out'].value)
model.condenser.L['in'].fix(0)
model.condenser.V['P'].fix(0)
model.condenser.H_L_.fix(0)
model.condenser.H_V_.fix(model.reactive[model.TRAY.first()].H_V.value)

# operating parameters
model.condenser.P.fix(19)
model.condenser.T_F.fix(200+273.15)
model.condenser.F.fix(0)
model.condenser.z.fix(0)
model.condenser.VLE_block.n_ave.fix(4)
model.condenser.PR_L.fix(1)

model.condenser.T.setub(30+273.15)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = model.condenser.T, sense = pe.maximize)

delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 958
# Active Inequality Constraints:	 0
# Active Variables:		 1130
# Fixed Variables:		 171
# DOF:				 1

# %%
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     3146
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4089
#
# Total number of variables............................:      959
#                      variables with only lower bounds:      165
#                 variables with lower and upper bounds:      707
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      958
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -2.9315000e+02 1.45e+03 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1r-2.9315000e+02 1.45e+03 9.99e+02   3.0 0.00e+00    -  0.00e+00 3.70e-09R  7
#    2r-2.9315000e+02 1.45e+03 4.30e+06   3.0 2.00e+06    -  3.25e-10 2.77e-10f  1
#    3r-2.9315000e+02 1.45e+03 4.30e+06   3.0 1.65e+05    -  2.40e-08 8.90e-10f  1
#    4r-2.9315006e+02 1.45e+03 4.87e+06   3.0 1.43e+05    -  4.07e-08 5.79e-08f  1
#    5r-2.9315018e+02 1.45e+03 4.87e+06   3.0 1.43e+05    -  3.72e-07 1.25e-07f  1
#    6r-2.9315165e+02 1.45e+03 6.48e+06   3.0 1.43e+05    -  1.35e-07 1.54e-06f  1
#    7r-2.9315274e+02 1.45e+03 6.48e+06   3.0 1.43e+05    -  3.68e-06 1.15e-06f  1
#    8r-2.9316179e+02 1.45e+03 6.48e+06   3.0 1.43e+05    -  7.35e-06 9.86e-06f  1
#    9r-2.9318770e+02 1.44e+03 6.48e+06   3.0 1.43e+05    -  1.59e-04 3.07e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-2.9333927e+02 1.25e+03 6.48e+06   2.3 1.44e+05    -  6.88e-05 8.98e-04f  1
#   11 -2.9333951e+02 1.25e+03 7.98e+01  -6.0 8.65e+03    -  6.27e-06 1.22e-04h  1
#   12r-2.9333951e+02 1.25e+03 9.99e+02   2.9 0.00e+00    -  0.00e+00 5.84e-11R  2
#   13r-2.9333951e+02 1.25e+03 1.17e+03   2.9 2.84e+05    -  3.20e-05 7.65e-11f  2
#   14r-2.9545165e+02 5.96e+02 1.14e+03  -0.6 2.87e+05    -  2.51e-04 2.82e-03f  1
#   15r-2.9545165e+02 5.96e+02 9.99e+02   2.7 0.00e+00    -  0.00e+00 1.53e-07R  2
#   16r-2.9545165e+02 5.96e+02 1.07e+03   2.7 5.28e+04    -  4.69e-05 3.38e-11f  2
#   17r-2.9596064e+02 5.14e+02 1.24e+03  -0.1 2.91e+04    -  7.17e-03 1.84e-03f  1
#   18r-2.9594515e+02 5.12e+02 1.28e+03  -0.1 1.03e+04    -  3.31e-03 1.34e-03f  1
#   19r-2.9587776e+02 5.09e+02 1.23e+03  -0.8 8.26e+03    -  4.20e-04 2.49e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r-2.9594295e+02 5.08e+02 1.48e+03  -0.8 9.12e+02   0.0 1.17e-02 2.47e-03f  1
#   21r-2.9617665e+02 5.05e+02 1.46e+03  -0.8 4.10e+02   0.4 1.78e-02 1.76e-02f  1
#   22r-2.9632753e+02 5.04e+02 1.49e+03  -0.8 1.80e+02   0.9 2.91e-02 2.48e-02f  1
#   23r-2.9650203e+02 5.01e+02 1.61e+03  -0.8 4.03e+02   0.4 1.98e-02 1.44e-02f  1
#   24r-2.9650352e+02 5.01e+02 2.37e+03  -0.8 1.78e+02   0.8 3.47e-02 2.56e-04f  1
#   25r-2.9654401e+02 5.00e+02 4.38e+03  -0.8 4.55e+02   0.3 2.01e-02 3.79e-03f  1
#   26r-2.9669543e+02 4.98e+02 3.87e+04  -0.8 1.77e+02   0.7 1.55e-01 2.69e-02f  1
#   27r-2.9689913e+02 4.91e+02 3.76e+04  -0.8 5.03e+02   0.3 3.01e-02 3.03e-02f  1
#   28r-2.9691807e+02 4.90e+02 3.75e+04  -0.8 2.69e+04    -  6.49e-04 3.93e-04f  1
#   29r-2.9682013e+02 4.71e+02 3.73e+04  -0.8 6.43e+03    -  7.37e-03 7.60e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30r-2.9658378e+02 4.23e+02 3.62e+04  -0.8 2.41e+03    -  2.82e-02 1.98e-02f  1
#   31r-2.9658378e+02 4.23e+02 9.99e+02   2.6 0.00e+00    -  0.00e+00 1.02e-08R  2
#   32r-2.9658378e+02 4.23e+02 1.95e+03   2.6 6.85e+05    -  7.51e-06 8.75e-11f  3
#   33r-2.9648447e+02 4.11e+02 9.36e+03   0.5 4.35e+03    -  1.83e-02 2.84e-03f  1
#   34r-2.9644422e+02 4.30e+01 1.02e+04  -0.2 4.31e+04    -  3.01e-02 9.44e-03f  1
#   35 -2.9643398e+02 4.30e+01 8.88e+01  -6.0 9.27e+03    -  3.89e-07 4.18e-05h  1
#   36 -2.9647311e+02 4.30e+01 2.05e+05  -6.0 6.06e+04    -  1.48e-10 2.44e-05f  1
#   37 -2.9647687e+02 4.37e+01 4.36e+06  -6.0 2.99e+03    -  5.64e-06 4.93e-04h  1
#   38 -2.9649575e+02 4.37e+01 4.31e+06  -6.0 9.56e+02    -  1.27e-09 2.50e-03f  1
#   39r-2.9649575e+02 4.37e+01 9.99e+02   1.2 0.00e+00    -  0.00e+00 8.28e-09R  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r-2.9649575e+02 4.37e+01 1.29e+03   1.2 9.00e+04    -  3.30e-05 3.95e-09f  2
#   41r-2.9650889e+02 4.10e+01 3.95e+03   1.2 1.21e+04    -  6.82e-03 7.94e-05f  1
#   42r-2.9686041e+02 1.65e+01 4.02e+03  -0.9 2.95e+03    -  2.40e-02 5.60e-03f  1
#   43r-2.9763822e+02 1.65e+01 3.96e+03  -0.9 1.42e+03    -  2.43e-03 1.95e-02f  1
#   44r-2.9794324e+02 1.65e+01 3.88e+03  -0.9 8.02e+02    -  4.40e-03 1.38e-02f  1
#   45r-2.9843434e+02 1.65e+01 3.59e+03  -0.9 5.61e+02    -  3.74e-03 3.23e-02f  1
#   46r-2.9864001e+02 1.65e+01 3.19e+03  -0.9 2.33e+02    -  9.25e-03 3.33e-02f  1
#   47r-2.9870249e+02 7.04e+01 1.80e+03  -0.9 3.15e+02    -  5.91e-03 3.56e-02f  1
#   48r-2.9869676e+02 8.00e+01 1.72e+03  -0.9 2.18e+02    -  1.88e-02 4.35e-02f  1
#   49r-2.9864135e+02 7.69e+01 1.65e+03  -0.9 8.15e+01    -  2.53e-02 5.18e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50r-2.9855327e+02 7.26e+01 1.58e+03  -0.9 6.02e+01    -  1.17e-02 5.60e-02f  1
#   51r-2.9844029e+02 6.83e+01 1.66e+03  -0.9 7.20e+01    -  3.90e-03 6.00e-02f  1
#   52r-2.9830327e+02 6.39e+01 1.43e+03  -0.9 7.82e+01    -  1.02e-01 6.69e-02f  1
#   53r-2.9788953e+02 5.56e+01 1.21e+03  -0.9 9.67e+01    -  2.39e-01 1.63e-01f  1
#   54r-2.9704793e+02 5.99e+01 9.19e+02  -0.9 1.42e+02    -  1.67e-01 2.25e-01f  1
#   55r-2.9704269e+02 5.99e+01 9.19e+02  -0.9 7.13e+02    -  1.10e-03 2.78e-04f  1
#   56r-2.9679142e+02 5.61e+01 8.54e+02  -0.9 1.54e+02    -  2.59e-02 6.19e-02f  1
#   57r-2.9677589e+02 5.60e+01 8.52e+02  -0.9 2.43e+02    -  1.23e-02 2.42e-03f  1
#   58r-2.9651050e+02 5.31e+01 8.61e+02  -0.9 1.91e+02    -  1.09e-01 5.26e-02f  1
#   59r-2.9580693e+02 4.67e+01 2.67e+03  -0.9 2.18e+02    -  3.14e-01 1.22e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r-2.9382234e+02 3.57e+01 5.69e+02  -0.9 3.06e+02    -  4.40e-02 2.44e-01f  1
#   61r-2.9360217e+02 3.45e+01 1.30e+03  -0.9 2.45e+02    -  4.47e-01 3.33e-02f  1
#   62r-2.9315452e+02 2.71e+01 1.48e+03  -0.9 7.66e+01    -  7.13e-01 2.15e-01f  1
#   63r-2.9315719e+02 2.04e+01 1.12e+03  -0.9 4.00e+00    -  9.90e-01 2.46e-01f  1
#   64r-2.9316104e+02 1.62e+01 1.81e+02  -0.9 4.89e+00    -  1.00e+00 9.21e-01f  1
#   65r-2.9315424e+02 1.62e+01 1.48e+02  -1.6 9.71e-01    -  9.01e-01 6.98e-01f  1
#   66r-2.9315191e+02 1.60e+01 1.20e+03  -2.3 2.55e+01    -  1.23e-01 4.24e-01f  1
#   67r-2.9315190e+02 1.60e+01 3.68e+02  -2.3 8.31e+01    -  1.48e-01 4.47e-03f  1
#   68r-2.9315184e+02 1.59e+01 4.88e+02  -2.3 8.27e+01    -  1.89e-03 4.11e-02f  1
#   69r-2.9315183e+02 1.59e+01 9.89e+02  -2.3 7.93e+01    -  3.16e-01 3.60e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70r-2.9315142e+02 1.56e+01 8.97e+02  -2.3 7.90e+01    -  2.23e-01 1.93e-01f  1
#   71r-2.9315142e+02 1.56e+01 9.99e+02   1.2 0.00e+00    -  0.00e+00 4.71e-07R  2
#   72r-2.9315142e+02 1.56e+01 9.99e+02   1.2 4.24e+04    -  1.90e-05 7.34e-09f  2
#   73r-2.9315178e+02 1.56e+01 9.99e+02   1.2 1.29e+04    -  1.22e-04 2.38e-05f  1
#   74r-2.9316568e+02 1.56e+01 1.26e+03   0.5 1.02e+03    -  1.17e-03 4.53e-03f  1
#   75r-2.9317530e+02 1.56e+01 2.82e+03   0.5 5.66e+02    -  1.66e-01 3.09e-03f  1
#   76r-2.9315025e+02 1.56e+01 3.85e+03  -1.6 4.27e+01    -  4.21e-01 5.04e-02f  1
#   77r-2.9315133e+02 1.32e+01 2.25e+03  -1.6 4.66e+02    -  1.00e-01 2.95e-01f  1
#   78 -2.9315132e+02 1.32e+01 4.93e+01  -6.0 2.12e+03    -  5.11e-05 2.91e-04h  1
#   79 -2.9333722e+02 1.31e+01 2.04e+07  -6.0 6.64e+03    -  3.16e-09 7.52e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -3.0314999e+02 1.26e+01 1.86e+07  -6.0 1.04e+04    -  3.15e-08 3.51e-02f  1
#   81 -3.0315000e+02 1.26e+01 1.86e+07  -6.0 7.25e+02    -  5.53e-02 1.34e-04h  1
#   82 -3.0315000e+02 1.22e+01 2.13e+07  -6.0 7.25e+02    -  5.59e-02 3.15e-02h  1
#   83r-3.0315000e+02 1.22e+01 9.99e+02   1.1 0.00e+00    -  0.00e+00 4.34e-08R  2
#   84r-3.0315000e+02 1.22e+01 9.99e+02   1.1 9.91e+03    -  1.15e-04 1.14e-07f  1
#   85r-3.0315000e+02 1.22e+01 2.96e+03   1.1 9.00e+03    -  1.56e-02 2.20e-04f  1
#   86r-3.0315000e+02 1.22e+01 3.25e+03  -1.0 5.48e+02    -  4.92e-02 1.64e-02f  1
#   87r-3.0314999e+02 1.11e+01 3.08e+03  -1.0 9.85e+02    -  6.84e-02 6.43e-02f  1
#   88r-3.0314997e+02 9.05e+00 2.50e+03  -1.0 9.46e+02    -  1.07e-01 1.25e-01f  1
#   89 -3.0314997e+02 8.26e+00 7.24e+02  -6.0 5.19e+02    -  9.80e-04 8.69e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90 -3.0314997e+02 6.17e+00 8.17e+03  -6.0 4.74e+02    -  6.50e-03 6.11e-01h  1
#   91 -3.0314997e+02 9.66e-01 6.09e+05  -6.0 1.85e+02    -  1.79e-06 7.34e-01h  1
#   92 -3.0314997e+02 1.60e-02 4.18e+04  -6.0 4.90e+01    -  1.07e-02 1.00e+00h  1
#   93 -3.0314997e+02 8.95e-07 3.50e+01  -6.0 4.58e-02    -  9.95e-01 1.00e+00h  1
#   94 -3.0314998e+02 7.97e-12 7.46e-05  -6.0 2.54e-04    -  1.00e+00 1.00e+00h  1
#   95 -3.0315000e+02 1.16e-10 4.50e-09  -6.0 9.91e-04    -  1.00e+00 1.00e+00f  1
#   96 -3.0315000e+02 1.35e-11 9.05e-07  -9.0 3.94e-05    -  1.00e+00 1.00e+00h  1
#   97 -3.0315000e+02 9.94e-11 1.00e-14  -9.0 4.14e-10    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 97
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.0315000303049999e+02   -3.0315000303049999e+02
# Dual infeasibility......:   1.0019762797242038e-14    1.0019762797242038e-14
# Constraint violation....:   9.9373484809851809e-11    9.9373484809851809e-11
# Complementarity.........:   1.0000000000037811e-09    1.0000000000037811e-09
# Overall NLP error.......:   1.0000000000037811e-09    1.0000000000037811e-09
#
#
# Number of objective function evaluations             = 128
# Number of objective gradient evaluations             = 34
# Number of equality constraint evaluations            = 128
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 105
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 97
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.120
# Total CPU secs in NLP function evaluations           =      0.073
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# # Construct a single reboiler and Initialize

# %% [markdown]
# ### Deactivate the condenser part first

# %%
model.condenser.deactivate()
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 0
# Active Inequality Constraints:	 0
# Active Variables:		 0
# Fixed Variables:		 0
# DOF:				 0

# %%
model.reboiler = pe.Block(rule=reboiler_stage_rule)
# Out:
# > Importing Non Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reboiler.T_F
# | reboiler.P
# | reboiler.Q_main
# | reboiler.x_
# | reboiler.y_
# | reboiler.x
# | reboiler.y
# | reboiler.z
# | reboiler.L
# | reboiler.V
# | reboiler.F
# | reboiler.H_L_
# | reboiler.H_V_
# | reboiler.H_L
# | reboiler.H_V
# | reboiler.T
# | reboiler.H_F
# | reboiler.f_V
# | reboiler.f_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.energy_block.dH_F
# | reboiler.energy_block.dH_V
# | reboiler.energy_block.dH_L
# | reboiler.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.VLE_block.P_VLE
# | reboiler.VLE_block.n_ave
# | reboiler.VLE_block.n_ave_cal
# | reboiler.VLE_block.Hen
# | reboiler.VLE_block.Hen0
# | reboiler.VLE_block.gamma
# | reboiler.VLE_block.P_sat
# | reboiler.VLE_block.P_sat_Y
# | reboiler.VLE_block.P_sat_dY_inf
# | reboiler.VLE_block.P_sat_dY0
# | reboiler.VLE_block.Hen_ref
# | reboiler.VLE_block.Hen0_ref
# | reboiler.VLE_block.gamma_ref
# | reboiler.VLE_block.V_L
# | reboiler.VLE_block.V_L_dY_inf
# | reboiler.VLE_block.V_L_dY0
# | reboiler.VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.MPCC.s_L
# | reboiler.MPCC.s_V
# | reboiler.MPCC.pf
# | reboiler.MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE

# %% [markdown]
# ### Use the reactive sections liquid output as input to reboiler

# %%
# in/out variables
model.reboiler.y_.fix(0)
for i in m.COMP_TOTAL:
    model.reboiler.x_['in',i].fix(model.reactive[model.TRAY.last()].x[i].value)
model.reboiler.L['in'].fix(model.reactive[model.TRAY.last()].L['out'].value)
model.reboiler.V['in'].fix(0)
model.reboiler.L['P'].fix(0)
model.reboiler.V['P'].fix(0)
model.reboiler.H_L_.fix(model.reactive[model.TRAY.last()].H_L.value)
model.reboiler.H_V_.fix(0)

# operating parameters
model.reboiler.P.fix(20)
model.reboiler.T_F.fix(200+273.15)
model.reboiler.F.fix(0)
model.reboiler.z.fix(0)
model.reboiler.VLE_block.n_ave.fix(20)

model.reboiler.T.setub(model.reactive[model.TRAY.last()].T.value)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = model.reboiler.T - model.reboiler.MPCC.pf, sense = pe.maximize)

delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 957
# Active Inequality Constraints:	 1
# Active Variables:		 1132
# Fixed Variables:		 171
# DOF:				 4

# %%
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     3224
# Number of nonzeros in inequality constraint Jacobian.:        5
# Number of nonzeros in Lagrangian Hessian.............:     4317
#
# Total number of variables............................:      961
#                      variables with only lower bounds:      167
#                 variables with lower and upper bounds:      786
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      957
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        1
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.7315000e+02 9.36e+03 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
# In iteration 0, 6 Slacks too small, adjusting variable bounds
#    1 -4.7315000e+02 9.36e+03 2.17e+02  -6.0 2.81e+04    -  6.75e-12 1.47e-09f  1
#    2r-4.7315000e+02 9.36e+03 9.99e+02   3.9 0.00e+00    -  0.00e+00 1.15e-10R  4
#    3r-4.7315000e+02 9.36e+03 1.35e+04   3.9 6.15e+09    -  2.47e-15 2.33e-09f  1
#    4r-4.7314997e+02 9.36e+03 1.34e+04   2.5 1.65e+04   2.0 5.18e-07 9.15e-08f  1
#    5r-4.7314962e+02 9.36e+03 1.34e+04   2.5 9.13e+03   2.4 1.62e-06 1.25e-06f  1
#    6r-4.7314905e+02 9.36e+03 1.34e+04   2.5 8.90e+02   2.9 2.93e-05 2.95e-06f  1
#    7r-4.7314279e+02 9.36e+03 1.34e+04   2.5 4.10e+02   2.4 1.36e-04 1.39e-04f  1
#    8r-4.7313537e+02 9.36e+03 8.43e+04   2.5 1.05e+02   2.8 1.04e-02 3.10e-04f  1
#    9r-4.7309937e+02 9.36e+03 1.06e+05   2.5 1.50e+01   2.3 7.17e-02 2.26e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-4.7308387e+02 5.13e+02 1.01e+05   2.5 9.42e+05    -  4.66e-02 9.85e-03f  1
#   11 -4.7308233e+02 5.13e+02 1.28e+01  -6.0 4.41e+03    -  5.55e-04 4.35e-05h  1
# In iteration 11, 1 Slack too small, adjusting variable bound
#   12 -4.7308237e+02 5.13e+02 8.63e+00  -6.0 6.42e+02    -  4.98e-04 7.01e-04h  1
#   13 -4.7308253e+02 5.12e+02 3.55e+00  -6.0 6.40e+02    -  1.20e-03 2.29e-03h  1
#   14r-4.7308253e+02 5.12e+02 9.99e+02   2.7 0.00e+00    -  0.00e+00 1.21e-09R  2
#   15r-4.7308207e+02 5.12e+02 2.43e+03   2.7 5.21e+04    -  6.33e-04 1.41e-06f  1
#   16r-4.7303399e+02 5.12e+02 1.49e+03   2.0 3.03e+04    -  7.14e-04 1.99e-03f  1
#   17r-4.7291883e+02 5.11e+02 1.86e+03   2.0 2.53e+04    -  6.66e-04 5.08e-03f  1
#   18r-4.7286704e+02 5.10e+02 2.25e+03   2.0 4.14e+03    -  2.90e-03 3.90e-03f  1
#   19r-4.7290377e+02 5.08e+02 4.02e+03   2.0 1.94e+03    -  4.57e-03 7.84e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r-4.7447411e+02 5.05e+02 6.59e+03   2.0 1.46e+04    -  8.43e-03 1.50e-02f  1
#   21r-4.7509004e+02 4.99e+02 2.62e+04   2.0 4.73e+03    -  1.35e-01 2.70e-02f  1
#   22r-4.7440636e+02 4.71e+02 1.85e+04   2.0 1.29e+03    -  8.74e-02 1.43e-01f  1
#   23r-4.7446340e+02 4.70e+02 1.48e+04   2.0 8.67e+00   2.0 3.41e-01 3.19e-01f  1
#   24r-4.7614452e+02 4.66e+02 1.10e+04   1.3 2.91e+01   1.5 2.00e-01 3.15e-01f  1
#   25r-4.7631259e+02 4.64e+02 1.03e+04   1.3 8.95e+01   1.0 3.00e-01 4.99e-02f  1
#   26r-4.7618091e+02 4.61e+02 1.02e+04   1.3 6.84e+02    -  4.53e-03 8.42e-03f  1
#   27 -4.7611797e+02 4.54e+02 1.32e+00  -6.0 7.44e+02    -  6.27e-03 1.43e-02h  1
#   28 -4.7474945e+02 3.01e+02 1.28e+02  -6.0 5.84e+02    -  3.46e-02 3.38e-01h  1
#   29 -4.7474949e+02 3.01e+02 1.05e+03  -6.0 7.63e+02    -  1.52e-01 6.40e-06h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30 -4.7973811e+02 1.95e+02 7.63e+02  -6.0 1.60e+03    -  1.85e-01 3.52e-01h  1
#   31 -4.7973356e+02 1.52e+02 2.07e+02  -6.0 1.95e+02    -  3.67e-01 2.18e-01h  1
#   32r-4.7973356e+02 1.52e+02 1.00e+03   2.2 0.00e+00    -  0.00e+00 1.81e-07R  2
#   33r-4.7973270e+02 1.52e+02 3.58e+03   2.2 2.45e+04    -  2.59e-03 3.66e-06f  1
#   34r-4.7972024e+02 1.10e+01 6.73e+03   1.5 2.30e+04    -  1.47e-01 6.55e-03f  1
#   35 -4.7808505e+02 9.15e+00 2.23e+01  -6.0 7.11e+02    -  1.67e-01 2.93e-01h  1
#   36 -4.7243851e+02 1.96e+01 9.72e+03  -6.0 1.26e+03    -  8.29e-05 5.74e-01h  1
#   37 -4.7276034e+02 1.54e+01 3.92e+03  -6.0 1.17e+02    -  6.83e-02 5.97e-01h  1
#   38 -4.7298043e+02 8.49e+00 1.36e+03  -6.0 1.13e+02    -  3.56e-01 6.53e-01h  1
#   39 -4.7314247e+02 4.09e+00 3.09e+02  -6.0 1.12e+02    -  2.60e-01 9.54e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 -4.7313804e+02 3.62e+00 4.38e+02  -6.0 5.25e+01    -  1.79e-04 1.15e-01h  1
#   41 -4.7309475e+02 4.68e-01 1.36e+02  -6.0 4.40e+01    -  5.95e-02 9.10e-01h  1
#   42 -4.7311758e+02 5.06e-02 2.50e+01  -6.0 1.08e+01    -  2.26e-01 9.08e-01h  1
#   43 -4.7452220e+02 7.04e-01 1.75e+05  -6.0 1.71e+02    -  9.29e-01 1.00e+00f  1
#   44 -4.8400002e+02 3.28e+01 8.96e+05  -6.0 2.11e+03    -  7.55e-02 5.51e-01f  1
#   45 -4.9312882e+02 5.15e+01 1.32e+06  -6.0 3.13e+03    -  1.29e-03 3.82e-01f  1
#   46 -4.9312928e+02 4.96e+01 2.83e+05  -6.0 5.15e+01    -  6.54e-01 3.79e-02h  1
#   47 -4.9314743e+02 9.63e-02 5.51e+05  -6.0 4.96e+01    -  3.86e-02 1.00e+00h  1
#   48 -4.9314760e+02 2.76e-02 5.38e+04  -6.0 6.05e+00    -  8.84e-01 1.00e+00h  1
#   49 -4.9314973e+02 2.22e-02 4.20e+03  -6.0 5.09e+00    -  9.45e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -4.9314997e+02 8.07e-03 9.88e-01  -6.0 3.11e+00    -  1.00e+00 1.00e+00h  1
#   51 -4.9314999e+02 2.16e-03 4.21e-01  -6.0 1.60e+00    -  1.00e+00 1.00e+00h  1
#   52 -4.9315000e+02 5.23e-04 1.25e-02  -6.0 7.86e-01    -  1.00e+00 1.00e+00h  1
#   53 -4.9315000e+02 1.42e-04 6.00e-03  -6.0 4.10e-01    -  1.00e+00 1.00e+00h  1
#   54 -4.9315000e+02 2.98e-05 2.30e-03  -6.0 1.88e-01    -  1.00e+00 1.00e+00h  1
#   55 -4.9315000e+02 3.71e-06 1.73e-04  -6.0 6.62e-02    -  1.00e+00 1.00e+00h  1
#   56 -4.9315000e+02 5.59e-08 6.92e-07  -6.0 8.13e-03    -  1.00e+00 1.00e+00h  1
#   57 -4.9315000e+02 1.40e-05 5.38e-01  -9.0 1.30e-01    -  9.98e-01 9.93e-01h  1
#   58 -4.9315000e+02 3.21e-06 3.74e-04  -9.0 6.16e-02    -  1.00e+00 1.00e+00h  1
#   59 -4.9315000e+02 7.81e-07 7.12e-05  -9.0 3.04e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -4.9315000e+02 1.82e-07 7.00e-05  -9.0 1.47e-02    -  1.00e+00 1.00e+00h  1
#   61 -4.9315000e+02 3.76e-08 3.30e-05  -9.0 6.66e-03    -  1.00e+00 1.00e+00h  1
#   62 -4.9315000e+02 4.33e-09 3.43e-06  -9.0 2.26e-03    -  1.00e+00 1.00e+00h  1
#   63 -4.9315000e+02 7.70e-11 2.70e-09  -9.0 3.02e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 63
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.9315000493737705e+02   -4.9315000493737705e+02
# Dual infeasibility......:   2.6970247365715877e-09    2.6970247365715877e-09
# Constraint violation....:   7.6985529062767455e-11    7.6985529062767455e-11
# Complementarity.........:   1.0012777009253446e-09    1.0012777009253446e-09
# Overall NLP error.......:   2.6970247365715877e-09    2.6970247365715877e-09
#
#
# Number of objective function evaluations             = 72
# Number of objective gradient evaluations             = 45
# Number of equality constraint evaluations            = 72
# Number of inequality constraint evaluations          = 73
# Number of equality constraint Jacobian evaluations   = 67
# Number of inequality constraint Jacobian evaluations = 67
# Number of Lagrangian Hessian evaluations             = 63
# Total CPU secs in IPOPT (w/o function evaluations)   =      2.466
# Total CPU secs in NLP function evaluations           =      0.127
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# # Initialization is complete

# %%
beautify(pe,model)
# Out:
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		W
# Condenser	30.00		-269.90		5.09673		0.00000		0.27643		4.17908
#
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		9.55224		0.00642		0.00000		20.00001
# Reactive[2]	220.00		-43.29		9.07463		0.01285		0.00000		20.00000
# Reactive[3]	220.00		-43.29		8.59702		0.01927		0.00000		20.00000
# Reactive[4]	220.00		-43.29		8.11941		0.02570		0.00000		20.00000
# Reactive[5]	220.00		-43.29		7.64180		0.03212		0.00000		20.00000
# Reactive[6]	220.00		-43.29		7.16418		0.03854		0.00000		20.00000
# Reactive[7]	220.00		-43.29		6.68657		0.04497		0.00000		20.00000
# Reactive[8]	220.00		-43.29		6.20896		0.05139		0.00000		20.00000
# Reactive[9]	220.00		-43.29		5.73135		0.05781		0.00000		20.00000
# Reactive[10]	220.00		-43.29		5.25373		0.06424		0.00000		20.00000
# Reactive[11]	220.00		-43.29		4.77612		0.07066		0.00000		20.00000
# Reactive[12]	220.00		-43.29		4.29851		0.07709		0.00000		20.00000
# Reactive[13]	220.00		-43.29		3.82090		0.08351		0.00000		20.00000
# Reactive[14]	220.00		-43.29		3.34329		0.08993		0.00000		20.00000
# Reactive[15]	220.00		-43.29		2.86567		0.09636		0.00000		20.00000
# Reactive[16]	220.00		-43.29		2.38806		0.10278		0.00000		20.00000
# Reactive[17]	220.00		-43.29		1.91045		0.10920		0.00000		20.00000
# Reactive[18]	220.00		-43.29		1.43284		0.11563		0.00000		20.00000
# Reactive[19]	220.00		-43.29		0.95522		0.12205		0.00000		20.00000
# Reactive[20]	220.00		-43.29		0.47761		0.12848		0.00000		20.00000
# Reboiler	220.00		0.00		0.00000		0.12847				19.99833
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Linking Condenser and Reboiler

# %% [markdown]
# ### Activate previously disabled constraint and variables

# %%
for i in model.block_data_objects():
    if i.name != 'reactive_distillation':
        i.activate()
for i in model.component_objects(pe.Constraint):
    i.activate()

# %% [markdown]
# ### Condenser Vapor

# %%
def V_condenser_rule(model):
    return model.reactive[model.TRAY.first()].V['out'] == model.condenser.V['in']
model.V_condenser_con = pe.Constraint(rule=V_condenser_rule)

def Vy_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].y[i] == model.condenser.y_['in',i]
model.Vy_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_condenser_rule)

def Vh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_V == model.condenser.H_V_['in']
model.Vh_condenser_con = pe.Constraint(rule=Vh_condenser_rule)

# %% [markdown]
# ### Condenser Liquid

# %%
def L_condenser_rule(model):
    return model.reactive[model.TRAY.first()].L['in'] == model.condenser.L['out']
model.L_condenser_con = pe.Constraint(rule=L_condenser_rule)

def Lx_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].x_['in',i] == model.condenser.x[i]
model.Lx_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_condenser_rule)

def Lh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_L_['in'] == model.condenser.H_L
model.Lh_condenser_con = pe.Constraint(rule=Lh_condenser_rule)

# %% [markdown]
# ### Reboiler Vapor

# %%
def V_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].V['in'] == model.reboiler.V['out']
model.V_reboiler_con = pe.Constraint(rule=V_reboiler_rule)

def Vy_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].y_['in',i] == model.reboiler.y[i]
model.Vy_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_reboiler_rule)

def Vh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_V_['in'] == model.reboiler.H_V
model.Vh_reboiler_con = pe.Constraint(rule=Vh_reboiler_rule)

# %% [markdown]
# ### Reboiler Liquid

# %%
def L_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].L['out'] + 1e-6 == model.reboiler.L['in']
model.L_reboiler_con = pe.Constraint(rule=L_reboiler_rule)

def Lx_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].x[i] == model.reboiler.x_['in',i]
model.Lx_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_reboiler_rule)

def Lh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_L == model.reboiler.H_L_['in']
model.Lh_reboiler_con = pe.Constraint(rule=Lh_reboiler_rule)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.reactive)\
                         - model.reboiler.MPCC.pf ,sense=pe.maximize)

# %%
delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# # Fixing Redundent Stream Variables

# %% [markdown]
# ### Condenser

# %%
# in/out variables
model.condenser.x_.fix(0)
for i in m.COMP_TOTAL:
    model.condenser.y_['in',i].unfix()
model.condenser.V['in'].unfix()
model.condenser.L['in'].fix(0)
model.condenser.V['P'].fix(0)
model.condenser.H_L_.fix(0)
model.condenser.H_V_.unfix()

# operating parameters
model.condenser.P.fix(19)
model.condenser.T_F.fix(200+273.15)
model.condenser.F.fix(0)
model.condenser.z.fix(0)
model.condenser.VLE_block.n_ave.fix(4)
model.condenser.PR_L.fix(1)

model.condenser.T.fix(30+273.15)

# %% [markdown]
# ### Reboiler

# %%
# in/out variables
model.reboiler.y_.fix(0)
for i in m.COMP_TOTAL:
    model.reboiler.x_['in',i].unfix()
model.reboiler.L['in'].unfix()
model.reboiler.V['in'].fix(0)
model.reboiler.L['P'].fix(0)
model.reboiler.V['P'].fix(0)
model.reboiler.H_L_.unfix()
model.reboiler.H_V_.fix(0)

# operating parameters
model.reboiler.P.fix(20)
model.reboiler.T_F.fix(200+273.15)
model.reboiler.F.fix(0)
model.reboiler.z.fix(0)
model.reboiler.VLE_block.n_ave.fix(20)

model.reboiler.T.fix(model.reactive[model.TRAY.last()].T.value)

# %% [markdown]
# ### Reactive

# %%
# unlock reflux and reboiler vapor
for j in model.reactive:
    model.reactive[j].x_.unfix()
    model.reactive[j].H_L_.unfix()
    model.reactive[j].L['in'].unfix()
    model.reactive[j].y_.unfix()
    model.reactive[j].V['in'].unfix()
    model.reactive[j].H_V_.unfix()

for j in model.reactive:
    model.reactive[j].cat.fix(3000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
    model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
    model.reactive[j].z['C30H62'].fix(0)
    
    model.reactive[j].PR_L.fix(0)
    model.reactive[j].PR_V.fix(0)
    
    # model.reactive[j].Q_main.fix(0)
    model.reactive[j].T.setub(220+273.15)
    model.reactive[j].T.setlb(200+273.15)

# %% [markdown]
# # Connected Solve

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 28997
# Active Inequality Constraints:	 21
# Active Variables:		 29462
# Fixed Variables:		 382
# DOF:				 83

# %%
# %%time

results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:   102942
# Number of nonzeros in inequality constraint Jacobian.:      145
# Number of nonzeros in Lagrangian Hessian.............:   102746
#
# Total number of variables............................:    29080
#                      variables with only lower bounds:    11234
#                 variables with lower and upper bounds:    14309
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    28997
# Total number of inequality constraints...............:       21
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       21
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -9.8630000e+03 2.03e+02 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -9.8630000e+03 2.03e+02 3.27e+02  -6.0 2.03e+02    -  2.26e-08 7.39e-06h  1
#    2 -9.8630000e+03 2.03e+02 3.27e+02  -6.0 2.03e+02    -  7.47e-06 1.90e-03h  1
#    3 -9.8630001e+03 1.75e-01 5.36e+02  -6.0 2.03e+02    -  1.89e-03 9.99e-01f  1
#    4 -9.8630001e+03 1.75e-01 5.36e+02  -6.0 1.74e-01    -  1.00e-02 1.05e-03h  1
#    5 -9.8630001e+03 1.35e-01 4.16e+02  -6.0 1.75e-01    -  9.97e-01 2.26e-01h  1
#    6 -9.8630000e+03 8.88e-02 2.72e+02  -6.0 1.35e-01    -  6.66e-01 3.43e-01h  1
#    7 -9.8630000e+03 1.04e-02 3.10e+01  -6.0 8.87e-02    -  3.52e-01 8.82e-01h  1
#    8 -9.8630000e+03 1.46e-03 4.48e+00  -6.0 2.87e-02    -  7.16e-01 8.60e-01f  1
#    9 -9.8630000e+03 3.89e-06 2.83e-01  -6.0 6.89e-02    -  4.42e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -9.8630000e+03 8.15e-06 3.66e-02  -6.0 9.82e-02    -  8.43e-01 1.00e+00h  1
#   11 -9.8630000e+03 1.29e-05 2.23e-03  -6.0 1.23e-01    -  9.93e-01 1.00e+00h  1
#   12 -9.8630000e+03 1.59e-07 2.39e-05  -6.0 1.37e-02    -  1.00e+00 1.00e+00h  1
#   13 -9.8630000e+03 6.96e-11 2.53e-08  -6.0 2.87e-04    -  1.00e+00 1.00e+00h  1
# Scaling factors are invalid - setting them all to 1.
#   14 -9.8630001e+03 2.15e-05 1.63e+00  -9.0 1.62e-01    -  9.97e-01 9.82e-01f  1
#   15 -9.8630001e+03 1.40e-05 2.90e+00  -9.0 7.50e-02    -  1.00e+00 3.82e-01h  1
#   16 -9.8630001e+03 6.36e-06 1.81e+00  -9.0 6.19e-02    -  1.00e+00 6.40e-01f  1
#   17 -9.8630001e+03 2.42e-06 4.44e-01  -9.0 4.20e-02    -  1.00e+00 7.52e-01f  1
#   18 -9.8630001e+03 5.78e-07 5.09e-04  -9.0 2.61e-02    -  1.00e+00 1.00e+00f  1
#   19 -9.8630001e+03 1.31e-07 1.59e-04  -9.0 1.24e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -9.8630001e+03 7.22e-09 1.03e-04  -9.0 2.92e-03    -  1.00e+00 1.00e+00h  1
#   21 -9.8630001e+03 6.61e-11 3.42e-08  -9.0 2.80e-04    -  1.00e+00 1.00e+00h  1
#   22 -9.8630001e+03 4.55e-13 1.44e-10  -9.0 4.76e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 22
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -9.8630000987940930e+03   -9.8630000987940930e+03
# Dual infeasibility......:   1.4392620743212264e-10    1.4392620743212264e-10
# Constraint violation....:   2.2737367544323206e-13    4.5474735088646412e-13
# Complementarity.........:   1.0000003519792283e-09    1.0000003519792283e-09
# Overall NLP error.......:   1.0000003519792283e-09    1.0000003519792283e-09
#
#
# Number of objective function evaluations             = 23
# Number of objective gradient evaluations             = 23
# Number of equality constraint evaluations            = 23
# Number of inequality constraint evaluations          = 23
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 23
# Number of Lagrangian Hessian evaluations             = 22
# Total CPU secs in IPOPT (w/o function evaluations)   =     56.551
# Total CPU secs in NLP function evaluations           =      1.741
#
# EXIT: Optimal Solution Found.
# CPU times: user 3.69 s, sys: 107 ms, total: 3.79 s
# Wall time: 24.1 s

# %%
beautify(pe,model)
# Out:
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		W
# Condenser	30.00		-269.90		5.09673		0.00000		0.27643		4.17908
#
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	220.00		-43.29		9.55225		0.00642		0.00000		20.00001
# Reactive[2]	220.00		-43.29		9.07463		0.01285		0.00000		20.00000
# Reactive[3]	220.00		-43.29		8.59702		0.01927		0.00000		20.00000
# Reactive[4]	220.00		-43.29		8.11941		0.02570		0.00000		20.00000
# Reactive[5]	220.00		-43.29		7.64180		0.03212		0.00000		20.00000
# Reactive[6]	220.00		-43.29		7.16418		0.03854		0.00000		20.00000
# Reactive[7]	220.00		-43.29		6.68657		0.04497		0.00000		20.00000
# Reactive[8]	220.00		-43.29		6.20896		0.05139		0.00000		20.00000
# Reactive[9]	220.00		-43.29		5.73135		0.05781		0.00000		20.00000
# Reactive[10]	220.00		-43.29		5.25374		0.06424		0.00000		20.00000
# Reactive[11]	220.00		-43.29		4.77612		0.07066		0.00000		20.00000
# Reactive[12]	220.00		-43.29		4.29851		0.07709		0.00000		20.00000
# Reactive[13]	220.00		-43.29		3.82090		0.08351		0.00000		20.00000
# Reactive[14]	220.00		-43.29		3.34329		0.08993		0.00000		20.00000
# Reactive[15]	220.00		-43.29		2.86567		0.09636		0.00000		20.00000
# Reactive[16]	220.00		-43.29		2.38806		0.10278		0.00000		20.00000
# Reactive[17]	220.00		-43.29		1.91045		0.10920		0.00000		20.00000
# Reactive[18]	220.00		-43.29		1.43284		0.11563		0.00000		20.00000
# Reactive[19]	220.00		-43.29		0.95523		0.12205		0.00000		20.00000
# Reactive[20]	220.00		-43.29		0.47761		0.12848		0.00000		20.00000
# Reboiler	220.00		0.00		0.00000		0.12848				19.99801
# ------------------------------------------------------------------------------------------------------------
