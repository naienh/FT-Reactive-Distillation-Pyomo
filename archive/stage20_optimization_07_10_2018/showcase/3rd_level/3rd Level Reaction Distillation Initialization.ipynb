# %% [markdown]
# # 3rd Level Model Structure: Initialize Procedure (20+ stages)

# %%
# system imports
import sys
import os
import datetime
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../..'))

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

import ipywidgets as widgets
from IPython.display import display, clear_output

import pickle
import dill
from copy import deepcopy

# %%
# pyomo imports
from pyomo import environ as pe
from global_sets.component import m

from stages.reactive_stage import reactive_stage_rule
from stages.condenser_stage import condenser_stage_rule
from stages.reboiler_stage import reboiler_stage_rule

from utility.display_utility import trans_product_mole, trans_product_mass, beautify, beautify_reactive, HiddenLogs, plot_distribution
from utility.model_utility import add_dual, update_dual, delete_dual, check_DOF, check_violate_constraint
from utility.data_utility import cal_cnumber

# %%
model = pe.ConcreteModel(name='reactive_distillation')

# %%
logname = datetime.datetime.now().strftime('%Y%m%d_%Hh%Mm%Ss')
log_text_dir = './log/text/'+logname+'.dat'
log_figure_dir = './log/figure/'+logname+'.pdf'

# %% [markdown]
# # Model Input

# %%
tray_number = 10
non_reactive_flag = [1,2,3,4,10]
# non_reactive_flag = []
side_draw_flag = {4:0.2,7:0.7}
# default temperature is 
temperature_flag = {6:240,7:240,8:245,9:250}
rr_ratio = 0.05

# %% [markdown]
# # Global Set

# %%
model.TRAY = pe.RangeSet(1,tray_number)
model.TRAY_nonreactive = pe.Set(initialize=non_reactive_flag)
model.TRAY_reactive = model.TRAY - model.TRAY_nonreactive

# %% [markdown]
# # Construct reactive stages and Initialization separately

# %%
model.reactive = pe.Block(model.TRAY,rule=reactive_stage_rule)
add_dual(pe,model)
# Out:
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[1].x_
# | reactive[1].y_
# | reactive[1].x
# | reactive[1].y
# | reactive[1].z
# | reactive[1].L
# | reactive[1].V
# | reactive[1].F
# | reactive[1].H_L_
# | reactive[1].H_V_
# | reactive[1].H_L
# | reactive[1].H_V
# | reactive[1].H_F
# | reactive[1].T
# | reactive[1].T_F
# | reactive[1].P
# | reactive[1].f_V
# | reactive[1].f_L
# | reactive[1].cat
# | reactive[1].Q_main
# | reactive[1].r_total_comp
# | reactive[1].PR_L
# | reactive[1].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].kinetics_block.k_FT
# | reactive[1].kinetics_block.r_FT_total
# | reactive[1].kinetics_block.g0_FT
# | reactive[1].kinetics_block.alpha
# | reactive[1].kinetics_block.r_FT_cnum
# | reactive[1].kinetics_block.r_FT_comp
# | reactive[1].kinetics_block.k_WGS
# | reactive[1].kinetics_block.Ke_WGS
# | reactive[1].kinetics_block.r_WGS
# | reactive[1].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].energy_block.dH_F
# | reactive[1].energy_block.dH_V
# | reactive[1].energy_block.dH_L
# | reactive[1].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].VLE_block.P_VLE
# | reactive[1].VLE_block.n_ave
# | reactive[1].VLE_block.n_ave_cal
# | reactive[1].VLE_block.Hen
# | reactive[1].VLE_block.Hen0
# | reactive[1].VLE_block.gamma
# | reactive[1].VLE_block.P_sat
# | reactive[1].VLE_block.P_sat_Y
# | reactive[1].VLE_block.P_sat_dY_inf
# | reactive[1].VLE_block.P_sat_dY0
# | reactive[1].VLE_block.Hen_ref
# | reactive[1].VLE_block.Hen0_ref
# | reactive[1].VLE_block.gamma_ref
# | reactive[1].VLE_block.V_L
# | reactive[1].VLE_block.V_L_dY_inf
# | reactive[1].VLE_block.V_L_dY0
# | reactive[1].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].MPCC.s_L
# | reactive[1].MPCC.s_V
# | reactive[1].MPCC.pf
# | reactive[1].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[2].x_
# | reactive[2].y_
# | reactive[2].x
# | reactive[2].y
# | reactive[2].z
# | reactive[2].L
# | reactive[2].V
# | reactive[2].F
# | reactive[2].H_L_
# | reactive[2].H_V_
# | reactive[2].H_L
# | reactive[2].H_V
# | reactive[2].H_F
# | reactive[2].T
# | reactive[2].T_F
# | reactive[2].P
# | reactive[2].f_V
# | reactive[2].f_L
# | reactive[2].cat
# | reactive[2].Q_main
# | reactive[2].r_total_comp
# | reactive[2].PR_L
# | reactive[2].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].kinetics_block.k_FT
# | reactive[2].kinetics_block.r_FT_total
# | reactive[2].kinetics_block.g0_FT
# | reactive[2].kinetics_block.alpha
# | reactive[2].kinetics_block.r_FT_cnum
# | reactive[2].kinetics_block.r_FT_comp
# | reactive[2].kinetics_block.k_WGS
# | reactive[2].kinetics_block.Ke_WGS
# | reactive[2].kinetics_block.r_WGS
# | reactive[2].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].energy_block.dH_F
# | reactive[2].energy_block.dH_V
# | reactive[2].energy_block.dH_L
# | reactive[2].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].VLE_block.P_VLE
# | reactive[2].VLE_block.n_ave
# | reactive[2].VLE_block.n_ave_cal
# | reactive[2].VLE_block.Hen
# | reactive[2].VLE_block.Hen0
# | reactive[2].VLE_block.gamma
# | reactive[2].VLE_block.P_sat
# | reactive[2].VLE_block.P_sat_Y
# | reactive[2].VLE_block.P_sat_dY_inf
# | reactive[2].VLE_block.P_sat_dY0
# | reactive[2].VLE_block.Hen_ref
# | reactive[2].VLE_block.Hen0_ref
# | reactive[2].VLE_block.gamma_ref
# | reactive[2].VLE_block.V_L
# | reactive[2].VLE_block.V_L_dY_inf
# | reactive[2].VLE_block.V_L_dY0
# | reactive[2].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].MPCC.s_L
# | reactive[2].MPCC.s_V
# | reactive[2].MPCC.pf
# | reactive[2].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[3].x_
# | reactive[3].y_
# | reactive[3].x
# | reactive[3].y
# | reactive[3].z
# | reactive[3].L
# | reactive[3].V
# | reactive[3].F
# | reactive[3].H_L_
# | reactive[3].H_V_
# | reactive[3].H_L
# | reactive[3].H_V
# | reactive[3].H_F
# | reactive[3].T
# | reactive[3].T_F
# | reactive[3].P
# | reactive[3].f_V
# | reactive[3].f_L
# | reactive[3].cat
# | reactive[3].Q_main
# | reactive[3].r_total_comp
# | reactive[3].PR_L
# | reactive[3].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].kinetics_block.k_FT
# | reactive[3].kinetics_block.r_FT_total
# | reactive[3].kinetics_block.g0_FT
# | reactive[3].kinetics_block.alpha
# | reactive[3].kinetics_block.r_FT_cnum
# | reactive[3].kinetics_block.r_FT_comp
# | reactive[3].kinetics_block.k_WGS
# | reactive[3].kinetics_block.Ke_WGS
# | reactive[3].kinetics_block.r_WGS
# | reactive[3].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].energy_block.dH_F
# | reactive[3].energy_block.dH_V
# | reactive[3].energy_block.dH_L
# | reactive[3].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].VLE_block.P_VLE
# | reactive[3].VLE_block.n_ave
# | reactive[3].VLE_block.n_ave_cal
# | reactive[3].VLE_block.Hen
# | reactive[3].VLE_block.Hen0
# | reactive[3].VLE_block.gamma
# | reactive[3].VLE_block.P_sat
# | reactive[3].VLE_block.P_sat_Y
# | reactive[3].VLE_block.P_sat_dY_inf
# | reactive[3].VLE_block.P_sat_dY0
# | reactive[3].VLE_block.Hen_ref
# | reactive[3].VLE_block.Hen0_ref
# | reactive[3].VLE_block.gamma_ref
# | reactive[3].VLE_block.V_L
# | reactive[3].VLE_block.V_L_dY_inf
# | reactive[3].VLE_block.V_L_dY0
# | reactive[3].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].MPCC.s_L
# | reactive[3].MPCC.s_V
# | reactive[3].MPCC.pf
# | reactive[3].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[4].x_
# | reactive[4].y_
# | reactive[4].x
# | reactive[4].y
# | reactive[4].z
# | reactive[4].L
# | reactive[4].V
# | reactive[4].F
# | reactive[4].H_L_
# | reactive[4].H_V_
# | reactive[4].H_L
# | reactive[4].H_V
# | reactive[4].H_F
# | reactive[4].T
# | reactive[4].T_F
# | reactive[4].P
# | reactive[4].f_V
# | reactive[4].f_L
# | reactive[4].cat
# | reactive[4].Q_main
# | reactive[4].r_total_comp
# | reactive[4].PR_L
# | reactive[4].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].kinetics_block.k_FT
# | reactive[4].kinetics_block.r_FT_total
# | reactive[4].kinetics_block.g0_FT
# | reactive[4].kinetics_block.alpha
# | reactive[4].kinetics_block.r_FT_cnum
# | reactive[4].kinetics_block.r_FT_comp
# | reactive[4].kinetics_block.k_WGS
# | reactive[4].kinetics_block.Ke_WGS
# | reactive[4].kinetics_block.r_WGS
# | reactive[4].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].energy_block.dH_F
# | reactive[4].energy_block.dH_V
# | reactive[4].energy_block.dH_L
# | reactive[4].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].VLE_block.P_VLE
# | reactive[4].VLE_block.n_ave
# | reactive[4].VLE_block.n_ave_cal
# | reactive[4].VLE_block.Hen
# | reactive[4].VLE_block.Hen0
# | reactive[4].VLE_block.gamma
# | reactive[4].VLE_block.P_sat
# | reactive[4].VLE_block.P_sat_Y
# | reactive[4].VLE_block.P_sat_dY_inf
# | reactive[4].VLE_block.P_sat_dY0
# | reactive[4].VLE_block.Hen_ref
# | reactive[4].VLE_block.Hen0_ref
# | reactive[4].VLE_block.gamma_ref
# | reactive[4].VLE_block.V_L
# | reactive[4].VLE_block.V_L_dY_inf
# | reactive[4].VLE_block.V_L_dY0
# | reactive[4].VLE_block.poynting
# --------------------------------------------------
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].MPCC.s_L
# | reactive[4].MPCC.s_V
# | reactive[4].MPCC.pf
# | reactive[4].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[5].x_
# | reactive[5].y_
# | reactive[5].x
# | reactive[5].y
# | reactive[5].z
# | reactive[5].L
# | reactive[5].V
# | reactive[5].F
# | reactive[5].H_L_
# | reactive[5].H_V_
# | reactive[5].H_L
# | reactive[5].H_V
# | reactive[5].H_F
# | reactive[5].T
# | reactive[5].T_F
# | reactive[5].P
# | reactive[5].f_V
# | reactive[5].f_L
# | reactive[5].cat
# | reactive[5].Q_main
# | reactive[5].r_total_comp
# | reactive[5].PR_L
# | reactive[5].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].kinetics_block.k_FT
# | reactive[5].kinetics_block.r_FT_total
# | reactive[5].kinetics_block.g0_FT
# | reactive[5].kinetics_block.alpha
# | reactive[5].kinetics_block.r_FT_cnum
# | reactive[5].kinetics_block.r_FT_comp
# | reactive[5].kinetics_block.k_WGS
# | reactive[5].kinetics_block.Ke_WGS
# | reactive[5].kinetics_block.r_WGS
# | reactive[5].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].energy_block.dH_F
# | reactive[5].energy_block.dH_V
# | reactive[5].energy_block.dH_L
# | reactive[5].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].VLE_block.P_VLE
# | reactive[5].VLE_block.n_ave
# | reactive[5].VLE_block.n_ave_cal
# | reactive[5].VLE_block.Hen
# | reactive[5].VLE_block.Hen0
# | reactive[5].VLE_block.gamma
# | reactive[5].VLE_block.P_sat
# | reactive[5].VLE_block.P_sat_Y
# | reactive[5].VLE_block.P_sat_dY_inf
# | reactive[5].VLE_block.P_sat_dY0
# | reactive[5].VLE_block.Hen_ref
# | reactive[5].VLE_block.Hen0_ref
# | reactive[5].VLE_block.gamma_ref
# | reactive[5].VLE_block.V_L
# | reactive[5].VLE_block.V_L_dY_inf
# | reactive[5].VLE_block.V_L_dY0
# | reactive[5].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].MPCC.s_L
# | reactive[5].MPCC.s_V
# | reactive[5].MPCC.pf
# | reactive[5].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[6].x_
# | reactive[6].y_
# | reactive[6].x
# | reactive[6].y
# | reactive[6].z
# | reactive[6].L
# | reactive[6].V
# | reactive[6].F
# | reactive[6].H_L_
# | reactive[6].H_V_
# | reactive[6].H_L
# | reactive[6].H_V
# | reactive[6].H_F
# | reactive[6].T
# | reactive[6].T_F
# | reactive[6].P
# | reactive[6].f_V
# | reactive[6].f_L
# | reactive[6].cat
# | reactive[6].Q_main
# | reactive[6].r_total_comp
# | reactive[6].PR_L
# | reactive[6].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].kinetics_block.k_FT
# | reactive[6].kinetics_block.r_FT_total
# | reactive[6].kinetics_block.g0_FT
# | reactive[6].kinetics_block.alpha
# | reactive[6].kinetics_block.r_FT_cnum
# | reactive[6].kinetics_block.r_FT_comp
# | reactive[6].kinetics_block.k_WGS
# | reactive[6].kinetics_block.Ke_WGS
# | reactive[6].kinetics_block.r_WGS
# | reactive[6].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].energy_block.dH_F
# | reactive[6].energy_block.dH_V
# | reactive[6].energy_block.dH_L
# | reactive[6].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].VLE_block.P_VLE
# | reactive[6].VLE_block.n_ave
# | reactive[6].VLE_block.n_ave_cal
# | reactive[6].VLE_block.Hen
# | reactive[6].VLE_block.Hen0
# | reactive[6].VLE_block.gamma
# | reactive[6].VLE_block.P_sat
# | reactive[6].VLE_block.P_sat_Y
# | reactive[6].VLE_block.P_sat_dY_inf
# | reactive[6].VLE_block.P_sat_dY0
# | reactive[6].VLE_block.Hen_ref
# | reactive[6].VLE_block.Hen0_ref
# | reactive[6].VLE_block.gamma_ref
# | reactive[6].VLE_block.V_L
# | reactive[6].VLE_block.V_L_dY_inf
# | reactive[6].VLE_block.V_L_dY0
# | reactive[6].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].MPCC.s_L
# | reactive[6].MPCC.s_V
# | reactive[6].MPCC.pf
# | reactive[6].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[7].x_
# | reactive[7].y_
# | reactive[7].x
# | reactive[7].y
# | reactive[7].z
# | reactive[7].L
# | reactive[7].V
# | reactive[7].F
# | reactive[7].H_L_
# | reactive[7].H_V_
# | reactive[7].H_L
# | reactive[7].H_V
# | reactive[7].H_F
# | reactive[7].T
# | reactive[7].T_F
# | reactive[7].P
# | reactive[7].f_V
# | reactive[7].f_L
# | reactive[7].cat
# | reactive[7].Q_main
# | reactive[7].r_total_comp
# | reactive[7].PR_L
# | reactive[7].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].kinetics_block.k_FT
# | reactive[7].kinetics_block.r_FT_total
# | reactive[7].kinetics_block.g0_FT
# | reactive[7].kinetics_block.alpha
# | reactive[7].kinetics_block.r_FT_cnum
# | reactive[7].kinetics_block.r_FT_comp
# | reactive[7].kinetics_block.k_WGS
# | reactive[7].kinetics_block.Ke_WGS
# | reactive[7].kinetics_block.r_WGS
# | reactive[7].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].energy_block.dH_F
# | reactive[7].energy_block.dH_V
# | reactive[7].energy_block.dH_L
# | reactive[7].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].VLE_block.P_VLE
# | reactive[7].VLE_block.n_ave
# | reactive[7].VLE_block.n_ave_cal
# | reactive[7].VLE_block.Hen
# | reactive[7].VLE_block.Hen0
# | reactive[7].VLE_block.gamma
# | reactive[7].VLE_block.P_sat
# | reactive[7].VLE_block.P_sat_Y
# | reactive[7].VLE_block.P_sat_dY_inf
# | reactive[7].VLE_block.P_sat_dY0
# | reactive[7].VLE_block.Hen_ref
# | reactive[7].VLE_block.Hen0_ref
# | reactive[7].VLE_block.gamma_ref
# | reactive[7].VLE_block.V_L
# | reactive[7].VLE_block.V_L_dY_inf
# | reactive[7].VLE_block.V_L_dY0
# | reactive[7].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].MPCC.s_L
# | reactive[7].MPCC.s_V
# | reactive[7].MPCC.pf
# | reactive[7].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[8].x_
# | reactive[8].y_
# | reactive[8].x
# | reactive[8].y
# | reactive[8].z
# | reactive[8].L
# | reactive[8].V
# | reactive[8].F
# | reactive[8].H_L_
# | reactive[8].H_V_
# | reactive[8].H_L
# | reactive[8].H_V
# | reactive[8].H_F
# | reactive[8].T
# | reactive[8].T_F
# | reactive[8].P
# | reactive[8].f_V
# | reactive[8].f_L
# | reactive[8].cat
# | reactive[8].Q_main
# | reactive[8].r_total_comp
# | reactive[8].PR_L
# | reactive[8].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].kinetics_block.k_FT
# | reactive[8].kinetics_block.r_FT_total
# | reactive[8].kinetics_block.g0_FT
# | reactive[8].kinetics_block.alpha
# | reactive[8].kinetics_block.r_FT_cnum
# | reactive[8].kinetics_block.r_FT_comp
# | reactive[8].kinetics_block.k_WGS
# | reactive[8].kinetics_block.Ke_WGS
# | reactive[8].kinetics_block.r_WGS
# | reactive[8].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].energy_block.dH_F
# | reactive[8].energy_block.dH_V
# | reactive[8].energy_block.dH_L
# | reactive[8].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].VLE_block.P_VLE
# | reactive[8].VLE_block.n_ave
# | reactive[8].VLE_block.n_ave_cal
# | reactive[8].VLE_block.Hen
# | reactive[8].VLE_block.Hen0
# | reactive[8].VLE_block.gamma
# | reactive[8].VLE_block.P_sat
# | reactive[8].VLE_block.P_sat_Y
# | reactive[8].VLE_block.P_sat_dY_inf
# | reactive[8].VLE_block.P_sat_dY0
# | reactive[8].VLE_block.Hen_ref
# | reactive[8].VLE_block.Hen0_ref
# | reactive[8].VLE_block.gamma_ref
# | reactive[8].VLE_block.V_L
# | reactive[8].VLE_block.V_L_dY_inf
# | reactive[8].VLE_block.V_L_dY0
# | reactive[8].VLE_block.poynting
# --------------------------------------------------
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].MPCC.s_L
# | reactive[8].MPCC.s_V
# | reactive[8].MPCC.pf
# | reactive[8].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[9].x_
# | reactive[9].y_
# | reactive[9].x
# | reactive[9].y
# | reactive[9].z
# | reactive[9].L
# | reactive[9].V
# | reactive[9].F
# | reactive[9].H_L_
# | reactive[9].H_V_
# | reactive[9].H_L
# | reactive[9].H_V
# | reactive[9].H_F
# | reactive[9].T
# | reactive[9].T_F
# | reactive[9].P
# | reactive[9].f_V
# | reactive[9].f_L
# | reactive[9].cat
# | reactive[9].Q_main
# | reactive[9].r_total_comp
# | reactive[9].PR_L
# | reactive[9].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].kinetics_block.k_FT
# | reactive[9].kinetics_block.r_FT_total
# | reactive[9].kinetics_block.g0_FT
# | reactive[9].kinetics_block.alpha
# | reactive[9].kinetics_block.r_FT_cnum
# | reactive[9].kinetics_block.r_FT_comp
# | reactive[9].kinetics_block.k_WGS
# | reactive[9].kinetics_block.Ke_WGS
# | reactive[9].kinetics_block.r_WGS
# | reactive[9].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].energy_block.dH_F
# | reactive[9].energy_block.dH_V
# | reactive[9].energy_block.dH_L
# | reactive[9].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].VLE_block.P_VLE
# | reactive[9].VLE_block.n_ave
# | reactive[9].VLE_block.n_ave_cal
# | reactive[9].VLE_block.Hen
# | reactive[9].VLE_block.Hen0
# | reactive[9].VLE_block.gamma
# | reactive[9].VLE_block.P_sat
# | reactive[9].VLE_block.P_sat_Y
# | reactive[9].VLE_block.P_sat_dY_inf
# | reactive[9].VLE_block.P_sat_dY0
# | reactive[9].VLE_block.Hen_ref
# | reactive[9].VLE_block.Hen0_ref
# | reactive[9].VLE_block.gamma_ref
# | reactive[9].VLE_block.V_L
# | reactive[9].VLE_block.V_L_dY_inf
# | reactive[9].VLE_block.V_L_dY0
# | reactive[9].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].MPCC.s_L
# | reactive[9].MPCC.s_V
# | reactive[9].MPCC.pf
# | reactive[9].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[10].x_
# | reactive[10].y_
# | reactive[10].x
# | reactive[10].y
# | reactive[10].z
# | reactive[10].L
# | reactive[10].V
# | reactive[10].F
# | reactive[10].H_L_
# | reactive[10].H_V_
# | reactive[10].H_L
# | reactive[10].H_V
# | reactive[10].H_F
# | reactive[10].T
# | reactive[10].T_F
# | reactive[10].P
# | reactive[10].f_V
# | reactive[10].f_L
# | reactive[10].cat
# | reactive[10].Q_main
# | reactive[10].r_total_comp
# | reactive[10].PR_L
# | reactive[10].PR_V
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].kinetics_block.k_FT
# | reactive[10].kinetics_block.r_FT_total
# | reactive[10].kinetics_block.g0_FT
# | reactive[10].kinetics_block.alpha
# | reactive[10].kinetics_block.r_FT_cnum
# | reactive[10].kinetics_block.r_FT_comp
# | reactive[10].kinetics_block.k_WGS
# | reactive[10].kinetics_block.Ke_WGS
# | reactive[10].kinetics_block.r_WGS
# | reactive[10].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].energy_block.dH_F
# | reactive[10].energy_block.dH_V
# | reactive[10].energy_block.dH_L
# | reactive[10].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].VLE_block.P_VLE
# | reactive[10].VLE_block.n_ave
# | reactive[10].VLE_block.n_ave_cal
# | reactive[10].VLE_block.Hen
# | reactive[10].VLE_block.Hen0
# | reactive[10].VLE_block.gamma
# | reactive[10].VLE_block.P_sat
# | reactive[10].VLE_block.P_sat_Y
# | reactive[10].VLE_block.P_sat_dY_inf
# | reactive[10].VLE_block.P_sat_dY0
# | reactive[10].VLE_block.Hen_ref
# | reactive[10].VLE_block.Hen0_ref
# | reactive[10].VLE_block.gamma_ref
# | reactive[10].VLE_block.V_L
# | reactive[10].VLE_block.V_L_dY_inf
# | reactive[10].VLE_block.V_L_dY0
# | reactive[10].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].MPCC.s_L
# | reactive[10].MPCC.s_V
# | reactive[10].MPCC.pf
# | reactive[10].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
# in/out variable
for j in model.reactive:
    model.reactive[j].x_.fix(0)
    model.reactive[j].y_.fix(0)
    model.reactive[j].L['in'].fix(0)
    model.reactive[j].V['in'].fix(0)
    model.reactive[j].H_L_.fix(0)
    model.reactive[j].H_V_.fix(0)

# operating parameters
for j in model.reactive:
    model.reactive[j].cat.fix(3000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
    model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
    model.reactive[j].z['C30H62'].fix(0)
    
    model.reactive[j].PR_L.fix(1)
    model.reactive[j].PR_V.fix(1)
    
    # model.reactive[j].Q_main.fix(0)
    model.reactive[j].T.setub(220+273.15)
    model.reactive[j].T.setlb(200+273.15)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 11840
# Active Inequality Constraints:	 10
# Active Variables:		 13600
# Fixed Variables:		 1720
# DOF:				 40

# %%
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf \
                                    for j in model.reactive),sense=pe.maximize)

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'

opt.options['linear_system_scaling '] = 'mc19'
opt.options['linear_scaling_on_demand '] = 'no'

# opt.options['warm_start_init_point'] = 'yes'
# opt.options['warm_start_bound_push'] = 1e-20
# opt.options['warm_start_mult_bound_push'] = 1e-20
# opt.options['mu_init'] = 1e-6

# opt.options['halt_on_ampl_error'] = 'yes'

opt.options['max_iter'] = 7000

# %%
# %%time

results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    41760
# Number of nonzeros in inequality constraint Jacobian.:       70
# Number of nonzeros in Lagrangian Hessian.............:    45570
#
# Total number of variables............................:    11880
#                      variables with only lower bounds:     3850
#                 variables with lower and upper bounds:     6330
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    11840
# Total number of inequality constraints...............:       10
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       10
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.7334000e+03 9.34e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.7334450e+03 9.34e+03 5.24e+00  -1.0 2.15e+04    -  3.22e-04 1.47e-04h  1
#    2r-4.7334450e+03 9.34e+03 9.99e+02   3.9 0.00e+00    -  0.00e+00 3.24e-07R  4
#    3r-4.7334427e+03 9.34e+03 9.99e+02   3.9 5.85e+05    -  3.19e-05 4.85e-07f  1
#    4r-4.7602820e+03 8.81e+03 9.98e+02   2.5 4.80e+05    -  7.33e-05 9.06e-04f  1
#    5r-4.8790094e+03 6.46e+03 9.97e+02   2.5 1.78e+06    -  4.02e-04 1.06e-03f  1
#    6 -4.8789775e+03 6.45e+03 1.12e+01  -1.0 2.93e+04    -  3.48e-04 2.18e-04h  1
#    7 -4.8790061e+03 6.45e+03 4.80e+01  -1.0 3.09e+03    -  6.31e-04 6.92e-05h  1
#    8 -4.8791523e+03 6.45e+03 1.50e+02  -1.0 3.96e+03    -  8.69e-04 3.38e-04h  1
#    9 -4.8791622e+03 6.45e+03 8.28e+03  -1.0 3.30e+03    -  1.78e-03 2.33e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-4.8791622e+03 6.45e+03 1.00e+03   3.7 0.00e+00    -  0.00e+00 2.44e-07R  2
#   11r-4.8791832e+03 6.45e+03 1.38e+03   3.7 5.87e+05    -  1.14e-03 7.80e-07f  1
#   12r-4.9302065e+03 5.46e+03 1.50e+03   2.3 6.16e+05    -  3.97e-03 1.31e-03f  1
#   13r-4.9302065e+03 5.46e+03 9.99e+02   3.7 0.00e+00    -  0.00e+00 4.05e-07R  4
#   14r-4.9302057e+03 5.46e+03 9.99e+02   3.7 2.60e+05    -  3.71e-04 1.37e-07f  1
#   15r-4.9306829e+03 5.35e+03 9.98e+02   2.3 2.74e+05    -  8.69e-03 3.48e-04f  1
#   16r-4.9303657e+03 2.47e+03 9.95e+02   2.3 9.15e+05    -  3.13e-03 3.15e-03f  1
#   17 -4.9303613e+03 2.47e+03 1.58e+00  -1.0 1.94e+04    -  6.26e-05 3.93e-05h  1
#   18 -4.9303688e+03 2.47e+03 9.86e+00  -1.0 3.31e+03    -  7.45e-05 1.78e-05h  1
#   19 -4.9303751e+03 2.47e+03 3.09e+02  -1.0 3.46e+03    -  5.71e-04 1.47e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r
60e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -4.9272460e+03 4.61e+00 6.76e+05  -1.0 1.29e+01    -  7.66e-01 9.90e-01h  1
#   51 -4.9277045e+03 1.93e-01 2.49e+05  -1.0 6.45e+00    -  1.00e+00 9.93e-01h  1
#   52 -4.9274008e+03 1.18e-02 1.18e+04  -1.0 3.63e+00    -  1.00e+00 1.00e+00h  1
#   53 -4.9271748e+03 1.04e-04 2.85e+02  -1.0 5.88e-01    -  1.00e+00 1.00e+00h  1
#   54 -4.9305834e+03 1.25e-03 2.72e+06  -2.5 5.30e+00    -  9.87e-01 7.07e-01f  1
#   55 -4.9313658e+03 4.33e-04 2.24e+04  -2.5 4.59e+00    -  1.00e+00 1.00e+00f  1
#   56 -4.9313705e+03 1.40e-04 1.42e+02  -2.5 7.74e-01    -  1.00e+00 1.00e+00h  1
#   57 -4.9313720e+03 3.73e-06 2.06e-01  -2.5 1.28e-01    -  1.00e+00 1.00e+00h  1
#   58 -4.9314863e+03 1.59e-04 2.02e+03  -3.8 8.23e-01    -  1.00e+00 1.00e+00f  1
#   59 -4.9314927e+03 1.16e-04 1.23e+01  -3.8 7.11e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -4.9314926e+03 4.23e-09 6.99e-04  -3.8 3.22e-03    -  1.00e+00 1.00e+00h  1
#   61 -4.9314999e+03 5.35e-06 2.07e+01  -5.7 1.53e-01    -  1.00e+00 1.00e+00f  1
#   62 -4.9315000e+03 9.82e-09 1.22e-03  -5.7 6.61e-03    -  1.00e+00 1.00e+00h  1
#   63 -4.9315000e+03 1.38e-10 1.85e-11  -5.7 2.99e-07    -  1.00e+00 1.00e+00h  1
#   64 -4.9315000e+03 9.73e-10 3.46e-03  -8.6 2.06e-03    -  1.00e+00 1.00e+00f  1
#   65 -4.9315000e+03 4.24e-11 1.57e-08  -8.6 8.41e-07    -  1.00e+00 1.00e+00h  1
#   66 -4.9315000e+03 4.24e-11 2.76e-08  -9.0 1.77e-06    -  1.00e+00 1.00e+00h  1
#   67 -4.9315000e+03 2.27e-13 6.51e-09  -9.0 2.14e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 67
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.9315000493886910e+03   -4.9315000493886910e+03
# Dual infeasibility......:   6.5107696257913101e-09    6.5107696257913101e-09
# Constraint violation....:   2.2737367544323206e-13    2.2737367544323206e-13
# Complementarity.........:   1.0404302700175745e-09    1.0404302700175745e-09
# Overall NLP error.......:   6.5107696257913101e-09    6.5107696257913101e-09
#
#
# Number of objective function evaluations             = 96
# Number of objective gradient evaluations             = 54
# Number of equality constraint evaluations            = 96
# Number of inequality constraint evaluations          = 96
# Number of equality constraint Jacobian evaluations   = 73
# Number of inequality constraint Jacobian evaluations = 73
# Number of Lagrangian Hessian evaluations             = 67
# Total CPU secs in IPOPT (w/o function evaluations)   =     32.025
# Total CPU secs in NLP function evaluations           =      1.753
#
# EXIT: Optimal Solution Found.
# CPU times: user 1.48 s, sys: 87.2 ms, total: 1.57 s
# Wall time: 13.1 s

# %%
print('First Solve, disconnected reactive stages')
print('-'*108)
beautify_reactive(pe,model)
# Out:
# First Solve, disconnected reactive stages
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# React-ive[1]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[2]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[3]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[4]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[5]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[6]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[7]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[8]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[9]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[10]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815

# %% [markdown]
# # Connect reactive stages and Initialize connectively

# %% [markdown]
# ### Vapor Between Reactive Stages

# %%
def V_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].V['in'] == model.reactive[j+1].V['out']
model.V_between_con = pe.Constraint(model.TRAY,rule=V_between_rule)

def Vy_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].y_['in',i] == model.reactive[j+1].y[i]
model.Vy_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Vy_between_rule)

def Vh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].H_V_['in'] == model.reactive[j+1].H_V
model.Vh_between_con = pe.Constraint(model.TRAY,rule=Vh_between_rule)

# %% [markdown]
# ### Liquid Between Reactive Stages

# %%
def L_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].L['in'] == model.reactive[j].L['out']
model.L_between_con = pe.Constraint(model.TRAY,rule=L_between_rule)

def Lx_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].x_['in',i] == model.reactive[j].x[i]
model.Ly_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Lx_between_rule)

def Lh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].H_L_['in'] == model.reactive[j].H_L
model.Lh_between_con = pe.Constraint(model.TRAY,rule=Lh_between_rule)

# %% [markdown]
# ### Unlock liquid and vapor in-flow

# %%
for j in model.reactive:
    if j != model.TRAY.first():
        model.reactive[j].x_.unfix()
        model.reactive[j].H_L_.unfix()
        model.reactive[j].L['in'].unfix()
    if j != model.TRAY.last():
        model.reactive[j].y_.unfix()
        model.reactive[j].V['in'].unfix()
        model.reactive[j].H_V_.unfix()

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 13298
# Active Inequality Constraints:	 10
# Active Variables:		 13600
# Fixed Variables:		 262
# DOF:				 40

# %%
opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6

results = opt.solve(model,tee=False)
update_dual(pe,model)

# %% [markdown]
# ### Iteratively reduce stage product draw ratio

# %% [markdown]
# \begin{align}
# PR_L &= \frac{\text{Liquid Side Draw}}{\text{Total Liquid Product}}
# \newline
# \newline
# PR_V &= \frac{\text{Vapor Side Draw}}{\text{Total Vapor Product}}
# \end{align}

# %%
# %%time

PR_range = np.linspace(1,0,11)
for r in PR_range:
    for j in model.reactive:
        model.reactive[j].PR_L.fix(r)
        model.reactive[j].PR_V.fix(r)
          
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    print('\n>','Working on PR ratio = {:.2f}'.format(r))
    print('-'*108)
    beautify_reactive(pe,model)
# Out:
# > Working on PR ratio = 1.00
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# React-ive[1]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[2]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[3]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[4]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[5]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[6]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[7]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[8]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[9]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
# React-ive[10]		220.0	-43.2		0.0000	0.0000	0.0064		20.000		0.2660	0.815
#
# > Working on PR ratio = 0.90
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# React-ive[1]		220.0	-43.2		0.0530	0.0006	0.0057		20.000		0.2660	0.798
# React-ive[2]		220.0	-43.2		0.0530	0.0007	0.0063		20.000		0.2660	0.798
# React-ive[3]		220.0	-43.2		0.0530	0.0007	0.0064		20.000		0.2660	0.798
# React-ive[4]		220.0	-43.2		0.0530	0.0007	0.0064		20.000		0.2660	0.798
# React-ive[5]		220.0	-43.2		0.0530	0.0007	0.0064		20.000		0.2660	0.798
# React-ive[6]		220.0	-43.2		0.0530	0.0007	0.0064		20.000		0.2660	0.798
# React-ive[7]		220.0	-43.2		0.0530	0.0007	0.0064		20.000		0.2660	0.798
# React-ive[8]		220.0	-43.2		0.0530	0.0007	0.0064		20.000		0.2660	0.799
# React-ive[9]		220.0	-43.2		0.0525	0.0007	0.0064		20.000		0.2660	0.800
# React-ive[10]		220.0	-43.2		0.0477	0.0007	0.0064		20.000		0.2660	0.815
#
# > Working on PR ratio = 0
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# React-ive[1]		220.0	-43.2		2.7997	0.0057	0.0006		20.000		0.2660	0.403
# React-ive[2]		220.0	-43.2		2.6331	0.0109	0.0012		20.000		0.2660	0.418
# React-ive[3]		220.0	-43.2		2.4481	0.0156	0.0017		20.000		0.2660	0.436
# React-ive[4]		220.0	-43.2		2.2425	0.0198	0.0022		20.000		0.2660	0.458
# React-ive[5]		220.0	-43.2		2.0141	0.0236	0.0026		20.000		0.2660	0.484
# React-ive[6]		220.0	-43.2		1.7602	0.0270	0.0030		20.000		0.2660	0.518
# React-ive[7]		220.0	-43.2		1.4782	0.0301	0.0033		20.000		0.2660	0.561
# React-ive[8]		220.0	-43.2		1.1649	0.0329	0.0036		20.000		0.2660	0.619
# React-ive[9]		220.0	-43.2		0.8167	0.0354	0.0039		20.000		0.2660	0.698
# React-ive[10]		220.0	-43.2		0.4298	0.0376	0.0041		20.000		0.2660	0.814
# > Working on PR ratio = 0.00
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# React-ive[1]		220.0	-43.2		4.7761	0.0064	0.0000		20.000		0.2660	0.306
# React-ive[2]		220.0	-43.2		4.2985	0.0128	0.0000		20.000		0.2660	0.328
# React-ive[3]		220.0	-43.2		3.8209	0.0192	0.0000		20.000		0.2660	0.355
# React-ive[4]		220.0	-43.2		3.3432	0.0257	0.0000		20.000		0.2660	0.386
# React-ive[5]		220.0	-43.2		2.8656	0.0321	0.0000		20.000		0.2660	0.423
# React-ive[6]		220.0	-43.2		2.3880	0.0385	0.0000		20.000		0.2660	0.468
# React-ive[7]		220.0	-43.2		1.9104	0.0449	0.0000		20.000		0.2660	0.524
# React-ive[8]		220.0	-43.2		1.4328	0.0513	0.0000		20.000		0.2660	0.594
# React-ive[9]		220.0	-43.2		0.9552	0.0578	0.0000		20.000		0.2660	0.687
# React-ive[10]		220.0	-43.2		0.4776	0.0642	0.0000		20.000		0.2660	0.814
# CPU times: user 17.6 s, sys: 360 ms, total: 18 s
# Wall time: 49.8 s

# %% [markdown]
# # Adjusting to non-reactive stages

# %%
# %%time

for j in model.TRAY_nonreactive:
    
    model.reactive[j].T.unfix()
    model.reactive[j].Q_main.fix(0)
    model.reactive[j].cat.fix(0)
    model.reactive[j].F.fix(0)
    
#     model.del_component(model.obj)
#     model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.TRAY_reactive)\
#                              + sum(- model.reactive[j].MPCC.pf for j in model.TRAY_nonreactive),sense=pe.maximize)
    
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    
    print('\n>','Working to remove catalyst and feed from stage {}, unfixing temperature, changing to adiabatic:'.format(j))
    print('-'*108)
    beautify_reactive(pe,model)
# Out:
# > Working to remove catalyst and feed from stage 1, unfixing temperature, changing to adiabatic:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		4.2985	0.0000	0.0000		20.000		0.0000	0.000
# React-ive[2]		220.0	-43.2		4.2985	0.0064	0.0000		20.000		0.2660	0.328
# React-ive[3]		220.0	-43.2		3.8209	0.0128	0.0000		20.000		0.2660	0.355
# React-ive[4]		220.0	-43.2		3.3432	0.0192	0.0000		20.000		0.2660	0.386
# React-ive[5]		220.0	-43.2		2.8656	0.0257	0.0000		20.000		0.2660	0.423
# React-ive[6]		220.0	-43.2		2.3880	0.0321	0.0000		20.000		0.2660	0.468
# React-ive[7]		220.0	-43.2		1.9104	0.0385	0.0000		20.000		0.2660	0.524
# React-ive[8]		220.0	-43.2		1.4328	0.0449	0.0000		20.000		0.2660	0.594
# React-ive[9]		220.0	-43.2		0.9552	0.0513	0.0000		20.000		0.2660	0.687
# React-ive[10]		220.0	-43.2		0.4776	0.0578	0.0000		20.000		0.2660	0.814
#
# > Working to remove catalyst and feed from stage 2, unfixing temperature, changing to adiabatic:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		3.8209	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[2]		220.0	0.000		3.8209	0.0000	0.0000		20.000		0.0000	0.000
# React-ive[3]		220.0	-43.2		3.8209	0.0064	0.0000		20.000		0.2660	0.355
# React-ive[4]		220.0	-43.2		3.3432	0.0128	0.0000		20.000		0.2660	0.386
# React-ive[5]		220.0	-43.2		2.8656	0.0192	0.0000		20.000		0.2660	0.423
# React-ive[6]		220.0	-43.2		2.3880	0.0257	0.0000		20.000		0.2660	0.468
# React-ive[7]		220.0	-43.2		1.9104	0.0321	0.0000		20.000		0.2660	0.524
# React-ive[8]		220.0	-43.2		1.4328	0.0385	0.0000		20.000		0.2660	0.595
# React-ive[9]		220.0	-43.2		0.9552	0.0449	0.0000		20.000		0.2660	0.687
# React-ive[10]		220.0	-43.2		0.4776	0.0513	0.0000		20.000		0.2660	0.814
#
# > Working to remove catalyst and feed from stage 3, unfixing temperature, changing to adiabatic:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		3.3432	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[2]		220.0	0.000		3.3432	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[3]		220.0	0.000		3.3432	0.0000	0.0000		20.000		0.0000	0.000
# React-ive[4]		220.0	-43.2		3.3432	0.0064	0.0000		20.000		0.2660	0.386
# React-ive[5]		220.0	-43.2		2.8656	0.0128	0.0000		20.000		0.2660	0.423
# React-ive[6]		220.0	-43.2		2.3880	0.0192	0.0000		20.000		0.2660	0.468
# React-ive[7]		220.0	-43.2		1.9104	0.0257	0.0000		20.000		0.2660	0.524
# React-ive[8]		220.0	-43.2		1.4328	0.0321	0.0000		20.000		0.2660	0.595
# React-ive[9]		220.0	-43.2		0.9552	0.0385	0.0000		20.000		0.2660	0.687
# React-ive[10]		220.0	-43.2		0.4776	0.0449	0.0000		20.000		0.2660	0.814
#
# > Working to remove catalyst and feed from stage 4, unfixing temperature, changing to adiabatic:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		2.8656	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[2]		220.0	0.000		2.8656	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[3]		220.0	0.000		2.8656	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[4]		220.0	0.000		2.8656	0.0000	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.8656	0.0064	0.0000		20.000		0.2660	0.423
# React-ive[6]		220.0	-43.2		2.3880	0.0128	0.0000		20.000		0.2660	0.468
# React-ive[7]		220.0	-43.2		1.9104	0.0192	0.0000		20.000		0.2660	0.524
# React-ive[8]		220.0	-43.2		1.4328	0.0257	0.0000		20.000		0.2660	0.595
# React-ive[9]		220.0	-43.2		0.9552	0.0321	0.0000		20.000		0.2660	0.687
# React-ive[10]		220.0	-43.2		0.4776	0.0385	0.0000		20.000		0.2660	0.814
#
# > Working to remove catalyst and feed from stage 10, unfixing temperature, changing to adiabatic:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[2]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[3]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[4]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.3880	0.0064	0.0000		20.000		0.2660	0.468
# React-ive[6]		220.0	-43.2		1.9104	0.0128	0.0000		20.000		0.2660	0.524
# React-ive[7]		220.0	-43.2		1.4328	0.0192	0.0000		20.000		0.2660	0.595
# React-ive[8]		220.0	-43.2		0.9552	0.0257	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4776	0.0321	0.0000		20.000		0.2660	0.815
# NON-react[10]		220.0	0.000		0.0000	0.0321	0.0000		20.000		0.0000	0.000
# CPU times: user 9.31 s, sys: 205 ms, total: 9.51 s
# Wall time: 1min 4s

# %% [markdown]
# # Construct a single condenser and Initialize

# %% [markdown]
# ### Deactivate the reactive part first

# %%
for i in model.block_data_objects():
    if i.name != 'reactive_distillation':
        i.deactivate()
for i in model.component_objects(pe.Constraint, active=True):
    i.deactivate()
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 0
# Active Inequality Constraints:	 0
# Active Variables:		 0
# Fixed Variables:		 0
# DOF:				 0

# %%
model.condenser = pe.Block(rule=condenser_stage_rule)
# Out:
# | Importing Condenser Stage......
# | Adding the following local variable:
# ------------------------------------
# | condenser.T
# | condenser.T_F
# | condenser.P
# | condenser.Q_main
# | condenser.x_
# | condenser.y_
# | condenser.x
# | condenser.y
# | condenser.z
# | condenser.L
# | condenser.W
# | condenser.V
# | condenser.F
# | condenser.H_L_
# | condenser.H_V_
# | condenser.H_L
# | condenser.H_V
# | condenser.H_F
# | condenser.f_V
# | condenser.f_L
# | condenser.PR_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.energy_block.dH_F
# | condenser.energy_block.dH_V
# | condenser.energy_block.dH_L
# | condenser.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.VLE_block.n_ave
# | condenser.VLE_block.n_ave_cal
# | condenser.VLE_block.Hen
# | condenser.VLE_block.Hen0
# | condenser.VLE_block.gamma
# | condenser.VLE_block.P_sat
# | condenser.VLE_block.P_sat_Y
# | condenser.VLE_block.P_sat_dY_inf
# | condenser.VLE_block.P_sat_dY0
# | condenser.VLE_block.Hen_ref
# | condenser.VLE_block.Hen0_ref
# | condenser.VLE_block.gamma_ref
# | condenser.VLE_block.V_L
# | condenser.VLE_block.V_L_dY_inf
# | condenser.VLE_block.V_L_dY0
# | condenser.VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# ### Use the reactive sections vapor output as input to condenser

# %%
# in/out variables
model.condenser.x_.fix(0)
for i in m.COMP_TOTAL:
    model.condenser.y_['in',i].fix(model.reactive[model.TRAY.first()].y[i].value)
model.condenser.V['in'].fix(model.reactive[model.TRAY.first()].V['out'].value)
model.condenser.L['in'].fix(0)
model.condenser.V['P'].fix(0)
model.condenser.H_L_.fix(0)
model.condenser.H_V_.fix(model.reactive[model.TRAY.first()].H_V.value)

# operating parameters
model.condenser.P.fix(19)
model.condenser.T_F.fix(200+273.15)
model.condenser.F.fix(0)
model.condenser.z.fix(0)
model.condenser.VLE_block.n_ave.fix(4)
model.condenser.PR_L.fix(1)

model.condenser.T.setub(30+273.15)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = model.condenser.T, sense = pe.maximize)

delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	
67e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -2.9460518e+02 8.94e-02 2.63e+05  -6.0 8.97e+01    -  4.70e-01 1.34e-04h  1
#   81 -2.9458801e+02 5.32e-04 2.97e+05  -6.0 8.92e-01    -  9.94e-01 9.94e-01h  1
#   82 -2.9599956e+02 2.33e-01 1.10e+06  -6.0 2.22e+03    -  2.42e-02 2.38e-02f  1
#   83 -3.0315000e+02 6.40e+00 1.17e+08  -6.0 2.19e+03    -  5.64e-02 1.23e-01f  1
#   84 -3.0315000e+02 6.40e+00 3.28e+08  -6.0 2.23e+03    -  2.53e-02 6.34e-08h  2
#   85 -3.0315000e+02 6.11e+00 2.71e+08  -6.0 6.40e+00    -  2.27e-07 4.54e-02h  1
#   86 -3.0314998e+02 2.99e-02 6.62e+05  -6.0 6.11e+00    -  4.89e-02 1.00e+00h  1
#   87 -3.0315000e+02 2.70e-02 5.98e+05  -6.0 4.57e-02    -  1.00e+00 9.71e-02h  1
#   88 -3.0315000e+02 2.82e-04 3.19e-01  -6.0 4.13e-02    -  1.00e+00 1.00e+00h  1
#   89 -3.0315000e+02 1.99e-08 2.26e-10  -6.0 3.50e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90 -3.0315000e+02 5.09e-11 9.05e-07  -9.0 3.94e-05    -  1.00e+00 1.00e+00h  1
#   91 -3.0315000e+02 9.94e-11 1.00e-14  -9.0 4.14e-10    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 91
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -3.0315000303049999e+02   -3.0315000303049999e+02
# Dual infeasibility......:   1.0019762797242038e-14    1.0019762797242038e-14
# Constraint violation....:   9.9373484809851809e-11    9.9373484809851809e-11
# Complementarity.........:   1.0000000002532509e-09    1.0000000002532509e-09
# Overall NLP error.......:   1.0000000002532509e-09    1.0000000002532509e-09
#
#
# Number of objective function evaluations             = 151
# Number of objective gradient evaluations             = 48
# Number of equality constraint evaluations            = 151
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 102
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 91
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.045
# Total CPU secs in NLP function evaluations           =      0.074
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# # Construct a single reboiler and Initialize

# %% [markdown]
# ### Deactivate the condenser part first

# %%
model.condenser.deactivate()
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 0
# Active Inequality Constraints:	 0
# Active Variables:		 0
# Fixed Variables:		 0
# DOF:				 0

# %%
model.reboiler = pe.Block(rule=reboiler_stage_rule)
# Out:
# > Importing Non Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reboiler.T_F
# | reboiler.P
# | reboiler.Q_main
# | reboiler.x_
# | reboiler.y_
# | reboiler.x
# | reboiler.y
# | reboiler.z
# | reboiler.L
# | reboiler.V
# | reboiler.F
# | reboiler.H_L_
# | reboiler.H_V_
# | reboiler.H_L
# | reboiler.H_V
# | reboiler.T
# | reboiler.H_F
# | reboiler.f_V
# | reboiler.f_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.energy_block.dH_F
# | reboiler.energy_block.dH_V
# | reboiler.energy_block.dH_L
# | reboiler.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.VLE_block.P_VLE
# | reboiler.VLE_block.n_ave
# | reboiler.VLE_block.n_ave_cal
# | reboiler.VLE_block.Hen
# | reboiler.VLE_block.Hen0
# | reboiler.VLE_block.gamma
# | reboiler.VLE_block.P_sat
# | reboiler.VLE_block.P_sat_Y
# | reboiler.VLE_block.P_sat_dY_inf
# | reboiler.VLE_block.P_sat_dY0
# | reboiler.VLE_block.Hen_ref
# | reboiler.VLE_block.Hen0_ref
# | reboiler.VLE_block.gamma_ref
# | reboiler.VLE_block.V_L
# | reboiler.VLE_block.V_L_dY_inf
# | reboiler.VLE_block.V_L_dY0
# | reboiler.VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_pf Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.MPCC.s_L
# | reboiler.MPCC.s_V
# | reboiler.MPCC.pf
# | reboiler.MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE

# %% [markdown]
# ### Use the reactive sections liquid output as input to reboiler

# %%
# in/out variables
model.reboiler.y_.fix(0)
for i in m.COMP_TOTAL:
    model.reboiler.x_['in',i].fix(model.reactive[model.TRAY.last()].x[i].value)
model.reboiler.L['in'].fix(model.reactive[model.TRAY.last()].L['out'].value)
model.reboiler.V['in'].fix(0)
model.reboiler.L['P'].fix(0)
model.reboiler.V['P'].fix(0)
model.reboiler.H_L_.fix(model.reactive[model.TRAY.last()].H_L.value)
model.reboiler.H_V_.fix(0)

# operating parameters
model.reboiler.P.fix(20)
model.reboiler.T_F.fix(200+273.15)
model.reboiler.F.fix(0)
model.reboiler.z.fix(0)
model.reboiler.VLE_block.n_ave.fix(20)

model.reboiler.T.setub(model.reactive[model.TRAY.last()].T.value)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = model.reboiler.T - model.reboiler.MPCC.pf, sense = pe.maximize)

delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 957
# Active Inequality Constraints:	 1
# Active Variables:		 1132
# Fixed Variables:		 171
# DOF:				 4

# %%
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     3224
# Number of nonzeros in inequality constraint Jacobian.:        5
# Number of nonzeros in Lagrangian Hessian.............:     4317
#
# Total number of variables............................:      961
#                      variables with only lower bounds:      167
#                 variables with lower and upper bounds:      786
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      957
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        1
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.7315000e+02 9.36e+03 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.7315000e+02 9.36e+03 2.24e+02  -6.0 2.10e+04    -  6.75e-12 1.52e-09f  1
#    2r-4.7315000e+02 9.36e+03 9.99e+02   3.9 0.00e+00    -  0.00e+00 1.33e-10R  4
#    3r-4.7315000e+02 9.36e+03 1.35e+04   3.9 5.99e+09    -  2.56e-15 2.40e-09f  1
#    4r-4.7314997e+02 9.36e+03 1.34e+04   2.5 1.62e+04   2.0 5.75e-07 9.78e-08f  1
#    5r-4.7314955e+02 9.36e+03 1.34e+04   2.5 8.69e+03   2.4 1.79e-06 1.48e-06f  1
#    6r-4.7314893e+02 9.36e+03 1.34e+04   2.5 4.75e+02   2.9 3.57e-05 3.41e-06f  1
#    7r-4.7312661e+02 9.36e+03 1.34e+04   2.5 3.81e+02   2.4 1.51e-04 5.57e-04f  1
#    8r-4.7312062e+02 9.36e+03 3.02e+05   2.5 9.84e+01   2.8 8.08e-02 4.94e-04f  1
#    9r-4.7311644e+02 5.13e+02 2.89e+05   2.5 9.41e+05    -  5.89e-02 9.85e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -4
-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 92
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.9315000493764040e+02   -4.9315000493764040e+02
# Dual infeasibility......:   8.3200834793788203e-09    8.3200834793788203e-09
# Constraint violation....:   2.7512125910789109e-10    2.7512125910789109e-10
# Complementarity.........:   1.0013118206430026e-09    1.0013118206430026e-09
# Overall NLP error.......:   8.3200834793788203e-09    8.3200834793788203e-09
#
#
# Number of objective function evaluations             = 120
# Number of objective gradient evaluations             = 67
# Number of equality constraint evaluations            = 120
# Number of inequality constraint evaluations          = 121
# Number of equality constraint Jacobian evaluations   = 100
# Number of inequality constraint Jacobian evaluations = 100
# Number of Lagrangian Hessian evaluations             = 92
# Total CPU secs in IPOPT (w/o function evaluations)   =      3.214
# Total CPU secs in NLP function evaluations           =      0.192
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# # Initialization is complete

# %%
beautify(pe,model)
# Out:
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.4		1.2741	0.0000	0.0691		1.0447
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[2]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[3]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# NON-react[4]		220.0	0.000		2.3880	0.0000	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.3880	0.0064	0.0000		20.000		0.2660	0.468
# React-ive[6]		220.0	-43.2		1.9104	0.0128	0.0000		20.000		0.2660	0.524
# React-ive[7]		220.0	-43.2		1.4328	0.0192	0.0000		20.000		0.2660	0.595
# React-ive[8]		220.0	-43.2		0.9552	0.0257	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4776	0.0321	0.0000		20.000		0.2660	0.815
# NON-react[10]		220.0	0.000		0.0000	0.0321	0.0000		20.000		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0321			19.996
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Linking Condenser and Reboiler

# %% [markdown]
# ### Activate previously disabled constraint and variables

# %%
for i in model.block_data_objects():
    if i.name != 'reactive_distillation':
        i.activate()
for i in model.component_objects(pe.Constraint):
    i.activate()

# %% [markdown]
# ### Condenser Vapor

# %%
def V_condenser_rule(model):
    return model.reactive[model.TRAY.first()].V['out'] == model.condenser.V['in']
model.V_condenser_con = pe.Constraint(rule=V_condenser_rule)

def Vy_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].y[i] == model.condenser.y_['in',i]
model.Vy_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_condenser_rule)

def Vh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_V == model.condenser.H_V_['in']
model.Vh_condenser_con = pe.Constraint(rule=Vh_condenser_rule)

# %% [markdown]
# ### Condenser Liquid

# %%
def L_condenser_rule(model):
    return model.reactive[model.TRAY.first()].L['in'] == model.condenser.L['out']
model.L_condenser_con = pe.Constraint(rule=L_condenser_rule)

def Lx_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].x_['in',i] == model.condenser.x[i]
model.Lx_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_condenser_rule)

def Lh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_L_['in'] == model.condenser.H_L
model.Lh_condenser_con = pe.Constraint(rule=Lh_condenser_rule)

# %% [markdown]
# ### Reboiler Vapor

# %%
def V_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].V['in'] == model.reboiler.V['out']
model.V_reboiler_con = pe.Constraint(rule=V_reboiler_rule)

def Vy_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].y_['in',i] == model.reboiler.y[i]
model.Vy_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_reboiler_rule)

def Vh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_V_['in'] == model.reboiler.H_V
model.Vh_reboiler_con = pe.Constraint(rule=Vh_reboiler_rule)

# %% [markdown]
# ### Reboiler Liquid

# %%
def L_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].L['out'] + 1e-6 == model.reboiler.L['in']
model.L_reboiler_con = pe.Constraint(rule=L_reboiler_rule)

def Lx_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].x[i] == model.reboiler.x_['in',i]
model.Lx_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_reboiler_rule)

def Lh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_L == model.reboiler.H_L_['in']
model.Lh_reboiler_con = pe.Constraint(rule=Lh_reboiler_rule)

# %%
model.del_component(model.obj)
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.TRAY_reactive)\
                        + sum( - model.reactive[j].MPCC.pf for j in model.TRAY_nonreactive) - model.reboiler.MPCC.pf ,sense=pe.maximize)

# %%
delete_dual(pe,model)
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# # Fixing Redundent Stream Variables

# %% [markdown]
# ### Condenser

# %%
# in/out variables
model.condenser.x_.fix(0)
for i in m.COMP_TOTAL:
    model.condenser.y_['in',i].unfix()
model.condenser.V['in'].unfix()
model.condenser.L['in'].fix(0)
model.condenser.V['P'].fix(0)
model.condenser.H_L_.fix(0)
model.condenser.H_V_.unfix()

# operating parameters
model.condenser.P.fix(19)
model.condenser.T_F.fix(200+273.15)
model.condenser.F.fix(0)
model.condenser.z.fix(0)
model.condenser.VLE_block.n_ave.fix(4)
model.condenser.PR_L.fix(1)

model.condenser.T.fix(30+273.15)

# %% [markdown]
# ### Reboiler

# %%
# in/out variables
model.reboiler.y_.fix(0)
for i in m.COMP_TOTAL:
    model.reboiler.x_['in',i].unfix()
model.reboiler.L['in'].unfix()
model.reboiler.V['in'].fix(0)
model.reboiler.L['P'].fix(0)
model.reboiler.V['P'].fix(0)
model.reboiler.H_L_.unfix()
model.reboiler.H_V_.fix(0)

# operating parameters
model.reboiler.P.fix(20)
model.reboiler.T_F.fix(200+273.15)
model.reboiler.F.fix(0)
model.reboiler.z.fix(0)
model.reboiler.VLE_block.n_ave.fix(20)

model.reboiler.T.fix(model.reactive[model.TRAY.last()].T.value)

# %% [markdown]
# ### Reactive

# %%
# unlock reflux and reboiler vapor
for j in model.reactive:
    model.reactive[j].x_.unfix()
    model.reactive[j].H_L_.unfix()
    model.reactive[j].L['in'].unfix()
    model.reactive[j].y_.unfix()
    model.reactive[j].V['in'].unfix()
    model.reactive[j].H_V_.unfix()

for j in model.reactive:
    if j in model.TRAY_reactive:
        model.reactive[j].cat.fix(3000)
        model.reactive[j].P.fix(20)
        model.reactive[j].VLE_block.n_ave.fix(20)

        model.reactive[j].F.fix(1)
        model.reactive[j].T_F.fix(200+273.15)
        model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
        model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
        model.reactive[j].z['C30H62'].fix(0)

        model.reactive[j].PR_L.fix(0)
        model.reactive[j].PR_V.fix(0)

        # model.reactive[j].Q_main.fix(0)
        model.reactive[j].T.setub(220+273.15)
        model.reactive[j].T.setlb(200+273.15)
    
    elif j in model.TRAY_nonreactive:
        model.reactive[j].cat.fix(0)
        model.reactive[j].P.fix(20)
        model.reactive[j].VLE_block.n_ave.fix(20)

        model.reactive[j].F.fix(0)
        model.reactive[j].T_F.fix(200+273.15)
        model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
        model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
        model.reactive[j].z['C30H62'].fix(0)

        model.reactive[j].PR_L.fix(0)
        model.reactive[j].PR_V.fix(0)

        model.reactive[j].Q_main.fix(0)
        model.reactive[j].T.setub(350+273.15)
        model.reactive[j].T.setlb(100+273.15)

# %% [markdown]
# # Connected Solve

# %% [markdown]
# **DOF:**
# * Each Reactive Stage:            4 (T, s_L, s_V, pf)
# * Each Non-Reactive Stage:        3 (s_L, s_V, pf)
# * Reboiler:                       3 (s_L, s_V, pf)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 15537
# Active Inequality Constraints:	 11
# Active Variables:		 15862
# Fixed Variables:		 287
# DOF:				 38

# %%
# %%time

results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    54687
# Number of nonzeros in inequality constraint Jacobian.:       75
# Number of nonzeros in Lagrangian Hessian.............:    55526
#
# Total number of variables............................:    15575
#                      variables with only lower bounds:     5784
#                 variables with lower and upper bounds:     7979
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    15537
# Total number of inequality constraints...............:       11
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       11
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -2.4657500e+03 2.03e+02 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -2.4657500e+03 2.03e+02 1.60e+02  -6.0 2.03e+02    -  2.15e-08 3.44e-06h  1
#    2 -2.4657500e+03 2.03e+02 1.71e+02  -6.0 2.03e+02    -  3.44e-06 6.02e-04h  1
#    3 -2.4657500e+03 2.84e-02 2.48e+03  -6.0 2.03e+02    -  4.69e-04 1.00e+00f  1
#    4 -2.4657500e+03 2.83e-02 2.47e+03  -6.0 2.83e-02    -  9.99e-03 4.20e-03h  1
#    5 -2.4657500e+03 1.62e-02 1.42e+03  -6.0 2.83e-02    -  5.54e-01 4.27e-01f  1
#    6 -2.4657500e+03 5.44e-10 8.35e-01  -6.0 1.62e-02    -  9.99e-01 1.00e+00f  1
#    7 -2.4657500e+03 1.40e-06 2.55e+00  -6.0 6.43e-02    -  7.12e-01 1.00e+00f  1
#    8 -2.4657500e+03 2.61e-05 1.91e+03  -6.0 1.30e+00    -  4.22e-01 1.00e+00h  1
#    9 -2.4657500e+03 4.08e-05 1.13e+03  -6.0 5.02e-01    -  8.48e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -2.4657500e+03 2.06e-04 3.99e+01  -6.0 5.07e-01    -  6.35e-01 1.00e+00h  1
#   11 -2.4657500e+03 6.96e-06 3.41e-01  -6.0 2.30e-01    -  1.00e+00 1.00e+00h  1
#   12 -2.4657500e+03 2.91e-07 3.20e-03  -6.0 4.66e-02    -  1.00e+00 1.00e+00h  1
#   13 -2.4657500e+03 2.09e-10 1.37e-08  -6.0 1.26e-03    -  1.00e+00 1.00e+00h  1
#   14 -2.4657500e+03 1.76e-04 1.65e+01  -9.0 5.75e-01    -  9.90e-01 9.10e-01h  1
#   15 -2.4657500e+03 9.17e-05 1.67e+01  -9.0 4.11e-01    -  7.65e-01 5.64e-01h  1
#   16 -2.4657500e+03 2.99e-05 1.54e+00  -9.0 1.72e-01    -  1.00e+00 8.87e-01f  1
#   17 -2.4657500e+03 1.33e-05 6.27e-01  -9.0 5.12e-01    -  8.94e-01 6.45e-01f  1
#   18 -2.4657500e+03 1.07e-05 5.06e-01  -9.0 1.12e-02  -4.0 1.89e-01 1.92e-01f  2
#   19 -2.4657500e+03 1.05e-05 5.19e-01  -9.0 6.54e+00    -  2.91e-01 2.37e-02h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -2.4657500e+03 3.73e-06 7.97e-02  -9.0 8.36e-02    -  1.00e+00 8.64e-01h  1
#   21 -2.4657500e+03 5.65e-07 2.94e-03  -9.0 2.96e-02    -  1.00e+00 1.00e+00f  1
#   22 -2.4657500e+03 6.97e-08 1.26e-04  -9.0 9.08e-03    -  1.00e+00 1.00e+00h  1
#   23 -2.4657500e+03 1.40e-10 4.58e-07  -9.0 3.25e-04    -  1.00e+00 1.00e+00h  1
#   24 -2.4657500e+03 1.38e-10 4.37e-09  -9.0 1.72e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 24
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -2.4657500247429689e+03   -2.4657500247429689e+03
# Dual infeasibility......:   4.3696248832811313e-09    4.3696248832811313e-09
# Constraint violation....:   1.3831896121096338e-10    1.3831896121096338e-10
# Complementarity.........:   1.0000147147187023e-09    1.0000147147187023e-09
# Overall NLP error.......:   4.3696248832811313e-09    4.3696248832811313e-09
#
#
# Number of objective function evaluations             = 28
# Number of objective gradient evaluations             = 25
# Number of equality constraint evaluations            = 28
# Number of inequality constraint evaluations          = 28
# Number of equality constraint Jacobian evaluations   = 25
# Number of inequality constraint Jacobian evaluations = 25
# Number of Lagrangian Hessian evaluations             = 24
# Total CPU secs in IPOPT (w/o function evaluations)   =     36.823
# Total CPU secs in NLP function evaluations           =      0.813
#
# EXIT: Optimal Solution Found.
# CPU times: user 1.96 s, sys: 74.4 ms, total: 2.04 s
# Wall time: 13.7 s

# %%
beautify(pe,model)
# Out:
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.4		1.2741	0.0000	0.0691		1.0447
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		2.3880	0.0000	0.0000		20.026		0.0000	0.000
# NON-react[2]		220.0	0.000		2.3880	0.0000	0.0000		20.005		0.0000	0.000
# NON-react[3]		220.0	0.000		2.3880	0.0000	0.0000		20.005		0.0000	0.000
# NON-react[4]		220.0	0.000		2.3880	0.0000	0.0000		20.007		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.3880	0.0064	0.0000		20.000		0.2660	0.468
# React-ive[6]		220.0	-43.2		1.9104	0.0128	0.0000		20.000		0.2660	0.524
# React-ive[7]		220.0	-43.2		1.4328	0.0192	0.0000		20.000		0.2660	0.595
# React-ive[8]		220.0	-43.2		0.9552	0.0257	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4776	0.0321	0.0000		20.000		0.2660	0.815
# NON-react[10]		219.9	0.000		0.0000	0.0321	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0321			19.994
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Introducing Reflux (Iteratively or directly)

# %%
# %%time

PR_range = np.linspace(1,rr_ratio,10)
for r in PR_range:
    model.condenser.PR_L.fix(r)
          
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    
    print('\n>','Working on PR ratio = {:.2f}'.format(r))
    print('-'*108)
    beautify(pe,model)
# Out:
# > Working on PR ratio = 1.00
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.4		1.2741	0.0000	0.0691		1.0447
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		220.0	0.000		2.3880	0.0000	0.0000		20.026		0.0000	0.000
# NON-react[2]		220.0	0.000		2.3880	0.0000	0.0000		20.005		0.0000	0.000
# NON-react[3]		220.0	0.000		2.3880	0.0000	0.0000		20.005		0.0000	0.000
# NON-react[4]		220.0	0.000		2.3880	0.0000	0.0000		20.007		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.3880	0.0064	0.0000		20.000		0.2660	0.468
# React-ive[6]		220.0	-43.2		1.9104	0.0128	0.0000		20.000		0.2660	0.524
# React-ive[7]		220.0	-43.2		1.4328	0.0192	0.0000		20.000		0.2660	0.595
# React-ive[8]		220.0	-43.2		0.9552	0.0257	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4776	0.0321	0.0000		20.000		0.2660	0.815
# NON-react[10]		219.9	0.000		0.0000	0.0321	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0321			19.994
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.89
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.4		1.2742	0.0081	0.0688		1.0447
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		213.4	0.000		2.3959	0.0013	0.0000		20.000		0.0000	0.000
# NON-react[2]		219.4	0.000		2.3891	0.0007	0.0000		20.000		0.0000	0.000
# NON-react[3]		219.7	0.000		2.3885	0.0005	0.0000		20.000		0.0000	0.000
# NON-react[4]		219.8	0.000		2.3883	0.0002	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.3880	0.0067	0.0000		20.000		0.2660	0.468
# React-ive[6]		220.0	-43.2		1.9104	0.0131	0.0000		20.000		0.2660	0.524
# React-ive[7]		220.0	-43.2		1.4328	0.0195	0.0000		20.000		0.2660	0.595
# React-ive[8]		220.0	-43.2		0.9552	0.0259	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4776	0.0323	0.0000		20.000		0.2660	0.815
# NON-react[10]		219.9	0.000		0.0000	0.0323	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0323			19.994
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.79
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.3		1.2744	0.0181	0.0677		1.0446
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		206.4	0.000		2.4049	0.0062	0.0000		20.000		0.0000	0.000
# NON-react[2]		217.5	0.000		2.3930	0.0041	0.0000		20.000		0.0000	0.000
# NON-react[3]		218.6	0.000		2.3909	0.0030	0.0000		20.000		0.0000	0.000
# NON-react[4]		219.1	0.000		2.3899	0.0016	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.3884	0.0078	0.0000		20.000		0.2660	0.468
# React-ive[6]		220.0	-43.2		1.9105	0.0141	0.0000		20.000		0.2660	0.524
# React-ive[7]		220.0	-43.2		1.4329	0.0205	0.0000		20.000		0.2660	0.595
# React-ive[8]		220.0	-43.2		0.9552	0.0269	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4776	0.0333	0.0000		20.000		0.2660	0.815
# NON-react[10]		219.9	0.000		0.0000	0.0333	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0333			19.994
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.68
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.2		1.2749	0.0305	0.0658		1.0443
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		199.0	0.000		2.4156	0.0152	0.0000		20.000		0.0000	0.000
# NON-react[2]		214.6	0.000		2.4004	0.0110	0.0000		20.000		0.0000	0.000
# NON-react[3]		217.1	0.000		2.3962	0.0086	0.0000		20.000		0.0000	0.000
# NON-react[4]		218.2	0.000		2.3938	0.0050	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-43.2		2.3901	0.0102	0.0000		20.000		0.2660	0.468
# React-ive[6]		220.0	-43.2		1.9113	0.0162	0.0000		20.000		0.2660	0.524
# React-ive[7]		220.0	-43.2		1.4332	0.0225	0.0000		20.000		0.2660	0.595
# React-ive[8]		220.0	-43.2		0.9554	0.0288	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4776	0.0351	0.0000		20.000		0.2660	0.814
# NON-react[10]		219.9	0.000		0.0000	0.0351	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0351			19.994
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.58
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.2		1.2760	0.0461	0.0631		1.0438
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		191.7	0.000		2.4291	0.0296	0.0000		20.000		0.0000	0.000
# NON-react[2]		211.2	0.000		2.4126	0.0229	0.0000		20.000		0.0000	0.000
# NON-react[3]		215.2	0.000		2.4059	0.0187	0.0000		20.000		0.0000	0.000
# NON-react[4]		217.1	0.000		2.4017	0.0123	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-43.0		2.3953	0.0147	0.0000		20.000		0.2659	0.468
# React-ive[6]		220.0	-43.2		1.9135	0.0197	0.0000		20.000		0.2659	0.524
# React-ive[7]		220.0	-43.2		1.4343	0.0254	0.0000		20.000		0.2660	0.594
# React-ive[8]		220.0	-43.2		0.9559	0.0314	0.0000		20.000		0.2660	0.687
# React-ive[9]		220.0	-43.2		0.4778	0.0376	0.0000		20.000		0.2660	0.814
# NON-react[10]		219.9	0.000		0.0000	0.0376	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0376			19.994
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.47
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.4		1.2780	0.0667	0.0597		1.0429
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		184.6	0.000		2.4474	0.0517	0.0000		20.000		0.0000	0.000
# NON-react[2]		207.3	0.000		2.4323	0.0423	0.0000		20.000		0.0000	0.000
# NON-react[3]		213.3	0.000		2.4229	0.0360	0.0000		20.000		0.0000	0.000
# NON-react[4]		216.1	0.000		2.4166	0.0263	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-42.7		2.4070	0.0228	0.0000		20.000		0.2657	0.467
# React-ive[6]		220.0	-43.0		1.9188	0.0251	0.0000		20.000		0.2658	0.523
# React-ive[7]		220.0	-43.1		1.4368	0.0296	0.0000		20.000		0.2659	0.594
# React-ive[8]		220.0	-43.2		0.9570	0.0350	0.0000		20.000		0.2659	0.687
# React-ive[9]		220.0	-43.2		0.4783	0.0407	0.0000		20.000		0.2660	0.814
# NON-react[10]		219.9	0.000		0.0000	0.0407	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0407			19.995
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.37
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-67.9		1.2817	0.0954	0.0552		1.0413
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		177.7	0.000		2.4738	0.0862	0.0000		20.000		0.0000	0.000
# NON-react[2]		203.1	0.000		2.4646	0.0742	0.0000		20.000		0.0000	0.000
# NON-react[3]		211.3	0.000		2.4526	0.0656	0.0000		20.000		0.0000	0.000
# NON-react[4]		215.2	0.000		2.4440	0.0526	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-42.2		2.4309	0.0379	0.0000		20.000		0.2653	0.466
# React-ive[6]		220.0	-42.8		1.9309	0.0342	0.0000		20.000		0.2656	0.523
# React-ive[7]		220.0	-43.0		1.4424	0.0358	0.0000		20.000		0.2658	0.594
# React-ive[8]		220.0	-43.1		0.9595	0.0397	0.0000		20.000		0.2659	0.687
# React-ive[9]		220.0	-43.2		0.4792	0.0447	0.0000		20.000		0.2659	0.814
# NON-react[10]		219.9	0.000		0.0000	0.0447	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0447			19.995
# ------------------------------------------------------------------------------------------------------------
# > Working on PR ratio = 0.26
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-69.0		1.2891	0.1396	0.0493		1.0383
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		170.8	0.000		2.5163	0.1452	0.0000		20.000		0.0000	0.000
# NON-react[2]		198.0	0.000		2.5220	0.1310	0.0000		20.000		0.0000	0.000
# NON-react[3]		208.8	0.000		2.5077	0.1199	0.0000		20.000		0.0000	0.000
# NON-react[4]		214.3	0.000		2.4967	0.1029	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-41.3		2.4797	0.0679	0.0000		20.000		0.2645	0.464
# React-ive[6]		220.0	-42.3		1.9578	0.0510	0.0000		20.000		0.2651	0.521
# React-ive[7]		220.0	-42.7		1.4551	0.0458	0.0000		20.000		0.2655	0.593
# React-ive[8]		220.0	-43.0		0.9650	0.0465	0.0000		20.000		0.2657	0.686
# React-ive[9]		220.0	-43.1		0.4810	0.0498	0.0000		20.000		0.2658	0.814
# NON-react[10]		219.9	0.000		0.0000	0.0498	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0498			19.995
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.16
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-71.8		1.3060	0.2218	0.0408		1.0316
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		164.6	0.000		2.6003	0.2667	0.0000		20.000		0.0000	0.000
# NON-react[2]		192.3	0.000		2.6452	0.2546	0.0000		20.000		0.0000	0.000
# NON-react[3]		205.4	0.000		2.6331	0.2427	0.0000		20.000		0.0000	0.000
# NON-react[4]		212.9	0.000		2.6212	0.2210	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-39.5		2.5995	0.1393	0.0000		20.000		0.2628	0.458
# React-ive[6]		220.0	-41.1		2.0275	0.0884	0.0000		20.000		0.2638	0.516
# React-ive[7]		220.0	-42.1		1.4884	0.0647	0.0000		20.000		0.2647	0.590
# React-ive[8]		220.0	-42.7		0.9782	0.0570	0.0000		20.000		0.2653	0.685
# React-ive[9]		220.0	-42.9		0.4851	0.0566	0.0000		20.000		0.2656	0.813
# NON-react[10]		219.9	0.000		0.0000	0.0566	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0566			19.995
# ------------------------------------------------------------------------------------------------------------
#
# > Working on PR ratio = 0.05
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-81.1		1.3642	0.4618	0.0243		1.0092
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		159.7	0.000		2.8595	0.6579	0.0000		20.000		0.0000	0.000
# NON-react[2]		186.4	0.000		3.0556	0.6724	0.0000		20.000		0.0000	0.000
# NON-react[3]		201.2	0.000		3.0701	0.6694	0.0000		20.000		0.0000	0.000
# NON-react[4]		211.1	0.000		3.0671	0.6439	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-33.8		3.0417	0.4026	0.0000		20.000		0.2569	0.438
# React-ive[6]		220.0	-37.6		2.2986	0.2260	0.0000		20.000		0.2592	0.501
# React-ive[7]		220.0	-39.6		1.6248	0.1224	0.0000		20.000		0.2617	0.579
# React-ive[8]		220.0	-41.5		1.0288	0.0806	0.0000		20.000		0.2638	0.679
# React-ive[9]		220.0	-42.5		0.4987	0.0680	0.0000		20.000		0.2649	0.811
# NON-react[10]		219.9	0.000		0.0000	0.0680	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0680			19.996
# ------------------------------------------------------------------------------------------------------------
# CPU times: user 21 s, sys: 458 ms, total: 21.4 s
# Wall time: 12min 11s

# %% [markdown]
# # Introducing Reboiler (Iteratively or directly)

# %%
# %%time

T_range = np.linspace(220+273.15,350+273.15,2)
for t in T_range:
    model.reboiler.T.fix(t)
          
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    print('\n>','Working on reboiler temperature = {:.2f}'.format(t))
    print('-'*108)
    beautify(pe,model)
# Out:
# > Working on reboiler temperature = 493.15
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-81.1		1.3642	0.4618	0.0243		1.0092
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		159.7	0.000		2.8595	0.6579	0.0000		20.000		0.0000	0.000
# NON-react[2]		186.4	0.000		3.0556	0.6724	0.0000		20.000		0.0000	0.000
# NON-react[3]		201.2	0.000		3.0701	0.6694	0.0000		20.000		0.0000	0.000
# NON-react[4]		211.1	0.000		3.0671	0.6439	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-33.8		3.0417	0.4026	0.0000		20.000		0.2569	0.438
# React-ive[6]		220.0	-37.6		2.2986	0.2260	0.0000		20.000		0.2592	0.501
# React-ive[7]		220.0	-39.6		1.6248	0.1224	0.0000		20.000		0.2617	0.579
# React-ive[8]		220.0	-41.5		1.0288	0.0806	0.0000		20.000		0.2638	0.679
# React-ive[9]		220.0	-42.5		0.4987	0.0680	0.0000		20.000		0.2649	0.811
# NON-react[10]		219.9	0.000		0.0000	0.0680	0.0000		19.998		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		220.0	0.000		0.0000	0.0680			19.996
# ------------------------------------------------------------------------------------------------------------
#
# > Working on reboiler temperature = 623.15
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-81.3		1.3667	0.4629	0.0243		1.0113
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		159.7	0.000		2.8654	0.6596	0.0000		20.000		0.0000	0.000
# NON-react[2]		186.5	0.000		3.0620	0.6741	0.0000		20.000		0.0000	0.000
# NON-react[3]		201.2	0.000		3.0766	0.6712	0.0000		20.000		0.0000	0.000
# NON-react[4]		211.1	0.000		3.0737	0.6459	0.0000		20.000		0.0000	0.000
# React-ive[5]		220.0	-33.8		3.0483	0.4043	0.0000		20.000		0.2569	0.438
# React-ive[6]		220.0	-37.5		2.3051	0.2273	0.0000		20.000		0.2592	0.500
# React-ive[7]		220.0	-39.6		1.6308	0.1232	0.0000		20.000		0.2616	0.578
# React-ive[8]		220.0	-41.5		1.0342	0.0810	0.0000		20.000		0.2637	0.678
# React-ive[9]		220.0	-42.5		0.5036	0.0682	0.0000		20.000		0.2648	0.810
# NON-react[10]		229.5	0.000		0.0044	0.0737	0.0000		20.000		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		350.0	5.881		0.0099	0.0638			20.000
# ------------------------------------------------------------------------------------------------------------
# CPU times: user 4.53 s, sys: 108 ms, total: 4.63 s
# Wall time: 25.4 s

# %% [markdown]
# # Introduce Side-draws

# %%
for j in side_draw_flag.keys():
    
    r = side_draw_flag[j]
    model.reactive[j].PR_L.fix(r)
          
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    print('\n>','Working on side draw of {:.1%} on stage {}'.format(r,j))
    print('-'*108)
    beautify(pe,model)
# Out:
# > Working on side draw of 20.0% on stage 4
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-69.8		1.3012	0.3085	0.0162		1.0353
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		138.0	0.000		2.6614	0.3892	0.0000		20.000		0.0000	0.000
# NON-react[2]		157.6	0.000		2.7420	0.3409	0.0000		20.000		0.0000	0.000
# NON-react[3]		174.1	0.000		2.6938	0.2708	0.0000		20.000		0.0000	0.000
# NON-react[4]		193.4	0.000		2.6236	0.1414	0.0353		20.000		0.0000	0.000
# React-ive[5]		220.0	-38.4		2.5296	0.0454	0.0000		20.000		0.2631	0.462
# React-ive[6]		220.0	-42.5		1.9441	0.0318	0.0000		20.000		0.2653	0.522
# React-ive[7]		220.0	-43.0		1.4451	0.0325	0.0000		20.000		0.2658	0.593
# React-ive[8]		220.0	-43.1		0.9613	0.0366	0.0000		20.000		0.2659	0.686
# React-ive[9]		220.0	-43.2		0.4812	0.0419	0.0000		20.000		0.2659	0.814
# NON-react[10]		225.2	0.000		0.0021	0.0441	0.0000		20.000		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		350.0	4.046		0.0044	0.0397			20.000
# ------------------------------------------------------------------------------------------------------------
#
# > Working on side draw of 70.0% on stage 7
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-69.8		1.3000	0.3078	0.0162		1.0350
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		137.9	0.000		2.6591	0.3882	0.0000		20.000		0.0000	0.000
# NON-react[2]		157.4	0.000		2.7395	0.3403	0.0000		20.000		0.0000	0.000
# NON-react[3]		173.8	0.000		2.6916	0.2705	0.0000		20.000		0.0000	0.000
# NON-react[4]		193.0	0.000		2.6218	0.1401	0.0350		20.000		0.0000	0.000
# React-ive[5]		220.0	-38.4		2.5264	0.0437	0.0000		20.000		0.2631	0.462
# React-ive[6]		220.0	-42.5		1.9405	0.0304	0.0000		20.000		0.2653	0.522
# React-ive[7]		220.0	-43.0		1.4419	0.0092	0.0215		20.000		0.2658	0.594
# React-ive[8]		220.0	-43.2		0.9578	0.0146	0.0000		20.000		0.2659	0.687
# React-ive[9]		220.0	-43.2		0.4791	0.0207	0.0000		20.000		0.2659	0.814
# NON-react[10]		224.7	0.000		0.0010	0.0217	0.0000		20.000		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		350.0	2.061		0.0021	0.0196			20.000
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Fine Tuning Stage Temperature

# %%
for j in temperature_flag.keys():
    
    t = temperature_flag[j] + 273.15
    model.reactive[j].T.setub(t)
          
    results = opt.solve(model,tee=False)
    update_dual(pe,model)
    print('\n>','Working on adjusting stage {} temperature to {:.2f}C '.format(j,t-273.15))
    print('-'*108)
    beautify(pe,model)
# Out:
# > Working on adjusting stage 6 temperature to 513.15C
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-74.0		1.1741	0.3655	0.0192		1.0991
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		135.2	0.000		2.6581	0.4589	0.0000		20.000		0.0000	0.000
# NON-react[2]		153.4	0.000		2.7515	0.4034	0.0000		20.000		0.0000	0.000
# NON-react[3]		170.2	0.000		2.6960	0.3212	0.0000		20.000		0.0000	0.000
# NON-react[4]		191.3	0.000		2.6138	0.1705	0.0426		20.000		0.0000	0.000
# React-ive[5]		220.0	-37.4		2.5057	0.0817	0.0000		20.000		0.2423	0.477
# React-ive[6]		240.0	-45.7		1.8869	0.0285	0.0000		20.000		0.3228	0.643
# React-ive[7]		220.0	-43.2		1.4444	0.0080	0.0187		20.000		0.2657	0.594
# React-ive[8]		220.0	-43.2		0.9580	0.0132	0.0000		20.000		0.2659	0.687
# React-ive[9]		220.0	-43.2		0.4790	0.0192	0.0000		20.000		0.2659	0.814
# NON-react[10]		224.8	0.000		0.0009	0.0202	0.0000		20.000		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		350.0	1.908		0.0019	0.0182			20.000
# ------------------------------------------------------------------------------------------------------------
#
# > Working on adjusting stage 7 temperature to 513.15C
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-76.7		1.1186	0.4144	0.0218		1.1317
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		133.4	0.000		2.6866	0.5166	0.0000		20.000		0.0000	0.000
# NON-react[2]		150.7	0.000		2.7889	0.4559	0.0000		20.000		0.0000	0.000
# NON-react[3]		167.6	0.000		2.7281	0.3648	0.0000		20.000		0.0000	0.000
# NON-react[4]		189.7	0.000		2.6370	0.1953	0.0488		20.000		0.0000	0.000
# React-ive[5]		220.0	-36.4		2.5164	0.0947	0.0000		20.000		0.2377	0.492
# React-ive[6]		240.0	-43.2		1.8768	0.0446	0.0000		20.000		0.2953	0.656
# React-ive[7]		240.0	-46.7		1.3854	0.0068	0.0160		20.000		0.3143	0.712
# React-ive[8]		220.0	-43.3		0.9583	0.0118	0.0000		20.000		0.2659	0.687
# React-ive[9]		220.0	-43.2		0.4790	0.0177	0.0000		20.000		0.2659	0.814
# NON-react[10]		224.8	0.000		0.0009	0.0187	0.0000		20.000		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		350.0	1.755		0.0018	0.0168			20.000
# ------------------------------------------------------------------------------------------------------------
#
# > Working on adjusting stage 8 temperature to 518.15C
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-78.6		1.1034	0.4671	0.0245		1.1463
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		131.2	0.000		2.7414	0.5758	0.0000		20.000		0.0000	0.000
# NON-react[2]		147.9	0.000		2.8502	0.5097	0.0000		20.000		0.0000	0.000
# NON-react[3]		164.8	0.000		2.7840	0.4098	0.0000		20.000		0.0000	0.000
# NON-react[4]		187.6	0.000		2.6841	0.2181	0.0545		20.000		0.0000	0.000
# React-ive[5]		220.0	-35.3		2.5469	0.0980	0.0000		20.000		0.2347	0.501
# React-ive[6]		240.0	-42.1		1.8821	0.0448	0.0000		20.000		0.2871	0.673
# React-ive[7]		240.0	-44.2		1.3722	0.0081	0.0189		20.000		0.2878	0.734
# React-ive[8]		245.0	-46.7		0.8988	0.0033	0.0000		20.000		0.3107	0.817
# React-ive[9]		220.0	-43.3		0.4782	0.0096	0.0000		20.000		0.2660	0.815
# NON-react[10]		224.6	0.000		0.0004	0.0101	0.0000		20.000		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		350.0	0.970		0.0009	0.0091			20.000
# ------------------------------------------------------------------------------------------------------------
#
# > Working on adjusting stage 9 temperature to 523.15C
# ------------------------------------------------------------------------------------------------------------
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages			T	Q		V_out	L_out	L_Prod		W
# Condenser		30.00	-79.8		1.1316	0.5197	0.0273		1.1415
#
# stages			T	Q		V_out	L_out	L_Prod		P_VLE		r_FT	Conversion
# NON-react[1]		129.1	0.000		2.8203	0.6335	0.0000		20.000		0.0000	0.000
# NON-react[2]		145.5	0.000		2.9340	0.5617	0.0000		20.000		0.0000	0.000
# NON-react[3]		162.3	0.000		2.8622	0.4526	0.0000		20.000		0.0000	0.000
# NON-react[4]		185.7	0.000		2.7531	0.2381	0.0595		20.000		0.0000	0.000
# React-ive[5]		220.0	-34.4		2.5982	0.1002	0.0000		20.000		0.2331	0.503
# React-ive[6]		240.0	-41.7		1.9124	0.0447	0.0000		20.000		0.2846	0.679
# React-ive[7]		240.0	-43.7		1.3954	0.0081	0.0190		20.000		0.2826	0.745
# React-ive[8]		245.0	-44.6		0.9124	0.0043	0.0000		20.000		0.2889	0.836
# React-ive[9]		250.0	-45.0		0.4519	0.0026	0.0000		20.000		0.2941	0.922
# NON-react[10]		252.4	0.000		0.0001	0.0027	0.0000		19.999		0.0000	0.000
#
# stages			T	Q		V_out	L_out			P_VLE
# Reboiler		350.0	0.213		0.0002	0.0025			19.999
# ------------------------------------------------------------------------------------------------------------

# %%
# with open('modelsaved.pickle','wb') as f:
#     dill.dump(model,f)

# %%
plot_distribution(model)
