# %% [markdown]
# # 2nd Level Model Structure: Reactive Stage

# %%
import sys
import os
import pickle
sys.path.append(os.path.abspath('..'))
import numpy as np
from matplotlib import pyplot as plt

# %%
from pyomo import environ as pe
from global_sets.component import m
from utility.display_utility import trans_product_mole, trans_product_mass
from utility.model_utility import add_dual, update_dual, check_DOF

# stage construction rules
from physics.kinetics_bounded import kinetic_block_rule
from physics.energy_bounded import energy_block_rule
from physics.VLE_bounded_MPCC_P import VLE_block_rule
from physics.MPCC_P import P_NCP_block_rule, P_Reg_block_rule, P_pf_block_rule

model = pe.ConcreteModel()

# %% [markdown]
# # Global Sets (Inlet / Outlet)

# %%
model.inlet = pe.Set(initialize=['in'])
model.outlet = pe.Set(initialize=['out','P'])
model.stream = model.inlet | model.outlet

# %% [markdown]
# # Global Variables

# %%
# Tray Inlet/Outlet Variable
model.x_ = pe.Var(model.inlet,m.COMP_TOTAL,within=pe.NonNegativeReals)
model.y_ = pe.Var(model.inlet,m.COMP_TOTAL,within=pe.NonNegativeReals)
model.x = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals)
model.y = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals)
model.z = pe.Var(m.COMP_FEED,within=pe.NonNegativeReals)

model.L = pe.Var(model.stream,within=pe.NonNegativeReals)
model.V = pe.Var(model.stream,within=pe.NonNegativeReals)
model.F = pe.Var(within=pe.NonNegativeReals)

model.H_L_ = pe.Var(model.inlet,within=pe.Reals)
model.H_V_ = pe.Var(model.inlet,within=pe.Reals)
model.H_L = pe.Var(within=pe.Reals)
model.H_V = pe.Var(within=pe.Reals)
model.H_F = pe.Var(within=pe.Reals)

# State Variable
model.T = pe.Var(within=pe.NonNegativeReals,bounds=(200+273.15,300+273.15)) # K
model.T_F = pe.Var(within=pe.NonNegativeReals) # K
model.P = pe.Var(within=pe.NonNegativeReals,bounds=(10,30)) # Bar

model.f_V = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals,initialize=1e-20)
model.f_L = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals,initialize=1e-20)

model.cat = pe.Var(within=pe.NonNegativeReals,initialize=3000) # kg
model.Q_main = pe.Var(within=pe.Reals) # MW
model.r_total_comp = pe.Var(m.COMP_TOTAL,within=pe.Reals) # kmol/s

# %% [markdown]
# # Construct Individual Blocks

# %%
model.kinetics_block = pe.Block(rule=kinetic_block_rule)
# Out:
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | kinetics_block.k_FT
# | kinetics_block.r_FT_total
# | kinetics_block.g0_FT
# | kinetics_block.alpha
# | kinetics_block.r_FT_cnum
# | kinetics_block.r_FT_comp
# | kinetics_block.k_WGS
# | kinetics_block.Ke_WGS
# | kinetics_block.r_WGS
# | kinetics_block.r_WGS_comp
# --------------------------------------------------

# %%
model.energy_block = pe.Block(rule=energy_block_rule)
# Out:
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | energy_block.dH_F
# | energy_block.dH_V
# | energy_block.dH_L
# | energy_block.dH_vap
# --------------------------------------------------

# %%
model.VLE_block = pe.Block(rule=VLE_block_rule)
# Out:
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | VLE_block.P_VLE
# | VLE_block.n_ave
# | VLE_block.n_ave_cal
# | VLE_block.Hen
# | VLE_block.Hen0
# | VLE_block.gamma
# | VLE_block.P_sat
# | VLE_block.P_sat_Y
# | VLE_block.P_sat_dY_inf
# | VLE_block.P_sat_dY0
# | VLE_block.Hen_ref
# | VLE_block.Hen0_ref
# | VLE_block.gamma_ref
# | VLE_block.V_L
# | VLE_block.V_L_dY_inf
# | VLE_block.V_L_dY0
# | VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# # Standard MESH Equations

# %% [markdown]
# ## Mass Balance

# %% [markdown]
# \begin{equation}
# Fz_{i}+\sum_{s\in{inlet}}L_{s}x'_{i,s}+\sum_{s\in{inlet}}V_{s}y'_{i,s}-\sum_{s\in{outlet}}L_{s}x_{i,s}+\sum_{s\in{ouelet}}V_{s}y_{i,s}+R_{i} = 0 \\
# i = 1,...NC
# \end{equation}

# %%
def mass_balance_main_rule(model,i):
    if i in m.COMP_FEED:
        return model.F*model.z[i] + sum(model.L[s]*model.x_[s,i] + model.V[s]*model.y_[s,i] for s in model.inlet)\
        + model.r_total_comp[i] - sum(model.L[s]*model.x[i] + model.V[s]*model.y[i] for s in model.outlet) == 0
    else:
        return sum(model.L[s]*model.x_[s,i] + model.V[s]*model.y_[s,i] for s in model.inlet)\
        + model.r_total_comp[i] - sum(model.L[s]*model.x[i] + model.V[s]*model.y[i] for s in model.outlet) == 0
model.mass_balance_main_con = pe.Constraint(m.COMP_TOTAL,rule=mass_balance_main_rule)

# %% [markdown]
# ## Equilibrium

# %% [markdown]
# \begin{align}
# &f_{i,V} = f_{i,L} \\
# &i = 1,...NC
# \end{align}

# %%
def VL_equil_rule(model,i):
    return model.f_V[i] == model.f_L[i]
model.VL_equil_con = pe.Constraint(m.COMP_TOTAL,rule=VL_equil_rule)

# %% [markdown]
# ## MPCC: P-Pspec

# %%
model.MPCC = pe.Block(rule = P_Reg_block_rule)
# Out:
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | MPCC.s_L
# | MPCC.s_V
# | MPCC.epi
# --------------------------------------------------
# > Adding complementarity constraint, spliting pressure used in VLE

# %% [markdown]
# ## Summation

# %% [markdown]
# \begin{equation}
# \sum_ix_{i} = \sum_iy_{i} \\
# F + L_{in} + V_{in} + R = L_{out} + V_{out}
# \end{equation}

# %%
def summation_x_y_rule(model):
    return sum(model.x[i] for i in m.COMP_TOTAL) == sum(model.y[i] for i in m.COMP_TOTAL)
model.summation_x_y_con = pe.Constraint(rule=summation_x_y_rule)

def summation_total_mass_rule(model):
    return model.F + sum(model.L[s] + model.V[s] for s in model.inlet) + sum(model.r_total_comp[i] for i in m.COMP_TOTAL)\
            - sum(model.L[s] + model.V[s] for s in model.outlet) == 0
model.summation_total_mass_con = pe.Constraint(rule=summation_total_mass_rule)

# %% [markdown]
# ## Energy Balance

# %% [markdown]
# \begin{equation}
# F H_f+\sum_{s\in{inlet}}L_{s}H_{l,s}+\sum_{s\in{inlet}}V_{s}H_{v,s}-\sum_{s\in{outlet}}L_{s}H_{l,s}-\sum_{s\in{outlet}}V_{s}H_{v,s}+Q = 0
# \end{equation}

# %%
def heat_balance_main_rule(model):
    return model.F*model.H_F + sum(model.L[s]*model.H_L_[s] + model.V[s]*model.H_V_[s] for s in model.inlet) \
            + model.Q_main - sum(model.L[s]*model.H_L + model.V[s]*model.H_V for s in model.outlet) == 0
model.heat_balance_main_con = pe.Constraint(rule=heat_balance_main_rule)

# %% [markdown]
# # Testing

# %%
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# ## Fixing In/Product Redundent Flow

# %%
model.x_.fix(0)
model.y_.fix(0)
model.L['in'].fix(0)
model.L['P'].fix(0)
model.V['in'].fix(0)
model.V['P'].fix(0)
model.H_L_.fix(0)
model.H_V_.fix(0)

# %% [markdown]
# ## Fixing Model Parameters

# %%
model.cat.fix(300)
model.P.fix(20)
model.T_F.fix(200+273.15)
model.F.fix(1)
model.z['CO'].fix(1/(1+0.8)-0/2)
model.z['H2'].fix(0.8/(1+0.8)-0/2)
model.z['C30H62'].fix(0)
model.VLE_block.n_ave.fix(20)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 1182
# Active Inequality Constraints:	 2
# Active Variables:		 1357
# Fixed Variables:		 172
# DOF:				 3

# %% [markdown]
# ## Fix T or to fix Q? we have found that Maximize against an upper bound is most reliable

# %%
model.T.setub(300+273.15)

# %%
# model.obj = pe.Objective(expr = model.L['out'],sense=pe.maximize)
# model.obj = pe.Objective(expr = model.cat,sense=pe.minimize)
# model.obj = pe.Objective(expr = model.T - model.MPCC.pf ,sense=pe.maximize)
model.obj = pe.Objective(expr = model.T ,sense=pe.maximize)

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'

opt.options['linear_system_scaling '] = 'mc19'
opt.options['linear_scaling_on_demand '] = 'no'
# opt.options['recalc_y'] = 'yes'
# opt.options['bound_relax_factor'] = 0
# opt.options['halt_on_ampl_error'] = 'yes'

opt.options['max_iter'] = 7000
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     4012
# Number of nonzeros in inequality constraint Jacobian.:        4
# Number of nonzeros in Lagrangian Hessian.............:     4395
#
# Total number of variables............................:     1185
#                      variables with only lower bounds:      382
#                 variables with lower and upper bounds:      633
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1182
# Total number of inequality constraints...............:        2
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        2
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.7415000e+02 7.97e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.7415765e+02 7.97e+03 5.08e+01  -1.0 1.29e+04    -  9.76e-05 2.02e-04h  1
#    2 -4.7415959e+02 7.97e+03 3.35e+01  -1.0 5.59e+03    -  1.77e-04 5.41e-05h  1
#    3 -4.7416439e+02 7.96e+03 1.88e+02  -1.0 4.58e+03    -  2.97e-04 1.29e-04h  1
#    4 -4.7416557e+02 7.96e+03 2.48e+02  -1.0 8.03e+03    -  7.12e-05 2.26e-05h  1
#    5 -4.7416844e+02 7.96e+03 7.56e+02  -1.0 8.37e+03    -  3.56e-04 5.43e-05h  1
#    6 -4.7420278e+02 7.96e+03 7.92e+04  -1.0 8.33e+03    -  5.38e-04 6.48e-04h  1
#    7 -4.7421196e+02 7.96e+03 9.79e+04  -1.0 7.85e+03    -  1.50e-03 1.73e-04h  1
#    8r-4.7421196e+02 7.96e+03 9.99e+02   3.8 0.00e+00    -  0.00e+00 4.36e-07R  3
#    9r-4.7422118e+02 7.96e+03 1.28e+03   3.8 5.59e+05    -  4.43e-04 2.23e-06f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r
-02 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150 -5.6791998e+02 7.37e-03 1.14e+05  -3.8 1.74e+01    -  9.93e-01 3.54e-01h  1
#  151 -5.6930220e+02 9.26e-01 2.14e+06  -3.8 4.86e+02    -  8.65e-01 5.73e-01f  1
#  152 -5.6930299e+02 9.26e-01 2.14e+06  -3.8 5.36e+03    -  5.77e-01 3.00e-05h  1
#  153 -5.7070219e+02 1.32e+00 5.85e+06  -3.8 4.69e+02    -  9.73e-01 6.06e-01f  1
#  154 -5.7070759e+02 1.31e+00 5.84e+06  -3.8 5.12e+02    -  1.06e-02 2.16e-03h  1
#  155 -5.7180446e+02 1.09e+00 1.08e+07  -3.8 3.63e+02    -  9.90e-01 6.18e-01f  1
#  156 -5.7224520e+02 9.11e-01 3.65e+09  -3.8 3.62e+02    -  2.20e-02 2.50e-01h  1
#  157 -5.7314987e+02 8.06e-01 8.86e+08  -3.8 3.36e+02    -  1.00e+00 5.55e-01f  1
#  158 -5.7315001e+02 8.06e-01 8.86e+08  -3.8 2.16e+02    -  2.58e-03 1.31e-04h  1
#  159 -5.7314983e+02 8.68e-04 1.14e+08  -3.8 7.70e-01    -  2.09e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160 -5.7314985e+02 1.72e-09 1.17e+05  -3.8 4.81e-03    -  1.00e+00 1.00e+00h  1
#  161 -5.7314985e+02 1.81e-10 3.37e+03  -3.8 3.26e-04    -  1.00e+00 1.00e+00h  1
#  162 -5.7314985e+02 3.05e-10 1.00e+02  -3.8 2.58e-05    -  1.00e+00 1.00e+00h  1
#  163 -5.7315001e+02 1.14e-08 1.23e+04  -5.7 3.15e-02    -  1.00e+00 9.99e-01f  1
#  164 -5.7315000e+02 8.28e-11 8.03e-02  -5.7 3.81e-04    -  1.00e+00 1.00e+00f  1
#  165 -5.7315001e+02 8.28e-11 1.84e+00  -8.6 3.80e-04    -  1.00e+00 1.00e+00h  1
#  166 -5.7315001e+02 1.53e-10 6.04e-11  -8.6 5.96e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 166
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -5.7315000572899407e+02   -5.7315000572899407e+02
# Dual infeasibility......:   6.0354943265394922e-11    6.0354943265394922e-11
# Constraint violation....:   1.5274228442382215e-10    1.5274228442382215e-10
# Complementarity.........:   2.5059035596944961e-09    2.5059035596944961e-09
# Overall NLP error.......:   2.5059035596944961e-09    2.5059035596944961e-09
#
#
# Number of objective function evaluations             = 244
# Number of objective gradient evaluations             = 155
# Number of equality constraint evaluations            = 244
# Number of inequality constraint evaluations          = 244
# Number of equality constraint Jacobian evaluations   = 173
# Number of inequality constraint Jacobian evaluations = 173
# Number of Lagrangian Hessian evaluations             = 166
# Total CPU secs in IPOPT (w/o function evaluations)   =     11.112
# Total CPU secs in NLP function evaluations           =      0.454
#
# EXIT: Optimal Solution Found.

# %%
model.T.value
# Out:
# 573.15

# %%
model.MPCC.s_L.value
# Out:
# 147.10139063235673

# %%
model.VLE_block.P_VLE.value
# Out:
# 167.101281767178

# %%
model.L['out'].value
# Out:
# 3.2304285569038267e-07

# %%
print('Component\t\tLiquid: {:.4f}\t\t\tVapor: {:.4f}'.format(model.L['out'].value,model.V['out'].value))
print('-'*108)
for i in model.x:
    print('{:10s}'.format(i),'\t\t{:8.4%}\t\t\t{:8.4%}'.format(model.x[i].value,model.y[i].value))
# Out:
# Component		Liquid: 0.0000			Vapor: 0.4593
# ------------------------------------------------------------------------------------------------------------
# H2         		 0.2828%			 0.7035%
# CO         		 0.2377%			 0.5086%
# CO2        		46.5717%			55.9864%
# H2O        		10.7859%			 8.4733%
# C2H4       		 5.6346%			 5.5577%
# C3H6       		 5.8014%			 3.1957%
# C4H8       		 2.3439%			 1.4195%
# C5H10      		 1.6857%			 0.5496%
# C6H12      		 1.3145%			 0.2569%
# C7H14      		 0.9576%			 0.1201%
# C8H16      		 0.6655%			 0.0561%
# C9H18      		 0.4470%			 0.0262%
# C10H20     		 0.2925%			 0.0123%
# C11H22     		 0.1195%			 0.0037%
# C12H24     		 0.0754%			 0.0017%
# C13H26     		 0.0469%			 0.0008%
# C14H28     		 0.0289%			 0.0004%
# C15H30     		 0.0176%			 0.0002%
# C16H32     		 0.0107%			 0.0001%
# C17H34     		 0.0064%			 0.0000%
# C18H36     		 0.0038%			 0.0000%
# C19H38     		 0.0023%			 0.0000%
# C20H40     		 0.0013%			 0.0000%
# C1H4       		13.3450%			18.2816%
# C2H6       		 3.2223%			 2.9880%
# C3H8       		 1.3634%			 0.7989%
# C4H10      		 0.8272%			 0.4478%
# C5H12      		 1.0875%			 0.3233%
# C6H14      		 0.8378%			 0.1511%
# C7H16      		 0.6054%			 0.0706%
# C8H18      		 0.4183%			 0.0330%
# C9H20      		 0.2797%			 0.0154%
# C10H22     		 0.1824%			 0.0072%
# C11H24     		 0.1886%			 0.0055%
# C12H26     		 0.1187%			 0.0025%
# C13H28     		 0.0738%			 0.0012%
# C14H30     		 0.0453%			 0.0006%
# C15H32     		 0.0276%			 0.0003%
# C16H34     		 0.0167%			 0.0001%
# C17H36     		 0.0100%			 0.0001%
# C18H38     		 0.0060%			 0.0000%
# C19H40     		 0.0035%			 0.0000%
# C20H42     		 0.0021%			 0.0000%
# C21H44     		 0.0021%			 0.0000%
# C22H46     		 0.0012%			 0.0000%
# C23H48     		 0.0007%			 0.0000%
# C24H50     		 0.0004%			 0.0000%
# C25H52     		 0.0002%			 0.0000%
# C26H54     		 0.0001%			 0.0000%
# C27H56     		 0.0001%			 0.0000%
# C28H58     		 0.0000%			 0.0000%
# C29H60     		 0.0000%			 0.0000%
# C30H62     		 0.0000%			 0.0000%
# C31H64     		 0.0000%			 0.0000%
# C32H66     		 0.0000%			 0.0000%
# C33H68     		 0.0000%			 0.0000%
# C34H70     		 0.0000%			 0.0000%
# C35H72     		 0.0000%			 0.0000%
# C36H74     		 0.0000%			 0.0000%
# C37H76     		 0.0000%			 0.0000%
# C38H78     		 0.0000%			 0.0000%
# C39H80     		 0.0000%			 0.0000%
# C40H82     		 0.0000%			 0.0000%
# C41H84     		 0.0000%			 0.0000%
# C42H86     		 0.0000%			 0.0000%
# C43H88     		 0.0000%			 0.0000%
# C44H90     		 0.0000%			 0.0000%
# C45H92     		 0.0000%			 0.0000%
# C46H94     		 0.0000%			 0.0000%
# C47H96     		 0.0000%			 0.0000%
# C48H98     		 0.0000%			 0.0000%
# C49H100    		 0.0000%			 0.0000%
# C50H102    		 0.0000%			 0.0000%
# C51H104    		 0.0000%			 0.0000%
# C52H106    		 0.0000%			 0.0000%
# C53H108    		 0.0000%			 0.0000%
# C54H110    		 0.0000%			 0.0000%
# C55H112    		 0.0000%			 0.0000%
# C56H114    		 0.0000%			 0.0000%

# %% [markdown]
# # Iterative Solve for Data Analysis

# %%
results_anchor = results
update_dual(pe,model)
model.solutions.store_to(results_anchor)

# %%
opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6

# %%
catrange = [3000,1000,500,300,100,50,25,10]
Trange = np.linspace(300+273.15,200+273.15,26)

# %%
rf_data_master = {}

for c in catrange:
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = model.cat ,sense=pe.minimize)

    model.solutions.load_from(results_anchor)
    update_dual(pe,model) 
       
    model.T.fix(300+273.15)
    model.cat.fixed = False
    model.cat.setlb(c)
    
    results_anchor = opt.solve(model,tee=False)
    model.solutions.store_to(results_anchor)
    update_dual(pe,model)
    
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = model.T ,sense=pe.maximize)
    model.T.fixed = False
    model.cat.fixed = True
    
    
    print('\nWorking on Cat = {} kg'.format(model.cat.value))
    print('-'*108)
    
    rf_data = {}
    rf_data['x'] = {};rf_data['y'] = {};
    rf_data['T'] = []; rf_data['Q'] = []; rf_data['V'] = []; rf_data['L'] = []; rf_data['P_VLE'] = []; 
    rf_data['s_L'] = [];
    for i in m.COMP_TOTAL:
        rf_data['x'][i] = []
        rf_data['y'][i] = []       

    for t in Trange:
        model.T.setub(t)
        results = opt.solve(model,tee=False)
        update_dual(pe,model)
        model.T.setub(300+273.15)
        print('Solved\t|T = {:.2f} K\t|V = {:.4f} kmol/s\t|L = {:.4f} kmol/s\t|s_L = {:.4f}\t|P_VLE = {:.1f}'.\
              format(model.T.value,model.V['out'].value,model.L['out'].value,model.MPCC.s_L.value,model.VLE_block.P_VLE.value))
    
        rf_data['T'].append(model.T.value)
        rf_data['Q'].append(model.Q_main.value)
        rf_data['V'].append(model.V['out'].value)
        rf_data['L'].append(model.L['out'].value)
        rf_data['P_VLE'].append(model.VLE_block.P_VLE.value)
        rf_data['s_L'].append(model.MPCC.s_L.value)

        for i in m.COMP_TOTAL:
            rf_data['x'][i].append(model.x[i].value)
            rf_data['y'][i].append(model.y[i].value)
        
    rf_data_master[c] = rf_data
# Out:
# Working on Cat = 3000.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4565 kmol/s	|L = 0.0000 kmol/s	|s_L = 145.8949	|P_VLE = 165.9
# Solved	|T = 569.15 K	|V = 0.4534 kmol/s	|L = 0.0000 kmol/s	|s_L = 140.3890	|P_VLE = 160.4
# Solved	|T = 565.15 K	|V = 0.4502 kmol/s	|L = 0.0000 kmol/s	|s_L = 134.1965	|P_VLE = 154.2
# Solved	|T = 561.15 K	|V = 0.4468 kmol/s	|L = 0.0000 kmol/s	|s_L = 127.2007	|P_VLE = 147.2
# Solved	|T = 557.15 K	|V = 0.4432 kmol/s	|L = 0.0000 kmol/s	|s_L = 119.2575	|P_VLE = 139.3
# Solved	|T = 553.15 K	|V = 0.4394 kmol/s	|L = 0.0000 kmol/s	|s_L = 110.1905	|P_VLE = 130.2
# Solved	|T = 549.15 K	|V = 0.4353 kmol/s	|L = 0.0000 kmol/s	|s_L = 99.7883	|P_VLE = 119.8
# Solved	|T = 545.15 K	|V = 0.4312 kmol/s	|L = 0.0000 kmol/s	|s_L = 87.8083	|P_VLE = 107.8
# Solved	|T = 541.15 K	|V = 0.4269 kmol/s	|L = 0.0000 kmol/s	|s_L = 74.0023	|P_VLE = 94.0
# Solved	|T = 537.15 K	|V = 0.4227 kmol/s	|L = 0.0000 kmol/s	|s_L = 58.1936	|P_VLE = 78.2
# Solved	|T = 533.15 K	|V = 0.4186 kmol/s	|L = 0.0000 kmol/s	|s_L = 40.4861	|P_VLE = 60.5
# Solved	|T = 529.15 K	|V = 0.4152 kmol/s	|L = 0.0000 kmol/s	|s_L = 21.7650	|P_VLE = 41.8
# Solved	|T = 525.15 K	|V = 0.4142 kmol/s	|L = 0.0000 kmol/s	|s_L = 4.4525	|P_VLE = 24.5
# Solved	|T = 521.15 K	|V = 0.4127 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0696	|P_VLE = 20.1
# Solved	|T = 517.15 K	|V = 0.4095 kmol/s	|L = 0.0004 kmol/s	|s_L = 0.0714	|P_VLE = 20.1
# Solved	|T = 513.15 K	|V = 0.4064 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0359	|P_VLE = 20.0
# Solved	|T = 509.15 K	|V = 0.4037 kmol/s	|L = 0.0025 kmol/s	|s_L = 0.0193	|P_VLE = 20.0
# Solved	|T = 505.15 K	|V = 0.4019 kmol/s	|L = 0.0040 kmol/s	|s_L = 0.0123	|P_VLE = 20.0
# Solved	|T = 501.15 K	|V = 0.4016 kmol/s	|L = 0.0055 kmol/s	|s_L = 0.0090	|P_VLE = 20.0
# Solved	|T = 497.15 K	|V = 0.4035 kmol/s	|L = 0.0069 kmol/s	|s_L = 0.0072	|P_VLE = 20.0
# Solved	|T = 493.15 K	|V = 0.4087 kmol/s	|L = 0.0080 kmol/s	|s_L = 0.0062	|P_VLE = 20.0
# Solved	|T = 489.15 K	|V = 0.4183 kmol/s	|L = 0.0087 kmol/s	|s_L = 0.0057	|P_VLE = 20.0
# Solved	|T = 485.15 K	|V = 0.4338 kmol/s	|L = 0.0090 kmol/s	|s_L = 0.0056	|P_VLE = 20.0
# Solved	|T = 481.15 K	|V = 0.4569 kmol/s	|L = 0.0088 kmol/s	|s_L = 0.0057	|P_VLE = 20.0
# Solved	|T = 477.15 K	|V = 0.4886 kmol/s	|L = 0.0083 kmol/s	|s_L = 0.0060	|P_VLE = 20.0
# Solved	|T = 473.15 K	|V = 0.5291 kmol/s	|L = 0.0076 kmol/s	|s_L = 0.0067	|P_VLE = 20.0
#
# Working on Cat = 1000.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4569 kmol/s	|L = 0.0000 kmol/s	|s_L = 146.0885	|P_VLE = 166.1
# Solved	|T = 569.15 K	|V = 0.4540 kmol/s	|L = 0.0000 kmol/s	|s_L = 140.6270	|P_VLE = 160.6
# Solved	|T = 565.15 K	|V = 0.4509 kmol/s	|L = 0.0000 kmol/s	|s_L = 134.4902	|P_VLE = 154.5
# Solved	|T = 561.15 K	|V = 0.4476 kmol/s	|L = 0.0000 kmol/s	|s_L = 127.5644	|P_VLE = 147.6
# Solved	|T = 557.15 K	|V = 0.4442 kmol/s	|L = 0.0000 kmol/s	|s_L = 119.7094	|P_VLE = 139.7
# Solved	|T = 553.15 K	|V = 0.4407 kmol/s	|L = 0.0000 kmol/s	|s_L = 110.7541	|P_VLE = 130.8
# Solved	|T = 549.15 K	|V = 0.4371 kmol/s	|L = 0.0000 kmol/s	|s_L = 100.4938	|P_VLE = 120.5
# Solved	|T = 545.15 K	|V = 0.4336 kmol/s	|L = 0.0000 kmol/s	|s_L = 88.6948	|P_VLE = 108.7
# Solved	|T = 541.15 K	|V = 0.4303 kmol/s	|L = 0.0000 kmol/s	|s_L = 75.1199	|P_VLE = 95.1
# Solved	|T = 537.15 K	|V = 0.4275 kmol/s	|L = 0.0000 kmol/s	|s_L = 59.6051	|P_VLE = 79.6
# Solved	|T = 533.15 K	|V = 0.4262 kmol/s	|L = 0.0000 kmol/s	|s_L = 42.2649	|P_VLE = 62.3
# Solved	|T = 529.15 K	|V = 0.4285 kmol/s	|L = 0.0000 kmol/s	|s_L = 23.9772	|P_VLE = 44.0
# Solved	|T = 525.15 K	|V = 0.4401 kmol/s	|L = 0.0000 kmol/s	|s_L = 7.0953	|P_VLE = 27.1
# Solved	|T = 521.15 K	|V = 0.4567 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0747	|P_VLE = 20.1
# Solved	|T = 517.15 K	|V = 0.4649 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.0975	|P_VLE = 20.1
# Solved	|T = 513.15 K	|V = 0.4768 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0664	|P_VLE = 20.1
# Solved	|T = 509.15 K	|V = 0.4932 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0378	|P_VLE = 20.0
# Solved	|T = 505.15 K	|V = 0.5151 kmol/s	|L = 0.0020 kmol/s	|s_L = 0.0252	|P_VLE = 20.0
# Solved	|T = 501.15 K	|V = 0.5433 kmol/s	|L = 0.0026 kmol/s	|s_L = 0.0194	|P_VLE = 20.0
# Solved	|T = 497.15 K	|V = 0.5772 kmol/s	|L = 0.0030 kmol/s	|s_L = 0.0167	|P_VLE = 20.0
# Solved	|T = 493.15 K	|V = 0.6156 kmol/s	|L = 0.0033 kmol/s	|s_L = 0.0156	|P_VLE = 20.0
# Solved	|T = 489.15 K	|V = 0.6561 kmol/s	|L = 0.0033 kmol/s	|s_L = 0.0156	|P_VLE = 20.0
# Solved	|T = 485.15 K	|V = 0.6966 kmol/s	|L = 0.0032 kmol/s	|s_L = 0.0162	|P_VLE = 20.0
# Solved	|T = 481.15 K	|V = 0.7355 kmol/s	|L = 0.0030 kmol/s	|s_L = 0.0176	|P_VLE = 20.0
# Solved	|T = 477.15 K	|V = 0.7715 kmol/s	|L = 0.0027 kmol/s	|s_L = 0.0197	|P_VLE = 20.0
# Solved	|T = 473.15 K	|V = 0.8042 kmol/s	|L = 0.0024 kmol/s	|s_L = 0.0225	|P_VLE = 20.0
#
# Working on Cat = 500.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4578 kmol/s	|L = 0.0000 kmol/s	|s_L = 146.4599	|P_VLE = 166.5
# Solved	|T = 569.15 K	|V = 0.4551 kmol/s	|L = 0.0000 kmol/s	|s_L = 141.0925	|P_VLE = 161.1
# Solved	|T = 565.15 K	|V = 0.4523 kmol/s	|L = 0.0000 kmol/s	|s_L = 135.0768	|P_VLE = 155.1
# Solved	|T = 561.15 K	|V = 0.4494 kmol/s	|L = 0.0000 kmol/s	|s_L = 128.3079	|P_VLE = 148.3
# Solved	|T = 557.15 K	|V = 0.4465 kmol/s	|L = 0.0000 kmol/s	|s_L = 120.6573	|P_VLE = 140.7
# Solved	|T = 553.15 K	|V = 0.4436 kmol/s	|L = 0.0000 kmol/s	|s_L = 111.9698	|P_VLE = 132.0
# Solved	|T = 549.15 K	|V = 0.4410 kmol/s	|L = 0.0000 kmol/s	|s_L = 102.0618	|P_VLE = 122.1
# Solved	|T = 545.15 K	|V = 0.4390 kmol/s	|L = 0.0000 kmol/s	|s_L = 90.7268	|P_VLE = 110.7
# Solved	|T = 541.15 K	|V = 0.4380 kmol/s	|L = 0.0000 kmol/s	|s_L = 77.7589	|P_VLE = 97.8
# Solved	|T = 537.15 K	|V = 0.4390 kmol/s	|L = 0.0000 kmol/s	|s_L = 63.0198	|P_VLE = 83.0
# Solved	|T = 533.15 K	|V = 0.4442 kmol/s	|L = 0.0000 kmol/s	|s_L = 46.6079	|P_VLE = 66.6
# Solved	|T = 529.15 K	|V = 0.4582 kmol/s	|L = 0.0000 kmol/s	|s_L = 29.2512	|P_VLE = 49.3
# Solved	|T = 525.15 K	|V = 0.4906 kmol/s	|L = 0.0000 kmol/s	|s_L = 12.9034	|P_VLE = 32.9
# Solved	|T = 521.15 K	|V = 0.5491 kmol/s	|L = 0.0000 kmol/s	|s_L = 1.2719	|P_VLE = 21.3
# Solved	|T = 517.15 K	|V = 0.5830 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.1903	|P_VLE = 20.2
# Solved	|T = 513.15 K	|V = 0.6147 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.2557	|P_VLE = 20.3
# Solved	|T = 509.15 K	|V = 0.6498 kmol/s	|L = 0.0003 kmol/s	|s_L = 0.1588	|P_VLE = 20.2
# Solved	|T = 505.15 K	|V = 0.6856 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0959	|P_VLE = 20.1
# Solved	|T = 501.15 K	|V = 0.7205 kmol/s	|L = 0.0008 kmol/s	|s_L = 0.0673	|P_VLE = 20.1
# Solved	|T = 497.15 K	|V = 0.7537 kmol/s	|L = 0.0010 kmol/s	|s_L = 0.0535	|P_VLE = 20.1
# Solved	|T = 493.15 K	|V = 0.7846 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0467	|P_VLE = 20.0
# Solved	|T = 489.15 K	|V = 0.8128 kmol/s	|L = 0.0013 kmol/s	|s_L = 0.0439	|P_VLE = 20.0
# Solved	|T = 485.15 K	|V = 0.8384 kmol/s	|L = 0.0013 kmol/s	|s_L = 0.0438	|P_VLE = 20.0
# Solved	|T = 481.15 K	|V = 0.8612 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0459	|P_VLE = 20.0
# Solved	|T = 477.15 K	|V = 0.8814 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0501	|P_VLE = 20.1
# Solved	|T = 473.15 K	|V = 0.8992 kmol/s	|L = 0.0010 kmol/s	|s_L = 0.0564	|P_VLE = 20.1
#
# Working on Cat = 300.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4593 kmol/s	|L = 0.0000 kmol/s	|s_L = 147.1014	|P_VLE = 167.1
# Solved	|T = 569.15 K	|V = 0.4570 kmol/s	|L = 0.0000 kmol/s	|s_L = 141.9128	|P_VLE = 161.9
# Solved	|T = 565.15 K	|V = 0.4547 kmol/s	|L = 0.0000 kmol/s	|s_L = 136.1336	|P_VLE = 156.1
# Solved	|T = 561.15 K	|V = 0.4525 kmol/s	|L = 0.0000 kmol/s	|s_L = 129.6796	|P_VLE = 149.7
# Solved	|T = 557.15 K	|V = 0.4506 kmol/s	|L = 0.0000 kmol/s	|s_L = 122.4510	|P_VLE = 142.5
# Solved	|T = 553.15 K	|V = 0.4492 kmol/s	|L = 0.0000 kmol/s	|s_L = 114.3310	|P_VLE = 134.3
# Solved	|T = 549.15 K	|V = 0.4488 kmol/s	|L = 0.0000 kmol/s	|s_L = 105.1853	|P_VLE = 125.2
# Solved	|T = 545.15 K	|V = 0.4499 kmol/s	|L = 0.0000 kmol/s	|s_L = 94.8633	|P_VLE = 114.9
# Solved	|T = 541.15 K	|V = 0.4536 kmol/s	|L = 0.0000 kmol/s	|s_L = 83.2031	|P_VLE = 103.2
# Solved	|T = 537.15 K	|V = 0.4619 kmol/s	|L = 0.0000 kmol/s	|s_L = 70.0466	|P_VLE = 90.0
# Solved	|T = 533.15 K	|V = 0.4783 kmol/s	|L = 0.0000 kmol/s	|s_L = 55.3018	|P_VLE = 75.3
# Solved	|T = 529.15 K	|V = 0.5087 kmol/s	|L = 0.0000 kmol/s	|s_L = 39.1907	|P_VLE = 59.2
# Solved	|T = 525.15 K	|V = 0.5613 kmol/s	|L = 0.0000 kmol/s	|s_L = 22.7993	|P_VLE = 42.8
# Solved	|T = 521.15 K	|V = 0.6331 kmol/s	|L = 0.0000 kmol/s	|s_L = 9.4997	|P_VLE = 29.5
# Solved	|T = 517.15 K	|V = 0.6933 kmol/s	|L = 0.0000 kmol/s	|s_L = 3.2976	|P_VLE = 23.3
# Solved	|T = 513.15 K	|V = 0.7310 kmol/s	|L = 0.0000 kmol/s	|s_L = 2.1709	|P_VLE = 22.2
# Solved	|T = 509.15 K	|V = 0.7673 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.8503	|P_VLE = 20.9
# Solved	|T = 505.15 K	|V = 0.7971 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.3827	|P_VLE = 20.4
# Solved	|T = 501.15 K	|V = 0.8230 kmol/s	|L = 0.0003 kmol/s	|s_L = 0.2182	|P_VLE = 20.2
# Solved	|T = 497.15 K	|V = 0.8461 kmol/s	|L = 0.0004 kmol/s	|s_L = 0.1500	|P_VLE = 20.1
# Solved	|T = 493.15 K	|V = 0.8667 kmol/s	|L = 0.0005 kmol/s	|s_L = 0.1184	|P_VLE = 20.1
# Solved	|T = 489.15 K	|V = 0.8850 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.1037	|P_VLE = 20.1
# Solved	|T = 485.15 K	|V = 0.9012 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0984	|P_VLE = 20.1
# Solved	|T = 481.15 K	|V = 0.9155 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0994	|P_VLE = 20.1
# Solved	|T = 477.15 K	|V = 0.9280 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.1057	|P_VLE = 20.1
# Solved	|T = 473.15 K	|V = 0.9389 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.1169	|P_VLE = 20.1
#
# Working on Cat = 100.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4742 kmol/s	|L = 0.0000 kmol/s	|s_L = 153.3795	|P_VLE = 173.4
# Solved	|T = 569.15 K	|V = 0.4767 kmol/s	|L = 0.0000 kmol/s	|s_L = 150.3215	|P_VLE = 170.3
# Solved	|T = 565.15 K	|V = 0.4811 kmol/s	|L = 0.0000 kmol/s	|s_L = 147.4644	|P_VLE = 167.5
# Solved	|T = 561.15 K	|V = 0.4882 kmol/s	|L = 0.0000 kmol/s	|s_L = 144.9831	|P_VLE = 165.0
# Solved	|T = 557.15 K	|V = 0.4992 kmol/s	|L = 0.0000 kmol/s	|s_L = 143.0541	|P_VLE = 163.1
# Solved	|T = 553.15 K	|V = 0.5152 kmol/s	|L = 0.0000 kmol/s	|s_L = 141.7756	|P_VLE = 161.8
# Solved	|T = 549.15 K	|V = 0.5371 kmol/s	|L = 0.0000 kmol/s	|s_L = 141.0186	|P_VLE = 161.0
# Solved	|T = 545.15 K	|V = 0.5653 kmol/s	|L = 0.0000 kmol/s	|s_L = 140.2157	|P_VLE = 160.2
# Solved	|T = 541.15 K	|V = 0.5992 kmol/s	|L = 0.0000 kmol/s	|s_L = 138.1806	|P_VLE = 158.2
# Solved	|T = 537.15 K	|V = 0.6374 kmol/s	|L = 0.0000 kmol/s	|s_L = 133.0600	|P_VLE = 153.1
# Solved	|T = 533.15 K	|V = 0.6786 kmol/s	|L = 0.0000 kmol/s	|s_L = 122.4080	|P_VLE = 142.4
# Solved	|T = 529.15 K	|V = 0.7222 kmol/s	|L = 0.0000 kmol/s	|s_L = 103.5921	|P_VLE = 123.6
# Solved	|T = 525.15 K	|V = 0.7686 kmol/s	|L = 0.0000 kmol/s	|s_L = 75.8656	|P_VLE = 95.9
# Solved	|T = 521.15 K	|V = 0.8146 kmol/s	|L = 0.0000 kmol/s	|s_L = 47.3136	|P_VLE = 67.3
# Solved	|T = 517.15 K	|V = 0.8503 kmol/s	|L = 0.0000 kmol/s	|s_L = 31.0446	|P_VLE = 51.0
# Solved	|T = 513.15 K	|V = 0.8800 kmol/s	|L = 0.0000 kmol/s	|s_L = 19.1426	|P_VLE = 39.1
# Solved	|T = 509.15 K	|V = 0.9055 kmol/s	|L = 0.0000 kmol/s	|s_L = 9.5080	|P_VLE = 29.5
# Solved	|T = 505.15 K	|V = 0.9236 kmol/s	|L = 0.0000 kmol/s	|s_L = 4.5015	|P_VLE = 24.5
# Solved	|T = 501.15 K	|V = 0.9363 kmol/s	|L = 0.0000 kmol/s	|s_L = 2.2785	|P_VLE = 22.3
# Solved	|T = 497.15 K	|V = 0.9459 kmol/s	|L = 0.0001 kmol/s	|s_L = 1.3278	|P_VLE = 21.3
# Solved	|T = 493.15 K	|V = 0.9538 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.8973	|P_VLE = 20.9
# Solved	|T = 489.15 K	|V = 0.9605 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.6894	|P_VLE = 20.7
# Solved	|T = 485.15 K	|V = 0.9663 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.5882	|P_VLE = 20.6
# Solved	|T = 481.15 K	|V = 0.9712 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.5458	|P_VLE = 20.5
# Solved	|T = 477.15 K	|V = 0.9756 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.5411	|P_VLE = 20.5
# Solved	|T = 473.15 K	|V = 0.9793 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.5648	|P_VLE = 20.6
#
# Working on Cat = 50.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.5312 kmol/s	|L = 0.0000 kmol/s	|s_L = 176.4428	|P_VLE = 196.4
# Solved	|T = 569.15 K	|V = 0.5511 kmol/s	|L = 0.0000 kmol/s	|s_L = 180.6779	|P_VLE = 200.7
# Solved	|T = 565.15 K	|V = 0.5757 kmol/s	|L = 0.0000 kmol/s	|s_L = 186.3124	|P_VLE = 206.3
# Solved	|T = 561.15 K	|V = 0.6041 kmol/s	|L = 0.0000 kmol/s	|s_L = 192.9513	|P_VLE = 213.0
# Solved	|T = 557.15 K	|V = 0.6351 kmol/s	|L = 0.0000 kmol/s	|s_L = 199.9639	|P_VLE = 220.0
# Solved	|T = 553.15 K	|V = 0.6673 kmol/s	|L = 0.0000 kmol/s	|s_L = 206.5973	|P_VLE = 226.6
# Solved	|T = 549.15 K	|V = 0.6993 kmol/s	|L = 0.0000 kmol/s	|s_L = 212.0336	|P_VLE = 232.0
# Solved	|T = 545.15 K	|V = 0.7305 kmol/s	|L = 0.0000 kmol/s	|s_L = 215.3468	|P_VLE = 235.3
# Solved	|T = 541.15 K	|V = 0.7603 kmol/s	|L = 0.0000 kmol/s	|s_L = 215.3517	|P_VLE = 235.4
# Solved	|T = 537.15 K	|V = 0.7885 kmol/s	|L = 0.0000 kmol/s	|s_L = 210.3278	|P_VLE = 230.3
# Solved	|T = 533.15 K	|V = 0.8152 kmol/s	|L = 0.0000 kmol/s	|s_L = 197.5957	|P_VLE = 217.6
# Solved	|T = 529.15 K	|V = 0.8410 kmol/s	|L = 0.0000 kmol/s	|s_L = 173.2504	|P_VLE = 193.3
# Solved	|T = 525.15 K	|V = 0.8668 kmol/s	|L = 0.0000 kmol/s	|s_L = 134.1620	|P_VLE = 154.2
# Solved	|T = 521.15 K	|V = 0.8920 kmol/s	|L = 0.0000 kmol/s	|s_L = 89.6222	|P_VLE = 109.6
# Solved	|T = 517.15 K	|V = 0.9125 kmol/s	|L = 0.0000 kmol/s	|s_L = 61.6473	|P_VLE = 81.6
# Solved	|T = 513.15 K	|V = 0.9298 kmol/s	|L = 0.0000 kmol/s	|s_L = 41.0098	|P_VLE = 61.0
# Solved	|T = 509.15 K	|V = 0.9453 kmol/s	|L = 0.0000 kmol/s	|s_L = 23.0463	|P_VLE = 43.0
# Solved	|T = 505.15 K	|V = 0.9571 kmol/s	|L = 0.0000 kmol/s	|s_L = 12.4440	|P_VLE = 32.4
# Solved	|T = 501.15 K	|V = 0.9654 kmol/s	|L = 0.0000 kmol/s	|s_L = 6.8160	|P_VLE = 26.8
# Solved	|T = 497.15 K	|V = 0.9715 kmol/s	|L = 0.0000 kmol/s	|s_L = 4.0177	|P_VLE = 24.0
# Solved	|T = 493.15 K	|V = 0.9760 kmol/s	|L = 0.0000 kmol/s	|s_L = 2.6454	|P_VLE = 22.6
# Solved	|T = 489.15 K	|V = 0.9797 kmol/s	|L = 0.0000 kmol/s	|s_L = 1.9554	|P_VLE = 22.0
# Solved	|T = 485.15 K	|V = 0.9827 kmol/s	|L = 0.0001 kmol/s	|s_L = 1.6025	|P_VLE = 21.6
# Solved	|T = 481.15 K	|V = 0.9853 kmol/s	|L = 0.0001 kmol/s	|s_L = 1.4313	|P_VLE = 21.4
# Solved	|T = 477.15 K	|V = 0.9876 kmol/s	|L = 0.0001 kmol/s	|s_L = 1.3701	|P_VLE = 21.4
# Solved	|T = 473.15 K	|V = 0.9895 kmol/s	|L = 0.0001 kmol/s	|s_L = 1.3853	|P_VLE = 21.4
#
# Working on Cat = 25.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.6880 kmol/s	|L = 0.0000 kmol/s	|s_L = 237.8537	|P_VLE = 257.9
# Solved	|T = 569.15 K	|V = 0.7163 kmol/s	|L = 0.0000 kmol/s	|s_L = 246.9215	|P_VLE = 266.9
# Solved	|T = 565.15 K	|V = 0.7435 kmol/s	|L = 0.0000 kmol/s	|s_L = 255.6385	|P_VLE = 275.6
# Solved	|T = 561.15 K	|V = 0.7692 kmol/s	|L = 0.0000 kmol/s	|s_L = 263.7712	|P_VLE = 283.8
# Solved	|T = 557.15 K	|V = 0.7932 kmol/s	|L = 0.0000 kmol/s	|s_L = 271.0919	|P_VLE = 291.1
# Solved	|T = 553.15 K	|V = 0.8154 kmol/s	|L = 0.0000 kmol/s	|s_L = 277.3409	|P_VLE = 297.3
# Solved	|T = 549.15 K	|V = 0.8359 kmol/s	|L = 0.0000 kmol/s	|s_L = 282.1734	|P_VLE = 302.2
# Solved	|T = 545.15 K	|V = 0.8545 kmol/s	|L = 0.0000 kmol/s	|s_L = 285.0729	|P_VLE = 305.1
# Solved	|T = 541.15 K	|V = 0.8716 kmol/s	|L = 0.0000 kmol/s	|s_L = 285.1948	|P_VLE = 305.2
# Solved	|T = 537.15 K	|V = 0.8871 kmol/s	|L = 0.0000 kmol/s	|s_L = 281.0561	|P_VLE = 301.1
# Solved	|T = 533.15 K	|V = 0.9014 kmol/s	|L = 0.0000 kmol/s	|s_L = 269.9145	|P_VLE = 289.9
# Solved	|T = 529.15 K	|V = 0.9147 kmol/s	|L = 0.0000 kmol/s	|s_L = 246.7195	|P_VLE = 266.7
# Solved	|T = 525.15 K	|V = 0.9275 kmol/s	|L = 0.0000 kmol/s	|s_L = 204.2261	|P_VLE = 224.2
# Solved	|T = 521.15 K	|V = 0.9402 kmol/s	|L = 0.0000 kmol/s	|s_L = 146.6758	|P_VLE = 166.7
# Solved	|T = 517.15 K	|V = 0.9511 kmol/s	|L = 0.0000 kmol/s	|s_L = 104.3282	|P_VLE = 124.3
# Solved	|T = 513.15 K	|V = 0.9601 kmol/s	|L = 0.0000 kmol/s	|s_L = 75.3925	|P_VLE = 95.4
# Solved	|T = 509.15 K	|V = 0.9686 kmol/s	|L = 0.0000 kmol/s	|s_L = 45.9438	|P_VLE = 65.9
# Solved	|T = 505.15 K	|V = 0.9755 kmol/s	|L = 0.0000 kmol/s	|s_L = 27.0742	|P_VLE = 47.1
# Solved	|T = 501.15 K	|V = 0.9806 kmol/s	|L = 0.0000 kmol/s	|s_L = 16.1007	|P_VLE = 36.1
# Solved	|T = 497.15 K	|V = 0.9844 kmol/s	|L = 0.0000 kmol/s	|s_L = 10.0057	|P_VLE = 30.0
# Solved	|T = 493.15 K	|V = 0.9872 kmol/s	|L = 0.0000 kmol/s	|s_L = 6.6972	|P_VLE = 26.7
# Solved	|T = 489.15 K	|V = 0.9893 kmol/s	|L = 0.0000 kmol/s	|s_L = 4.9080	|P_VLE = 24.9
# Solved	|T = 485.15 K	|V = 0.9910 kmol/s	|L = 0.0000 kmol/s	|s_L = 3.9402	|P_VLE = 23.9
# Solved	|T = 481.15 K	|V = 0.9924 kmol/s	|L = 0.0000 kmol/s	|s_L = 3.4331	|P_VLE = 23.4
# Solved	|T = 477.15 K	|V = 0.9936 kmol/s	|L = 0.0000 kmol/s	|s_L = 3.2046	|P_VLE = 23.2
# Solved	|T = 473.15 K	|V = 0.9946 kmol/s	|L = 0.0000 kmol/s	|s_L = 3.1630	|P_VLE = 23.2
#
# Working on Cat = 10.0 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.8620 kmol/s	|L = 0.0000 kmol/s	|s_L = 306.2858	|P_VLE = 326.3
# Solved	|T = 569.15 K	|V = 0.8766 kmol/s	|L = 0.0000 kmol/s	|s_L = 312.8211	|P_VLE = 332.8
# Solved	|T = 565.15 K	|V = 0.8899 kmol/s	|L = 0.0000 kmol/s	|s_L = 319.0080	|P_VLE = 339.0
# Solved	|T = 561.15 K	|V = 0.9019 kmol/s	|L = 0.0000 kmol/s	|s_L = 324.8000	|P_VLE = 344.8
# Solved	|T = 557.15 K	|V = 0.9129 kmol/s	|L = 0.0000 kmol/s	|s_L = 330.1291	|P_VLE = 350.1
# Solved	|T = 553.15 K	|V = 0.9227 kmol/s	|L = 0.0000 kmol/s	|s_L = 334.8919	|P_VLE = 354.9
# Solved	|T = 549.15 K	|V = 0.9316 kmol/s	|L = 0.0000 kmol/s	|s_L = 338.9232	|P_VLE = 358.9
# Solved	|T = 545.15 K	|V = 0.9396 kmol/s	|L = 0.0000 kmol/s	|s_L = 341.9467	|P_VLE = 361.9
# Solved	|T = 541.15 K	|V = 0.9467 kmol/s	|L = 0.0000 kmol/s	|s_L = 343.4725	|P_VLE = 363.5
# Solved	|T = 537.15 K	|V = 0.9532 kmol/s	|L = 0.0000 kmol/s	|s_L = 342.5686	|P_VLE = 362.6
# Solved	|T = 533.15 K	|V = 0.9590 kmol/s	|L = 0.0000 kmol/s	|s_L = 337.3145	|P_VLE = 357.3
# Solved	|T = 529.15 K	|V = 0.9643 kmol/s	|L = 0.0000 kmol/s	|s_L = 323.4416	|P_VLE = 343.4
# Solved	|T = 525.15 K	|V = 0.9692 kmol/s	|L = 0.0000 kmol/s	|s_L = 291.5423	|P_VLE = 311.5
# Solved	|T = 521.15 K	|V = 0.9740 kmol/s	|L = 0.0000 kmol/s	|s_L = 233.5937	|P_VLE = 253.6
# Solved	|T = 517.15 K	|V = 0.9784 kmol/s	|L = 0.0000 kmol/s	|s_L = 176.1454	|P_VLE = 196.1
# Solved	|T = 513.15 K	|V = 0.9819 kmol/s	|L = 0.0000 kmol/s	|s_L = 140.4350	|P_VLE = 160.4
# Solved	|T = 509.15 K	|V = 0.9854 kmol/s	|L = 0.0000 kmol/s	|s_L = 96.7593	|P_VLE = 116.8
# Solved	|T = 505.15 K	|V = 0.9884 kmol/s	|L = 0.0000 kmol/s	|s_L = 62.0452	|P_VLE = 82.0
# Solved	|T = 501.15 K	|V = 0.9908 kmol/s	|L = 0.0000 kmol/s	|s_L = 39.8501	|P_VLE = 59.9
# Solved	|T = 497.15 K	|V = 0.9927 kmol/s	|L = 0.0000 kmol/s	|s_L = 26.4378	|P_VLE = 46.4
# Solved	|T = 493.15 K	|V = 0.9941 kmol/s	|L = 0.0000 kmol/s	|s_L = 18.4998	|P_VLE = 38.5
# Solved	|T = 489.15 K	|V = 0.9952 kmol/s	|L = 0.0000 kmol/s	|s_L = 13.8371	|P_VLE = 33.8
# Solved	|T = 485.15 K	|V = 0.9960 kmol/s	|L = 0.0000 kmol/s	|s_L = 11.1211	|P_VLE = 31.1
# Solved	|T = 481.15 K	|V = 0.9967 kmol/s	|L = 0.0000 kmol/s	|s_L = 9.5836	|P_VLE = 29.6
# Solved	|T = 477.15 K	|V = 0.9972 kmol/s	|L = 0.0000 kmol/s	|s_L = 8.7913	|P_VLE = 28.8
# Solved	|T = 473.15 K	|V = 0.9976 kmol/s	|L = 0.0000 kmol/s	|s_L = 8.5030	|P_VLE = 28.5

# %% [markdown]
# # Optimization results across disappearing phases

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,rf_data_master[c]['V'])
ax1.set_ylabel('Vapor Flow Rate (kmol/s)',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.grid()

for c in catrange:
    ax2.plot(Trange,rf_data_master[c]['L'])
ax2.set_ylabel('Liquid Flow Rate (kmol/s)',fontsize=14)
ax2.set_xlabel('Temperature (K)',fontsize=14)
ax2.tick_params(labelsize=14)
ax2.grid()

ax2.legend(catrange,fontsize=14)
fig.suptitle('Vapor and Liquid Flow Rate',fontsize=18)

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,np.divide(rf_data_master[c]['V'],np.add(rf_data_master[c]['V'],rf_data_master[c]['L'])))
ax1.set_ylabel('Vapor Fraction',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.legend(catrange,fontsize=14)
ax1.set_title('Vapor Fraction',fontsize=18)
ax1.grid()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,rf_data_master[c]['P_VLE'])
ax1.set_ylabel(r'$P_{VLE}$ value',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.legend(catrange,fontsize=14)
ax1.set_title(r'$P_{VLE}$ (Bar)',fontsize=18)
ax1.grid()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,np.multiply(rf_data_master[c]['s_L'],rf_data_master[c]['L']))
ax1.set_ylabel(r'$s_L \cdot L$ value',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.legend(catrange,fontsize=14)
# ax1.set_ylim(2.49e-5,2.51e-5)
ax1.set_title(r'$s_L \cdot L$',fontsize=18)
ax1.grid()
plt.show()
