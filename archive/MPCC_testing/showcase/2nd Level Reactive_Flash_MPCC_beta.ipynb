# %% [markdown]
# # 2nd Level Model Structure: Reactive Stage

# %%
import sys
import os
import pickle
sys.path.append(os.path.abspath('..'))
import numpy as np
from matplotlib import pyplot as plt

# %%
from pyomo import environ as pe
from global_sets.component import m
from utility.display_utility import trans_product_mole, trans_product_mass
from utility.model_utility import add_dual, update_dual, check_DOF

# stage construction rules
from physics.kinetics_bounded import kinetic_block_rule
from physics.energy_bounded import energy_block_rule
from physics.VLE_bounded import VLE_block_rule
from physics.MPCC_beta import beta_NCP_block_rule, beta_Reg_block_rule, beta_pf_block_rule

model = pe.ConcreteModel()

# %% [markdown]
# # Global Sets (Inlet / Outlet)

# %%
model.inlet = pe.Set(initialize=['in'])
model.outlet = pe.Set(initialize=['out','P'])
model.stream = model.inlet | model.outlet

# %% [markdown]
# # Global Variables

# %%
# Tray Inlet/Outlet Variable
model.x_ = pe.Var(model.inlet,m.COMP_TOTAL,within=pe.NonNegativeReals)
model.y_ = pe.Var(model.inlet,m.COMP_TOTAL,within=pe.NonNegativeReals)
model.x = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals)
model.y = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals)
model.z = pe.Var(m.COMP_FEED,within=pe.NonNegativeReals)

model.L = pe.Var(model.stream,within=pe.NonNegativeReals)
model.V = pe.Var(model.stream,within=pe.NonNegativeReals)
model.F = pe.Var(within=pe.NonNegativeReals)

model.H_L_ = pe.Var(model.inlet,within=pe.Reals)
model.H_V_ = pe.Var(model.inlet,within=pe.Reals)
model.H_L = pe.Var(within=pe.Reals)
model.H_V = pe.Var(within=pe.Reals)
model.H_F = pe.Var(within=pe.Reals)

# State Variable
model.T = pe.Var(within=pe.NonNegativeReals,bounds=(200+273.15,300+273.15)) # K
model.T_F = pe.Var(within=pe.NonNegativeReals) # K
model.P = pe.Var(within=pe.NonNegativeReals,bounds=(10,30)) # Bar

model.f_V = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals,initialize=1e-20)
model.f_L = pe.Var(m.COMP_TOTAL,within=pe.NonNegativeReals,initialize=1e-20)

model.cat = pe.Var(within=pe.NonNegativeReals,initialize=3000) # kg
model.Q_main = pe.Var(within=pe.Reals) # MW
model.r_total_comp = pe.Var(m.COMP_TOTAL,within=pe.Reals) # kmol/s

# %% [markdown]
# # Construct Individual Blocks

# %%
model.kinetics_block = pe.Block(rule=kinetic_block_rule)
# Out:
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | kinetics_block.k_FT
# | kinetics_block.r_FT_total
# | kinetics_block.g0_FT
# | kinetics_block.alpha
# | kinetics_block.r_FT_cnum
# | kinetics_block.r_FT_comp
# | kinetics_block.k_WGS
# | kinetics_block.Ke_WGS
# | kinetics_block.r_WGS
# | kinetics_block.r_WGS_comp
# --------------------------------------------------

# %%
model.energy_block = pe.Block(rule=energy_block_rule)
# Out:
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | energy_block.dH_F
# | energy_block.dH_V
# | energy_block.dH_L
# | energy_block.dH_vap
# --------------------------------------------------

# %%
model.VLE_block = pe.Block(rule=VLE_block_rule)
# Out:
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | VLE_block.n_ave
# | VLE_block.n_ave_cal
# | VLE_block.Hen
# | VLE_block.Hen0
# | VLE_block.gamma
# | VLE_block.P_sat
# | VLE_block.P_sat_Y
# | VLE_block.P_sat_dY_inf
# | VLE_block.P_sat_dY0
# | VLE_block.Hen_ref
# | VLE_block.Hen0_ref
# | VLE_block.gamma_ref
# | VLE_block.V_L
# | VLE_block.V_L_dY_inf
# | VLE_block.V_L_dY0
# | VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# # Standard MESH Equations

# %% [markdown]
# ## Mass Balance

# %% [markdown]
# \begin{equation}
# Fz_{i}+\sum_{s\in{inlet}}L_{s}x'_{i,s}+\sum_{s\in{inlet}}V_{s}y'_{i,s}-\sum_{s\in{outlet}}L_{s}x_{i,s}+\sum_{s\in{ouelet}}V_{s}y_{i,s}+R_{i} = 0 \\
# i = 1,...NC
# \end{equation}

# %%
def mass_balance_main_rule(model,i):
    if i in m.COMP_FEED:
        return model.F*model.z[i] + sum(model.L[s]*model.x_[s,i] + model.V[s]*model.y_[s,i] for s in model.inlet)\
        + model.r_total_comp[i] - sum(model.L[s]*model.x[i] + model.V[s]*model.y[i] for s in model.outlet) == 0
    else:
        return sum(model.L[s]*model.x_[s,i] + model.V[s]*model.y_[s,i] for s in model.inlet)\
        + model.r_total_comp[i] - sum(model.L[s]*model.x[i] + model.V[s]*model.y[i] for s in model.outlet) == 0
model.mass_balance_main_con = pe.Constraint(m.COMP_TOTAL,rule=mass_balance_main_rule)

# %% [markdown]
# ## Equilibrium

# %% [markdown]
# \begin{align}
# &f_{i,V} = f_{i,L} \\
# &i = 1,...NC
# \end{align}

# %%
def VL_equil_rule(model,i):
    return model.f_V[i] == model.f_L[i]
model.VL_equil_con = pe.Constraint(m.COMP_TOTAL,rule=VL_equil_rule)

# %%
model.VL_equil_con.pprint()
# Out:
# VL_equil_con : Size=79, Index=COMP_TOTAL, Active=True
#     Key     : Lower : Body                        : Upper : Active
#      C10H20 :   0.0 :   f_V[C10H20] - f_L[C10H20] :   0.0 :   True
#      C10H22 :   0.0 :   f_V[C10H22] - f_L[C10H22] :   0.0 :   True
#      C11H22 :   0.0 :   f_V[C11H22] - f_L[C11H22] :   0.0 :   True
#      C11H24 :   0.0 :   f_V[C11H24] - f_L[C11H24] :   0.0 :   True
#      C12H24 :   0.0 :   f_V[C12H24] - f_L[C12H24] :   0.0 :   True
#      C12H26 :   0.0 :   f_V[C12H26] - f_L[C12H26] :   0.0 :   True
#      C13H26 :   0.0 :   f_V[C13H26] - f_L[C13H26] :   0.0 :   True
#      C13H28 :   0.0 :   f_V[C13H28] - f_L[C13H28] :   0.0 :   True
#      C14H28 :   0.0 :   f_V[C14H28] - f_L[C14H28] :   0.0 :   True
#      C14H30 :   0.0 :   f_V[C14H30] - f_L[C14H30] :   0.0 :   True
#      C15H30 :   0.0 :   f_V[C15H30] - f_L[C15H30] :   0.0 :   True
#      C15H32 :   0.0 :   f_V[C15H32] - f_L[C15H32] :   0.0 :   True
#      C16H32 :   0.0 :   f_V[C16H32] - f_L[C16H32] :   0.0 :   True
#      C16H34 :   0.0 :   f_V[C16H34] - f_L[C16H34] :   0.0 :   True
#      C17H34 :   0.0 :   f_V[C17H34] - f_L[C17H34] :   0.0 :   True
#      C17H36 :   0.0 :   f_V[C17H36] - f_L[C17H36] :   0.0 :   True
#      C18H36 :   0.0 :   f_V[C18H36] - f_L[C18H36] :   0.0 :   True
#      C18H38 :   0.0 :   f_V[C18H38] - f_L[C18H38] :   0.0 :   True
#      C19H38 :   0.0 :   f_V[C19H38] - f_L[C19H38] :   0.0 :   True
#      C19H40 :   0.0 :   f_V[C19H40] - f_L[C19H40] :   0.0 :   True
#        C1H4 :   0.0 :       f_V[C1H4] - f_L[C1H4] :   0.0 :   True
#      C20H40 :   0.0 :   f_V[C20H40] - f_L[C20H40] :   0.0 :   True
#      C20H42 :   0.0 :   f_V[C20H42] - f_L[C20H42] :   0.0 :   True
#      C21H44 :   0.0 :   f_V[C21H44] - f_L[C21H44] :   0.0 :   True
#      C22H46 :   0.0 :   f_V[C22H46] - f_L[C22H46] :   0.0 :   True
#      C23H48 :   0.0 :   f_V[C23H48] - f_L[C23H48] :   0.0 :   True
#      C24H50 :   0.0 :   f_V[C24H50] - f_L[C24H50] :   0.0 :   True
#      C25H52 :   0.0 :   f_V[C25H52] - f_L[C25H52] :   0.0 :   True
#      C26H54 :   0.0 :   f_V[C26H54] - f_L[C26H54] :   0.0 :   True
#      C27H56 :   0.0 :   f_V[C27H56] - f_L[C27H56] :   0.0 :   True
#      C28H58 :   0.0 :   f_V[C28H58] - f_L[C28H58] :   0.0 :   True
#      C29H60 :   0.0 :   f_V[C29H60] - f_L[C29H60] :   0.0 :   True
#        C2H4 :   0.0 :       f_V[C2H4] - f_L[C2H4] :   0.0 :   True
#        C2H6 :   0.0 :       f_V[C2H6] - f_L[C2H6] :   0.0 :   True
#      C30H62 :   0.0 :   f_V[C30H62] - f_L[C30H62] :   0.0 :   True
#      C31H64 :   0.0 :   f_V[C31H64] - f_L[C31H64] :   0.0 :   True
#      C32H66 :   0.0 :   f_V[C32H66] - f_L[C32H66] :   0.0 :   True
#      C33H68 :   0.0 :   f_V[C33H68] - f_L[C33H68] :   0.0 :   True
#      C34H70 :   0.0 :   f_V[C34H70] - f_L[C34H70] :   0.0 :   True
#      C35H72 :   0.0 :   f_V[C35H72] - f_L[C35H72] :   0.0 :   True
#      C36H74 :   0.0 :   f_V[C36H74] - f_L[C36H74] :   0.0 :   True
#      C37H76 :   0.0 :   f_V[C37H76] - f_L[C37H76] :   0.0 :   True
#      C38H78 :   0.0 :   f_V[C38H78] - f_L[C38H78] :   0.0 :   True
#      C39H80 :   0.0 :   f_V[C39H80] - f_L[C39H80] :   0.0 :   True
#        C3H6 :   0.0 :       f_V[C3H6] - f_L[C3H6] :   0.0 :   True
#        C3H8 :   0.0 :       f_V[C3H8] - f_L[C3H8] :   0.0 :   True
#      C40H82 :   0.0 :   f_V[C40H82] - f_L[C40H82] :   0.0 :   True
#      C41H84 :   0.0 :   f_V[C41H84] - f_L[C41H84] :   0.0 :   True
#      C42H86 :   0.0 :   f_V[C42H86] - f_L[C42H86] :   0.0 :   True
#      C43H88 :   0.0 :   f_V[C43H88] - f_L[C43H88] :   0.0 :   True
#      C44H90 :   0.0 :   f_V[C44H90] - f_L[C44H90] :   0.0 :   True
#      C45H92 :   0.0 :   f_V[C45H92] - f_L[C45H92] :   0.0 :   True
#      C46H94 :   0.0 :   f_V[C46H94] - f_L[C46H94] :   0.0 :   True
#      C47H96 :   0.0 :   f_V[C47H96] - f_L[C47H96] :   0.0 :   True
#      C48H98 :   0.0 :   f_V[C48H98] - f_L[C48H98] :   0.0 :   True
#     C49H100 :   0.0 : f_V[C49H100] - f_L[C49H100] :   0.0 :   True
#       C4H10 :   0.0 :     f_V[C4H10] - f_L[C4H10] :   0.0 :   True
#        C4H8 :   0.0 :       f_V[C4H8] - f_L[C4H8] :   0.0 :   True
#     C50H102 :   0.0 : f_V[C50H102] - f_L[C50H102] :   0.0 :   True
#     C51H104 :   0.0 : f_V[C51H104] - f_L[C51H104] :   0.0 :   True
#     C52H106 :   0.0 : f_V[C52H106] - f_L[C52H106] :   0.0 :   True
#     C53H108 :   0.0 : f_V[C53H108] - f_L[C53H108] :   0.0 :   True
#     C54H110 :   0.0 : f_V[C54H110] - f_L[C54H110] :   0.0 :   True
#     C55H112 :   0.0 : f_V[C55H112] - f_L[C55H112] :   0.0 :   True
#     C56H114 :   0.0 : f_V[C56H114] - f_L[C56H114] :   0.0 :   True
#       C5H10 :   0.0 :     f_V[C5H10] - f_L[C5H10] :   0.0 :   True
#       C5H12 :   0.0 :     f_V[C5H12] - f_L[C5H12] :   0.0 :   True
#       C6H12 :   0.0 :     f_V[C6H12] - f_L[C6H12] :   0.0 :   True
#       C6H14 :   0.0 :     f_V[C6H14] - f_L[C6H14] :   0.0 :   True
#       C7H14 :   0.0 :     f_V[C7H14] - f_L[C7H14] :   0.0 :   True
#       C7H16 :   0.0 :     f_V[C7H16] - f_L[C7H16] :   0.0 :   True
#       C8H16 :   0.0 :     f_V[C8H16] - f_L[C8H16] :   0.0 :   True
#       C8H18 :   0.0 :     f_V[C8H18] - f_L[C8H18] :   0.0 :   True
#       C9H18 :   0.0 :     f_V[C9H18] - f_L[C9H18] :   0.0 :   True
#       C9H20 :   0.0 :     f_V[C9H20] - f_L[C9H20] :   0.0 :   True
#          CO :   0.0 :           f_V[CO] - f_L[CO] :   0.0 :   True
#         CO2 :   0.0 :         f_V[CO2] - f_L[CO2] :   0.0 :   True
#          H2 :   0.0 :           f_V[H2] - f_L[H2] :   0.0 :   True
#         H2O :   0.0 :         f_V[H2O] - f_L[H2O] :   0.0 :   True

# %% [markdown]
# ## MPCC: Beta

# %%
model.MPCC = pe.Block(rule = beta_NCP_block_rule)
# Out:
# > Importing MPCC_beta_NCP Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | MPCC.beta
# | MPCC.s_L
# | MPCC.s_V
# | MPCC.epi
# --------------------------------------------------
# > Adjusting the f_V = f_L bounds to f_V = beta * f_L

# %% [markdown]
# ## Summation

# %% [markdown]
# \begin{equation}
# \sum_ix_{i} = \sum_iy_{i} \\
# F + L_{in} + V_{in} + R = L_{out} + V_{out}
# \end{equation}

# %%
def summation_x_y_rule(model):
    return sum(model.x[i] for i in m.COMP_TOTAL) == sum(model.y[i] for i in m.COMP_TOTAL)
model.summation_x_y_con = pe.Constraint(rule=summation_x_y_rule)

def summation_total_mass_rule(model):
    return model.F + sum(model.L[s] + model.V[s] for s in model.inlet) + sum(model.r_total_comp[i] for i in m.COMP_TOTAL)\
            - sum(model.L[s] + model.V[s] for s in model.outlet) == 0
model.summation_total_mass_con = pe.Constraint(rule=summation_total_mass_rule)

# %% [markdown]
# ## Energy Balance

# %% [markdown]
# \begin{equation}
# F H_f+\sum_{s\in{inlet}}L_{s}H_{l,s}+\sum_{s\in{inlet}}V_{s}H_{v,s}-\sum_{s\in{outlet}}L_{s}H_{l,s}-\sum_{s\in{outlet}}V_{s}H_{v,s}+Q = 0
# \end{equation}

# %%
def heat_balance_main_rule(model):
    return model.F*model.H_F + sum(model.L[s]*model.H_L_[s] + model.V[s]*model.H_V_[s] for s in model.inlet) \
            + model.Q_main - sum(model.L[s]*model.H_L + model.V[s]*model.H_V for s in model.outlet) == 0
model.heat_balance_main_con = pe.Constraint(rule=heat_balance_main_rule)

# %% [markdown]
# # Testing

# %%
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# ## Fixing In/Product Redundent Flow

# %%
model.x_.fix(0)
model.y_.fix(0)
model.L['in'].fix(0)
model.L['P'].fix(0)
model.V['in'].fix(0)
model.V['P'].fix(0)
model.H_L_.fix(0)
model.H_V_.fix(0)

# %% [markdown]
# ## Fixing Model Parameters

# %%
model.cat.fix(3000)
model.P.fix(20)
model.T_F.fix(200+273.15)
model.F.fix(1)
model.z['CO'].fix(1/(1+0.8)-0/2)
model.z['H2'].fix(0.8/(1+0.8)-0/2)
model.z['C30H62'].fix(0)
model.VLE_block.n_ave.fix(20)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 1184
# Active Inequality Constraints:	 0
# Active Variables:		 1357
# Fixed Variables:		 172
# DOF:				 1

# %% [markdown]
# ## Fix T or to fix Q? we have found that Maximize against an upper bound is most reliable

# %%
model.T.setub(300+273.15)

# %%
# model.obj = pe.Objective(expr = model.L['out'],sense=pe.maximize)
# model.obj = pe.Objective(expr = model.cat,sense=pe.minimize)
model.obj = pe.Objective(expr = model.T ,sense=pe.maximize)

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'

opt.options['linear_scaling_on_demand '] = 'no'
opt.options['linear_system_scaling '] = 'mc19'

opt.options['max_iter'] = 7000
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_scaling_on_demand =no
# linear_system_scaling =mc19
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     4016
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4399
#
# Total number of variables............................:     1185
#                      variables with only lower bounds:      382
#                 variables with lower and upper bounds:      633
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1184
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -5.7215001e+02 3.62e+02 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -5.7298863e+02 1.16e+02 1.02e+04  -1.0 7.30e+01    -  4.07e-01 6.18e-01h  1
#    2 -5.7299457e+02 1.15e+02 3.71e+04  -1.0 1.40e+02    -  9.52e-01 5.60e-03h  1
#    3 -5.7299496e+02 1.15e+02 4.72e+05  -1.0 7.27e+02    -  3.50e-01 1.46e-03h  1
#    4 -5.7299564e+02 1.15e+02 1.57e+08  -1.0 7.31e+02    -  9.89e-01 2.89e-03h  1
#    5 -5.7299565e+02 1.15e+02 1.71e+12  -1.0 6.85e+02    -  3.61e-01 3.09e-05h  1
#    6r-5.7299565e+02 1.15e+02 1.00e+03   1.6 0.00e+00    -  0.00e+00 1.56e-07R  2
#    7r-5.7299942e+02 1.07e+02 1.39e+03   1.6 7.18e+04    -  5.28e-03 2.17e-04f  1
#    8 -5.7299993e+02 1.07e+02 1.32e+04  -1.0 1.22e+02    -  9.49e-01 5.71e-04h  1
#    9r-5.7299993e+02 1.07e+02 1.00e+03   1.5 0.00e+00    -  0.00e+00 3.80e-07R  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-5.7303206e+02 8.38e+01 1.96e+03   1.5 5.34e+04    -  5.26e-03 1.01e-03f  1
#   11 -5.7303369e+02 8.37e+01 5.92e+03  -1.0 2.61e+02    -  8.02e-01 1.29e-03h  1
#   12 -5.7303372e+02 8.37e+01 4.41e+05  -1.0 2.42e+02    -  9.47e-03 7.03e-05h  1
#   13 -5.7303374e+02 8.37e+01 1.85e+08  -1.0 2.96e+02    -  4.61e-02 1.11e-04h  1
#   14r-5.7303374e+02 8.37e+01 1.00e+03   1.1 0.00e+00    -  0.00e+00 3.54e-07R  3
#   15r-5.7303361e+02 8.34e+01 1.50e+03   1.1 3.40e+03    -  2.68e-03 8.28e-05f  1
#   16r-5.7302852e+02 7.14e+01 1.37e+03   1.1 1.62e+03    -  2.96e-03 3.51e-03f  1
#   17 -5.7303059e+02 7.13e+01 2.33e+02  -1.0 8.01e+02    -  5.61e-02 5.34e-04h  1
#   18 -5.7303073e+02 7.13e+01 1.96e+02  -1.0 3.24e+02    -  1.14e-05 5.90e-04f  1
#   19 -5.7314881e+02 2.47e+01 6.68e+04  -1.0 3.28e+02    -  3.62e-03 6.53e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -5.7311319e+02 9.55e-01 2.43e+04  -1.0 5.09e+01    -  1.21e-01 9.61e-01h  1
#   21 -5.7298021e+02 6.51e-01 5.00e+04  -1.0 5.47e+01    -  2.91e-01 9.78e-01h  1
#   22 -5.7245705e+02 4.40e+00 3.04e+06  -1.0 1.16e+02    -  5.96e-01 9.91e-01H  1
#   23 -5.7156903e+02 3.26e-01 3.86e+06  -1.0 1.84e+02    -  5.38e-01 9.92e-01H  1
#   24 -5.6980170e+02 5.71e-03 1.10e+08  -1.0 3.70e+02    -  5.21e-01 9.92e-01H  1
#   25 -5.6735988e+02 4.41e-03 1.17e+10  -1.0 5.22e+02    -  2.98e-01 1.00e+00F  1
#   26 -5.6690811e+02 1.29e-02 3.86e+10  -1.0 9.14e+01    -  9.87e-01 1.00e+00F  1
#   27 -5.6682520e+02 2.51e-02 3.63e+10  -1.0 2.66e+02    -  2.76e-01 6.25e-02f  5
#   28 -5.6680115e+02 2.65e-02 3.60e+10  -1.0 6.16e+02    -  7.47e-01 7.81e-03f  8
#   29 -5.6353824e+02 6.92e-04 6.68e+10  -1.0 5.65e+02    -  6.56e-01 1.00e+00F  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30 -5.4927193e+02 9.60e+01 1.48e+12  -1.0 7.13e+03    -  9.82e-02 3.95e-01f  1
#   31 -5.5576691e+02 1.95e+01 1.35e+12  -1.0 1.29e+03    -  3.21e-01 1.00e+00f  1
#   32 -5.5422238e+02 1.11e+00 3.08e+11  -1.0 2.74e+02    -  1.00e+00 1.00e+00h  1
#   33 -5.4946056e+02 1.05e+01 1.34e+11  -1.0 8.95e+02    -  5.20e-01 1.00e+00f  1
#   34 -5.4782451e+02 1.23e+00 2.59e+11  -1.0 2.90e+02    -  4.58e-01 1.00e+00f  1
#   35 -5.4479767e+02 4.17e+00 3.11e+11  -1.0 5.51e+02    -  5.97e-01 1.00e+00f  1
#   36 -5.4267612e+02 2.03e+00 1.98e+11  -1.0 3.77e+02    -  4.70e-01 1.00e+00f  1
#   37 -5.4040020e+02 2.32e+00 1.73e+10  -1.0 4.02e+02    -  6.84e-01 1.00e+00f  1
#   38 -5.3900778e+02 1.21e+00 5.25e+10  -1.0 2.42e+02    -  1.70e-01 1.00e+00f  1
#   39 -5.3845677e+02 1.35e-01 5.25e+09  -1.0 9.53e+01  -4.0 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 -5.3215241e+02 1.77e+01 1.53e+11  -1.0 1.92e+04    -  2.01e-02 5.71e-02f  2
#   41 -5.3249052e+02 1.42e-01 5.18e+09  -1.0 7.46e+01    -  8.47e-01 1.00e+00f  1
#   42 -5.3121599e+02 7.07e-01 9.92e+08  -1.0 2.15e+02  -4.5 1.00e+00 1.00e+00f  1
#   43 -5.2513956e+02 1.65e+01 7.89e+09  -1.0 4.49e+03    -  9.33e-02 2.27e-01f  2
#   44 -5.2502169e+02 6.45e-01 5.41e+07  -1.0 1.43e+01    -  1.00e+00 1.00e+00f  1
#   45 -5.2220416e+02 3.38e+00 4.24e+08  -1.0 5.46e+03    -  8.15e-02 8.38e-02f  3
#   46 -5.2001868e+02 2.01e+00 3.99e+07  -1.0 3.46e+02  -5.0 1.00e+00 1.00e+00f  1
#   47 -5.1920605e+02 2.77e-01 2.24e+07  -1.0 1.26e+02    -  9.84e-01 1.00e+00h  1
#   48 -5.1876982e+02 7.95e-02 3.86e+06  -1.0 6.84e+01    -  1.00e+00 1.00e+00h  1
#   49 -5.1882842e+02 1.43e-03 6.74e+04  -1.0 9.28e+00    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -5.2209969e+02 4.49e+00 1.64e+07  -1.7 8.56e+02    -  6.83e-01 6.00e-01f  1
#   51 -5.2266947e+02 4.11e+00 2.82e+07  -1.7 7.99e+02    -  1.00e+00 1.15e-01h  1
#   52 -5.2665616e+02 6.75e+00 7.23e+08  -1.7 6.43e+02    -  1.00e+00 1.00e+00f  1
#   53 -5.2819189e+02 5.72e+00 8.56e+08  -1.7 8.37e+02    -  1.00e+00 3.03e-01h  1
#   54 -5.3232200e+02 7.37e+00 7.93e+09  -1.7 6.87e+02    -  3.38e-01 1.00e+00f  1
#   55 -5.3350675e+02 6.96e+00 6.42e+09  -1.7 1.44e+03    -  1.00e+00 1.39e-01h  1
#   56 -5.3779265e+02 8.07e+00 5.99e+10  -1.7 7.34e+02    -  2.89e-01 1.00e+00f  1
#   57 -5.3928134e+02 7.65e+00 5.18e+10  -1.7 1.49e+03    -  1.00e+00 1.74e-01h  1
#   58 -5.4185383e+02 6.04e+00 4.72e+10  -1.7 7.60e+02    -  3.86e-01 5.97e-01f  1
#   59 -5.4291335e+02 5.07e+00 4.19e+10  -1.7 7.77e+02    -  1.00e+00 2.43e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60 -5.4683827e+02 6.96e+00 1.05e+11  -1.7 7.03e+02    -  6.20e-01 1.00e+00f  1
#   61 -5.4780708e+02 6.68e+00 1.03e+11  -1.7 1.74e+03    -  1.00e+00 1.02e-01h  1
#   62 -5.5219365e+02 8.83e+00 4.65e+11  -1.7 8.07e+02    -  2.22e-01 1.00e+00f  1
#   63 -5.5627755e+02 7.75e+00 5.40e+11  -1.7 7.70e+02    -  8.61e-01 1.00e+00f  1
#   64 -5.5918218e+02 8.98e+00 3.03e+11  -1.7 1.58e+03  -5.4 1.00e+00 3.52e-01f  1
#   65 -5.6414866e+02 1.17e+01 1.18e+11  -1.7 9.67e+02    -  8.08e-01 1.00e+00f  1
#   66 -5.6582344e+02 1.14e+01 1.01e+11  -1.7 2.44e+03  -5.9 9.95e-01 1.36e-01h  1
#   67 -5.6902241e+02 1.01e+01 4.22e+10  -1.7 1.17e+03    -  3.46e-01 5.52e-01h  1
#   68 -5.6977770e+02 9.07e+00 3.70e+10  -1.7 1.22e+03    -  1.00e+00 1.26e-01h  1
#   69 -5.7166694e+02 2.34e+00 4.29e+09  -1.7 4.20e+02    -  1.56e-01 9.34e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70 -5.7236905e+02 2.41e-01 5.50e+08  -1.7 1.46e+02    -  5.82e-01 1.00e+00h  1
#   71 -5.7236013e+02 3.90e-05 3.01e+05  -1.7 1.59e+00    -  1.00e+00 1.00e+00h  1
#   72 -5.7315000e+02 3.06e-01 2.42e+09  -5.7 8.43e+02    -  7.86e-01 1.93e-01f  1
#   73 -5.7315000e+02 5.55e-08 2.27e+07  -5.7 3.05e-01    -  8.88e-01 1.00e+00h  1
#   74 -5.7315000e+02 1.54e-10 3.16e+01  -5.7 7.11e-04    -  1.00e+00 1.00e+00h  1
#   75 -5.7315000e+02 2.85e-10 9.27e-06  -5.7 6.86e-05    -  1.00e+00 1.00e+00h  1
#   76 -5.7315001e+02 4.50e-11 1.99e+00  -8.6 3.80e-04    -  1.00e+00 1.00e+00h  1
#   77 -5.7315001e+02 1.92e-10 5.68e-11  -8.6 5.21e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 77
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -5.7315000572899407e+02   -5.7315000572899407e+02
# Dual infeasibility......:   5.6827820227312031e-11    5.6827820227312031e-11
# Constraint violation....:   1.9189402150621149e-10    1.9189402150621149e-10
# Complementarity.........:   2.5059035596897228e-09    2.5059035596897228e-09
# Overall NLP error.......:   2.5059035596897228e-09    2.5059035596897228e-09
#
#
# Number of objective function evaluations             = 130
# Number of objective gradient evaluations             = 77
# Number of equality constraint evaluations            = 130
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 81
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 77
# Total CPU secs in IPOPT (w/o function evaluations)   =      4.267
# Total CPU secs in NLP function evaluations           =      0.212
#
# EXIT: Optimal Solution Found.

# %%
model.T.value
# Out:
# 573.15

# %%
model.MPCC.beta.value
# Out:
# 0.12015583264388327

# %%
model.MPCC.s_L.value
# Out:
# 0.8798447134527502

# %%
model.L['out'].value
# Out:
# 2.8414104920246856e-07

# %%
print('Component\t\tLiquid: {:.4f}\t\t\tVapor: {:.4f}'.format(model.L['out'].value,model.V['out'].value))
print('-'*108)
for i in model.x:
    print('{:10s}'.format(i),'\t\t{:8.4%}\t\t\t{:8.4%}'.format(model.x[i].value,model.y[i].value))
# Out:
# Component		Liquid: 0.0000			Vapor: 0.4578
# ------------------------------------------------------------------------------------------------------------
# H2         		 0.1371%			 0.3424%
# CO         		 0.1236%			 0.2654%
# CO2        		46.5965%			56.2353%
# H2O        		10.9282%			 8.6187%
# C2H4       		 5.6470%			 5.5917%
# C3H6       		 5.8141%			 3.2153%
# C4H8       		 2.3491%			 1.4282%
# C5H10      		 1.6894%			 0.5529%
# C6H12      		 1.3174%			 0.2585%
# C7H14      		 0.9597%			 0.1208%
# C8H16      		 0.6670%			 0.0565%
# C9H18      		 0.4480%			 0.0264%
# C10H20     		 0.2932%			 0.0123%
# C11H22     		 0.1198%			 0.0037%
# C12H24     		 0.0756%			 0.0017%
# C13H26     		 0.0470%			 0.0008%
# C14H28     		 0.0289%			 0.0004%
# C15H30     		 0.0176%			 0.0002%
# C16H32     		 0.0107%			 0.0001%
# C17H34     		 0.0064%			 0.0000%
# C18H36     		 0.0038%			 0.0000%
# C19H38     		 0.0023%			 0.0000%
# C20H40     		 0.0013%			 0.0000%
# C1H4       		13.3744%			18.3934%
# C2H6       		 3.2294%			 3.0063%
# C3H8       		 1.3664%			 0.8038%
# C4H10      		 0.8290%			 0.4505%
# C5H12      		 1.0899%			 0.3253%
# C6H14      		 0.8397%			 0.1520%
# C7H16      		 0.6067%			 0.0711%
# C8H18      		 0.4192%			 0.0332%
# C9H20      		 0.2803%			 0.0155%
# C10H22     		 0.1828%			 0.0073%
# C11H24     		 0.1890%			 0.0055%
# C12H26     		 0.1190%			 0.0026%
# C13H28     		 0.0739%			 0.0012%
# C14H30     		 0.0454%			 0.0006%
# C15H32     		 0.0277%			 0.0003%
# C16H34     		 0.0167%			 0.0001%
# C17H36     		 0.0100%			 0.0001%
# C18H38     		 0.0060%			 0.0000%
# C19H40     		 0.0036%			 0.0000%
# C20H42     		 0.0021%			 0.0000%
# C21H44     		 0.0021%			 0.0000%
# C22H46     		 0.0012%			 0.0000%
# C23H48     		 0.0007%			 0.0000%
# C24H50     		 0.0004%			 0.0000%
# C25H52     		 0.0002%			 0.0000%
# C26H54     		 0.0001%			 0.0000%
# C27H56     		 0.0001%			 0.0000%
# C28H58     		 0.0000%			 0.0000%
# C29H60     		 0.0000%			 0.0000%
# C30H62     		 0.0000%			 0.0000%
# C31H64     		 0.0000%			 0.0000%
# C32H66     		 0.0000%			 0.0000%
# C33H68     		 0.0000%			 0.0000%
# C34H70     		 0.0000%			 0.0000%
# C35H72     		 0.0000%			 0.0000%
# C36H74     		 0.0000%			 0.0000%
# C37H76     		 0.0000%			 0.0000%
# C38H78     		 0.0000%			 0.0000%
# C39H80     		 0.0000%			 0.0000%
# C40H82     		 0.0000%			 0.0000%
# C41H84     		 0.0000%			 0.0000%
# C42H86     		 0.0000%			 0.0000%
# C43H88     		 0.0000%			 0.0000%
# C44H90     		 0.0000%			 0.0000%
# C45H92     		 0.0000%			 0.0000%
# C46H94     		 0.0000%			 0.0000%
# C47H96     		 0.0000%			 0.0000%
# C48H98     		 0.0000%			 0.0000%
# C49H100    		 0.0000%			 0.0000%
# C50H102    		 0.0000%			 0.0000%
# C51H104    		 0.0000%			 0.0000%
# C52H106    		 0.0000%			 0.0000%
# C53H108    		 0.0000%			 0.0000%
# C54H110    		 0.0000%			 0.0000%
# C55H112    		 0.0000%			 0.0000%
# C56H114    		 0.0000%			 0.0000%

# %% [markdown]
# # Iterative Solve for Data Analysis

# %%
results_anchor = results
update_dual(pe,model)
model.solutions.store_to(results_anchor)

# %%
opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6

# %%
catrange = [3000,1000,500,300,100,50,25,10]
Trange = np.linspace(300+273.15,200+273.15,26)

# %%
rf_data_master = {}

for c in catrange:
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = model.cat ,sense=pe.minimize)

    model.solutions.load_from(results_anchor)
    update_dual(pe,model) 
       
    model.T.fix(300+273.15)
    # model.cat.fixed = False
    model.cat.fix(c)
    
    results_anchor = opt.solve(model,tee=False)
    model.solutions.store_to(results_anchor)
    update_dual(pe,model)
    
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = model.T ,sense=pe.maximize)
    model.T.fixed = False
    model.cat.fixed = True
    
    
    print('\nWorking on Cat = {} kg'.format(model.cat.value))
    print('-'*108)
    
    rf_data = {}
    rf_data['x'] = {};rf_data['y'] = {};
    rf_data['T'] = []; rf_data['Q'] = []; rf_data['V'] = []; rf_data['L'] = []; rf_data['beta'] = []; 
    rf_data['s_L'] = [];
    for i in m.COMP_TOTAL:
        rf_data['x'][i] = []
        rf_data['y'][i] = []       

    for t in Trange:
        model.T.setub(t)
        results = opt.solve(model,tee=False)
        update_dual(pe,model)
        model.T.setub(300+273.15)
        print('Solved\t|T = {:.2f} K\t|V = {:.4f} kmol/s\t|L = {:.4f} kmol/s\t|s_L = {:.4f}\t|beta = {:.4f}'.\
              format(model.T.value,model.V['out'].value,model.L['out'].value,model.MPCC.s_L.value,model.MPCC.beta.value))
    
        rf_data['T'].append(model.T.value)
        rf_data['Q'].append(model.Q_main.value)
        rf_data['V'].append(model.V['out'].value)
        rf_data['L'].append(model.L['out'].value)
        rf_data['beta'].append(model.MPCC.beta.value)
        rf_data['s_L'].append(model.MPCC.s_L.value)

        for i in m.COMP_TOTAL:
            rf_data['x'][i].append(model.x[i].value)
            rf_data['y'][i].append(model.y[i].value)
        
    rf_data_master[c] = rf_data
# Out:
# Working on Cat = 3000 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4578 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8798	|beta = 0.1202
# Solved	|T = 569.15 K	|V = 0.4550 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8758	|beta = 0.1242
# Solved	|T = 565.15 K	|V = 0.4520 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8709	|beta = 0.1291
# Solved	|T = 561.15 K	|V = 0.4488 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8649	|beta = 0.1351
# Solved	|T = 557.15 K	|V = 0.4455 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8574	|beta = 0.1426
# Solved	|T = 553.15 K	|V = 0.4420 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8477	|beta = 0.1523
# Solved	|T = 549.15 K	|V = 0.4384 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8347	|beta = 0.1653
# Solved	|T = 545.15 K	|V = 0.4347 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8167	|beta = 0.1833
# Solved	|T = 541.15 K	|V = 0.4309 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7902	|beta = 0.2098
# Solved	|T = 537.15 K	|V = 0.4271 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7486	|beta = 0.2514
# Solved	|T = 533.15 K	|V = 0.4233 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.6769	|beta = 0.3231
# Solved	|T = 529.15 K	|V = 0.4196 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.5393	|beta = 0.4607
# Solved	|T = 525.15 K	|V = 0.4160 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.2534	|beta = 0.7466
# Solved	|T = 521.15 K	|V = 0.4127 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0070	|beta = 0.9930
# Solved	|T = 517.15 K	|V = 0.4095 kmol/s	|L = 0.0004 kmol/s	|s_L = 0.0007	|beta = 0.9993
# Solved	|T = 513.15 K	|V = 0.4065 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 509.15 K	|V = 0.4038 kmol/s	|L = 0.0025 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 505.15 K	|V = 0.4019 kmol/s	|L = 0.0039 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 501.15 K	|V = 0.4016 kmol/s	|L = 0.0055 kmol/s	|s_L = 0.0000	|beta = 1.0000
# Solved	|T = 497.15 K	|V = 0.4036 kmol/s	|L = 0.0069 kmol/s	|s_L = 0.0000	|beta = 1.0000
# Solved	|T = 493.15 K	|V = 0.4087 kmol/s	|L = 0.0080 kmol/s	|s_L = 0.0000	|beta = 1.0000
# Solved	|T = 489.15 K	|V = 0.4183 kmol/s	|L = 0.0087 kmol/s	|s_L = 0.0000	|beta = 1.0000
# Solved	|T = 485.15 K	|V = 0.4339 kmol/s	|L = 0.0090 kmol/s	|s_L = 0.0000	|beta = 1.0000
# Solved	|T = 481.15 K	|V = 0.4569 kmol/s	|L = 0.0088 kmol/s	|s_L = 0.0000	|beta = 1.0000
# Solved	|T = 477.15 K	|V = 0.4887 kmol/s	|L = 0.0083 kmol/s	|s_L = 0.0000	|beta = 1.0000
# Solved	|T = 473.15 K	|V = 0.5291 kmol/s	|L = 0.0076 kmol/s	|s_L = 0.0000	|beta = 1.0000
#
# Working on Cat = 1000 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4616 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8810	|beta = 0.1190
# Solved	|T = 569.15 K	|V = 0.4594 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8772	|beta = 0.1228
# Solved	|T = 565.15 K	|V = 0.4572 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8728	|beta = 0.1272
# Solved	|T = 561.15 K	|V = 0.4550 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8673	|beta = 0.1327
# Solved	|T = 557.15 K	|V = 0.4529 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8605	|beta = 0.1395
# Solved	|T = 553.15 K	|V = 0.4508 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8518	|beta = 0.1482
# Solved	|T = 549.15 K	|V = 0.4490 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8402	|beta = 0.1598
# Solved	|T = 545.15 K	|V = 0.4474 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8243	|beta = 0.1757
# Solved	|T = 541.15 K	|V = 0.4464 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8012	|beta = 0.1988
# Solved	|T = 537.15 K	|V = 0.4459 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7650	|beta = 0.2350
# Solved	|T = 533.15 K	|V = 0.4464 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7034	|beta = 0.2966
# Solved	|T = 529.15 K	|V = 0.4480 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.5867	|beta = 0.4133
# Solved	|T = 525.15 K	|V = 0.4514 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.3441	|beta = 0.6559
# Solved	|T = 521.15 K	|V = 0.4569 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0244	|beta = 0.9756
# Solved	|T = 517.15 K	|V = 0.4652 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.0015	|beta = 0.9985
# Solved	|T = 513.15 K	|V = 0.4770 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0004	|beta = 0.9996
# Solved	|T = 509.15 K	|V = 0.4934 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 505.15 K	|V = 0.5153 kmol/s	|L = 0.0019 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 501.15 K	|V = 0.5434 kmol/s	|L = 0.0026 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 497.15 K	|V = 0.5774 kmol/s	|L = 0.0030 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 493.15 K	|V = 0.6157 kmol/s	|L = 0.0033 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 489.15 K	|V = 0.6562 kmol/s	|L = 0.0033 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 485.15 K	|V = 0.6967 kmol/s	|L = 0.0032 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 481.15 K	|V = 0.7356 kmol/s	|L = 0.0030 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 477.15 K	|V = 0.7716 kmol/s	|L = 0.0027 kmol/s	|s_L = 0.0001	|beta = 0.9999
# Solved	|T = 473.15 K	|V = 0.8042 kmol/s	|L = 0.0024 kmol/s	|s_L = 0.0001	|beta = 0.9999
#
# Working on Cat = 500 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4688 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8831	|beta = 0.1169
# Solved	|T = 569.15 K	|V = 0.4680 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8799	|beta = 0.1201
# Solved	|T = 565.15 K	|V = 0.4675 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8762	|beta = 0.1238
# Solved	|T = 561.15 K	|V = 0.4674 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8718	|beta = 0.1282
# Solved	|T = 557.15 K	|V = 0.4679 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8664	|beta = 0.1336
# Solved	|T = 553.15 K	|V = 0.4691 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8596	|beta = 0.1404
# Solved	|T = 549.15 K	|V = 0.4713 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8509	|beta = 0.1491
# Solved	|T = 545.15 K	|V = 0.4750 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8391	|beta = 0.1609
# Solved	|T = 541.15 K	|V = 0.4804 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8222	|beta = 0.1778
# Solved	|T = 537.15 K	|V = 0.4881 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7965	|beta = 0.2035
# Solved	|T = 533.15 K	|V = 0.4989 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7534	|beta = 0.2466
# Solved	|T = 529.15 K	|V = 0.5133 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.6739	|beta = 0.3261
# Solved	|T = 525.15 K	|V = 0.5322 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.5118	|beta = 0.4882
# Solved	|T = 521.15 K	|V = 0.5558 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.1912	|beta = 0.8088
# Solved	|T = 517.15 K	|V = 0.5842 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0115	|beta = 0.9885
# Solved	|T = 513.15 K	|V = 0.6163 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0020	|beta = 0.9980
# Solved	|T = 509.15 K	|V = 0.6508 kmol/s	|L = 0.0003 kmol/s	|s_L = 0.0008	|beta = 0.9992
# Solved	|T = 505.15 K	|V = 0.6861 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0004	|beta = 0.9996
# Solved	|T = 501.15 K	|V = 0.7208 kmol/s	|L = 0.0008 kmol/s	|s_L = 0.0003	|beta = 0.9997
# Solved	|T = 497.15 K	|V = 0.7539 kmol/s	|L = 0.0010 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 493.15 K	|V = 0.7848 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 489.15 K	|V = 0.8130 kmol/s	|L = 0.0013 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 485.15 K	|V = 0.8385 kmol/s	|L = 0.0013 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 481.15 K	|V = 0.8613 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 477.15 K	|V = 0.8815 kmol/s	|L = 0.0012 kmol/s	|s_L = 0.0002	|beta = 0.9998
# Solved	|T = 473.15 K	|V = 0.8993 kmol/s	|L = 0.0010 kmol/s	|s_L = 0.0002	|beta = 0.9998
#
# Working on Cat = 300 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.4811 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8865	|beta = 0.1135
# Solved	|T = 569.15 K	|V = 0.4828 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8842	|beta = 0.1158
# Solved	|T = 565.15 K	|V = 0.4855 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8818	|beta = 0.1182
# Solved	|T = 561.15 K	|V = 0.4893 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8789	|beta = 0.1211
# Solved	|T = 557.15 K	|V = 0.4947 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8757	|beta = 0.1243
# Solved	|T = 553.15 K	|V = 0.5020 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8718	|beta = 0.1282
# Solved	|T = 549.15 K	|V = 0.5119 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8671	|beta = 0.1329
# Solved	|T = 545.15 K	|V = 0.5248 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8608	|beta = 0.1392
# Solved	|T = 541.15 K	|V = 0.5414 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8518	|beta = 0.1482
# Solved	|T = 537.15 K	|V = 0.5620 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8379	|beta = 0.1621
# Solved	|T = 533.15 K	|V = 0.5866 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8143	|beta = 0.1857
# Solved	|T = 529.15 K	|V = 0.6148 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7700	|beta = 0.2300
# Solved	|T = 525.15 K	|V = 0.6456 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.6782	|beta = 0.3218
# Solved	|T = 521.15 K	|V = 0.6778 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.4759	|beta = 0.5241
# Solved	|T = 517.15 K	|V = 0.7101 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.1284	|beta = 0.8716
# Solved	|T = 513.15 K	|V = 0.7415 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0130	|beta = 0.9870
# Solved	|T = 509.15 K	|V = 0.7711 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0032	|beta = 0.9968
# Solved	|T = 505.15 K	|V = 0.7987 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.0014	|beta = 0.9986
# Solved	|T = 501.15 K	|V = 0.8238 kmol/s	|L = 0.0003 kmol/s	|s_L = 0.0008	|beta = 0.9992
# Solved	|T = 497.15 K	|V = 0.8466 kmol/s	|L = 0.0004 kmol/s	|s_L = 0.0006	|beta = 0.9994
# Solved	|T = 493.15 K	|V = 0.8670 kmol/s	|L = 0.0005 kmol/s	|s_L = 0.0005	|beta = 0.9995
# Solved	|T = 489.15 K	|V = 0.8852 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0004	|beta = 0.9996
# Solved	|T = 485.15 K	|V = 0.9014 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0004	|beta = 0.9996
# Solved	|T = 481.15 K	|V = 0.9156 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0004	|beta = 0.9996
# Solved	|T = 477.15 K	|V = 0.9281 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0004	|beta = 0.9996
# Solved	|T = 473.15 K	|V = 0.9390 kmol/s	|L = 0.0006 kmol/s	|s_L = 0.0004	|beta = 0.9996
#
# Working on Cat = 100 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.5799 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9072	|beta = 0.0928
# Solved	|T = 569.15 K	|V = 0.5997 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9091	|beta = 0.0909
# Solved	|T = 565.15 K	|V = 0.6223 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9112	|beta = 0.0888
# Solved	|T = 561.15 K	|V = 0.6470 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9133	|beta = 0.0867
# Solved	|T = 557.15 K	|V = 0.6732 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9153	|beta = 0.0847
# Solved	|T = 553.15 K	|V = 0.7002 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9171	|beta = 0.0829
# Solved	|T = 549.15 K	|V = 0.7271 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9184	|beta = 0.0816
# Solved	|T = 545.15 K	|V = 0.7533 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9190	|beta = 0.0810
# Solved	|T = 541.15 K	|V = 0.7784 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9185	|beta = 0.0815
# Solved	|T = 537.15 K	|V = 0.8019 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9162	|beta = 0.0838
# Solved	|T = 533.15 K	|V = 0.8238 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9109	|beta = 0.0891
# Solved	|T = 529.15 K	|V = 0.8439 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8994	|beta = 0.1006
# Solved	|T = 525.15 K	|V = 0.8622 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8745	|beta = 0.1255
# Solved	|T = 521.15 K	|V = 0.8788 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8179	|beta = 0.1821
# Solved	|T = 517.15 K	|V = 0.8938 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.6806	|beta = 0.3194
# Solved	|T = 513.15 K	|V = 0.9072 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.3739	|beta = 0.6261
# Solved	|T = 509.15 K	|V = 0.9191 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0825	|beta = 0.9175
# Solved	|T = 505.15 K	|V = 0.9297 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0194	|beta = 0.9806
# Solved	|T = 501.15 K	|V = 0.9391 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0075	|beta = 0.9925
# Solved	|T = 497.15 K	|V = 0.9474 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0040	|beta = 0.9960
# Solved	|T = 493.15 K	|V = 0.9547 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0027	|beta = 0.9973
# Solved	|T = 489.15 K	|V = 0.9611 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0021	|beta = 0.9979
# Solved	|T = 485.15 K	|V = 0.9667 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0018	|beta = 0.9982
# Solved	|T = 481.15 K	|V = 0.9716 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.0016	|beta = 0.9984
# Solved	|T = 477.15 K	|V = 0.9758 kmol/s	|L = 0.0002 kmol/s	|s_L = 0.0016	|beta = 0.9984
# Solved	|T = 473.15 K	|V = 0.9795 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0017	|beta = 0.9983
#
# Working on Cat = 50 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.7239 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9264	|beta = 0.0736
# Solved	|T = 569.15 K	|V = 0.7479 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9285	|beta = 0.0715
# Solved	|T = 565.15 K	|V = 0.7712 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9304	|beta = 0.0696
# Solved	|T = 561.15 K	|V = 0.7933 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9321	|beta = 0.0679
# Solved	|T = 557.15 K	|V = 0.8142 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9335	|beta = 0.0665
# Solved	|T = 553.15 K	|V = 0.8336 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9348	|beta = 0.0652
# Solved	|T = 549.15 K	|V = 0.8515 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9357	|beta = 0.0643
# Solved	|T = 545.15 K	|V = 0.8679 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9362	|beta = 0.0638
# Solved	|T = 541.15 K	|V = 0.8829 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9361	|beta = 0.0639
# Solved	|T = 537.15 K	|V = 0.8964 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9353	|beta = 0.0647
# Solved	|T = 533.15 K	|V = 0.9086 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9329	|beta = 0.0671
# Solved	|T = 529.15 K	|V = 0.9196 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9276	|beta = 0.0724
# Solved	|T = 525.15 K	|V = 0.9294 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9163	|beta = 0.0837
# Solved	|T = 521.15 K	|V = 0.9382 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8907	|beta = 0.1093
# Solved	|T = 517.15 K	|V = 0.9460 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8295	|beta = 0.1705
# Solved	|T = 513.15 K	|V = 0.9529 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.6754	|beta = 0.3246
# Solved	|T = 509.15 K	|V = 0.9591 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.3553	|beta = 0.6447
# Solved	|T = 505.15 K	|V = 0.9645 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0982	|beta = 0.9018
# Solved	|T = 501.15 K	|V = 0.9693 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0309	|beta = 0.9691
# Solved	|T = 497.15 K	|V = 0.9735 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0140	|beta = 0.9860
# Solved	|T = 493.15 K	|V = 0.9772 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0082	|beta = 0.9918
# Solved	|T = 489.15 K	|V = 0.9805 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0058	|beta = 0.9942
# Solved	|T = 485.15 K	|V = 0.9833 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0046	|beta = 0.9954
# Solved	|T = 481.15 K	|V = 0.9858 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0041	|beta = 0.9959
# Solved	|T = 477.15 K	|V = 0.9879 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0039	|beta = 0.9961
# Solved	|T = 473.15 K	|V = 0.9898 kmol/s	|L = 0.0001 kmol/s	|s_L = 0.0039	|beta = 0.9961
#
# Working on Cat = 25 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.8476 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9376	|beta = 0.0624
# Solved	|T = 569.15 K	|V = 0.8632 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9389	|beta = 0.0611
# Solved	|T = 565.15 K	|V = 0.8776 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9400	|beta = 0.0600
# Solved	|T = 561.15 K	|V = 0.8907 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9411	|beta = 0.0589
# Solved	|T = 557.15 K	|V = 0.9027 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9420	|beta = 0.0580
# Solved	|T = 553.15 K	|V = 0.9135 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9428	|beta = 0.0572
# Solved	|T = 549.15 K	|V = 0.9233 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9434	|beta = 0.0566
# Solved	|T = 545.15 K	|V = 0.9322 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9439	|beta = 0.0561
# Solved	|T = 541.15 K	|V = 0.9401 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9441	|beta = 0.0559
# Solved	|T = 537.15 K	|V = 0.9472 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9439	|beta = 0.0561
# Solved	|T = 533.15 K	|V = 0.9536 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9430	|beta = 0.0570
# Solved	|T = 529.15 K	|V = 0.9593 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9406	|beta = 0.0594
# Solved	|T = 525.15 K	|V = 0.9643 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9354	|beta = 0.0646
# Solved	|T = 521.15 K	|V = 0.9688 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9237	|beta = 0.0763
# Solved	|T = 517.15 K	|V = 0.9728 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8965	|beta = 0.1035
# Solved	|T = 513.15 K	|V = 0.9763 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8292	|beta = 0.1708
# Solved	|T = 509.15 K	|V = 0.9794 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.6598	|beta = 0.3402
# Solved	|T = 505.15 K	|V = 0.9822 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.3470	|beta = 0.6530
# Solved	|T = 501.15 K	|V = 0.9846 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.1211	|beta = 0.8789
# Solved	|T = 497.15 K	|V = 0.9867 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0484	|beta = 0.9516
# Solved	|T = 493.15 K	|V = 0.9886 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0253	|beta = 0.9747
# Solved	|T = 489.15 K	|V = 0.9902 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0163	|beta = 0.9837
# Solved	|T = 485.15 K	|V = 0.9916 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0123	|beta = 0.9877
# Solved	|T = 481.15 K	|V = 0.9929 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0103	|beta = 0.9897
# Solved	|T = 477.15 K	|V = 0.9939 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0094	|beta = 0.9906
# Solved	|T = 473.15 K	|V = 0.9949 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0092	|beta = 0.9908
#
# Working on Cat = 10 kg
# ------------------------------------------------------------------------------------------------------------
# Solved	|T = 573.15 K	|V = 0.9363 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9438	|beta = 0.0562
# Solved	|T = 569.15 K	|V = 0.9432 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9446	|beta = 0.0554
# Solved	|T = 565.15 K	|V = 0.9494 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9453	|beta = 0.0547
# Solved	|T = 561.15 K	|V = 0.9551 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9460	|beta = 0.0540
# Solved	|T = 557.15 K	|V = 0.9602 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9466	|beta = 0.0534
# Solved	|T = 553.15 K	|V = 0.9647 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9472	|beta = 0.0528
# Solved	|T = 549.15 K	|V = 0.9688 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9478	|beta = 0.0522
# Solved	|T = 545.15 K	|V = 0.9725 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9482	|beta = 0.0518
# Solved	|T = 541.15 K	|V = 0.9758 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9486	|beta = 0.0514
# Solved	|T = 537.15 K	|V = 0.9787 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9488	|beta = 0.0512
# Solved	|T = 533.15 K	|V = 0.9813 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9487	|beta = 0.0513
# Solved	|T = 529.15 K	|V = 0.9836 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9480	|beta = 0.0520
# Solved	|T = 525.15 K	|V = 0.9856 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9463	|beta = 0.0537
# Solved	|T = 521.15 K	|V = 0.9875 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9421	|beta = 0.0579
# Solved	|T = 517.15 K	|V = 0.9891 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9326	|beta = 0.0674
# Solved	|T = 513.15 K	|V = 0.9905 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.9107	|beta = 0.0893
# Solved	|T = 509.15 K	|V = 0.9918 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.8570	|beta = 0.1430
# Solved	|T = 505.15 K	|V = 0.9929 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.7241	|beta = 0.2759
# Solved	|T = 501.15 K	|V = 0.9938 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.4679	|beta = 0.5321
# Solved	|T = 497.15 K	|V = 0.9947 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.2251	|beta = 0.7749
# Solved	|T = 493.15 K	|V = 0.9954 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.1105	|beta = 0.8895
# Solved	|T = 489.15 K	|V = 0.9961 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0647	|beta = 0.9353
# Solved	|T = 485.15 K	|V = 0.9967 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0447	|beta = 0.9553
# Solved	|T = 481.15 K	|V = 0.9972 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0352	|beta = 0.9648
# Solved	|T = 477.15 K	|V = 0.9976 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0306	|beta = 0.9694
# Solved	|T = 473.15 K	|V = 0.9980 kmol/s	|L = 0.0000 kmol/s	|s_L = 0.0287	|beta = 0.9713

# %% [markdown]
# # Optimization results across disappearing phases

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,rf_data_master[c]['V'])
ax1.set_ylabel('Vapor Flow Rate (kmol/s)',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.grid()

for c in catrange:
    ax2.plot(Trange,rf_data_master[c]['L'])
ax2.set_ylabel('Liquid Flow Rate (kmol/s)',fontsize=14)
ax2.set_xlabel('Temperature (K)',fontsize=14)
ax2.tick_params(labelsize=14)
ax2.grid()

ax2.legend(catrange,fontsize=14)
fig.suptitle('Vapor and Liquid Flow Rate',fontsize=18)

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,np.divide(rf_data_master[c]['V'],np.add(rf_data_master[c]['V'],rf_data_master[c]['L'])))
ax1.set_ylabel('Vapor Fraction',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.legend(catrange,fontsize=14)
ax1.set_title('Vapor Fraction',fontsize=18)
ax1.grid()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,rf_data_master[c]['beta'])
ax1.set_ylabel(r'$\beta$ value',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.legend(catrange,fontsize=14)
ax1.set_title(r'$\beta$',fontsize=18)
ax1.grid()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,9))
for c in catrange:
    ax1.plot(Trange,np.multiply(rf_data_master[c]['s_L'],rf_data_master[c]['L']))
ax1.set_ylabel(r'$s_L \cdot L$ value',fontsize=14)
ax1.set_xlabel('Temperature (K)',fontsize=14)
ax1.tick_params(labelsize=14)
ax1.legend(catrange,fontsize=14)
ax1.set_ylim(2.49e-7,2.51e-7)
ax1.set_title(r'$s_L \cdot L$',fontsize=18)
ax1.grid()
plt.show()
