# %% [markdown]
# # Reactive Flash Validation: Based on Marano & Holder (1997)

# %%
import sys
import os
import pickle
sys.path.append(os.path.abspath('..'))
import numpy as np

# %%
from pyomo import environ as pe
from global_sets.component import m
from utility.display_utility import trans_product_mole, trans_product_mass
from utility.model_utility import add_dual, update_dual, check_DOF

# stage construction rules
from stages.reactive_stage import reactive_stage_rule
from stages.non_reactive_stage import non_reactive_stage_rule

model = pe.ConcreteModel()

# %% [markdown]
# # Validate 3 cases of Mobil F-T reactor effluent

# %%
model.TRAY = pe.RangeSet(1,3)

# %% [markdown]
# ### Construct a single reactive flash stage

# %%
model.reactive = pe.Block(model.TRAY,rule=reactive_stage_rule)
# Out:
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[1].T_F
# | reactive[1].P
# | reactive[1].cat
# | reactive[1].Q_main
# | reactive[1].x_
# | reactive[1].y_
# | reactive[1].x
# | reactive[1].y
# | reactive[1].z
# | reactive[1].L
# | reactive[1].V
# | reactive[1].F
# | reactive[1].H_L_
# | reactive[1].H_V_
# | reactive[1].H_L
# | reactive[1].H_V
# | reactive[1].T
# | reactive[1].H_F
# | reactive[1].f_V
# | reactive[1].f_L
# | reactive[1].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].kinetics_block.k_FT
# | reactive[1].kinetics_block.r_FT_total
# | reactive[1].kinetics_block.g0_FT
# | reactive[1].kinetics_block.alpha
# | reactive[1].kinetics_block.r_FT_cnum
# | reactive[1].kinetics_block.r_FT_comp
# | reactive[1].kinetics_block.k_WGS
# | reactive[1].kinetics_block.Ke_WGS
# | reactive[1].kinetics_block.r_WGS
# | reactive[1].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].energy_block.dH_F
# | reactive[1].energy_block.dH_V
# | reactive[1].energy_block.dH_L
# | reactive[1].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].VLE_block.n_ave
# | reactive[1].VLE_block.n_ave_cal
# | reactive[1].VLE_block.Hen
# | reactive[1].VLE_block.Hen0
# | reactive[1].VLE_block.gamma
# | reactive[1].VLE_block.P_sat
# | reactive[1].VLE_block.P_sat_Y
# | reactive[1].VLE_block.P_sat_dY_inf
# | reactive[1].VLE_block.P_sat_dY0
# | reactive[1].VLE_block.Hen_ref
# | reactive[1].VLE_block.Hen0_ref
# | reactive[1].VLE_block.gamma_ref
# | reactive[1].VLE_block.V_L
# | reactive[1].VLE_block.V_L_dY_inf
# | reactive[1].VLE_block.V_L_dY0
# | reactive[1].VLE_block.poynting
# --------------------------------------------------
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[2].T_F
# | reactive[2].P
# | reactive[2].cat
# | reactive[2].Q_main
# | reactive[2].x_
# | reactive[2].y_
# | reactive[2].x
# | reactive[2].y
# | reactive[2].z
# | reactive[2].L
# | reactive[2].V
# | reactive[2].F
# | reactive[2].H_L_
# | reactive[2].H_V_
# | reactive[2].H_L
# | reactive[2].H_V
# | reactive[2].T
# | reactive[2].H_F
# | reactive[2].f_V
# | reactive[2].f_L
# | reactive[2].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].kinetics_block.k_FT
# | reactive[2].kinetics_block.r_FT_total
# | reactive[2].kinetics_block.g0_FT
# | reactive[2].kinetics_block.alpha
# | reactive[2].kinetics_block.r_FT_cnum
# | reactive[2].kinetics_block.r_FT_comp
# | reactive[2].kinetics_block.k_WGS
# | reactive[2].kinetics_block.Ke_WGS
# | reactive[2].kinetics_block.r_WGS
# | reactive[2].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].energy_block.dH_F
# | reactive[2].energy_block.dH_V
# | reactive[2].energy_block.dH_L
# | reactive[2].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].VLE_block.n_ave
# | reactive[2].VLE_block.n_ave_cal
# | reactive[2].VLE_block.Hen
# | reactive[2].VLE_block.Hen0
# | reactive[2].VLE_block.gamma
# | reactive[2].VLE_block.P_sat
# | reactive[2].VLE_block.P_sat_Y
# | reactive[2].VLE_block.P_sat_dY_inf
# | reactive[2].VLE_block.P_sat_dY0
# | reactive[2].VLE_block.Hen_ref
# | reactive[2].VLE_block.Hen0_ref
# | reactive[2].VLE_block.gamma_ref
# | reactive[2].VLE_block.V_L
# | reactive[2].VLE_block.V_L_dY_inf
# | reactive[2].VLE_block.V_L_dY0
# | reactive[2].VLE_block.poynting
# --------------------------------------------------
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[3].T_F
# | reactive[3].P
# | reactive[3].cat
# | reactive[3].Q_main
# | reactive[3].x_
# | reactive[3].y_
# | reactive[3].x
# | reactive[3].y
# | reactive[3].z
# | reactive[3].L
# | reactive[3].V
# | reactive[3].F
# | reactive[3].H_L_
# | reactive[3].H_V_
# | reactive[3].H_L
# | reactive[3].H_V
# | reactive[3].T
# | reactive[3].H_F
# | reactive[3].f_V
# | reactive[3].f_L
# | reactive[3].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].kinetics_block.k_FT
# | reactive[3].kinetics_block.r_FT_total
# | reactive[3].kinetics_block.g0_FT
# | reactive[3].kinetics_block.alpha
# | reactive[3].kinetics_block.r_FT_cnum
# | reactive[3].kinetics_block.r_FT_comp
# | reactive[3].kinetics_block.k_WGS
# | reactive[3].kinetics_block.Ke_WGS
# | reactive[3].kinetics_block.r_WGS
# | reactive[3].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].energy_block.dH_F
# | reactive[3].energy_block.dH_V
# | reactive[3].energy_block.dH_L
# | reactive[3].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].VLE_block.n_ave
# | reactive[3].VLE_block.n_ave_cal
# | reactive[3].VLE_block.Hen
# | reactive[3].VLE_block.Hen0
# | reactive[3].VLE_block.gamma
# | reactive[3].VLE_block.P_sat
# | reactive[3].VLE_block.P_sat_Y
# | reactive[3].VLE_block.P_sat_dY_inf
# | reactive[3].VLE_block.P_sat_dY0
# | reactive[3].VLE_block.Hen_ref
# | reactive[3].VLE_block.Hen0_ref
# | reactive[3].VLE_block.gamma_ref
# | reactive[3].VLE_block.V_L
# | reactive[3].VLE_block.V_L_dY_inf
# | reactive[3].VLE_block.V_L_dY0
# | reactive[3].VLE_block.poynting
# --------------------------------------------------

# %%
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# ### Fixing In/Product Redundent Flow

# %%
for j in model.reactive:   
    model.reactive[j].x_.fix(0)
    model.reactive[j].y_.fix(0)
    model.reactive[j].L['in'].fix(0)
    model.reactive[j].L['P'].fix(0)
    model.reactive[j].V['in'].fix(0)
    model.reactive[j].V['P'].fix(0)
    model.reactive[j].H_L_.fix(0)
    model.reactive[j].H_V_.fix(0)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].F.fix(1)
    model.reactive[j].z['CO'].fix(1/(1+0.679)-0.001/2)
    model.reactive[j].z['H2'].fix(0.679/(1+0.679)-0.001/2)
    model.reactive[j].z['C30H62'].fix(0.001)

# %% [markdown]
# ### Input Model Parameters

# %%
model.reactive[1].cat.fix(580)
model.reactive[1].P.fix(14.8)
model.reactive[1].T.setub(260+273.15)
model.reactive[1].VLE_block.n_ave.fix(27.8)

model.reactive[2].cat.fix(150)
model.reactive[2].P.fix(25.15)
model.reactive[2].T.setub(256+273.15)
model.reactive[2].VLE_block.n_ave.fix(41)

model.reactive[3].cat.fix(440)
model.reactive[3].P.fix(14.73)
model.reactive[3].T.setub(244+273.15)
model.reactive[3].VLE_block.n_ave.fix(58.4)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 3543
# Active Inequality Constraints:	 0
# Active Variables:		 4062
# Fixed Variables:		 516
# DOF:				 3

# %% [markdown]
# ### Solve

# %%
model.obj = pe.Objective(expr = sum(model.reactive[j].T for j in model.TRAY) ,sense=pe.maximize)

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_scaling_on_demand '] = 'no'
opt.options['linear_solver'] = 'ma86'
opt.options['linear_system_scaling '] = 'mc19'
# opt.options['bound_relax_factor'] = 0
# opt.options['halt_on_ampl_error'] = 'yes'

opt.options['max_iter'] = 7000
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_scaling_on_demand =no
# linear_solver=ma86
# linear_system_scaling =mc19
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    11555
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    12942
#
# Total number of variables............................:     3546
#                      variables with only lower bounds:      663
#                 variables with lower and upper bounds:     2373
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     3543
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -1.4210500e+03 8.04e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -1.
12e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -1.5766875e+03 4.06e+00 9.87e+08  -3.8 8.51e+02    -  8.35e-03 1.08e-04h  1
#   81 -1.5778510e+03 3.66e+00 7.46e+08  -3.8 8.00e+02    -  1.00e+00 2.44e-01f  1
#   82 -1.5778512e+03 3.66e+00 7.46e+08  -3.8 8.63e+02    -  2.19e-03 5.16e-05h  1
#   83 -1.5790251e+03 3.36e+00 5.63e+08  -3.8 8.07e+02    -  1.44e-01 2.45e-01f  1
#   84 -1.5790253e+03 3.36e+00 5.63e+08  -3.8 8.81e+02    -  3.29e-03 4.98e-05h  1
#   85 -1.5794498e+03 3.14e+00 5.14e+08  -3.8 8.17e+02    -  1.45e-01 8.81e-02f  1
#   86 -1.5794498e+03 3.14e+00 5.14e+08  -3.8 8.37e+02    -  2.70e-03 1.30e-05h  1
#   87 -1.5794496e+03 4.61e-04 3.18e+09  -3.8 3.11e+00    -  5.13e-06 1.00e+00f  1
#   88 -1.5794496e+03 8.56e-09 6.73e+06  -3.8 8.30e-03    -  1.00e+00 1.00e+00h  1
#   89 -1.5794496e+03 3.06e-10 5.74e+00  -3.8 4.51e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90 -1.5794496e+03 4.37e-10 1.48e-07  -3.8 1.45e-05    -  1.00e+00 1.00e+00h  1
#   91 -1.5794500e+03 9.79e-09 7.06e+00  -5.7 2.53e-02    -  1.00e+00 1.00e+00f  1
#   92 -1.5794500e+03 2.91e-10 1.05e-06  -5.7 8.99e-05    -  1.00e+00 1.00e+00h  1
#   93 -1.5794500e+03 1.65e-10 1.08e-03  -8.6 3.12e-04    -  1.00e+00 1.00e+00h  1
#   94 -1.5794500e+03 1.45e-10 3.05e-14  -8.6 1.37e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 94
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.5794500157869822e+03   -1.5794500157869822e+03
# Dual infeasibility......:   3.0531133177191805e-14    3.0531133177191805e-14
# Constraint violation....:   1.4490030128457704e-10    1.4490030128457704e-10
# Complementarity.........:   2.5059035597480047e-09    2.5059035597480047e-09
# Overall NLP error.......:   2.5059035597480047e-09    2.5059035597480047e-09
#
#
# Number of objective function evaluations             = 190
# Number of objective gradient evaluations             = 80
# Number of equality constraint evaluations            = 190
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 102
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 94
# Total CPU secs in IPOPT (w/o function evaluations)   =      5.260
# Total CPU secs in NLP function evaluations           =      0.226
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# # Calculate Reactor Effluent (CT-256-3)

# %%
print('Temperature (C): \t{:.2f}\t\t'.format(model.reactive[1].T.value-273.15))
print('Conversion(H2+CO): \t{:.2f}\t\t'.format(1-((model.reactive[1].y['CO'].value+model.reactive[1].y['H2'].value)*model.reactive[1].V['out'].value)))
print('Total FLow (kmol/s): \t{:.2f}\t\t'.format(model.reactive[1].L['out'].value+model.reactive[1].V['out'].value))
print('-'*72)
for i in model.reactive[1].x:
    print('{:10s}'.format(i),'\t\t{:.4%}'.format((model.reactive[1].x[i].value*model.reactive[1].L['out'].value\
        +model.reactive[1].y[i].value*model.reactive[1].V['out'].value)/(model.reactive[1].L['out'].value+model.reactive[1].V['out'].value)))
# Out:
# Temperature (C): 	260.00
# Conversion(H2+CO): 	0.85
# Total FLow (kmol/s): 	0.50
# ------------------------------------------------------------------------
# H2         		13.3157%
# CO         		16.1067%
# CO2        		48.8147%
# H2O        		4.5129%
# C2H4       		2.4120%
# C3H6       		2.0183%
# C4H8       		1.3047%
# C5H10      		0.7351%
# C6H12      		0.5000%
# C7H14      		0.3402%
# C8H16      		0.2314%
# C9H18      		0.1574%
# C10H20     		0.1071%
# C11H22     		0.0464%
# C12H24     		0.0316%
# C13H26     		0.0215%
# C14H28     		0.0146%
# C15H30     		0.0099%
# C16H32     		0.0068%
# C17H34     		0.0046%
# C18H36     		0.0031%
# C19H38     		0.0021%
# C20H40     		0.0014%
# C1H4       		5.4520%
# C2H6       		1.2968%
# C3H8       		0.5046%
# C4H10      		0.4116%
# C5H12      		0.4324%
# C6H14      		0.2941%
# C7H16      		0.2001%
# C8H18      		0.1361%
# C9H20      		0.0926%
# C10H22     		0.0630%
# C11H24     		0.0693%
# C12H26     		0.0471%
# C13H28     		0.0321%
# C14H30     		0.0218%
# C15H32     		0.0148%
# C16H34     		0.0101%
# C17H36     		0.0069%
# C18H38     		0.0047%
# C19H40     		0.0032%
# C20H42     		0.0022%
# C21H44     		0.0025%
# C22H46     		0.0017%
# C23H48     		0.0011%
# C24H50     		0.0008%
# C25H52     		0.0005%
# C26H54     		0.0004%
# C27H56     		0.0002%
# C28H58     		0.0002%
# C29H60     		0.0001%
# C30H62     		0.1988%
# C31H64     		0.0001%
# C32H66     		0.0000%
# C33H68     		0.0000%
# C34H70     		0.0000%
# C35H72     		0.0000%
# C36H74     		0.0000%
# C37H76     		0.0000%
# C38H78     		0.0000%
# C39H80     		0.0000%
# C40H82     		0.0000%
# C41H84     		0.0000%
# C42H86     		0.0000%
# C43H88     		0.0000%
# C44H90     		0.0000%
# C45H92     		0.0000%
# C46H94     		0.0000%
# C47H96     		0.0000%
# C48H98     		0.0000%
# C49H100    		0.0000%
# C50H102    		0.0000%
# C51H104    		0.0000%
# C52H106    		0.0000%
# C53H108    		0.0000%
# C54H110    		0.0000%
# C55H112    		0.0000%
# C56H114    		0.0000%

# %% [markdown]
# # Calculate Reactor Effluent (CT-256-4)

# %%
print('Temperature (C): \t{:.2f}\t\t'.format(model.reactive[2].T.value-273.15))
print('Conversion(H2+CO): \t{:.2f}\t\t'.format(1-((model.reactive[2].y['CO'].value+model.reactive[2].y['H2'].value)*model.reactive[2].V['out'].value)))
print('Total FLow (kmol/s): \t{:.2f}\t\t'.format(model.reactive[2].L['out'].value+model.reactive[2].V['out'].value))
print('-'*72)
for i in model.reactive[2].x:
    print('{:10s}'.format(i),'\t\t{:.4%}'.format((model.reactive[2].x[i].value*model.reactive[2].L['out'].value\
        +model.reactive[2].y[i].value*model.reactive[2].V['out'].value)/(model.reactive[2].L['out'].value+model.reactive[2].V['out'].value)))
# Out:
# Temperature (C): 	256.00
# Conversion(H2+CO): 	0.41
# Total FLow (kmol/s): 	0.76
# ------------------------------------------------------------------------
# H2         		32.3890%
# CO         		45.1366%
# CO2        		16.1901%
# H2O        		1.0296%
# C2H4       		0.6963%
# C3H6       		0.6017%
# C4H8       		0.4017%
# C5H10      		0.2337%
# C6H12      		0.1642%
# C7H14      		0.1153%
# C8H16      		0.0810%
# C9H18      		0.0569%
# C10H20     		0.0400%
# C11H22     		0.0179%
# C12H24     		0.0126%
# C13H26     		0.0088%
# C14H28     		0.0062%
# C15H30     		0.0044%
# C16H32     		0.0031%
# C17H34     		0.0022%
# C18H36     		0.0015%
# C19H38     		0.0011%
# C20H40     		0.0007%
# C1H4       		1.5239%
# C2H6       		0.3743%
# C3H8       		0.1504%
# C4H10      		0.1267%
# C5H12      		0.1375%
# C6H14      		0.0966%
# C7H16      		0.0678%
# C8H18      		0.0477%
# C9H20      		0.0335%
# C10H22     		0.0235%
# C11H24     		0.0267%
# C12H26     		0.0188%
# C13H28     		0.0132%
# C14H30     		0.0093%
# C15H32     		0.0065%
# C16H34     		0.0046%
# C17H36     		0.0032%
# C18H38     		0.0023%
# C19H40     		0.0016%
# C20H42     		0.0011%
# C21H44     		0.0013%
# C22H46     		0.0009%
# C23H48     		0.0006%
# C24H50     		0.0005%
# C25H52     		0.0003%
# C26H54     		0.0002%
# C27H56     		0.0002%
# C28H58     		0.0001%
# C29H60     		0.0001%
# C30H62     		0.1320%
# C31H64     		0.0000%
# C32H66     		0.0000%
# C33H68     		0.0000%
# C34H70     		0.0000%
# C35H72     		0.0000%
# C36H74     		0.0000%
# C37H76     		0.0000%
# C38H78     		0.0000%
# C39H80     		0.0000%
# C40H82     		0.0000%
# C41H84     		0.0000%
# C42H86     		0.0000%
# C43H88     		0.0000%
# C44H90     		0.0000%
# C45H92     		0.0000%
# C46H94     		0.0000%
# C47H96     		0.0000%
# C48H98     		0.0000%
# C49H100    		0.0000%
# C50H102    		0.0000%
# C51H104    		0.0000%
# C52H106    		0.0000%
# C53H108    		0.0000%
# C54H110    		0.0000%
# C55H112    		0.0000%
# C56H114    		0.0000%

# %% [markdown]
# # Calculate Reactor Effluent (CT-256-5)

# %%
print('Temperature (C): \t{:.2f}\t\t'.format(model.reactive[3].T.value-273.15))
print('Conversion(H2+CO): \t{:.2f}\t\t'.format(1-((model.reactive[3].y['CO'].value+model.reactive[3].y['H2'].value)*model.reactive[3].V['out'].value)))
print('Total FLow (kmol/s): \t{:.2f}\t\t'.format(model.reactive[3].L['out'].value+model.reactive[3].V['out'].value))
print('-'*72)
for i in model.reactive[3].x:
    print('{:10s}'.format(i),'\t\t{:.4%}'.format((model.reactive[3].x[i].value*model.reactive[3].L['out'].value\
        +model.reactive[3].y[i].value*model.reactive[3].V['out'].value)/(model.reactive[3].L['out'].value+model.reactive[3].V['out'].value)))
# Out:
# Temperature (C): 	244.00
# Conversion(H2+CO): 	0.57
# Total FLow (kmol/s): 	0.66
# ------------------------------------------------------------------------
# H2         		28.4629%
# CO         		37.3009%
# CO2        		25.5309%
# H2O        		2.1197%
# C2H4       		0.7470%
# C3H6       		0.7051%
# C4H8       		0.5141%
# C5H10      		0.3267%
# C6H12      		0.2507%
# C7H14      		0.1924%
# C8H16      		0.1476%
# C9H18      		0.1133%
# C10H20     		0.0869%
# C11H22     		0.0425%
# C12H24     		0.0326%
# C13H26     		0.0250%
# C14H28     		0.0192%
# C15H30     		0.0147%
# C16H32     		0.0113%
# C17H34     		0.0087%
# C18H36     		0.0067%
# C19H38     		0.0051%
# C20H40     		0.0039%
# C1H4       		1.4969%
# C2H6       		0.4016%
# C3H8       		0.1763%
# C4H10      		0.1622%
# C5H12      		0.1922%
# C6H14      		0.1475%
# C7H16      		0.1132%
# C8H18      		0.0868%
# C9H20      		0.0666%
# C10H22     		0.0511%
# C11H24     		0.0634%
# C12H26     		0.0487%
# C13H28     		0.0373%
# C14H30     		0.0287%
# C15H32     		0.0220%
# C16H34     		0.0169%
# C17H36     		0.0129%
# C18H38     		0.0099%
# C19H40     		0.0076%
# C20H42     		0.0058%
# C21H44     		0.0075%
# C22H46     		0.0058%
# C23H48     		0.0044%
# C24H50     		0.0034%
# C25H52     		0.0026%
# C26H54     		0.0020%
# C27H56     		0.0015%
# C28H58     		0.0012%
# C29H60     		0.0009%
# C30H62     		0.1527%
# C31H64     		0.0005%
# C32H66     		0.0004%
# C33H68     		0.0003%
# C34H70     		0.0002%
# C35H72     		0.0002%
# C36H74     		0.0001%
# C37H76     		0.0001%
# C38H78     		0.0001%
# C39H80     		0.0001%
# C40H82     		0.0000%
# C41H84     		0.0000%
# C42H86     		0.0000%
# C43H88     		0.0000%
# C44H90     		0.0000%
# C45H92     		0.0000%
# C46H94     		0.0000%
# C47H96     		0.0000%
# C48H98     		0.0000%
# C49H100    		0.0000%
# C50H102    		0.0000%
# C51H104    		0.0000%
# C52H106    		0.0000%
# C53H108    		0.0000%
# C54H110    		0.0000%
# C55H112    		0.0000%
# C56H114    		0.0000%

# %% [markdown]
# # Vapor Liquid Separation (CT-256-4)

# %%
print('Component\t\t Liquid:\t\t\tVapor:\t\t\tlog K')
print('-'*108)
for i in model.reactive[2].x:
    print('{:7s}\t\t\t{:8.4%}\t\t\t{:8.4%}\t\t{:.4f}'.format(i,model.reactive[2].x[i].value,model.reactive[2].y[i].value,np.log10(model.reactive[2].y[i].value/model.reactive[2].x[i].value)))
# Out:
# Component		 Liquid:			Vapor:			log K
# ------------------------------------------------------------------------------------------------------------
# H2     			 2.5602%			32.4351%		1.1027
# CO     			 4.0836%			45.2001%		1.0441
# CO2    			 3.0869%			16.2104%		0.7203
# H2O    			 0.8905%			 1.0298%		0.0631
# C2H4   			 0.1760%			 0.6971%		0.5978
# C3H6   			 0.2878%			 0.6022%		0.3206
# C4H8   			 0.1733%			 0.4020%		0.3655
# C5H10  			 0.1971%			 0.2338%		0.0741
# C6H12  			 0.2454%			 0.1641%		-0.1748
# C7H14  			 0.2869%			 0.1151%		-0.3968
# C8H16  			 0.3212%			 0.0807%		-0.6002
# C9H18  			 0.3482%			 0.0565%		-0.7901
# C10H20 			 0.3682%			 0.0395%		-0.9697
# C11H22 			 0.2429%			 0.0176%		-1.1412
# C12H24 			 0.2472%			 0.0122%		-1.3062
# C13H26 			 0.2475%			 0.0085%		-1.4660
# C14H28 			 0.2441%			 0.0058%		-1.6214
# C15H30 			 0.2372%			 0.0040%		-1.7731
# C16H32 			 0.2268%			 0.0027%		-1.9216
# C17H34 			 0.2131%			 0.0018%		-2.0674
# C18H36 			 0.1966%			 0.0012%		-2.2108
