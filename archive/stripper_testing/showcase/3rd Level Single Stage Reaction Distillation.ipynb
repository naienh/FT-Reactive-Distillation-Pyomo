# %% [markdown]
# # 3rd Level Model Structure: Single Stage Reactive Distillation

# %%
import sys
import os
import pickle
sys.path.append(os.path.abspath('..'))

import numpy as np
from matplotlib import pyplot as plt
import ipywidgets as widgets

# %%
from pyomo import environ as pe
from global_sets.component import m

from stages.reactive_stage import reactive_stage_rule
from stages.condenser_stage import condenser_stage_rule

from utility.display_utility import trans_product_mole, trans_product_mass, beautify2
from utility.model_utility import add_dual, update_dual, check_DOF
from utility.data_utility import cal_cnumber

model = pe.ConcreteModel()

# %% [markdown]
# # Global Set

# %%
model.TRAY = pe.RangeSet(1,1)

# %% [markdown]
# # Construct Reactive Stages

# %%
model.reactive = pe.Block(model.TRAY,rule=reactive_stage_rule)
# Out:
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[1].T_F
# | reactive[1].P
# | reactive[1].cat
# | reactive[1].Q_main
# | reactive[1].x_
# | reactive[1].y_
# | reactive[1].x
# | reactive[1].y
# | reactive[1].z
# | reactive[1].L
# | reactive[1].V
# | reactive[1].F
# | reactive[1].H_L_
# | reactive[1].H_V_
# | reactive[1].H_L
# | reactive[1].H_V
# | reactive[1].T
# | reactive[1].H_F
# | reactive[1].f_V
# | reactive[1].f_L
# | reactive[1].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].kinetics_block.k_FT
# | reactive[1].kinetics_block.r_FT_total
# | reactive[1].kinetics_block.g0_FT
# | reactive[1].kinetics_block.alpha
# | reactive[1].kinetics_block.r_FT_cnum
# | reactive[1].kinetics_block.r_FT_comp
# | reactive[1].kinetics_block.k_WGS
# | reactive[1].kinetics_block.Ke_WGS
# | reactive[1].kinetics_block.r_WGS
# | reactive[1].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].energy_block.dH_F
# | reactive[1].energy_block.dH_V
# | reactive[1].energy_block.dH_L
# | reactive[1].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].VLE_block.n_ave
# | reactive[1].VLE_block.n_ave_cal
# | reactive[1].VLE_block.Hen
# | reactive[1].VLE_block.Hen0
# | reactive[1].VLE_block.gamma
# | reactive[1].VLE_block.P_sat
# | reactive[1].VLE_block.P_sat_Y
# | reactive[1].VLE_block.P_sat_dY_inf
# | reactive[1].VLE_block.P_sat_dY0
# | reactive[1].VLE_block.Hen_ref
# | reactive[1].VLE_block.Hen0_ref
# | reactive[1].VLE_block.gamma_ref
# | reactive[1].VLE_block.V_L
# | reactive[1].VLE_block.V_L_dY_inf
# | reactive[1].VLE_block.V_L_dY0
# | reactive[1].VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# # Construct a single condenser

# %%
model.condenser = pe.Block(rule=condenser_stage_rule)
# Out:
# | Importing Condenser Stage......
# | Adding the following local variable:
# ------------------------------------
# | condenser.T
# | condenser.T_F
# | condenser.P
# | condenser.Q_main
# | condenser.x_
# | condenser.y_
# | condenser.x
# | condenser.y
# | condenser.z
# | condenser.L
# | condenser.W
# | condenser.V
# | condenser.F
# | condenser.H_L_
# | condenser.H_V_
# | condenser.H_L
# | condenser.H_V
# | condenser.H_F
# | condenser.f_V
# | condenser.f_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.energy_block.dH_F
# | condenser.energy_block.dH_V
# | condenser.energy_block.dH_L
# | condenser.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.VLE_block.n_ave
# | condenser.VLE_block.n_ave_cal
# | condenser.VLE_block.Hen
# | condenser.VLE_block.Hen0
# | condenser.VLE_block.gamma
# | condenser.VLE_block.P_sat
# | condenser.VLE_block.P_sat_Y
# | condenser.VLE_block.P_sat_dY_inf
# | condenser.VLE_block.P_sat_dY0
# | condenser.VLE_block.Hen_ref
# | condenser.VLE_block.Hen0_ref
# | condenser.VLE_block.gamma_ref
# | condenser.VLE_block.V_L
# | condenser.VLE_block.V_L_dY_inf
# | condenser.VLE_block.V_L_dY0
# | condenser.VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# # Linking Stage Variables

# %% [markdown]
# ### Vapor Between Reactive Stages

# %%
def V_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].V['in'] == model.reactive[j+1].V['out']
model.V_between_con = pe.Constraint(model.TRAY,rule=V_between_rule)

def Vy_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].y_['in',i] == model.reactive[j+1].y[i]
model.Vy_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Vy_between_rule)

def Vh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].H_V_['in'] == model.reactive[j+1].H_V
model.Vh_between_con = pe.Constraint(model.TRAY,rule=Vh_between_rule)

# %% [markdown]
# ### Liquid Between Reactive Stages

# %%
def L_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].L['in'] == model.reactive[j].L['out']
model.L_between_con = pe.Constraint(model.TRAY,rule=L_between_rule)

def Lx_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].x_['in',i] == model.reactive[j].x[i]
model.Ly_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Lx_between_rule)

def Lh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].H_L_['in'] == model.reactive[j].H_L
model.Lh_between_con = pe.Constraint(model.TRAY,rule=Lh_between_rule)

# %% [markdown]
# ### Condenser

# %%
def V_condenser_rule(model):
    return model.reactive[model.TRAY.first()].V['out'] == model.condenser.V['in']
model.V_condenser_con = pe.Constraint(rule=V_condenser_rule)

def Vy_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].y[i] == model.condenser.y_['in',i]
model.Vy_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_condenser_rule)

def Vh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_V == model.condenser.H_V_['in']
model.Vh_condenser_con = pe.Constraint(rule=Vh_condenser_rule)

# %%
def L_condenser_rule(model):
    return model.reactive[model.TRAY.first()].L['in'] == model.condenser.L['out']
model.L_condenser_con = pe.Constraint(rule=L_condenser_rule)

def Lx_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].x_['in',i] == model.condenser.x[i]
model.Lx_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_condenser_rule)

def Lh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_L_['in'] == model.condenser.H_L
model.Lh_condenser_con = pe.Constraint(rule=Lh_condenser_rule)

# %% [markdown]
# # Fixing Redundent Stream Variables

# %%
# condenser
model.condenser.VLE_block.n_ave.fix(4)

model.condenser.F.fix(0)
model.condenser.T_F.fix(300+273.15)
model.condenser.z.fix(0)

model.condenser.V['P'].fix(0)
model.condenser.L['in'].fix(0)
for i in m.COMP_TOTAL: model.condenser.x_['in',i].fix(0)
model.condenser.H_L_['in'].fix(0)

# %%
# 'reboiler' fixing last stage V_in

model.reactive[model.TRAY.last()].V['in'].fix(0)
for i in m.COMP_TOTAL: model.reactive[model.TRAY.last()].y_['in',i].fix(0)
model.reactive[model.TRAY.last()].H_V_['in'].fix(0)

# %% [markdown]
# # Load Operating Parameters

# %%
# condenser
model.condenser.P.fix(19)
# model.condenser.T.fix(30+273.15)
model.condenser.T.fix(30+273.15)
model.condenser.L['out'].fix(0)

# reactive stage
for j in model.reactive:
    model.reactive[j].cat.fix(5000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2)-0.002/2)
    model.reactive[j].z['H2'].fix(2/(1+2)-0.002/2)
    model.reactive[j].z['C30H62'].fix(0.002)
    model.reactive[j].V['P'].fix(0)
    model.reactive[j].L['P'].fix(0)
    # model.reactive[j].Q_main.fix(0)
    # model.reactive[j].T.setlb(300+273.15)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 2300
# Active Inequality Constraints:	 0
# Active Variables:		 2483
# Fixed Variables:		 182
# DOF:				 1

# %%
model.obj = pe.Objective(expr = model.reactive[1].T ,sense=pe.maximize)

# %%
opt = pe.SolverFactory('ipopt')
opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'
# opt.options['nlp_scaling_method'] = None
# opt.options['constr_viol_tol'] = 1e-7
# opt.options['acceptable_constr_viol_tol'] = 1e-7
opt.options['max_iter'] = 7000
# opt.options['dual_inf_tol'] = '+inf'
# opt.options['acceptable_dual_inf_tol'] = '+inf'

# %%
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %%
results = opt.solve(model,tee=True)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                            linear_solver = ma86                  yes
#                                 max_iter = 7000                  yes
#                       print_user_options = yes                   yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:     7301
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     8403
#
# Total number of variables............................:     2301
#                      variables with only lower bounds:      387
#                 variables with lower and upper bounds:     1655
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2300
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.7415000e+02 7.97e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -4.7415342e+02 7.97e+03 1.61e+11  -1.0 6.25e+03    -  3.08e-05 7.01e-05h  1
#    2 -4.7415442e+02 7.97e+03 5.90e+11  -1.0 1.56e+04    -  4.51e-07 2.00e-05f  1
#    3 -4.7415452e+02 7.97e+03 5.90e+11  -1.0 6.67e+03   8.0 1.89e-06 1.89e-06s 12
#    4 -4.7415462e+02 7.97e+03 5.89e+11  -1.0 6.22e+03   8.4 2.18e-06 2.18e-06s 12
#    5 -4.7415465e+02 7.97e+03 5.89e+11  -1.0 8.38e+03   8.9 7.68e-07 7.68e-07s 12
  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400r-5.7313527e+02 1.34e-05 1.00e+03  -5.0 0.00e+00   7.3 0.00e+00 3.18e-07R  7
#  401r-5.7313521e+02 7.17e-06 9.99e+02  -5.0 1.18e+01    -  1.32e-03 9.90e-04f  1
#  402 -5.7314785e+02 7.84e-05 8.63e+03  -5.7 2.61e+00    -  9.99e-01 1.00e+00f  1
#  403 -5.7315001e+02 1.36e-05 2.36e+04  -5.7 5.20e-01    -  1.00e+00 8.56e-01h  1
#  404 -5.7315000e+02 3.06e-10 1.90e-01  -5.7 3.66e-04    -  1.00e+00 1.00e+00h  1
#  405 -5.7315000e+02 1.53e-10 3.16e-08  -5.7 6.73e-08    -  1.00e+00 1.00e+00h  1
#  406 -5.7315001e+02 2.44e-11 2.64e-03  -8.6 3.80e-04    -  1.00e+00 1.00e+00h  1
#  407 -5.7315001e+02 1.53e-10 6.26e-14  -8.6 6.48e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 407
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -5.7315000572899407e+02   -5.7315000572899407e+02
# Dual infeasibility......:   6.2616578588858829e-14    6.2616578588858829e-14
# Constraint violation....:   1.5274205489822223e-10    1.5274205489822223e-10
# Complementarity.........:   2.5059035597338844e-09    2.5059035597338844e-09
# Overall NLP error.......:   2.5059035597338844e-09    2.5059035597338844e-09
#
#
# Number of objective function evaluations             = 724
# Number of objective gradient evaluations             = 278
# Number of equality constraint evaluations            = 724
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 430
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 407
# Total CPU secs in IPOPT (w/o function evaluations)   =     52.718
# Total CPU secs in NLP function evaluations           =      1.784
#
# EXIT: Optimal Solution Found.

# %%
update_dual(pe,model)

# %%
beautify2(pe,model)
# Out:
# Here comes the result:
# ----------------------------------------------------------------------------------------------------
# 		T		 Q			 V			 L
#                30.00 	       -17.6521277784 	         0.1898639734 	         0.0000000000
#               300.00 	       -46.6371828120 	         0.4598211652 	         0.0011329672
# ----------------------------------------------------------------------------------------------------
# Top
# V	 0.18986397340734695
# L	 0.012365437982382972
# W	 0.2575917538485565
# ----------------------------------------------------------------------------------------------------
# Bottom
# L	 0.0011329672358523358
# ----------------------------------------------------------------------------------------------------
# Condenser:	Vapor		Liquid		Last Stage	Vapor		Liquid
# H2 		3.412%		0.045%		 H2       	1.410%		0.068%
# CO 		0.058%		0.002%		 CO       	0.024%		0.001%
# CO2 		19.268%		3.744%		 CO2      	8.057%		0.802%
# H2O 		0.223%		0.000%		 H2O      	56.112%		8.549%
# C2H4 		13.133%		4.102%		 C2H4     	5.533%		0.671%
# C3H6 		6.947%		11.617%		 C3H6     	3.181%		0.691%
# C4H8 		2.531%		13.685%		 C4H8     	1.413%		0.279%
# C5H10 		0.600%		11.114%		 C5H10    	0.547%		0.201%
# C6H12 		0.125%		7.581%		 C6H12    	0.255%		0.156%
# C7H14 		0.021%		4.110%		 C7H14    	0.119%		0.114%
# C8H16 		0.003%		2.020%		 C8H16    	0.056%		0.079%
# C9H18 		0.001%		0.959%		 C9H18    	0.026%		0.053%
# C10H20 		0.000%		0.450%		 C10H20   	0.012%		0.035%
# C11H22 		0.000%		0.134%		 C11H22   	0.004%		0.014%
# C12H24 		0.000%		0.062%		 C12H24   	0.002%		0.009%
# C13H26 		0.000%		0.029%		 C13H26   	0.001%		0.005%
# C14H28 		0.000%		0.014%		 C14H28   	0.000%		0.003%
# C15H30 		0.000%		0.006%		 C15H30   	0.000%		0.002%
# C16H32 		0.000%		0.003%		 C16H32   	0.000%		0.001%
# C17H34 		0.000%		0.001%		 C17H34   	0.000%		0.001%
# C1H4 		43.841%		3.700%		 C1H4     	18.202%		1.590%
# C2H6 		6.960%		3.747%		 C2H6     	2.975%		0.384%
# C3H8 		1.730%		3.014%		 C3H8     	0.795%		0.162%
# C4H10 		0.755%		4.976%		 C4H10    	0.446%		0.099%
# C5H12 		0.317%		7.091%		 C5H12    	0.322%		0.129%
# C6H14 		0.063%		4.615%		 C6H14    	0.150%		0.100%
# C7H16 		0.011%		2.447%		 C7H16    	0.070%		0.072%
# C8H18 		0.002%		1.193%		 C8H18    	0.033%		0.050%
# C9H20 		0.000%		0.565%		 C9H20    	0.015%		0.033%
# C10H22 		0.000%		0.265%		 C10H22   	0.007%		0.022%
# C11H24 		0.000%		0.200%		 C11H24   	0.005%		0.022%
# C12H26 		0.000%		0.093%		 C12H26   	0.003%		0.014%
# C13H28 		0.000%		0.043%		 C13H28   	0.001%		0.009%
# C14H30 		0.000%		0.020%		 C14H30   	0.001%		0.005%
# C15H32 		0.000%		0.009%		 C15H32   	0.000%		0.003%
# C16H34 		0.000%		0.004%		 C16H34   	0.000%		0.002%
# C17H36 		0.000%		0.002%		 C17H36   	0.000%		0.001%
# C30H62 		0.000%		8.334%		 C30H62   	0.224%		85.565%

# %%
model.reactive[1].kinetics_block.r_FT_total.value
# Out:
# 0.2951681295456062

# %%
# model.solutions.store_to(results)
# with open('../saved_solutions/1_stage_condenser_adiabatic.pickle','wb') as f:
#     pickle.dump(results,f)

# %% [markdown]
# ### Check non-active constraints (dual = 0)

# %%
for i in model.dual:
    if abs(model.dual[i]) == 0:
        print('{:40s}'.format(str(i)),'\t\t',model.dual[i])
# Out:
# reactive[1].heat_balance_main_con        		 0.0
# Lh_condenser_con                         		 0.0
# reactive[1].energy_block.dH_F_con[C30H62] 		 0.0
# reactive[1].energy_block.dH_F_con[CO]    		 0.0
# reactive[1].energy_block.dH_F_con[H2]    		 0.0
# reactive[1].energy_block.H_F_con         		 0.0
# condenser.energy_block.dH_F_con[C30H62]  		 0.0
# condenser.energy_block.dH_F_con[CO]      		 0.0
# condenser.energy_block.dH_F_con[H2]      		 0.0
# condenser.energy_block.H_F_con           		 0.0

# %% [markdown]
# # Iterative Data Analysis

# %%
opt.options['linear_solver'] = 'ma86'
opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6

# %%
results_anchor = results
update_dual(pe,model)
model.solutions.store_to(results_anchor)

# %%
Refluxrange = np.linspace(0,2,21)
Trange = np.linspace(300+273.15,200+273.15,11)

# %%
rf_data_master = {}

for t in Trange:
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = model.reactive[1].T,sense=pe.maximize)
    model.solutions.load_from(results_anchor)
    update_dual(pe,model)
    model.reactive[1].T.fixed = False
    model.reactive[1].T.setub(t)
    model.condenser.L['out'].fix(0)
    results_anchor = opt.solve(model,tee=False)
    model.solutions.store_to(results_anchor)
    model.del_component(model.obj)
    model.obj = pe.Objective(expr = model.condenser.L['out'],sense=pe.maximize)
    print('\nWorking on T = {} K'.format(model.reactive[1].T.value))
    print('-'*108)

    rf_data = {}
    rf_data['r'] = {}; rf_data['T'] = []; rf_data['Q'] = []; rf_data['V'] = []; rf_data['L'] = []; rf_data['Re'] = []; rf_data['D'] = []
    rf_data['y_CO'] = []; rf_data['y_H2'] = []; rf_data['y_CO2'] = []; rf_data['y_H2O'] = []; rf_data['r_WGS'] = []; rf_data['r_FT'] = []
    rf_data['g'] = {}; rf_data['d'] = {}; rf_data['b'] = {};
    
    for i in model.reactive[1].r_total_comp:
        rf_data['r'][i] = []
        rf_data['g'][i] = []
        rf_data['d'][i] = []
        rf_data['b'][i] = []       

    for re in Refluxrange:
        model.condenser.L['out'].fixed = False
        model.condenser.L['out'].setub(re)
        model.reactive[1].T.fix(t)
        results = opt.solve(model,tee=False)
        update_dual(pe,model)
        print('Solved\t|Reflux = {:.3f} kmol/s\t|Vapor = {:.3f} kmol/s\t|Distillate = {:.3f} kmol/s\t|Bottom = {:.3f} kmol/s'.\
              format(model.condenser.L['out'].value,model.condenser.V['out'].value,model.condenser.L['P'].value,model.reactive[1].L['out'].value))
        rf_data['T'].append(model.reactive[1].T.value)
        rf_data['Q'].append(model.reactive[1].Q_main.value)
        rf_data['V'].append(model.condenser.V['out'].value)
        rf_data['Re'].append(model.condenser.L['out'].value)
        rf_data['D'].append(model.reactive[1].L['P'].value)

        for i in model.reactive[1].r_total_comp:
            rf_data['r'][i].append(model.reactive[1].r_total_comp[i].value)
            rf_data['g'][i].append(model.condenser.y[i].value*model.condenser.V['out'].value)
            rf_data['d'][i].append(model.condenser.x[i].value*model.condenser.L['P'].value)
            rf_data['b'][i].append(model.reactive[1].x[i].value*model.reactive[1].L['out'].value)

        rf_data['y_H2O'].append(model.reactive[1].y['H2O'].value)
        rf_data['y_CO'].append(model.reactive[1].y['CO'].value)
        rf_data['y_H2'].append(model.reactive[1].y['H2'].value)
        rf_data['y_CO2'].append(model.reactive[1].y['CO2'].value)
        rf_data['r_WGS'].append(model.reactive[1].kinetics_block.r_WGS.value)
        rf_data['r_FT'].append(model.reactive[1].kinetics_block.r_FT_total.value)

    rf_data_master[t] = rf_data
# Out:
# Working on T = 573.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.190 kmol/s	|Distillate = 0.012 kmol/s	|Bottom = 0.001 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.192 kmol/s	|Distillate = 0.010 kmol/s	|Bottom = 0.002 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.194 kmol/s	|Distillate = 0.009 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.195 kmol/s	|Distillate = 0.009 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.196 kmol/s	|Distillate = 0.009 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.197 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.198 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.198 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.199 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.200 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.200 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.201 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.202 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.202 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.203 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.203 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.204 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.204 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.205 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.205 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.205 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.003 kmol/s
#
# Working on T = 563.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.170 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.002 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.173 kmol/s	|Distillate = 0.016 kmol/s	|Bottom = 0.002 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.175 kmol/s	|Distillate = 0.016 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.176 kmol/s	|Distillate = 0.015 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.178 kmol/s	|Distillate = 0.015 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.179 kmol/s	|Distillate = 0.015 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.180 kmol/s	|Distillate = 0.014 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.181 kmol/s	|Distillate = 0.014 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.182 kmol/s	|Distillate = 0.014 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.183 kmol/s	|Distillate = 0.014 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.185 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.186 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.187 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.188 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.188 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.189 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.190 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.190 kmol/s	|Distillate = 0.012 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.191 kmol/s	|Distillate = 0.012 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.191 kmol/s	|Distillate = 0.012 kmol/s	|Bottom = 0.004 kmol/s
#
# Working on T = 553.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.151 kmol/s	|Distillate = 0.025 kmol/s	|Bottom = 0.002 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.154 kmol/s	|Distillate = 0.023 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.157 kmol/s	|Distillate = 0.023 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.159 kmol/s	|Distillate = 0.022 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.161 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.163 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.164 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.166 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.167 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.169 kmol/s	|Distillate = 0.019 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.170 kmol/s	|Distillate = 0.019 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.171 kmol/s	|Distillate = 0.019 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.172 kmol/s	|Distillate = 0.019 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.173 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.175 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.176 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.177 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.178 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.179 kmol/s	|Distillate = 0.017 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.180 kmol/s	|Distillate = 0.017 kmol/s	|Bottom = 0.004 kmol/s
#
# Working on T = 543.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.135 kmol/s	|Distillate = 0.031 kmol/s	|Bottom = 0.002 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.139 kmol/s	|Distillate = 0.029 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.142 kmol/s	|Distillate = 0.028 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.145 kmol/s	|Distillate = 0.027 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.148 kmol/s	|Distillate = 0.026 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.150 kmol/s	|Distillate = 0.025 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.153 kmol/s	|Distillate = 0.025 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.155 kmol/s	|Distillate = 0.024 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.157 kmol/s	|Distillate = 0.024 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.159 kmol/s	|Distillate = 0.023 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.160 kmol/s	|Distillate = 0.023 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.162 kmol/s	|Distillate = 0.022 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.164 kmol/s	|Distillate = 0.022 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.165 kmol/s	|Distillate = 0.022 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.167 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.168 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.169 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.171 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.172 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.173 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.006 kmol/s
#
# Working on T = 533.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.124 kmol/s	|Distillate = 0.034 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.130 kmol/s	|Distillate = 0.032 kmol/s	|Bottom = 0.004 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.134 kmol/s	|Distillate = 0.030 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.138 kmol/s	|Distillate = 0.028 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.142 kmol/s	|Distillate = 0.027 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.145 kmol/s	|Distillate = 0.026 kmol/s	|Bottom = 0.007 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.149 kmol/s	|Distillate = 0.025 kmol/s	|Bottom = 0.007 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.151 kmol/s	|Distillate = 0.024 kmol/s	|Bottom = 0.008 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.154 kmol/s	|Distillate = 0.023 kmol/s	|Bottom = 0.008 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.157 kmol/s	|Distillate = 0.022 kmol/s	|Bottom = 0.008 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.159 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.009 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.161 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.009 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.164 kmol/s	|Distillate = 0.020 kmol/s	|Bottom = 0.009 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.166 kmol/s	|Distillate = 0.019 kmol/s	|Bottom = 0.010 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.168 kmol/s	|Distillate = 0.019 kmol/s	|Bottom = 0.010 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.170 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.010 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.171 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.010 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.173 kmol/s	|Distillate = 0.018 kmol/s	|Bottom = 0.010 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.175 kmol/s	|Distillate = 0.017 kmol/s	|Bottom = 0.010 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.176 kmol/s	|Distillate = 0.017 kmol/s	|Bottom = 0.011 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.178 kmol/s	|Distillate = 0.016 kmol/s	|Bottom = 0.011 kmol/s
#
# Working on T = 523.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.122 kmol/s	|Distillate = 0.034 kmol/s	|Bottom = 0.003 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.129 kmol/s	|Distillate = 0.030 kmol/s	|Bottom = 0.006 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.135 kmol/s	|Distillate = 0.026 kmol/s	|Bottom = 0.008 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.141 kmol/s	|Distillate = 0.023 kmol/s	|Bottom = 0.010 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.146 kmol/s	|Distillate = 0.021 kmol/s	|Bottom = 0.011 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.150 kmol/s	|Distillate = 0.019 kmol/s	|Bottom = 0.012 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.154 kmol/s	|Distillate = 0.017 kmol/s	|Bottom = 0.013 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.158 kmol/s	|Distillate = 0.016 kmol/s	|Bottom = 0.014 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.162 kmol/s	|Distillate = 0.015 kmol/s	|Bottom = 0.015 kmol/s
# Solved	|Reflux = 0.900 kmol/s	|Vapor = 0.165 kmol/s	|Distillate = 0.014 kmol/s	|Bottom = 0.015 kmol/s
# Solved	|Reflux = 1.000 kmol/s	|Vapor = 0.169 kmol/s	|Distillate = 0.012 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 1.100 kmol/s	|Vapor = 0.172 kmol/s	|Distillate = 0.012 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 1.200 kmol/s	|Vapor = 0.175 kmol/s	|Distillate = 0.011 kmol/s	|Bottom = 0.017 kmol/s
# Solved	|Reflux = 1.300 kmol/s	|Vapor = 0.177 kmol/s	|Distillate = 0.010 kmol/s	|Bottom = 0.017 kmol/s
# Solved	|Reflux = 1.400 kmol/s	|Vapor = 0.180 kmol/s	|Distillate = 0.009 kmol/s	|Bottom = 0.018 kmol/s
# Solved	|Reflux = 1.500 kmol/s	|Vapor = 0.183 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.018 kmol/s
# Solved	|Reflux = 1.600 kmol/s	|Vapor = 0.185 kmol/s	|Distillate = 0.008 kmol/s	|Bottom = 0.018 kmol/s
# Solved	|Reflux = 1.700 kmol/s	|Vapor = 0.187 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.019 kmol/s
# Solved	|Reflux = 1.800 kmol/s	|Vapor = 0.190 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.019 kmol/s
# Solved	|Reflux = 1.900 kmol/s	|Vapor = 0.192 kmol/s	|Distillate = 0.006 kmol/s	|Bottom = 0.019 kmol/s
# Solved	|Reflux = 2.000 kmol/s	|Vapor = 0.194 kmol/s	|Distillate = 0.006 kmol/s	|Bottom = 0.019 kmol/s
#
# Working on T = 513.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.129 kmol/s	|Distillate = 0.030 kmol/s	|Bottom = 0.005 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.138 kmol/s	|Distillate = 0.022 kmol/s	|Bottom = 0.011 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.146 kmol/s	|Distillate = 0.017 kmol/s	|Bottom = 0.015 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.153 kmol/s	|Distillate = 0.013 kmol/s	|Bottom = 0.018 kmol/s
# Solved	|Reflux = 0.400 kmol/s	|Vapor = 0.159 kmol/s	|Distillate = 0.009 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.500 kmol/s	|Vapor = 0.165 kmol/s	|Distillate = 0.007 kmol/s	|Bottom = 0.021 kmol/s
# Solved	|Reflux = 0.600 kmol/s	|Vapor = 0.170 kmol/s	|Distillate = 0.005 kmol/s	|Bottom = 0.022 kmol/s
# Solved	|Reflux = 0.700 kmol/s	|Vapor = 0.175 kmol/s	|Distillate = 0.003 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.800 kmol/s	|Vapor = 0.180 kmol/s	|Distillate = 0.001 kmol/s	|Bottom = 0.024 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.882 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
#
# Working on T = 503.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.144 kmol/s	|Distillate = 0.023 kmol/s	|Bottom = 0.008 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.155 kmol/s	|Distillate = 0.011 kmol/s	|Bottom = 0.017 kmol/s
# Solved	|Reflux = 0.200 kmol/s	|Vapor = 0.165 kmol/s	|Distillate = 0.005 kmol/s	|Bottom = 0.022 kmol/s
# Solved	|Reflux = 0.300 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
# Solved	|Reflux = 0.301 kmol/s	|Vapor = 0.174 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.025 kmol/s
#
# Working on T = 493.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.168 kmol/s	|Distillate = 0.015 kmol/s	|Bottom = 0.011 kmol/s
# Solved	|Reflux = 0.100 kmol/s	|Vapor = 0.181 kmol/s	|Distillate = 0.002 kmol/s	|Bottom = 0.022 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
# Solved	|Reflux = 0.120 kmol/s	|Vapor = 0.184 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.023 kmol/s
#
# Working on T = 483.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.204 kmol/s	|Distillate = 0.009 kmol/s	|Bottom = 0.013 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
# Solved	|Reflux = 0.051 kmol/s	|Vapor = 0.213 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.020 kmol/s
#
# Working on T = 473.15 K
# ------------------------------------------------------------------------------------------------------------
# Solved	|Reflux = 0.000 kmol/s	|Vapor = 0.264 kmol/s	|Distillate = 0.005 kmol/s	|Bottom = 0.012 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s
# Solved	|Reflux = 0.022 kmol/s	|Vapor = 0.268 kmol/s	|Distillate = 0.000 kmol/s	|Bottom = 0.016 kmol/s

# %%
cnumber_range = list(range(1,30)) + list(range(31,57))

# %%
rf_data = rf_data_master[543.15]

# %%
def trans_cnumber(dic):
    molefraction = {}
    for i in range(1,57):
        molefraction[i] = []
    for i in m.COMP_ORG:
        molefraction[cal_cnumber(i)].append(np.array(dic[i]))
    for i in range(1,57):
        molefraction[i] = np.sum(molefraction[i],0)
    molefraction.pop(30)
    length = len(molefraction[1])
    tmp = {}
    for j in range(length):
        tmp[j] = []
        for i in cnumber_range:
            tmp[j].append(molefraction[i][j])
    return tmp

# %%
g_data = {}
d_data = {}
b_data = {}
r_data = {}

for t in Trange:
    g_data[t] = trans_cnumber(rf_data_master[t]['g'])
    d_data[t] = trans_cnumber(rf_data_master[t]['d'])
    b_data[t] = trans_cnumber(rf_data_master[t]['b'])
    r_data[t] = trans_cnumber(rf_data_master[t]['r'])

# %%
 def plot_distribution(temperature,index):
    fig, ax = plt.subplots(figsize=(16,9))
    ax.plot(cnumber_range,g_data[temperature][index],'go-')
    ax.plot(cnumber_range,d_data[temperature][index],'ro-')
    ax.plot(cnumber_range,b_data[temperature][index],'bo-')
    ax.plot(cnumber_range,r_data[temperature][index],'c-',alpha=0.7,linewidth=5)
    ax.set_yscale("log")
    ax.set_ylim(1e-12, 1)
    ax.legend(['Vapor','Distillate','Bottom'],fontsize=18)
    ax.set_title('T, Reflux {:.2f} kmol/s'.format(rf_data['Re'][index]),fontsize=18)

    ax.set_ylabel('Molar Flow (kmol/s)', color='K',fontsize=18)
    ax.set_xlabel('Carbon Number', color='K',fontsize=18)
    # ax.tick_params('y', colors='k',labelsize=18)
    # ax.tick_params('x', colors='k',labelsize=18)
    ax.grid()
    plt.show()

# %%
widgets.interact(plot_distribution, index = widgets.IntSlider(
    value=0,
    min=0,
    max=20,
    step=1,
    description='Reflux:',), temperature=widgets.SelectionSlider(
    options=Trange,
    value=Trange[0],
    description='Temperature',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True
));
# Out:
# interactive(children=(SelectionSlider(continuous_update=False, description='Temperature', options=(573.15, 563…
