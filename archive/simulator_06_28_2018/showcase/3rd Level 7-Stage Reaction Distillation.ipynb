# %% [markdown]
# # 3rd Level Model Structure: Simulator

# %%
import sys
import os
import pickle
sys.path.append(os.path.abspath('..'))

import numpy as np
from matplotlib import pyplot as plt

import ipywidgets as widgets
from IPython.display import display, clear_output

from copy import deepcopy

# %%
from pyomo import environ as pe
from global_sets.component import m

from stages.reactive_stage import reactive_stage_rule
from stages.condenser_stage import condenser_stage_rule
from stages.non_reactive_stage import non_reactive_stage_rule

from utility.display_utility import trans_product_mole, trans_product_mass, beautify
from utility.model_utility import add_dual, update_dual, check_DOF
from utility.data_utility import cal_cnumber

model = pe.ConcreteModel()

# %% [markdown]
# # Global Set

# %%
model.TRAY = pe.RangeSet(1,20)

# %% [markdown]
# # Construct Reactive Stages

# %%
model.reactive = pe.Block(model.TRAY,rule=reactive_stage_rule)
# Out:
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[1].T_F
# | reactive[1].P
# | reactive[1].cat
# | reactive[1].Q_main
# | reactive[1].x_
# | reactive[1].y_
# | reactive[1].x
# | reactive[1].y
# | reactive[1].z
# | reactive[1].L
# | reactive[1].V
# | reactive[1].F
# | reactive[1].H_L_
# | reactive[1].H_V_
# | reactive[1].H_L
# | reactive[1].H_V
# | reactive[1].T
# | reactive[1].H_F
# | reactive[1].f_V
# | reactive[1].f_L
# | reactive[1].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].kinetics_block.k_FT
# | reactive[1].kinetics_block.r_FT_total
# | reactive[1].kinetics_block.g0_FT
# | reactive[1].kinetics_block.alpha
# | reactive[1].kinetics_block.r_FT_cnum
# | reactive[1].kinetics_block.r_FT_comp
# | reactive[1].kinetics_block.k_WGS
# | reactive[1].kinetics_block.Ke_WGS
# | reactive[1].kinetics_block.r_WGS
# | reactive[1].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].energy_block.dH_F
# | reactive[1].energy_block.dH_V
# | reactive[1].energy_block.dH_L
# | reactive[1].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].VLE_block.P_VLE
# | reactive[1].VLE_block.n_ave
# | reactive[1].VLE_block.n_ave_cal
# | reactive[1].VLE_block.Hen
# | reactive[1].VLE_block.Hen0
# | reactive[1].VLE_block.gamma
# | reactive[1].VLE_block.P_sat
# | reactive[1].VLE_block.P_sat_Y
# | reactive[1].VLE_block.P_sat_dY_inf
# | reactive[1].VLE_block.P_sat_dY0
# | reactive[1].VLE_block.Hen_ref
# | reactive[1].VLE_block.Hen0_ref
# | reactive[1].VLE_block.gamma_ref
# | reactive[1].VLE_block.V_L
# | reactive[1].VLE_block.V_L_dY_inf
# | reactive[1].VLE_block.V_L_dY0
# | reactive[1].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[1].MPCC.s_L
# | reactive[1].MPCC.s_V
# | reactive[1].MPCC.pf
# | reactive[1].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[2].T_F
# | reactive[2].P
# | reactive[2].cat
# | reactive[2].Q_main
# | reactive[2].x_
# | reactive[2].y_
# | reactive[2].x
# | reactive[2].y
# | reactive[2].z
# | reactive[2].L
# | reactive[2].V
# | reactive[2].F
# | reactive[2].H_L_
# | reactive[2].H_V_
# | reactive[2].H_L
# | reactive[2].H_V
# | reactive[2].T
# | reactive[2].H_F
# | reactive[2].f_V
# | reactive[2].f_L
# | reactive[2].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].kinetics_block.k_FT
# | reactive[2].kinetics_block.r_FT_total
# | reactive[2].kinetics_block.g0_FT
# | reactive[2].kinetics_block.alpha
# | reactive[2].kinetics_block.r_FT_cnum
# | reactive[2].kinetics_block.r_FT_comp
# | reactive[2].kinetics_block.k_WGS
# | reactive[2].kinetics_block.Ke_WGS
# | reactive[2].kinetics_block.r_WGS
# | reactive[2].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].energy_block.dH_F
# | reactive[2].energy_block.dH_V
# | reactive[2].energy_block.dH_L
# | reactive[2].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].VLE_block.P_VLE
# | reactive[2].VLE_block.n_ave
# | reactive[2].VLE_block.n_ave_cal
# | reactive[2].VLE_block.Hen
# | reactive[2].VLE_block.Hen0
# | reactive[2].VLE_block.gamma
# | reactive[2].VLE_block.P_sat
# | reactive[2].VLE_block.P_sat_Y
# | reactive[2].VLE_block.P_sat_dY_inf
# | reactive[2].VLE_block.P_sat_dY0
# | reactive[2].VLE_block.Hen_ref
# | reactive[2].VLE_block.Hen0_ref
# | reactive[2].VLE_block.gamma_ref
# | reactive[2].VLE_block.V_L
# | reactive[2].VLE_block.V_L_dY_inf
# | reactive[2].VLE_block.V_L_dY0
# | reactive[2].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[2].MPCC.s_L
# | reactive[2].MPCC.s_V
# | reactive[2].MPCC.pf
# | reactive[2].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[3].T_F
# | reactive[3].P
# | reactive[3].cat
# | reactive[3].Q_main
# | reactive[3].x_
# | reactive[3].y_
# | reactive[3].x
# | reactive[3].y
# | reactive[3].z
# | reactive[3].L
# | reactive[3].V
# | reactive[3].F
# | reactive[3].H_L_
# | reactive[3].H_V_
# | reactive[3].H_L
# | reactive[3].H_V
# | reactive[3].T
# | reactive[3].H_F
# | reactive[3].f_V
# | reactive[3].f_L
# | reactive[3].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].kinetics_block.k_FT
# | reactive[3].kinetics_block.r_FT_total
# | reactive[3].kinetics_block.g0_FT
# | reactive[3].kinetics_block.alpha
# | reactive[3].kinetics_block.r_FT_cnum
# | reactive[3].kinetics_block.r_FT_comp
# | reactive[3].kinetics_block.k_WGS
# | reactive[3].kinetics_block.Ke_WGS
# | reactive[3].kinetics_block.r_WGS
# | reactive[3].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].energy_block.dH_F
# | reactive[3].energy_block.dH_V
# | reactive[3].energy_block.dH_L
# | reactive[3].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].VLE_block.P_VLE
# | reactive[3].VLE_block.n_ave
# | reactive[3].VLE_block.n_ave_cal
# | reactive[3].VLE_block.Hen
# | reactive[3].VLE_block.Hen0
# | reactive[3].VLE_block.gamma
# | reactive[3].VLE_block.P_sat
# | reactive[3].VLE_block.P_sat_Y
# | reactive[3].VLE_block.P_sat_dY_inf
# | reactive[3].VLE_block.P_sat_dY0
# | reactive[3].VLE_block.Hen_ref
# | reactive[3].VLE_block.Hen0_ref
# | reactive[3].VLE_block.gamma_ref
# | reactive[3].VLE_block.V_L
# | reactive[3].VLE_block.V_L_dY_inf
# | reactive[3].VLE_block.V_L_dY0
# | reactive[3].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[3].MPCC.s_L
# | reactive[3].MPCC.s_V
# | reactive[3].MPCC.pf
# | reactive[3].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[4].T_F
# | reactive[4].P
# | reactive[4].cat
# | reactive[4].Q_main
# | reactive[4].x_
# | reactive[4].y_
# | reactive[4].x
# | reactive[4].y
# | reactive[4].z
# | reactive[4].L
# | reactive[4].V
# | reactive[4].F
# | reactive[4].H_L_
# | reactive[4].H_V_
# | reactive[4].H_L
# | reactive[4].H_V
# | reactive[4].T
# | reactive[4].H_F
# | reactive[4].f_V
# | reactive[4].f_L
# | reactive[4].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].kinetics_block.k_FT
# | reactive[4].kinetics_block.r_FT_total
# | reactive[4].kinetics_block.g0_FT
# | reactive[4].kinetics_block.alpha
# | reactive[4].kinetics_block.r_FT_cnum
# | reactive[4].kinetics_block.r_FT_comp
# | reactive[4].kinetics_block.k_WGS
# | reactive[4].kinetics_block.Ke_WGS
# | reactive[4].kinetics_block.r_WGS
# | reactive[4].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].energy_block.dH_F
# | reactive[4].energy_block.dH_V
# | reactive[4].energy_block.dH_L
# | reactive[4].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].VLE_block.P_VLE
# | reactive[4].VLE_block.n_ave
# | reactive[4].VLE_block.n_ave_cal
# | reactive[4].VLE_block.Hen
# | reactive[4].VLE_block.Hen0
# | reactive[4].VLE_block.gamma
# | reactive[4].VLE_block.P_sat
# | reactive[4].VLE_block.P_sat_Y
# | reactive[4].VLE_block.P_sat_dY_inf
# | reactive[4].VLE_block.P_sat_dY0
# | reactive[4].VLE_block.Hen_ref
# | reactive[4].VLE_block.Hen0_ref
# | reactive[4].VLE_block.gamma_ref
# | reactive[4].VLE_block.V_L
# | reactive[4].VLE_block.V_L_dY_inf
# | reactive[4].VLE_block.V_L_dY0
# | reactive[4].VLE_block.poynting
# --------------------------------------------------
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[4].MPCC.s_L
# | reactive[4].MPCC.s_V
# | reactive[4].MPCC.pf
# | reactive[4].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[5].T_F
# | reactive[5].P
# | reactive[5].cat
# | reactive[5].Q_main
# | reactive[5].x_
# | reactive[5].y_
# | reactive[5].x
# | reactive[5].y
# | reactive[5].z
# | reactive[5].L
# | reactive[5].V
# | reactive[5].F
# | reactive[5].H_L_
# | reactive[5].H_V_
# | reactive[5].H_L
# | reactive[5].H_V
# | reactive[5].T
# | reactive[5].H_F
# | reactive[5].f_V
# | reactive[5].f_L
# | reactive[5].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].kinetics_block.k_FT
# | reactive[5].kinetics_block.r_FT_total
# | reactive[5].kinetics_block.g0_FT
# | reactive[5].kinetics_block.alpha
# | reactive[5].kinetics_block.r_FT_cnum
# | reactive[5].kinetics_block.r_FT_comp
# | reactive[5].kinetics_block.k_WGS
# | reactive[5].kinetics_block.Ke_WGS
# | reactive[5].kinetics_block.r_WGS
# | reactive[5].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].energy_block.dH_F
# | reactive[5].energy_block.dH_V
# | reactive[5].energy_block.dH_L
# | reactive[5].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].VLE_block.P_VLE
# | reactive[5].VLE_block.n_ave
# | reactive[5].VLE_block.n_ave_cal
# | reactive[5].VLE_block.Hen
# | reactive[5].VLE_block.Hen0
# | reactive[5].VLE_block.gamma
# | reactive[5].VLE_block.P_sat
# | reactive[5].VLE_block.P_sat_Y
# | reactive[5].VLE_block.P_sat_dY_inf
# | reactive[5].VLE_block.P_sat_dY0
# | reactive[5].VLE_block.Hen_ref
# | reactive[5].VLE_block.Hen0_ref
# | reactive[5].VLE_block.gamma_ref
# | reactive[5].VLE_block.V_L
# | reactive[5].VLE_block.V_L_dY_inf
# | reactive[5].VLE_block.V_L_dY0
# | reactive[5].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[5].MPCC.s_L
# | reactive[5].MPCC.s_V
# | reactive[5].MPCC.pf
# | reactive[5].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[6].T_F
# | reactive[6].P
# | reactive[6].cat
# | reactive[6].Q_main
# | reactive[6].x_
# | reactive[6].y_
# | reactive[6].x
# | reactive[6].y
# | reactive[6].z
# | reactive[6].L
# | reactive[6].V
# | reactive[6].F
# | reactive[6].H_L_
# | reactive[6].H_V_
# | reactive[6].H_L
# | reactive[6].H_V
# | reactive[6].T
# | reactive[6].H_F
# | reactive[6].f_V
# | reactive[6].f_L
# | reactive[6].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].kinetics_block.k_FT
# | reactive[6].kinetics_block.r_FT_total
# | reactive[6].kinetics_block.g0_FT
# | reactive[6].kinetics_block.alpha
# | reactive[6].kinetics_block.r_FT_cnum
# | reactive[6].kinetics_block.r_FT_comp
# | reactive[6].kinetics_block.k_WGS
# | reactive[6].kinetics_block.Ke_WGS
# | reactive[6].kinetics_block.r_WGS
# | reactive[6].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].energy_block.dH_F
# | reactive[6].energy_block.dH_V
# | reactive[6].energy_block.dH_L
# | reactive[6].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].VLE_block.P_VLE
# | reactive[6].VLE_block.n_ave
# | reactive[6].VLE_block.n_ave_cal
# | reactive[6].VLE_block.Hen
# | reactive[6].VLE_block.Hen0
# | reactive[6].VLE_block.gamma
# | reactive[6].VLE_block.P_sat
# | reactive[6].VLE_block.P_sat_Y
# | reactive[6].VLE_block.P_sat_dY_inf
# | reactive[6].VLE_block.P_sat_dY0
# | reactive[6].VLE_block.Hen_ref
# | reactive[6].VLE_block.Hen0_ref
# | reactive[6].VLE_block.gamma_ref
# | reactive[6].VLE_block.V_L
# | reactive[6].VLE_block.V_L_dY_inf
# | reactive[6].VLE_block.V_L_dY0
# | reactive[6].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[6].MPCC.s_L
# | reactive[6].MPCC.s_V
# | reactive[6].MPCC.pf
# | reactive[6].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[7].T_F
# | reactive[7].P
# | reactive[7].cat
# | reactive[7].Q_main
# | reactive[7].x_
# | reactive[7].y_
# | reactive[7].x
# | reactive[7].y
# | reactive[7].z
# | reactive[7].L
# | reactive[7].V
# | reactive[7].F
# | reactive[7].H_L_
# | reactive[7].H_V_
# | reactive[7].H_L
# | reactive[7].H_V
# | reactive[7].T
# | reactive[7].H_F
# | reactive[7].f_V
# | reactive[7].f_L
# | reactive[7].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].kinetics_block.k_FT
# | reactive[7].kinetics_block.r_FT_total
# | reactive[7].kinetics_block.g0_FT
# | reactive[7].kinetics_block.alpha
# | reactive[7].kinetics_block.r_FT_cnum
# | reactive[7].kinetics_block.r_FT_comp
# | reactive[7].kinetics_block.k_WGS
# | reactive[7].kinetics_block.Ke_WGS
# | reactive[7].kinetics_block.r_WGS
# | reactive[7].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].energy_block.dH_F
# | reactive[7].energy_block.dH_V
# | reactive[7].energy_block.dH_L
# | reactive[7].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].VLE_block.P_VLE
# | reactive[7].VLE_block.n_ave
# | reactive[7].VLE_block.n_ave_cal
# | reactive[7].VLE_block.Hen
# | reactive[7].VLE_block.Hen0
# | reactive[7].VLE_block.gamma
# | reactive[7].VLE_block.P_sat
# | reactive[7].VLE_block.P_sat_Y
# | reactive[7].VLE_block.P_sat_dY_inf
# | reactive[7].VLE_block.P_sat_dY0
# | reactive[7].VLE_block.Hen_ref
# | reactive[7].VLE_block.Hen0_ref
# | reactive[7].VLE_block.gamma_ref
# | reactive[7].VLE_block.V_L
# | reactive[7].VLE_block.V_L_dY_inf
# | reactive[7].VLE_block.V_L_dY0
# | reactive[7].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[7].MPCC.s_L
# | reactive[7].MPCC.s_V
# | reactive[7].MPCC.pf
# | reactive[7].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[8].T_F
# | reactive[8].P
# | reactive[8].cat
# | reactive[8].Q_main
# | reactive[8].x_
# | reactive[8].y_
# | reactive[8].x
# | reactive[8].y
# | reactive[8].z
# | reactive[8].L
# | reactive[8].V
# | reactive[8].F
# | reactive[8].H_L_
# | reactive[8].H_V_
# | reactive[8].H_L
# | reactive[8].H_V
# | reactive[8].T
# | reactive[8].H_F
# | reactive[8].f_V
# | reactive[8].f_L
# | reactive[8].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].kinetics_block.k_FT
# | reactive[8].kinetics_block.r_FT_total
# | reactive[8].kinetics_block.g0_FT
# | reactive[8].kinetics_block.alpha
# | reactive[8].kinetics_block.r_FT_cnum
# | reactive[8].kinetics_block.r_FT_comp
# | reactive[8].kinetics_block.k_WGS
# | reactive[8].kinetics_block.Ke_WGS
# | reactive[8].kinetics_block.r_WGS
# | reactive[8].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].energy_block.dH_F
# | reactive[8].energy_block.dH_V
# | reactive[8].energy_block.dH_L
# | reactive[8].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].VLE_block.P_VLE
# | reactive[8].VLE_block.n_ave
# | reactive[8].VLE_block.n_ave_cal
# | reactive[8].VLE_block.Hen
# | reactive[8].VLE_block.Hen0
# | reactive[8].VLE_block.gamma
# | reactive[8].VLE_block.P_sat
# | reactive[8].VLE_block.P_sat_Y
# | reactive[8].VLE_block.P_sat_dY_inf
# | reactive[8].VLE_block.P_sat_dY0
# | reactive[8].VLE_block.Hen_ref
# | reactive[8].VLE_block.Hen0_ref
# | reactive[8].VLE_block.gamma_ref
# | reactive[8].VLE_block.V_L
# | reactive[8].VLE_block.V_L_dY_inf
# | reactive[8].VLE_block.V_L_dY0
# | reactive[8].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[8].MPCC.s_L
# | reactive[8].MPCC.s_V
# | reactive[8].MPCC.pf
# | reactive[8].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[9].T_F
# | reactive[9].P
# | reactive[9].cat
# | reactive[9].Q_main
# | reactive[9].x_
# | reactive[9].y_
# | reactive[9].x
# | reactive[9].y
# | reactive[9].z
# | reactive[9].L
# | reactive[9].V
# | reactive[9].F
# | reactive[9].H_L_
# | reactive[9].H_V_
# | reactive[9].H_L
# | reactive[9].H_V
# | reactive[9].T
# | reactive[9].H_F
# | reactive[9].f_V
# | reactive[9].f_L
# | reactive[9].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].kinetics_block.k_FT
# | reactive[9].kinetics_block.r_FT_total
# | reactive[9].kinetics_block.g0_FT
# | reactive[9].kinetics_block.alpha
# | reactive[9].kinetics_block.r_FT_cnum
# | reactive[9].kinetics_block.r_FT_comp
# | reactive[9].kinetics_block.k_WGS
# | reactive[9].kinetics_block.Ke_WGS
# | reactive[9].kinetics_block.r_WGS
# | reactive[9].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].energy_block.dH_F
# | reactive[9].energy_block.dH_V
# | reactive[9].energy_block.dH_L
# | reactive[9].energy_block.dH_vap
# --------------------------------------------------
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].VLE_block.P_VLE
# | reactive[9].VLE_block.n_ave
# | reactive[9].VLE_block.n_ave_cal
# | reactive[9].VLE_block.Hen
# | reactive[9].VLE_block.Hen0
# | reactive[9].VLE_block.gamma
# | reactive[9].VLE_block.P_sat
# | reactive[9].VLE_block.P_sat_Y
# | reactive[9].VLE_block.P_sat_dY_inf
# | reactive[9].VLE_block.P_sat_dY0
# | reactive[9].VLE_block.Hen_ref
# | reactive[9].VLE_block.Hen0_ref
# | reactive[9].VLE_block.gamma_ref
# | reactive[9].VLE_block.V_L
# | reactive[9].VLE_block.V_L_dY_inf
# | reactive[9].VLE_block.V_L_dY0
# | reactive[9].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[9].MPCC.s_L
# | reactive[9].MPCC.s_V
# | reactive[9].MPCC.pf
# | reactive[9].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[10].T_F
# | reactive[10].P
# | reactive[10].cat
# | reactive[10].Q_main
# | reactive[10].x_
# | reactive[10].y_
# | reactive[10].x
# | reactive[10].y
# | reactive[10].z
# | reactive[10].L
# | reactive[10].V
# | reactive[10].F
# | reactive[10].H_L_
# | reactive[10].H_V_
# | reactive[10].H_L
# | reactive[10].H_V
# | reactive[10].T
# | reactive[10].H_F
# | reactive[10].f_V
# | reactive[10].f_L
# | reactive[10].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].kinetics_block.k_FT
# | reactive[10].kinetics_block.r_FT_total
# | reactive[10].kinetics_block.g0_FT
# | reactive[10].kinetics_block.alpha
# | reactive[10].kinetics_block.r_FT_cnum
# | reactive[10].kinetics_block.r_FT_comp
# | reactive[10].kinetics_block.k_WGS
# | reactive[10].kinetics_block.Ke_WGS
# | reactive[10].kinetics_block.r_WGS
# | reactive[10].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].energy_block.dH_F
# | reactive[10].energy_block.dH_V
# | reactive[10].energy_block.dH_L
# | reactive[10].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].VLE_block.P_VLE
# | reactive[10].VLE_block.n_ave
# | reactive[10].VLE_block.n_ave_cal
# | reactive[10].VLE_block.Hen
# | reactive[10].VLE_block.Hen0
# | reactive[10].VLE_block.gamma
# | reactive[10].VLE_block.P_sat
# | reactive[10].VLE_block.P_sat_Y
# | reactive[10].VLE_block.P_sat_dY_inf
# | reactive[10].VLE_block.P_sat_dY0
# | reactive[10].VLE_block.Hen_ref
# | reactive[10].VLE_block.Hen0_ref
# | reactive[10].VLE_block.gamma_ref
# | reactive[10].VLE_block.V_L
# | reactive[10].VLE_block.V_L_dY_inf
# | reactive[10].VLE_block.V_L_dY0
# | reactive[10].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[10].MPCC.s_L
# | reactive[10].MPCC.s_V
# | reactive[10].MPCC.pf
# | reactive[10].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[11].T_F
# | reactive[11].P
# | reactive[11].cat
# | reactive[11].Q_main
# | reactive[11].x_
# | reactive[11].y_
# | reactive[11].x
# | reactive[11].y
# | reactive[11].z
# | reactive[11].L
# | reactive[11].V
# | reactive[11].F
# | reactive[11].H_L_
# | reactive[11].H_V_
# | reactive[11].H_L
# | reactive[11].H_V
# | reactive[11].T
# | reactive[11].H_F
# | reactive[11].f_V
# | reactive[11].f_L
# | reactive[11].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].kinetics_block.k_FT
# | reactive[11].kinetics_block.r_FT_total
# | reactive[11].kinetics_block.g0_FT
# | reactive[11].kinetics_block.alpha
# | reactive[11].kinetics_block.r_FT_cnum
# | reactive[11].kinetics_block.r_FT_comp
# | reactive[11].kinetics_block.k_WGS
# | reactive[11].kinetics_block.Ke_WGS
# | reactive[11].kinetics_block.r_WGS
# | reactive[11].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].energy_block.dH_F
# | reactive[11].energy_block.dH_V
# | reactive[11].energy_block.dH_L
# | reactive[11].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].VLE_block.P_VLE
# | reactive[11].VLE_block.n_ave
# | reactive[11].VLE_block.n_ave_cal
# | reactive[11].VLE_block.Hen
# | reactive[11].VLE_block.Hen0
# | reactive[11].VLE_block.gamma
# | reactive[11].VLE_block.P_sat
# | reactive[11].VLE_block.P_sat_Y
# | reactive[11].VLE_block.P_sat_dY_inf
# | reactive[11].VLE_block.P_sat_dY0
# | reactive[11].VLE_block.Hen_ref
# | reactive[11].VLE_block.Hen0_ref
# | reactive[11].VLE_block.gamma_ref
# | reactive[11].VLE_block.V_L
# | reactive[11].VLE_block.V_L_dY_inf
# | reactive[11].VLE_block.V_L_dY0
# | reactive[11].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[11].MPCC.s_L
# | reactive[11].MPCC.s_V
# | reactive[11].MPCC.pf
# | reactive[11].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[12].T_F
# | reactive[12].P
# | reactive[12].cat
# | reactive[12].Q_main
# | reactive[12].x_
# | reactive[12].y_
# | reactive[12].x
# | reactive[12].y
# | reactive[12].z
# | reactive[12].L
# | reactive[12].V
# | reactive[12].F
# | reactive[12].H_L_
# | reactive[12].H_V_
# | reactive[12].H_L
# | reactive[12].H_V
# | reactive[12].T
# | reactive[12].H_F
# | reactive[12].f_V
# | reactive[12].f_L
# | reactive[12].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].kinetics_block.k_FT
# | reactive[12].kinetics_block.r_FT_total
# | reactive[12].kinetics_block.g0_FT
# | reactive[12].kinetics_block.alpha
# | reactive[12].kinetics_block.r_FT_cnum
# | reactive[12].kinetics_block.r_FT_comp
# | reactive[12].kinetics_block.k_WGS
# | reactive[12].kinetics_block.Ke_WGS
# | reactive[12].kinetics_block.r_WGS
# | reactive[12].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].energy_block.dH_F
# | reactive[12].energy_block.dH_V
# | reactive[12].energy_block.dH_L
# | reactive[12].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].VLE_block.P_VLE
# | reactive[12].VLE_block.n_ave
# | reactive[12].VLE_block.n_ave_cal
# | reactive[12].VLE_block.Hen
# | reactive[12].VLE_block.Hen0
# | reactive[12].VLE_block.gamma
# | reactive[12].VLE_block.P_sat
# | reactive[12].VLE_block.P_sat_Y
# | reactive[12].VLE_block.P_sat_dY_inf
# | reactive[12].VLE_block.P_sat_dY0
# | reactive[12].VLE_block.Hen_ref
# | reactive[12].VLE_block.Hen0_ref
# | reactive[12].VLE_block.gamma_ref
# | reactive[12].VLE_block.V_L
# | reactive[12].VLE_block.V_L_dY_inf
# | reactive[12].VLE_block.V_L_dY0
# | reactive[12].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[12].MPCC.s_L
# | reactive[12].MPCC.s_V
# | reactive[12].MPCC.pf
# | reactive[12].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[13].T_F
# | reactive[13].P
# | reactive[13].cat
# | reactive[13].Q_main
# | reactive[13].x_
# | reactive[13].y_
# | reactive[13].x
# | reactive[13].y
# | reactive[13].z
# | reactive[13].L
# | reactive[13].V
# | reactive[13].F
# | reactive[13].H_L_
# | reactive[13].H_V_
# | reactive[13].H_L
# | reactive[13].H_V
# | reactive[13].T
# | reactive[13].H_F
# | reactive[13].f_V
# | reactive[13].f_L
# | reactive[13].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].kinetics_block.k_FT
# | reactive[13].kinetics_block.r_FT_total
# | reactive[13].kinetics_block.g0_FT
# | reactive[13].kinetics_block.alpha
# | reactive[13].kinetics_block.r_FT_cnum
# | reactive[13].kinetics_block.r_FT_comp
# | reactive[13].kinetics_block.k_WGS
# | reactive[13].kinetics_block.Ke_WGS
# | reactive[13].kinetics_block.r_WGS
# | reactive[13].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].energy_block.dH_F
# | reactive[13].energy_block.dH_V
# | reactive[13].energy_block.dH_L
# | reactive[13].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].VLE_block.P_VLE
# | reactive[13].VLE_block.n_ave
# | reactive[13].VLE_block.n_ave_cal
# | reactive[13].VLE_block.Hen
# | reactive[13].VLE_block.Hen0
# | reactive[13].VLE_block.gamma
# | reactive[13].VLE_block.P_sat
# | reactive[13].VLE_block.P_sat_Y
# | reactive[13].VLE_block.P_sat_dY_inf
# | reactive[13].VLE_block.P_sat_dY0
# | reactive[13].VLE_block.Hen_ref
# | reactive[13].VLE_block.Hen0_ref
# | reactive[13].VLE_block.gamma_ref
# | reactive[13].VLE_block.V_L
# | reactive[13].VLE_block.V_L_dY_inf
# | reactive[13].VLE_block.V_L_dY0
# | reactive[13].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[13].MPCC.s_L
# | reactive[13].MPCC.s_V
# | reactive[13].MPCC.pf
# | reactive[13].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[14].T_F
# | reactive[14].P
# | reactive[14].cat
# | reactive[14].Q_main
# | reactive[14].x_
# | reactive[14].y_
# | reactive[14].x
# | reactive[14].y
# | reactive[14].z
# | reactive[14].L
# | reactive[14].V
# | reactive[14].F
# | reactive[14].H_L_
# | reactive[14].H_V_
# | reactive[14].H_L
# | reactive[14].H_V
# | reactive[14].T
# | reactive[14].H_F
# | reactive[14].f_V
# | reactive[14].f_L
# | reactive[14].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].kinetics_block.k_FT
# | reactive[14].kinetics_block.r_FT_total
# | reactive[14].kinetics_block.g0_FT
# | reactive[14].kinetics_block.alpha
# | reactive[14].kinetics_block.r_FT_cnum
# | reactive[14].kinetics_block.r_FT_comp
# | reactive[14].kinetics_block.k_WGS
# | reactive[14].kinetics_block.Ke_WGS
# | reactive[14].kinetics_block.r_WGS
# | reactive[14].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].energy_block.dH_F
# | reactive[14].energy_block.dH_V
# | reactive[14].energy_block.dH_L
# | reactive[14].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].VLE_block.P_VLE
# | reactive[14].VLE_block.n_ave
# | reactive[14].VLE_block.n_ave_cal
# | reactive[14].VLE_block.Hen
# | reactive[14].VLE_block.Hen0
# | reactive[14].VLE_block.gamma
# | reactive[14].VLE_block.P_sat
# | reactive[14].VLE_block.P_sat_Y
# | reactive[14].VLE_block.P_sat_dY_inf
# | reactive[14].VLE_block.P_sat_dY0
# | reactive[14].VLE_block.Hen_ref
# | reactive[14].VLE_block.Hen0_ref
# | reactive[14].VLE_block.gamma_ref
# | reactive[14].VLE_block.V_L
# | reactive[14].VLE_block.V_L_dY_inf
# | reactive[14].VLE_block.V_L_dY0
# | reactive[14].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[14].MPCC.s_L
# | reactive[14].MPCC.s_V
# | reactive[14].MPCC.pf
# | reactive[14].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[15].T_F
# | reactive[15].P
# | reactive[15].cat
# | reactive[15].Q_main
# | reactive[15].x_
# | reactive[15].y_
# | reactive[15].x
# | reactive[15].y
# | reactive[15].z
# | reactive[15].L
# | reactive[15].V
# | reactive[15].F
# | reactive[15].H_L_
# | reactive[15].H_V_
# | reactive[15].H_L
# | reactive[15].H_V
# | reactive[15].T
# | reactive[15].H_F
# | reactive[15].f_V
# | reactive[15].f_L
# | reactive[15].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].kinetics_block.k_FT
# | reactive[15].kinetics_block.r_FT_total
# | reactive[15].kinetics_block.g0_FT
# | reactive[15].kinetics_block.alpha
# | reactive[15].kinetics_block.r_FT_cnum
# | reactive[15].kinetics_block.r_FT_comp
# | reactive[15].kinetics_block.k_WGS
# | reactive[15].kinetics_block.Ke_WGS
# | reactive[15].kinetics_block.r_WGS
# | reactive[15].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].energy_block.dH_F
# | reactive[15].energy_block.dH_V
# | reactive[15].energy_block.dH_L
# | reactive[15].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].VLE_block.P_VLE
# | reactive[15].VLE_block.n_ave
# | reactive[15].VLE_block.n_ave_cal
# | reactive[15].VLE_block.Hen
# | reactive[15].VLE_block.Hen0
# | reactive[15].VLE_block.gamma
# | reactive[15].VLE_block.P_sat
# | reactive[15].VLE_block.P_sat_Y
# | reactive[15].VLE_block.P_sat_dY_inf
# | reactive[15].VLE_block.P_sat_dY0
# | reactive[15].VLE_block.Hen_ref
# | reactive[15].VLE_block.Hen0_ref
# | reactive[15].VLE_block.gamma_ref
# | reactive[15].VLE_block.V_L
# | reactive[15].VLE_block.V_L_dY_inf
# | reactive[15].VLE_block.V_L_dY0
# | reactive[15].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[15].MPCC.s_L
# | reactive[15].MPCC.s_V
# | reactive[15].MPCC.pf
# | reactive[15].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[16].T_F
# | reactive[16].P
# | reactive[16].cat
# | reactive[16].Q_main
# | reactive[16].x_
# | reactive[16].y_
# | reactive[16].x
# | reactive[16].y
# | reactive[16].z
# | reactive[16].L
# | reactive[16].V
# | reactive[16].F
# | reactive[16].H_L_
# | reactive[16].H_V_
# | reactive[16].H_L
# | reactive[16].H_V
# | reactive[16].T
# | reactive[16].H_F
# | reactive[16].f_V
# | reactive[16].f_L
# | reactive[16].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].kinetics_block.k_FT
# | reactive[16].kinetics_block.r_FT_total
# | reactive[16].kinetics_block.g0_FT
# | reactive[16].kinetics_block.alpha
# | reactive[16].kinetics_block.r_FT_cnum
# | reactive[16].kinetics_block.r_FT_comp
# | reactive[16].kinetics_block.k_WGS
# | reactive[16].kinetics_block.Ke_WGS
# | reactive[16].kinetics_block.r_WGS
# | reactive[16].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].energy_block.dH_F
# | reactive[16].energy_block.dH_V
# | reactive[16].energy_block.dH_L
# | reactive[16].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].VLE_block.P_VLE
# | reactive[16].VLE_block.n_ave
# | reactive[16].VLE_block.n_ave_cal
# | reactive[16].VLE_block.Hen
# | reactive[16].VLE_block.Hen0
# | reactive[16].VLE_block.gamma
# | reactive[16].VLE_block.P_sat
# | reactive[16].VLE_block.P_sat_Y
# | reactive[16].VLE_block.P_sat_dY_inf
# | reactive[16].VLE_block.P_sat_dY0
# | reactive[16].VLE_block.Hen_ref
# | reactive[16].VLE_block.Hen0_ref
# | reactive[16].VLE_block.gamma_ref
# | reactive[16].VLE_block.V_L
# | reactive[16].VLE_block.V_L_dY_inf
# | reactive[16].VLE_block.V_L_dY0
# | reactive[16].VLE_block.poynting
# --------------------------------------------------
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[16].MPCC.s_L
# | reactive[16].MPCC.s_V
# | reactive[16].MPCC.pf
# | reactive[16].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[17].T_F
# | reactive[17].P
# | reactive[17].cat
# | reactive[17].Q_main
# | reactive[17].x_
# | reactive[17].y_
# | reactive[17].x
# | reactive[17].y
# | reactive[17].z
# | reactive[17].L
# | reactive[17].V
# | reactive[17].F
# | reactive[17].H_L_
# | reactive[17].H_V_
# | reactive[17].H_L
# | reactive[17].H_V
# | reactive[17].T
# | reactive[17].H_F
# | reactive[17].f_V
# | reactive[17].f_L
# | reactive[17].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].kinetics_block.k_FT
# | reactive[17].kinetics_block.r_FT_total
# | reactive[17].kinetics_block.g0_FT
# | reactive[17].kinetics_block.alpha
# | reactive[17].kinetics_block.r_FT_cnum
# | reactive[17].kinetics_block.r_FT_comp
# | reactive[17].kinetics_block.k_WGS
# | reactive[17].kinetics_block.Ke_WGS
# | reactive[17].kinetics_block.r_WGS
# | reactive[17].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].energy_block.dH_F
# | reactive[17].energy_block.dH_V
# | reactive[17].energy_block.dH_L
# | reactive[17].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].VLE_block.P_VLE
# | reactive[17].VLE_block.n_ave
# | reactive[17].VLE_block.n_ave_cal
# | reactive[17].VLE_block.Hen
# | reactive[17].VLE_block.Hen0
# | reactive[17].VLE_block.gamma
# | reactive[17].VLE_block.P_sat
# | reactive[17].VLE_block.P_sat_Y
# | reactive[17].VLE_block.P_sat_dY_inf
# | reactive[17].VLE_block.P_sat_dY0
# | reactive[17].VLE_block.Hen_ref
# | reactive[17].VLE_block.Hen0_ref
# | reactive[17].VLE_block.gamma_ref
# | reactive[17].VLE_block.V_L
# | reactive[17].VLE_block.V_L_dY_inf
# | reactive[17].VLE_block.V_L_dY0
# | reactive[17].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[17].MPCC.s_L
# | reactive[17].MPCC.s_V
# | reactive[17].MPCC.pf
# | reactive[17].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[18].T_F
# | reactive[18].P
# | reactive[18].cat
# | reactive[18].Q_main
# | reactive[18].x_
# | reactive[18].y_
# | reactive[18].x
# | reactive[18].y
# | reactive[18].z
# | reactive[18].L
# | reactive[18].V
# | reactive[18].F
# | reactive[18].H_L_
# | reactive[18].H_V_
# | reactive[18].H_L
# | reactive[18].H_V
# | reactive[18].T
# | reactive[18].H_F
# | reactive[18].f_V
# | reactive[18].f_L
# | reactive[18].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].kinetics_block.k_FT
# | reactive[18].kinetics_block.r_FT_total
# | reactive[18].kinetics_block.g0_FT
# | reactive[18].kinetics_block.alpha
# | reactive[18].kinetics_block.r_FT_cnum
# | reactive[18].kinetics_block.r_FT_comp
# | reactive[18].kinetics_block.k_WGS
# | reactive[18].kinetics_block.Ke_WGS
# | reactive[18].kinetics_block.r_WGS
# | reactive[18].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].energy_block.dH_F
# | reactive[18].energy_block.dH_V
# | reactive[18].energy_block.dH_L
# | reactive[18].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].VLE_block.P_VLE
# | reactive[18].VLE_block.n_ave
# | reactive[18].VLE_block.n_ave_cal
# | reactive[18].VLE_block.Hen
# | reactive[18].VLE_block.Hen0
# | reactive[18].VLE_block.gamma
# | reactive[18].VLE_block.P_sat
# | reactive[18].VLE_block.P_sat_Y
# | reactive[18].VLE_block.P_sat_dY_inf
# | reactive[18].VLE_block.P_sat_dY0
# | reactive[18].VLE_block.Hen_ref
# | reactive[18].VLE_block.Hen0_ref
# | reactive[18].VLE_block.gamma_ref
# | reactive[18].VLE_block.V_L
# | reactive[18].VLE_block.V_L_dY_inf
# | reactive[18].VLE_block.V_L_dY0
# | reactive[18].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[18].MPCC.s_L
# | reactive[18].MPCC.s_V
# | reactive[18].MPCC.pf
# | reactive[18].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[19].T_F
# | reactive[19].P
# | reactive[19].cat
# | reactive[19].Q_main
# | reactive[19].x_
# | reactive[19].y_
# | reactive[19].x
# | reactive[19].y
# | reactive[19].z
# | reactive[19].L
# | reactive[19].V
# | reactive[19].F
# | reactive[19].H_L_
# | reactive[19].H_V_
# | reactive[19].H_L
# | reactive[19].H_V
# | reactive[19].T
# | reactive[19].H_F
# | reactive[19].f_V
# | reactive[19].f_L
# | reactive[19].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].kinetics_block.k_FT
# | reactive[19].kinetics_block.r_FT_total
# | reactive[19].kinetics_block.g0_FT
# | reactive[19].kinetics_block.alpha
# | reactive[19].kinetics_block.r_FT_cnum
# | reactive[19].kinetics_block.r_FT_comp
# | reactive[19].kinetics_block.k_WGS
# | reactive[19].kinetics_block.Ke_WGS
# | reactive[19].kinetics_block.r_WGS
# | reactive[19].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].energy_block.dH_F
# | reactive[19].energy_block.dH_V
# | reactive[19].energy_block.dH_L
# | reactive[19].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].VLE_block.P_VLE
# | reactive[19].VLE_block.n_ave
# | reactive[19].VLE_block.n_ave_cal
# | reactive[19].VLE_block.Hen
# | reactive[19].VLE_block.Hen0
# | reactive[19].VLE_block.gamma
# | reactive[19].VLE_block.P_sat
# | reactive[19].VLE_block.P_sat_Y
# | reactive[19].VLE_block.P_sat_dY_inf
# | reactive[19].VLE_block.P_sat_dY0
# | reactive[19].VLE_block.Hen_ref
# | reactive[19].VLE_block.Hen0_ref
# | reactive[19].VLE_block.gamma_ref
# | reactive[19].VLE_block.V_L
# | reactive[19].VLE_block.V_L_dY_inf
# | reactive[19].VLE_block.V_L_dY0
# | reactive[19].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[19].MPCC.s_L
# | reactive[19].MPCC.s_V
# | reactive[19].MPCC.pf
# | reactive[19].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE
#
# > Importing Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reactive[20].T_F
# | reactive[20].P
# | reactive[20].cat
# | reactive[20].Q_main
# | reactive[20].x_
# | reactive[20].y_
# | reactive[20].x
# | reactive[20].y
# | reactive[20].z
# | reactive[20].L
# | reactive[20].V
# | reactive[20].F
# | reactive[20].H_L_
# | reactive[20].H_V_
# | reactive[20].H_L
# | reactive[20].H_V
# | reactive[20].T
# | reactive[20].H_F
# | reactive[20].f_V
# | reactive[20].f_L
# | reactive[20].r_total_comp
# ------------------------------------
#
# > Importing Kinetics Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].kinetics_block.k_FT
# | reactive[20].kinetics_block.r_FT_total
# | reactive[20].kinetics_block.g0_FT
# | reactive[20].kinetics_block.alpha
# | reactive[20].kinetics_block.r_FT_cnum
# | reactive[20].kinetics_block.r_FT_comp
# | reactive[20].kinetics_block.k_WGS
# | reactive[20].kinetics_block.Ke_WGS
# | reactive[20].kinetics_block.r_WGS
# | reactive[20].kinetics_block.r_WGS_comp
# --------------------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].energy_block.dH_F
# | reactive[20].energy_block.dH_V
# | reactive[20].energy_block.dH_L
# | reactive[20].energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].VLE_block.P_VLE
# | reactive[20].VLE_block.n_ave
# | reactive[20].VLE_block.n_ave_cal
# | reactive[20].VLE_block.Hen
# | reactive[20].VLE_block.Hen0
# | reactive[20].VLE_block.gamma
# | reactive[20].VLE_block.P_sat
# | reactive[20].VLE_block.P_sat_Y
# | reactive[20].VLE_block.P_sat_dY_inf
# | reactive[20].VLE_block.P_sat_dY0
# | reactive[20].VLE_block.Hen_ref
# | reactive[20].VLE_block.Hen0_ref
# | reactive[20].VLE_block.gamma_ref
# | reactive[20].VLE_block.V_L
# | reactive[20].VLE_block.V_L_dY_inf
# | reactive[20].VLE_block.V_L_dY0
# | reactive[20].VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reactive[20].MPCC.s_L
# | reactive[20].MPCC.s_V
# | reactive[20].MPCC.pf
# | reactive[20].MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE

# %% [markdown]
# # Construct a single condenser

# %%
model.condenser = pe.Block(rule=condenser_stage_rule)
# Out:
# | Importing Condenser Stage......
# | Adding the following local variable:
# ------------------------------------
# | condenser.T
# | condenser.T_F
# | condenser.P
# | condenser.Q_main
# | condenser.x_
# | condenser.y_
# | condenser.x
# | condenser.y
# | condenser.z
# | condenser.L
# | condenser.W
# | condenser.V
# | condenser.F
# | condenser.H_L_
# | condenser.H_V_
# | condenser.H_L
# | condenser.H_V
# | condenser.H_F
# | condenser.f_V
# | condenser.f_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.energy_block.dH_F
# | condenser.energy_block.dH_V
# | condenser.energy_block.dH_L
# | condenser.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | condenser.VLE_block.n_ave
# | condenser.VLE_block.n_ave_cal
# | condenser.VLE_block.Hen
# | condenser.VLE_block.Hen0
# | condenser.VLE_block.gamma
# | condenser.VLE_block.P_sat
# | condenser.VLE_block.P_sat_Y
# | condenser.VLE_block.P_sat_dY_inf
# | condenser.VLE_block.P_sat_dY0
# | condenser.VLE_block.Hen_ref
# | condenser.VLE_block.Hen0_ref
# | condenser.VLE_block.gamma_ref
# | condenser.VLE_block.V_L
# | condenser.VLE_block.V_L_dY_inf
# | condenser.VLE_block.V_L_dY0
# | condenser.VLE_block.poynting
# --------------------------------------------------

# %% [markdown]
# # Construct a single reboiler

# %%
model.reboiler = pe.Block(rule=non_reactive_stage_rule)
# Out:
# > Importing Non Reactive Stage......
# > Adding the following local variable:
# ------------------------------------
# | reboiler.T_F
# | reboiler.P
# | reboiler.Q_main
# | reboiler.x_
# | reboiler.y_
# | reboiler.x
# | reboiler.y
# | reboiler.z
# | reboiler.L
# | reboiler.V
# | reboiler.F
# | reboiler.H_L_
# | reboiler.H_V_
# | reboiler.H_L
# | reboiler.H_V
# | reboiler.T
# | reboiler.H_F
# | reboiler.f_V
# | reboiler.f_L
# ------------------------------------
#
# > Importing Energy Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.energy_block.dH_F
# | reboiler.energy_block.dH_V
# | reboiler.energy_block.dH_L
# | reboiler.energy_block.dH_vap
# --------------------------------------------------
#
# > Importing VLE Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.VLE_block.P_VLE
# | reboiler.VLE_block.n_ave
# | reboiler.VLE_block.n_ave_cal
# | reboiler.VLE_block.Hen
# | reboiler.VLE_block.Hen0
# | reboiler.VLE_block.gamma
# | reboiler.VLE_block.P_sat
# | reboiler.VLE_block.P_sat_Y
# | reboiler.VLE_block.P_sat_dY_inf
# | reboiler.VLE_block.P_sat_dY0
# | reboiler.VLE_block.Hen_ref
# | reboiler.VLE_block.Hen0_ref
# | reboiler.VLE_block.gamma_ref
# | reboiler.VLE_block.V_L
# | reboiler.VLE_block.V_L_dY_inf
# | reboiler.VLE_block.V_L_dY0
# | reboiler.VLE_block.poynting
# --------------------------------------------------
#
# > Importing MPCC_P_Reg Blocks......
# > Adding the following local variable:
# --------------------------------------------------
# | reboiler.MPCC.s_L
# | reboiler.MPCC.s_V
# | reboiler.MPCC.pf
# | reboiler.MPCC.rho
# --------------------------------------------------
# > Spliting pressure used in VLE

# %% [markdown]
# # Linking Stage Variables

# %% [markdown]
# ### Vapor Between Reactive Stages

# %%
def V_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].V['in'] == model.reactive[j+1].V['out']
model.V_between_con = pe.Constraint(model.TRAY,rule=V_between_rule)

def Vy_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].y_['in',i] == model.reactive[j+1].y[i]
model.Vy_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Vy_between_rule)

def Vh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j].H_V_['in'] == model.reactive[j+1].H_V
model.Vh_between_con = pe.Constraint(model.TRAY,rule=Vh_between_rule)

# %% [markdown]
# ### Liquid Between Reactive Stages

# %%
def L_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].L['in'] == model.reactive[j].L['out']
model.L_between_con = pe.Constraint(model.TRAY,rule=L_between_rule)

def Lx_between_rule(model,j,i):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].x_['in',i] == model.reactive[j].x[i]
model.Ly_between_con = pe.Constraint(model.TRAY,m.COMP_TOTAL,rule=Lx_between_rule)

def Lh_between_rule(model,j):
    if j == model.TRAY.last(): return pe.Constraint.Skip
    return model.reactive[j+1].H_L_['in'] == model.reactive[j].H_L
model.Lh_between_con = pe.Constraint(model.TRAY,rule=Lh_between_rule)

# %% [markdown]
# ### Condenser Vapor

# %%
def V_condenser_rule(model):
    return model.reactive[model.TRAY.first()].V['out'] == model.condenser.V['in']
model.V_condenser_con = pe.Constraint(rule=V_condenser_rule)

def Vy_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].y[i] == model.condenser.y_['in',i]
model.Vy_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_condenser_rule)

def Vh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_V == model.condenser.H_V_['in']
model.Vh_condenser_con = pe.Constraint(rule=Vh_condenser_rule)

# %% [markdown]
# ### Condenser Liquid

# %%
def L_condenser_rule(model):
    return model.reactive[model.TRAY.first()].L['in'] == model.condenser.L['out']
model.L_condenser_con = pe.Constraint(rule=L_condenser_rule)

def Lx_condenser_rule(model,i):
    return model.reactive[model.TRAY.first()].x_['in',i] == model.condenser.x[i]
model.Lx_condenser_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_condenser_rule)

def Lh_condenser_rule(model):
    return model.reactive[model.TRAY.first()].H_L_['in'] == model.condenser.H_L
model.Lh_condenser_con = pe.Constraint(rule=Lh_condenser_rule)

# %% [markdown]
# ### Reboiler Vapor

# %%
def V_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].V['in'] == model.reboiler.V['out']
model.V_reboiler_con = pe.Constraint(rule=V_reboiler_rule)

def Vy_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].y_['in',i] == model.reboiler.y[i]
model.Vy_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Vy_reboiler_rule)

def Vh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_V_['in'] == model.reboiler.H_V
model.Vh_reboiler_con = pe.Constraint(rule=Vh_reboiler_rule)

# %% [markdown]
# ### Reboiler Liquid

# %%
def L_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].L['out'] == model.reboiler.L['in']
model.L_reboiler_con = pe.Constraint(rule=L_reboiler_rule)

def Lx_reboiler_rule(model,i):
    return model.reactive[model.TRAY.last()].x[i] == model.reboiler.x_['in',i]
model.Lx_reboiler_con = pe.Constraint(m.COMP_TOTAL,rule=Lx_reboiler_rule)

def Lh_reboiler_rule(model):
    return model.reactive[model.TRAY.last()].H_L == model.reboiler.H_L_['in']
model.Lh_reboiler_con = pe.Constraint(rule=Lh_reboiler_rule)

# %%
model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.TRAY)\
                         - model.reboiler.MPCC.pf ,sense=pe.maximize)
# model.obj = pe.Objective(expr = sum(model.reactive[j].T - model.reactive[j].MPCC.pf for j in model.TRAY) ,sense=pe.maximize)
# model.obj = pe.Objective(expr = sum(model.reactive[j].T for j in model.TRAY) ,sense=pe.maximize)

# %%
add_dual(pe,model)
# Out:
# Created the follow pyomo suffixes:
# ipopt_zL_out, ipopt_zU_out, ipopt_zL_in, ipopt_zU_in, dual

# %% [markdown]
# # Load from Reactive Flash solutions

# %%
with open('../saved_solutions/reactive_flash_MPCC_P_pf_200C.pickle', 'rb') as f:
    results_imported = pickle.load(f)
results_changed = deepcopy(results_imported)

# %% [markdown]
# ### Duplicate variable solution and bounds multiplier

# %%
results_changed.Solution.Variable = {}
for i in list(results_imported.Solution.Variable.keys()):
    for j in model.TRAY:
        results_changed.Solution.Variable['reactive[{}].{}'.format(j,i)] = \
        results_imported.Solution.Variable[i]

# %% [markdown]
# ### Duplicate constraint multiplier

# %%
results_changed.Solution.Constraint = {}
for i in list(results_imported.Solution.Constraint.keys()):
    for j in model.TRAY:
        results_changed.Solution.Constraint['reactive[{}].{}'.format(j,i)] = \
        results_imported.Solution.Constraint[i]

# %% [markdown]
# # Load from Condenser solutions

# %%
with open('../saved_solutions/condenser_MPCC_P_pf_30C.pickle', 'rb') as f:
    condenser_results_imported = pickle.load(f)

# %% [markdown]
# ### Duplicate variable solution and bounds multiplier

# %%
for i in list(condenser_results_imported.Solution.Variable.keys()):
    results_changed.Solution.Variable['condenser.{}'.format(i)] = \
    condenser_results_imported.Solution.Variable[i]

# %% [markdown]
# ### Duplicate constraint multiplier

# %%
for i in list(condenser_results_imported.Solution.Constraint.keys()):
    results_changed.Solution.Constraint['condenser.{}'.format(i)] = \
    condenser_results_imported.Solution.Constraint[i]

# %% [markdown]
# # Load from Reboiler solutions

# %%
with open('../saved_solutions/reboiler_MPCC_P_pf_200C.pickle', 'rb') as f:
    reboiler_results_imported = pickle.load(f)

# %% [markdown]
# ### Duplicate variable solution and bounds multiplier

# %%
for i in list(reboiler_results_imported.Solution.Variable.keys()):
    results_changed.Solution.Variable['reboiler.{}'.format(i)] = \
    reboiler_results_imported.Solution.Variable[i]

# %% [markdown]
# ### Duplicate constraint multiplier

# %%
for i in list(reboiler_results_imported.Solution.Constraint.keys()):
    results_changed.Solution.Constraint['reboiler.{}'.format(i)] = \
    reboiler_results_imported.Solution.Constraint[i]

# %%
model.solutions.load_from(results_changed)

# %% [markdown]
# # Fixing Redundent Stream Variables

# %%
# condenser
model.condenser.VLE_block.n_ave.fix(4)

model.condenser.F.fix(0)
model.condenser.T_F.fix(300+273.15)
model.condenser.z.fix(0)

model.condenser.V['P'].fix(0)
model.condenser.L['in'].fix(0)
for i in m.COMP_TOTAL: model.condenser.x_['in',i].fix(0)
model.condenser.H_L_['in'].fix(0)

# %%
# reboiler
model.reboiler.VLE_block.n_ave.fix(20)

model.reboiler.F.fix(0)
model.reboiler.T_F.fix(300+273.15)
model.reboiler.z.fix(0)

model.reboiler.V['P'].fix(0)
model.reboiler.V['in'].fix(0)
for i in m.COMP_TOTAL: model.reboiler.y_['in',i].fix(0)
model.reboiler.H_V_['in'].fix(0)
model.reboiler.L['P'].fix(0)

# %% [markdown]
# # Load Operating Parameters

# %%
# condenser
model.condenser.P.fix(19)
# model.condenser.T.fix(30+273.15)
model.condenser.T.fix(30+273.15)
model.condenser.L['out'].fix(0)

# reboiler
model.reboiler.P.fix(20)
# model.reboiler.T.fix(30+273.15)
model.reboiler.T.fix(200+273.15)
# model.reboiler.Q_main.fix(0)

# reactive stage
for j in model.reactive:
    model.reactive[j].cat.fix(3000)
    model.reactive[j].P.fix(20)
    model.reactive[j].VLE_block.n_ave.fix(20)
    
    model.reactive[j].F.fix(1)
    model.reactive[j].T_F.fix(200+273.15)
    model.reactive[j].z['CO'].fix(1/(1+2)-0/2)
    model.reactive[j].z['H2'].fix(2/(1+2)-0/2)
    model.reactive[j].z['C30H62'].fix(0)
    model.reactive[j].V['P'].fix(0)
    model.reactive[j].L['P'].fix(0)
    # model.reactive[j].Q_main.fix(0)
    model.reactive[j].T.setub(200+273.15)

# %%
check_DOF(pe,model)
# Out:
# Active Equality Constraints:	 28956
# Active Inequality Constraints:	 21
# Active Variables:		 29421
# Fixed Variables:		 382
# DOF:				 83

# %%
opt = pe.SolverFactory('ipopt')

opt.options['print_user_options'] = 'yes'
opt.options['linear_solver'] = 'ma86'

opt.options['linear_system_scaling '] = 'mc19'
opt.options['linear_scaling_on_demand '] = 'no'

opt.options['warm_start_init_point'] = 'yes'
opt.options['warm_start_bound_push'] = 1e-20
opt.options['warm_start_mult_bound_push'] = 1e-20
opt.options['mu_init'] = 1e-6
# opt.options['recalc_y'] = 'yes'
# opt.options['bound_relax_factor'] = 0
# opt.options['halt_on_ampl_error'] = 'yes'

opt.options['max_iter'] = 7000
results = opt.solve(model,tee=True)
update_dual(pe,model)
# Out:
# Ipopt 3.12.8: print_user_options=yes
# linear_solver=ma86
# linear_system_scaling =mc19
# linear_scaling_on_demand =no
# warm_start_init_point=yes
# warm_start_bound_push=1e-20
# warm_start_mult_bound_push=1e-20
# mu_init=1e-06
# max_iter=7000
#
#
# List of user-set options:
#
#                                     Name   Value                used
#                 linear_scaling_on_demand = no                    yes
#                            linear_solver = ma86                  yes
#                    linear_system_scaling = mc19                  yes
#                                 max_iter = 7000                  yes
#                                  mu_init = 1e-06                 yes
#                       print_user_options = yes                   yes
#                    warm_start_bound_push = 1e-20                 yes
#                    warm_start_init_point = yes                   yes
#               warm_start_mult_bound_push = 1e-20                 yes
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.8, running with linear solver ma86.
#
# Number of nonzeros in equality constraint Jacobian...:    94360
# Number of nonzeros in inequality constraint Jacobian.:      105
# Number of nonzeros in Lagrangian Hessian.............:    97786
#
# Total number of variables............................:    29019
#                      variables with only lower bounds:     4873
#                 variables with lower and upper bounds:    20609
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    28956
# Total number of inequality constraints...............:       21
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       21
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -9.4630000e+03 4.98e+02 1.00e+00  -6.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1r-9.4630000e+03 4.98e+02 9.99e+02   2.7 0.00e+00    -  0.00e+00 5.98e-10R  3
#    2r-9.4630000e+03 4.98e+02 1.82e+06   2.7 2.32e+06    -  1.06e-07 1.65e-10f  1
#    3r-9.4629977e+03 4.98e+02 1.88e+06   2.7 8.07e+04    -  9.33e-08 2.23e-07f  1
#    4r-9.4629922e+03 4.98e+02 1.88e+06   2.7 7.97e+04    -  2.09e-06 5.17e-07f  1
#    5r-9.4629385e+03 4.98e+02 1.88e+06   2.7 5.45e+04    -  2.53e-05 4.83e-06f  1
#    6r-9.4621102e+03 4.97e+02 1.88e+06   2.7 2.29e+04    -  1.07e-05 5.52e-05f  1
#    7r-9.4615149e+03 4.95e+02 1.88e+06   2.7 2.21e+04    -  5.36e-04 7.97e-05f  1
#    8r-9.4590898e+03 4.78e+02 1.87e+06   2.7 2.05e+04    -  3.14e-03 8.41e-04f  1
#    9r-9.4578645e+03 5.00e+02 1.87e+06   2.0 1.97e+04    -  2.60e-03 5.23e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -9.4582201e+03 4.94e+02 1.39e+02  -6.0 3.41e+03    -  5.46e-03 1.03e-02h  1
#   11 -9.4582190e+03 4.94e+02 1.39e+02  -6.0 6.32e+03    -  1.32e-02 1.66e-04h  1
#   12 -9.4581426e+03 4.91e+02 5.70e+02  -6.0 6.67e+03    -  1.55e-02 7.20e-03h  1
#   13 -9.4581355e+03 4.90e+02 5.69e+02  -6.0 4.62e+03    -  1.15e-02 4.24e-04h  1
#   14 -9.4579317e+03 4.89e+02 5.07e+02  -6.0 3.84e+03    -  7.59e-04 3.42e-03h  1
#   15 -9.4578837e+03 4.88e+02 5.06e+02  -6.0 9.10e+03    -  2.27e-03 6.25e-04h  1
#   16 -9.4578259e+03 4.88e+02 5.07e+02  -6.0 1.69e+04    -  1.28e-09 3.23e-04h  1
#   17 -9.4577948e+03 4.88e+02 5.07e+02  -6.0 9.09e+04    -  3.21e-04 5.00e-05h  1
#   18 -9.4574859e+03 4.88e+02 5.06e+02  -6.0 1.51e+05    -  6.17e-05 4.13e-04h  1
#   19r-9.4574859e+03 4.88e+02 9.99e+02   2.6 0.00e+00    -  0.00e+00 3.29e-07R  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r-9.4574859e+03 4.88e+02 2.70e+06   2.6 2.18e+04    -  9.36e-06 1.23e-09f  1
#   21r-9.4574259e+03 4.95e+02 2.67e+06   2.6 2.39e+04    -  1.14e-02 1.82e-05f  1
#   22r-9.4559374e+03 3.41e+02 2.65e+06   1.9 2.43e+04    -  9.77e-03 1.00e-02f  1
#   23 -9.4557118e+03 3.40e+02 5.26e+02  -6.0 6.89e+03    -  2.48e-04 1.19e-03h  1
#   24r-9.4557118e+03 3.40e+02 9.99e+02   2.3 0.00e+00    -  0.00e+00 8.14e-09R  2
#   25r-9.4557118e+03 3.40e+02 1.28e+06   2.3 7.12e+06    -  2.18e-07 7.63e-10f  1
#   26r-9.4557111e+03 3.40e+02 1.28e+06   2.3 2.08e+04    -  4.25e-05 2.96e-07f  2
#   27r-9.4553277e+03 3.68e+02 1.24e+06   2.3 1.98e+04    -  3.25e-02 1.73e-04f  1
#   28r-9.4526554e+03 1.58e+02 1.22e+06   0.9 1.08e+04    -  1.18e-02 1.29e-02f  1
#   29 -9.4519495e+03 1.57e+02 3.34e+02  -6.0 5.10e+03    -  1.26e-03 4.89e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30 -9.4515974e+03 1.57e+02 5.54e+02  -6.0 9.61e+03    -  3.97e-03 1.26e-03h  1
#   31 -9.4515594e+03 1.57e+02 6.36e+02  -6.0 1.21e+04    -  4.41e-04 1.11e-04h  1
#   32 -9.4507176e+03 1.56e+02 3.28e+02  -6.0 1.38e+04    -  1.51e-04 2.42e-03h  1
#   33 -9.4506236e+03 1.56e+02 1.20e+03  -6.0 1.37e+04    -  6.57e-03 3.31e-04h  1
#   34 -9.4501334e+03 1.56e+02 1.39e+03  -6.0 1.40e+04    -  2.49e-03 1.72e-03h  1
#   35 -9.4498812e+03 1.56e+02 1.31e+03  -6.0 1.59e+04    -  4.15e-04 7.54e-04h  1
#   36 -9.4498198e+03 1.56e+02 1.75e+03  -6.0 1.52e+04    -  2.94e-03 1.92e-04h  1
#   37 -9.4497626e+03 1.56e+02 1.77e+03  -6.0 1.18e+04    -  3.82e-04 1.78e-04h  1
#   38 -9.4497320e+03 1.56e+02 1.77e+03  -6.0 9.02e+03    -  1.62e-10 1.11e-04h  1
#   39 -9.4492633e+03 1.55e+02 1.64e+03  -6.0 1.78e+04    -  5.66e-04 1.29e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r-9.4492633e+03 1.55e+02 9.99e+02   1.9 0.00e+00    -  0.00e+00 2.62e-07R  5
#   41r-9.4492633e+03 1.55e+02 4.30e+05   1.9 1.40e+04    -  9.09e-06 1.20e-08f  1
#   42r-9.4491946e+03 1.57e+02 4.18e+05   1.9 1.53e+04    -  2.72e-02 3.33e-05f  1
#   43r-9.4440652e+03 1.24e+02 4.12e+05   1.2 7.22e+03    -  1.32e-02 8.78e-03f  1
#   44 -9.4438680e+03 1.24e+02 7.36e+00  -6.0 2.95e+03    -  1.91e-04 1.58e-03h  1
#   45r-9.4438680e+03 1.24e+02 9.99e+02   1.6 0.00e+00    -  0.00e+00 2.63e-07R  6
#   46r-9.4438680e+03 1.24e+02 9.99e+02   1.6 1.04e+04    -  1.04e-04 3.12e-10f  2
#   47r-9.4436414e+03 1.28e+02 5.46e+03   1.6 1.01e+04    -  1.78e-02 2.38e-04f  1
#   48r-9.4429479e+03 1.20e+02 7.57e+03   0.2 3.52e+03    -  1.41e-02 5.61e-03f  1
#   49 -9.4420577e+03 1.19e+02 2.55e+01  -6.0 2.90e+03    -  2.86e-04 7.38e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -9.4420360e+03 1.19e+02 3.05e+01  -6.0 3.44e+03    -  5.23e-03 1.97e-04h  1
#   51 -9.4419529e+03 1.19e+02 5.97e+01  -6.0 3.99e+03    -  3.80e-03 1.02e-03h  1
#   52 -9.4418729e+03 1.18e+02 1.02e+02  -6.0 4.47e+03    -  4.00e-03 1.40e-03h  1
#   53 -9.4417901e+03 1.18e+02 2.26e+02  -6.0 4.06e+03    -  4.82e-03 1.07e-03h  1
#   54 -9.4416844e+03 1.18e+02 2.18e+02  -6.0 6.07e+03    -  6.81e-04 7.73e-04h  1
#   55 -9.4416526e+03 1.18e+02 2.28e+02  -6.0 1.22e+04    -  4.37e-04 3.85e-04h  1
#   56 -9.4416526e+03 1.18e+02 6.85e+02  -6.0 1.96e+04    -  1.43e-03 2.28e-04h  1
#   57 -9.4415240e+03 1.18e+02 6.78e+02  -6.0 2.84e+04    -  4.70e-04 4.82e-04h  1
#   58 -9.4413602e+03 1.18e+02 1.10e+03  -6.0 2.99e+04    -  1.06e-03 3.03e-04h  1
#   59 -9.4408358e+03 1.18e+02 9.19e+02  -6.0 3.04e+04    -  1.11e-04 4.61e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r-9.4408358e+03 1.18e+02 9.99e+02   1.3 0.00e+00    -  0.00e+00 3.90e-07R  3
#   61r-9.4408358e+03 1.18e+02 9.99e+02   1.3 8.66e+03    -  5.37e-04 9.08e-09f  1
#   62r-9.4406753e+03 1.19e+02 3.06e+03   1.3 6.63e+03    -  1.10e-02 4.96e-04f  1
#   63r-9.4406753e+03 1.19e+02 9.99e+02   1.2 0.00e+00    -  0.00e+00 3.21e-07R  5
#   64r-9.4406753e+03 1.19e+02 2.79e+03   1.2 6.00e+03    -  1.15e-02 1.23e-08f  2
#   65r-9.4404590e+03 1.19e+02 4.66e+03   0.5 2.15e+03    -  1.33e-02 7.12e-03f  1
#   66 -9.4403994e+03 1.19e+02 2.18e+00  -6.0 3.17e+03    -  9.60e-04 4.39e-04h  1
#   67 -9.4403778e+03 1.19e+02 1.86e+02  -6.0 3.96e+03    -  8.18e-03 1.22e-04h  1
#   68 -9.4403158e+03 1.19e+02 3.12e+02  -6.0 1.77e+04    -  5.69e-04 2.80e-04h  1
#   69 -9.4403042e+03 1.19e+02 7.69e+02  -6.0 2.10e+04    -  1.88e-04 3.08e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70 -9.4400458e+03 1.19e+02 1.60e+02  -6.0 4.59e+04    -  1.47e-06 4.10e-04h  1
#   71 -9.4400223e+03 1.19e+02 1.46e+03  -6.0 4.62e+04    -  7.12e-04 2.33e-05h  1
#   72r-9.4400223e+03 1.19e+02 1.00e+03   0.6 0.00e+00    -  0.00e+00 2.37e-07R  2
#   73r-9.4400223e+03 1.19e+02 9.99e+02   0.6 4.06e+03    -  6.44e-04 2.02e-08f  1
#   74r-9.4399574e+03 1.19e+02 2.33e+03   0.6 2.52e+03    -  1.31e-02 1.17e-03f  1
#   75 -9.4399550e+03 1.19e+02 1.13e+05  -6.0 3.51e+03    -  2.32e-03 1.26e-05h  1
#   76 -9.4399432e+03 1.19e+02 1.68e+05  -6.0 3.94e+04    -  1.46e-05 2.17e-05h  1
#   77r-9.4399432e+03 1.19e+02 9.99e+02   0.2 0.00e+00    -  0.00e+00 1.12e-11R  2
#   78r-9.4399451e+03 1.19e+02 7.41e+03   0.2 3.86e+07    -  1.03e-08 1.54e-09f  1
#   79r-9.4399451e+03 1.19e+02 7.39e+03   0.2 1.79e+03    -  2.35e-03 5.70e-08f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80r-9.4399295e+03 1.18e+02 7.35e+03   0.2 9.62e+02    -  5.78e-03 2.46e-03f  1
#   81r-9.4399295e+03 1.18e+02 9.99e+02   0.1 0.00e+00    -  0.00e+00 4.18e-07R  5
#   82r-9.4399295e+03 1.18e+02 1.00e+03   0.1 1.21e+03    -  1.40e-03 1.11e-08f  1
#   83r-9.4400210e+03 1.17e+02 9.95e+02   0.1 9.23e+02    -  6.92e-03 3.63e-03f  1
#   84r-9.4403951e+03 1.13e+02 9.84e+02   0.1 7.83e+02    -  1.03e-02 1.17e-02f  1
#   85 -9.4403570e+03 1.13e+02 2.98e+01  -6.0 5.07e+03    -  7.62e-03 2.56e-04h  1
#   86 -9.4403064e+03 1.13e+02 3.88e+02  -6.0 5.23e+03    -  8.87e-03 2.77e-04h  1
#   87 -9.4401348e+03 1.13e+02 3.54e+02  -6.0 1.36e+04    -  3.48e-04 4.81e-04h  1
#   88 -9.4400777e+03 1.13e+02 5.59e+02  -6.0 1.13e+04    -  6.05e-04 1.47e-04h  1
#   89r-9.4400777e+03 1.13e+02 9.99e+02   0.0 0.00e+00    -  0.00e+00 2.67e-07R  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90r-9.4400777e+03 1.13e+02 9.99e+02   0.0 7.14e+02    -  2.88e-03 5.66e-08f  2
#   91r-9.4402368e+03 1.11e+02 9.93e+02   0.0 6.70e+02    -  1.34e-02 6.34e-03f  1
#   92r-9.4402176e+03 1.07e+02 1.04e+03   0.0 5.59e+02    -  3.77e-02 1.44e-02f  1
#   93r-9.4402176e+03 1.07e+02 9.99e+02  -0.0 0.00e+00    -  0.00e+00 2.85e-07R  6
#   94r-9.4402176e+03 1.07e+02 1.00e+03  -0.0 9.42e+02    -  3.03e-02 3.45e-07f  2
#   95r-9.4397448e+03 9.58e+01 9.64e+02  -0.0 9.88e+02    -  1.35e-02 3.77e-02f  1
#   96r-9.4392220e+03 9.18e+01 9.47e+02  -0.0 2.05e+03    -  2.16e-02 1.78e-02f  1
#   97r-9.4388449e+03 8.91e+01 9.35e+02  -0.0 1.65e+03    -  2.25e-02 1.19e-02f  1
#   98r-9.4385885e+03 8.71e+01 9.26e+02  -0.0 1.28e+03    -  1.29e-02 1.03e-02f  1
#   99r-9.4378163e+03 8.31e+01 9.06e+02  -0.0 1.21e+03    -  1.96e-02 2.15e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100r-9.4377032e+03 8.29e+01 9.04e+02  -0.0 2.18e+03    -  1.70e-03 1.52e-03f  1
#  101r-9.4368230e+03 7.90e+01 9.33e+02  -0.0 1.12e+03    -  4.55e-03 2.50e-02f  1
#  102r-9.4367730e+03 7.89e+01 9.88e+02  -0.0 2.87e+04    -  4.04e-04 7.70e-05f  1
#  103r-9.4364813e+03 7.79e+01 8.81e+02  -0.0 1.10e+03    -  1.77e-02 8.08e-03f  1
#  104r-9.4348752e+03 7.32e+01 1.16e+03  -0.0 1.60e+01   0.0 6.57e-03 3.91e-02f  1
#  105r-9.4347982e+03 7.31e+01 1.31e+03  -0.0 4.76e+02  -0.5 3.74e-03 9.70e-04f  1
#  106r-9.4345601e+03 7.26e+01 1.34e+03  -0.0 1.05e+02  -1.0 7.50e-04 5.54e-03f  1
#  107r-9.4344914e+03 7.25e+01 1.39e+03  -0.0 5.64e+02  -0.5 2.52e-03 6.24e-04f  1
#  108r-9.4343140e+03 7.22e+01 1.38e+03  -0.0 4.80e+01  -0.1 3.23e-03 2.53e-03f  1
#  109r-9.4336536e+03 7.10e+01 1.27e+03  -0.0 1.95e+01   0.3 2.01e-02 1.31e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110r-9.4329928e+03 6.91e+01 1.28e+03  -0.0 2.48e+01  -0.2 1.93e-02 2.14e-02f  1
#  111r-9.4326860e+03 6.88e+01 1.23e+03  -0.0 4.89e+02  -0.6 8.53e-05 3.55e-03f  1
#  112r-9.4326935e+03 6.88e+01 1.27e+03  -0.0 7.52e+03  -0.2 9.96e-09 2.91e-05h  1
#  113r-9.4323307e+03 6.83e+01 1.31e+03  -0.0 3.28e+01   0.2 2.00e-02 6.09e-03f  1
#  114r-9.4322360e+03 6.82e+01 1.27e+03  -0.0 9.50e+01  -0.3 1.86e-04 1.74e-03f  1
#  115r-9.4320901e+03 6.80e+01 1.37e+03  -0.0 4.90e+01   0.2 9.58e-03 1.82e-03f  1
#  116r-9.4308014e+03 6.55e+01 1.63e+03  -0.0 1.12e+01   0.6 9.32e-03 3.62e-02f  1
#  117r-9.4307051e+03 6.53e+01 1.41e+03  -0.0 1.10e+01   0.1 2.76e-02 2.72e-03f  1
#  118r-9.4289079e+03 6.24e+01 1.47e+03  -0.0 1.18e+01   0.5 2.76e-02 4.83e-02f  1
#  119r-9.4285481e+03 6.15e+01 1.16e+03  -0.0 7.44e+00   1.0 5.17e-02 1.82e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120r-9.4283225e+03 6.05e+01 1.21e+03  -0.0 7.08e+00   0.5 1.23e-02 2.15e-02f  1
#  121r-9.4281757e+03 6.04e+01 1.29e+03  -0.0 3.24e+02   0.0 2.74e-03 1.10e-03f  1
#  122r-9.4282432e+03 5.98e+01 1.28e+03  -0.0 2.51e+01  -0.5 1.32e-02 1.51e-02f  1
#  123r-9.4284714e+03 5.75e+01 1.26e+03  -0.0 5.63e+00  -0.0 5.34e-02 6.05e-02f  1
#  124r-9.4286444e+03 5.63e+01 1.32e+03  -0.0 2.54e+01  -0.5 2.63e-02 4.21e-02f  1
#  125r-9.4288413e+03 5.57e+01 1.33e+03  -0.0 8.99e+01  -1.0 1.05e-02 1.97e-02f  1
#  126r-9.4289565e+03 5.57e+01 1.50e+03  -0.0 2.73e+02  -1.5 1.13e-02 3.28e-03f  1
#  127r-9.4290729e+03 5.56e+01 1.53e+03  -0.0 4.60e+01  -0.1 1.03e-02 2.23e-03f  1
#  128r-9.4290352e+03 5.49e+01 1.47e+03  -0.0 1.81e+01  -0.6 3.36e-02 2.84e-02f  1
#  129r-9.4291502e+03 5.49e+01 1.42e+03  -0.0 5.79e+02  -1.1 3.44e-04 1.18e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130r-9.4291356e+03 5.44e+01 1.38e+03  -0.0 7.68e+01  -1.6 3.56e-02 1.94e-02f  1
#  131r-9.4292070e+03 5.40e+01 1.30e+03  -0.0 1.54e+02  -2.0 3.63e-03 1.87e-02f  1
#  132r-9.4293668e+03 5.39e+01 1.34e+03  -0.0 1.67e+03    -  1.18e-02 5.04e-03f  1
#  133r-9.4296989e+03 5.38e+01 1.21e+03  -0.0 1.88e+03  -2.5 9.40e-04 4.08e-03f  1
#  134r-9.4295036e+03 5.32e+01 1.19e+03  -0.0 3.73e+02    -  1.02e-02 2.45e-02f  1
#  135r-9.4292106e+03 5.26e+01 1.17e+03  -0.0 3.72e+00   0.6 1.64e-01 3.34e-02f  1
#  136r-9.4285144e+03 5.12e+01 1.17e+03  -0.0 4.56e+00   0.1 1.04e-01 8.78e-02f  1
#  137r-9.4285043e+03 5.06e+01 3.74e+03  -0.0 1.55e+00   2.4 4.10e-01 5.29e-02f  1
#  138r-9.4284893e+03 5.02e+01 3.40e+03  -0.0 2.44e+00   1.9 1.11e-02 4.60e-02f  1
#  139r-9.4283132e+03 4.19e+01 3.08e+03  -0.7 5.44e-01   1.4 1.29e-01 1.75e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140r-9.4281791e+03 4.03e+01 2.71e+03  -0.7 1.33e+00   0.9 8.45e-02 4.66e-02f  1
#  141r-9.4266498e+03 3.44e+01 2.95e+03  -0.7 2.32e+00   0.5 5.75e-02 1.65e-01f  1
#  142r-9.4250938e+03 3.32e+01 2.93e+03  -0.7 9.47e+00  -0.0 3.16e-02 4.18e-02f  1
#  143r-9.4241262e+03 3.29e+01 3.18e+03  -0.7 4.91e+01   0.4 8.92e-03 1.36e-02f  1
#  144r-9.4241050e+03 3.26e+01 3.13e+03  -0.7 2.44e+00   1.7 1.25e-02 9.31e-03f  1
#  145r-9.4233207e+03 2.75e+01 2.12e+03  -0.7 7.93e-01   1.3 3.00e-01 1.80e-01f  1
#  146r-9.4231643e+03 2.65e+01 2.14e+03  -0.7 1.57e+00   1.7 2.97e-03 5.26e-02f  1
#  147r-9.4231078e+03 2.63e+01 1.72e+03  -0.7 1.06e+00   1.2 1.75e-01 1.09e-02f  1
#  148r-9.4223219e+03 2.50e+01 1.64e+03  -0.7 3.41e+00   0.7 2.78e-02 7.19e-02f  1
#  149r-9.4213119e+03 2.27e+01 1.84e+03  -0.7 1.79e+00   1.2 1.78e-02 1.31e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150r-9.4213007e+03 2.22e+01 1.15e+03  -0.7 4.06e-01   2.5 4.66e-01 3.88e-02f  1
#  151r-9.4206432e+03 1.26e+01 7.00e+02  -0.7 2.02e-01   2.0 3.38e-01 7.24e-01f  1
#  152 -9.4204529e+03 1.26e+01 7.55e+02  -6.0 8.36e+02    -  6.73e-04 1.86e-03h  1
#  153 -9.4203338e+03 1.26e+01 7.54e+02  -6.0 3.96e+02    -  3.13e-03 1.42e-03h  1
#  154 -9.4201275e+03 1.25e+01 7.52e+02  -6.0 4.05e+02    -  4.48e-03 2.90e-03h  1
#  155 -9.4199710e+03 1.25e+01 7.50e+02  -6.0 5.19e+02    -  2.36e-03 3.04e-03h  1
#  156 -9.4197437e+03 1.24e+01 7.47e+02  -6.0 8.86e+02    -  5.10e-04 8.29e-03h  2
#  157 -9.4200944e+03 1.23e+01 7.45e+02  -6.0 5.13e+02    -  1.63e-03 4.09e-03f  1
#  158 -9.4204357e+03 1.23e+01 7.44e+02  -6.0 5.10e+02    -  2.77e-03 3.74e-03f  1
#  159 -9.4205014e+03 1.23e+01 7.43e+02  -6.0 4.83e+02    -  1.66e-03 1.35e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160 -9.4205670e+03 1.23e+01 7.43e+02  -6.0 5.25e+02    -  3.97e-04 1.02e-03f  1
#  161 -9.4206032e+03 1.23e+01 7.42e+02  -6.0 5.63e+02    -  9.36e-04 4.85e-04f  1
#  162 -9.4207996e+03 1.22e+01 7.40e+02  -6.0 6.38e+02    -  2.56e-03 2.28e-03f  1
#  163 -9.4212642e+03 1.21e+01 1.77e+03  -6.0 5.66e+02    -  3.44e-03 6.58e-03f  1
#  164 -9.4218257e+03 1.20e+01 3.80e+03  -6.0 5.17e+02    -  3.74e-03 8.68e-03f  1
#  165 -9.4218228e+03 1.20e+01 3.80e+03  -6.0 3.64e+02    -  5.89e-04 1.86e-05h  1
#  166 -9.4215882e+03 1.20e+01 4.34e+03  -6.0 6.82e+02    -  2.64e-09 5.61e-03h  1
#  167 -9.4217310e+03 1.19e+01 3.54e+03  -6.0 6.34e+02    -  1.87e-04 5.87e-03h  1
#  168r-9.4217310e+03 1.19e+01 9.99e+02  -0.6 0.00e+00    -  0.00e+00 4.68e-08R  2
#  169r-9.4217311e+03 1.19e+01 9.99e+02  -0.6 1.16e+05    -  1.87e-09 3.92e-08f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170r-9.4217305e+03 1.19e+01 9.99e+02  -0.6 4.00e+02    -  2.25e-05 1.44e-05f  1
#  171r-9.4217286e+03 1.19e+01 9.99e+02  -0.6 3.94e+02    -  1.77e-05 4.85e-05f  1
#  172r-9.4217251e+03 1.19e+01 9.99e+02  -0.6 3.84e+02    -  8.03e-04 9.12e-05f  1
#  173r-9.4216652e+03 1.19e+01 9.97e+02  -0.6 3.07e+02    -  4.42e-03 1.69e-03f  1
#  174r-9.4215865e+03 1.19e+01 9.95e+02  -0.6 2.21e+02    -  9.44e-03 2.22e-03f  1
#  175r-9.4209947e+03 1.20e+01 9.79e+02  -0.6 2.23e+02    -  4.18e-02 1.60e-02f  1
#  176r-9.4191812e+03 1.20e+01 9.40e+02  -0.6 2.15e+02    -  9.04e-02 4.01e-02f  1
#  177r-9.4149417e+03 1.20e+01 1.00e+03  -0.6 2.00e+02    -  8.70e-02 7.75e-02f  1
#  178r-9.4148293e+03 1.20e+01 1.90e+03  -0.6 3.13e+01   0.0 3.81e-02 3.06e-03f  1
#  179r-9.4092524e+03 1.23e+01 1.63e+03  -0.6 2.18e+02    -  1.11e-01 1.19e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180r-9.4062076e+03 3.11e+01 1.42e+03  -0.6 2.26e+02    -  5.71e-02 7.64e-02f  1
#  181r-9.4057336e+03 3.08e+01 3.32e+03  -0.6 2.24e+02    -  6.15e-02 1.57e-02f  1
#  182r-9.4048621e+03 3.02e+01 3.36e+04  -0.6 2.23e+02    -  1.37e-01 2.67e-02f  1
#  183r-9.4034304e+03 2.90e+01 3.35e+04  -0.6 2.03e+02    -  7.14e-02 4.64e-02f  1
#  184r-9.4033207e+03 2.89e+01 3.21e+04  -0.6 5.34e+01  -0.5 7.69e-03 4.45e-03f  1
#  185r-9.4025673e+03 2.79e+01 2.55e+04  -0.6 2.15e+01  -1.0 6.58e-02 3.67e-02f  1
#  186r-9.3970221e+03 1.26e+01 3.90e+04  -0.6 2.78e+01  -1.4 5.40e-03 2.37e-01f  1
#  187r-9.3961901e+03 1.26e+01 7.84e+04  -0.6 3.94e+00  -0.1 2.93e-02 6.82e-02f  1
#  188r-9.3958295e+03 1.26e+01 7.40e+04  -0.6 2.28e+00   0.3 1.31e-01 7.69e-02f  1
#  189r-9.3957773e+03 1.26e+01 7.26e+04  -0.6 1.49e+00   0.7 3.44e-02 1.64e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190r-9.3957693e+03 1.26e+01 7.31e+04  -0.6 6.19e-01   2.1 3.88e-01 2.32e-02f  1
#  191r-9.3953304e+03 1.30e+01 1.64e+04  -0.6 3.44e-01   1.6 3.80e-01 7.74e-01f  1
#  192 -9.3949743e+03 1.29e+01 7.33e+02  -6.0 3.40e+02    -  1.21e-02 7.32e-03h  3
#  193 -9.3946203e+03 1.29e+01 7.56e+02  -6.0 3.39e+02    -  2.94e-02 4.75e-03h  4
#  194 -9.3937274e+03 1.28e+01 7.96e+02  -6.0 3.10e+02    -  5.47e-02 7.69e-03h  3
#  195 -9.3916742e+03 1.26e+01 8.03e+02  -6.0 2.20e+02    -  3.87e-02 1.03e-02h  2
#  196 -9.3890424e+03 1.25e+01 8.08e+02  -6.0 2.30e+02    -  3.95e-02 1.10e-02h  1
#  197 -9.3877281e+03 1.24e+01 8.27e+02  -6.0 1.61e+02    -  2.32e-02 5.04e-03h  2
#  198 -9.3854983e+03 1.23e+01 8.75e+02  -6.0 1.76e+02    -  3.31e-02 8.27e-03h  3
#  199 -9.3835447e+03 1.22e+01 9.50e+02  -6.0 2.16e+02    -  2.80e-02 8.03e-03h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200 -9.3820099e+03 1.21e+01 1.07e+03  -6.0 2.41e+02    -  3.35e-02 7.74e-03h  4
#  201 -9.3814816e+03 1.20e+01 1.53e+03  -6.0 2.53e+02    -  9.44e-02 3.23e-03h  5
#  202 -9.3809762e+03 1.20e+01 1.89e+03  -6.0 2.58e+02    -  5.42e-02 3.30e-03h  5
#  203 -9.3804485e+03 1.20e+01 2.58e+03  -6.0 2.52e+02    -  8.79e-02 3.25e-03h  5
#  204 -9.3798676e+03 1.19e+01 3.23e+03  -6.0 2.40e+02    -  6.61e-02 3.14e-03h  5
#  205 -9.3792374e+03 1.19e+01 4.48e+03  -6.0 2.30e+02    -  1.11e-01 3.09e-03h  5
#  206 -9.3784172e+03 1.18e+01 5.53e+03  -6.0 2.08e+02    -  7.86e-02 3.37e-03h  5
#  207 -9.3594252e+03 1.08e+01 8.84e+03  -6.0 1.90e+02    -  9.91e-02 6.80e-02w  1
#  208 -9.3556819e+03 1.07e+01 2.23e+04  -6.0 1.57e+02  -2.0 5.45e-02 1.08e-02w  1
#  209 -9.3503849e+03 1.05e+01 2.60e+04  -6.0 2.10e+02  -2.5 6.46e-02 1.94e-02w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210 -9.3772302e+03 1.18e+01 7.00e+03  -6.0 3.00e+02    -  9.91e-02 4.25e-03h  4
#  211 -9.3736767e+03 1.17e+01 7.06e+03  -6.0 2.38e+02    -  1.82e-02 7.64e-03h  5
#  212 -9.3731330e+03 1.17e+01 6.87e+03  -6.0 1.44e+03    -  3.68e-03 3.16e-04h  7
#  213 -9.3726054e+03 1.17e+01 6.26e+03  -6.0 1.75e+03    -  8.81e-03 2.58e-04h  7
#  214 -9.3706374e+03 1.16e+01 6.65e+03  -6.0 2.63e+02  -3.0 9.62e-02 3.94e-03h  6
#  215 -9.3689243e+03 1.16e+01 6.58e+03  -6.0 4.74e+02  -3.4 1.34e-02 2.41e-03h  6
#  216 -9.3682162e+03 1.16e+01 6.24e+03  -6.0 8.92e+02  -3.9 1.42e-02 6.34e-04h  7
#  217 -9.3664370e+03 1.16e+01 6.02e+03  -6.0 4.47e+02  -3.5 6.70e-02 2.66e-03h  6
#  218 -9.3643203e+03 1.15e+01 6.37e+03  -6.0 2.63e+02  -3.1 9.99e-02 4.32e-03h  6
#  219 -9.3626163e+03 1.15e+01 6.24e+03  -6.0 5.47e+02  -3.5 2.06e-02 2.32e-03h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220 -9.3007589e+03 1.12e+01 9.33e+03  -6.0 2.48e+02  -3.1 1.03e-01 1.31e-01w  1
#  221 -9.3008394e+03 1.12e+01 9.33e+03  -6.0 1.60e+03  -3.6 1.66e-02 8.40e-05w  1
#  222 -9.3173064e+03 1.21e+01 9.04e+03  -6.0 3.35e+03    -  1.82e-02 6.59e-03w  1
#  223 -9.3606832e+03 1.15e+01 8.92e+03  -6.0 3.04e+02    -  1.03e-01 4.08e-03h  5
#  224 -9.3587955e+03 1.14e+01 1.01e+04  -6.0 2.44e+02  -3.2 4.09e-02 3.94e-03h  6
#  225 -9.3586682e+03 1.14e+01 9.37e+03  -6.0 2.34e+03  -3.6 4.61e-03 6.36e-05h  8
#  226 -9.3569861e+03 1.14e+01 1.26e+04  -6.0 1.82e+02  -3.2 9.27e-02 3.91e-03h  6
#  227 -9.3554765e+03 1.13e+01 1.60e+04  -6.0 1.67e+02  -2.8 7.55e-02 3.56e-03h  6
#  228 -9.3538215e+03 1.13e+01 1.76e+04  -6.0 1.73e+02  -3.3 4.18e-02 4.05e-03h  5
#  229 -9.3523356e+03 1.12e+01 2.10e+04  -6.0 1.59e+02  -2.8 7.58e-02 3.53e-03h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230 -9.3498451e+03 1.11e+01 2.24e+04  -6.0 2.55e+02  -3.3 3.27e-02 8.44e-03h  2
#  231 -9.3477407e+03 1.11e+01 2.55e+04  -6.0 1.65e+02  -2.9 7.31e-02 5.40e-03h  4
#  232 -9.3462081e+03 1.10e+01 3.37e+04  -6.0 1.50e+02  -2.5 1.20e-01 3.91e-03h  5
#  233 -9.3355608e+03 1.08e+01 3.53e+04  -6.0 1.56e+02  -2.9 7.01e-02 2.56e-02w  1
#  234 -9.3355640e+03 1.08e+01 3.75e+04  -6.0 1.79e+03    -  7.88e-03 2.15e-06w  1
#  235 -9.3339111e+03 1.04e+01 4.29e+04  -6.0 2.57e+02    -  1.07e-01 3.60e-02w  1
#  236 -9.3435463e+03 1.10e+01 3.70e+04  -6.0 5.26e+02  -3.4 7.01e-02 6.41e-03h  2
#  237 -9.3405782e+03 1.09e+01 4.15e+04  -6.0 1.58e+02  -3.0 8.91e-02 7.36e-03h  2
#  238 -9.3390361e+03 1.08e+01 4.73e+04  -6.0 1.50e+02  -2.6 8.00e-02 3.78e-03h  3
#  239 -9.3367224e+03 1.08e+01 5.14e+04  -6.0 1.54e+02  -3.0 6.40e-02 5.55e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240 -9.3365486e+03 1.08e+01 5.16e+04  -6.0 6.10e+02    -  3.14e-03 3.70e-04h  1
#  241 -9.3343008e+03 1.07e+01 5.77e+04  -6.0 2.53e+02    -  1.02e-01 4.63e-03h  5
#  242 -9.3320148e+03 1.07e+01 6.31e+04  -6.0 2.44e+02    -  6.99e-02 4.66e-03h  5
#  243 -9.3298767e+03 1.06e+01 7.79e+04  -6.0 2.29e+02    -  1.49e-01 4.41e-03h  5
#  244 -9.3277730e+03 1.06e+01 8.30e+04  -6.0 1.85e+02    -  3.77e-02 4.05e-03h  5
#  245 -9.3261066e+03 1.06e+01 1.10e+05  -6.0 2.01e+02  -2.6 1.47e-01 3.80e-03h  6
#  246 -9.3236237e+03 1.05e+01 1.14e+05  -6.0 3.11e+02  -3.1 2.17e-02 4.10e-03h  4
#  247 -9.3207242e+03 1.04e+01 1.31e+05  -6.0 2.33e+02  -2.7 7.52e-02 5.95e-03h  6
#  248 -9.3207062e+03 1.04e+01 1.33e+05  -6.0 1.29e+03  -3.1 5.57e-03 2.16e-05h  1
#  249 -9.3190458e+03 1.04e+01 1.31e+05  -6.0 2.47e+02  -2.7 6.01e-04 3.30e-03h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250 -9.3161752e+03 1.03e+01 1.75e+05  -6.0 2.05e+02  -2.3 1.34e-01 6.94e-03h  5
#  251 -9.3135995e+03 1.03e+01 2.03e+05  -6.0 2.63e+02  -2.8 9.06e-02 4.70e-03h  6
#  252 -9.3111762e+03 1.02e+01 3.18e+05  -6.0 2.41e+02  -2.3 2.46e-01 5.20e-03h  6
#  253 -9.3089351e+03 1.02e+01 3.36e+05  -6.0 2.97e+02  -2.8 4.09e-02 3.53e-03h  3
#  254 -9.3070746e+03 1.02e+01 3.50e+05  -6.0 2.77e+02  -2.4 2.71e-02 3.35e-03h  7
#  255 -9.3045019e+03 1.01e+01 4.06e+05  -6.0 2.25e+02  -2.0 6.77e-02 5.35e-03h  4
#  256 -9.2978790e+03 1.00e+01 4.09e+05  -6.0 2.54e+02  -2.4 2.11e-02 9.83e-03h  5
#  257 -9.2953009e+03 9.96e+00 4.72e+05  -6.0 2.24e+02  -2.0 7.69e-02 4.75e-03h  6
#  258 -9.2904910e+03 9.90e+00 4.80e+05  -6.0 2.41e+02  -2.5 2.59e-02 6.69e-03h  5
#  259 -9.1279789e+03 1.59e+01 6.34e+05  -6.0 2.26e+02  -2.1 3.89e-02 2.65e-01w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260 -9.1279764e+03 1.59e+01 6.34e+05  -6.0 1.12e+02  -1.6 5.30e-02 2.55e-05w  1
#  261 -9.1274516e+03 1.58e+01 6.33e+05  -6.0 1.21e+02  -1.2 8.86e-02 2.60e-03w  1
#  262 -9.2854125e+03 9.81e+00 5.04e+05  -6.0 2.09e+02  -1.7 3.89e-02 8.27e-03h  5
#  263 -9.2804018e+03 9.74e+00 6.25e+05  -6.0 2.26e+02  -2.2 1.59e-01 7.60e-03h  6
#  264 -9.2769536e+03 9.68e+00 8.03e+05  -6.0 2.09e+02  -1.7 1.28e-01 6.33e-03h  4
#  265 -9.2740301e+03 9.64e+00 8.39e+05  -6.0 2.37e+02  -2.2 4.48e-02 3.75e-03h  6
#  266 -9.2691412e+03 9.56e+00 1.18e+06  -6.0 2.25e+02  -1.8 2.21e-01 8.05e-03h  5
#  267 -9.2666469e+03 9.54e+00 1.20e+06  -6.0 2.27e+02  -2.3 3.20e-02 2.72e-03h  6
#  268 -9.2640229e+03 9.50e+00 1.51e+06  -6.0 2.41e+02  -1.8 1.74e-01 3.80e-03h  7
#  269 -9.2615100e+03 9.48e+00 1.52e+06  -6.0 3.04e+02  -2.3 2.46e-02 2.29e-03h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270 -9.2593407e+03 9.45e+00 1.87e+06  -6.0 2.50e+02  -1.9 1.82e-01 2.84e-03h  7
#  271 -9.2592893e+03 9.45e+00 1.87e+06  -6.0 2.05e+03  -2.4 2.44e-03 1.43e-04h  6
#  272 -9.1491972e+03 8.09e+00 1.57e+06  -6.0 2.56e+02  -1.9 8.79e-02 1.30e-01w  1
#  273 -9.1080506e+03 7.31e+00 1.20e+06  -6.0 1.64e+02  -1.5 2.79e-05 9.16e-02w  1
#  274 -9.1080506e+03 7.31e+00 1.31e+06  -6.0 1.53e+02  -1.1 3.77e-02 3.20e-07w  1
#  275 -9.2558489e+03 9.41e+00 2.02e+06  -6.0 1.76e+02  -1.6 8.79e-02 4.07e-03h  5
#  276 -9.2530110e+03 9.38e+00 2.19e+06  -6.0 2.51e+02  -2.1 1.06e-01 2.98e-03h  6
#  277 -9.2503978e+03 9.35e+00 2.50e+06  -6.0 2.44e+02  -1.6 9.50e-02 3.78e-03h  7
#  278 -9.2477482e+03 9.32e+00 2.57e+06  -6.0 2.98e+02  -2.1 5.61e-02 2.41e-03h  6
#  279 -9.2451027e+03 9.29e+00 2.55e+06  -6.0 2.50e+02  -1.7 2.71e-03 3.49e-03h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280 -9.2448610e+03 9.29e+00 2.62e+06  -6.0 3.68e+02  -2.2 6.17e-02 2.18e-04h  1
#  281 -9.2422277e+03 9.26e+00 2.60e+06  -6.0 2.54e+02  -1.7 2.07e-06 3.36e-03h  7
#  282 -9.2389269e+03 9.21e+00 3.09e+06  -6.0 1.91e+02  -1.3 9.82e-02 5.46e-03h  4
#  283 -9.2349445e+03 9.17e+00 3.08e+06  -6.0 2.40e+02  -1.8 5.72e-03 4.29e-03h  6
#  284 -9.2324272e+03 9.13e+00 3.05e+06  -6.0 2.02e+02  -1.4 1.06e-03 3.79e-03h  5
#  285 -9.2287419e+03 9.10e+00 3.22e+06  -6.0 2.45e+02  -1.8 7.84e-02 3.87e-03h  1
#  286 -9.2251924e+03 9.05e+00 3.18e+06  -6.0 2.05e+02  -1.4 1.07e-06 5.14e-03h  5
#  287 -9.2248268e+03 9.05e+00 3.27e+06  -6.0 2.73e+02  -1.9 4.34e-02 3.64e-04h  1
#  288 -9.2223323e+03 9.02e+00 3.24e+06  -6.0 2.07e+02  -1.5 9.97e-06 3.49e-03h  6
#  289 -9.2194405e+03 8.99e+00 3.37e+06  -6.0 3.03e+02  -1.9 7.35e-02 2.74e-03h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290 -9.2157396e+03 8.95e+00 3.33e+06  -6.0 2.11e+02  -1.5 1.19e-03 4.89e-03h  6
#  291 -9.2120966e+03 8.89e+00 3.64e+06  -6.0 1.67e+02  -1.1 4.86e-02 6.54e-03h  3
#  292 -9.2081853e+03 8.84e+00 3.68e+06  -6.0 2.12e+02  -1.6 1.81e-02 4.90e-03h  6
#  293 -9.2047516e+03 8.79e+00 4.45e+06  -6.0 1.71e+02  -1.1 1.11e-01 5.87e-03h  3
#  294 -9.2007282e+03 8.75e+00 4.58e+06  -6.0 2.23e+02  -1.6 4.30e-02 4.52e-03h  6
#  295 -9.1961459e+03 8.69e+00 6.03e+06  -6.0 1.86e+02  -1.2 1.97e-01 7.05e-03h  3
#  296 -9.1926355e+03 8.66e+00 6.08e+06  -6.0 2.76e+02  -1.7 2.51e-02 3.39e-03h  6
#  297 -9.1899351e+03 8.63e+00 6.33e+06  -6.0 2.07e+02  -1.2 3.70e-02 3.62e-03h  5
#  298 -9.0880623e+03 7.76e+00 5.65e+06  -6.0 3.04e+02  -1.7 5.01e-02 9.29e-02w  1
#  299 -9.0868893e+03 7.75e+00 6.14e+06  -6.0 1.71e+02  -1.3 7.64e-02 1.61e-03w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300 -9.0850274e+03 7.73e+00 6.12e+06  -6.0 1.53e+02  -0.9 3.31e-03 3.20e-03w  1
#  301 -9.1867516e+03 8.60e+00 6.43e+06  -6.0 1.84e+02  -1.3 5.01e-02 2.90e-03h  5
#  302 -9.1865421e+03 8.60e+00 6.42e+06  -6.0 3.56e+03  -1.8 7.74e-04 8.57e-04h  2
#  303 -9.1828159e+03 8.56e+00 6.94e+06  -6.0 2.21e+02  -1.4 9.14e-02 4.45e-03h  5
#  304 -9.1795169e+03 8.51e+00 8.44e+06  -6.0 1.81e+02  -1.0 1.23e-01 5.23e-03h  3
#  305 -9.1760410e+03 8.48e+00 8.59e+06  -6.0 2.43e+02  -1.4 3.65e-02 3.66e-03h  5
#  306 -9.1713592e+03 8.43e+00 1.01e+07  -6.0 1.97e+02  -1.0 1.26e-01 6.73e-03h  3
#  307 -9.1685037e+03 8.40e+00 1.01e+07  -6.0 2.81e+02  -1.5 2.33e-02 2.75e-03h  5
#  308 -9.1643946e+03 8.36e+00 1.42e+07  -6.0 2.10e+02  -1.1 3.33e-01 5.42e-03h  4
#  309 -9.1616029e+03 8.34e+00 1.42e+07  -6.0 3.48e+02  -1.5 1.41e-02 2.39e-03h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310 -9.1568508e+03 8.29e+00 1.50e+07  -6.0 2.38e+02  -1.1 7.69e-02 5.41e-03h  4
#  311 -9.1004782e+03 7.88e+00 1.43e+07  -6.0 3.81e+02  -1.6 1.77e-02 4.78e-02w  1
#  312 -9.0971009e+03 7.85e+00 1.66e+07  -6.0 2.43e+02  -1.2 2.22e-01 3.80e-03w  1
#  313 -9.0574342e+03 7.38e+00 1.57e+07  -6.0 2.00e+02  -0.7 5.78e-02 5.77e-02w  1
#  314 -9.1533275e+03 8.27e+00 1.50e+07  -6.0 2.31e+02  -1.2 1.77e-02 2.99e-03h  4
#  315 -9.1524250e+03 8.25e+00 1.49e+07  -6.0 9.81e+02  -1.7 1.39e-02 1.36e-03h  4
#  316 -9.1488330e+03 8.22e+00 1.62e+07  -6.0 2.71e+02  -1.3 1.60e-01 3.72e-03h  5
#  317 -9.1453346e+03 8.18e+00 2.33e+07  -6.0 2.14e+02  -0.8 3.16e-01 4.89e-03h  4
#  318 -9.1403900e+03 8.15e+00 2.33e+07  -6.0 3.47e+02  -1.3 2.18e-02 4.55e-03h  5
#  319 -9.1345270e+03 8.09e+00 2.93e+07  -6.0 2.45e+02  -0.9 2.77e-01 7.22e-03h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320 -9.1298946e+03 8.05e+00 2.92e+07  -6.0 3.83e+02  -1.4 2.06e-02 3.95e-03h  4
#  321 -9.1250479e+03 8.01e+00 3.36e+07  -6.0 2.64e+02  -0.9 2.18e-01 5.41e-03h  4
#  322 -9.1228959e+03 8.00e+00 3.35e+07  -6.0 3.90e+02  -1.4 2.27e-02 1.76e-03h  4
#  323 -9.1194305e+03 7.97e+00 3.70e+07  -6.0 2.89e+02  -1.0 1.86e-01 3.61e-03h  4
#  324 -9.1106591e+03 7.91e+00 3.67e+07  -6.0 3.69e+02  -1.5 2.40e-02 6.91e-03w  1
#  325 -9.1076388e+03 7.89e+00 3.88e+07  -6.0 3.04e+02  -1.0 1.31e-01 2.96e-03w  1
#  326 -9.0640267e+03 7.42e+00 3.92e+07  -6.0 2.34e+02  -0.6 1.08e-01 5.66e-02w  1
#  327 -9.1172376e+03 7.95e+00 3.68e+07  -6.0 2.87e+02  -1.1 2.40e-02 1.73e-03h  2
#  328 -9.1112202e+03 7.89e+00 4.40e+07  -6.0 2.39e+02  -0.7 1.83e-01 7.79e-03h  2
#  329 -9.1080555e+03 7.87e+00 4.43e+07  -6.0 3.31e+02  -1.1 4.11e-02 2.81e-03h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330 -9.1040496e+03 7.83e+00 5.10e+07  -6.0 2.57e+02  -0.7 1.77e-01 4.72e-03h  4
#  331 -9.0995716e+03 7.80e+00 5.10e+07  -6.0 3.25e+02  -1.2 3.40e-02 3.66e-03h  5
#  332 -9.0934974e+03 7.75e+00 5.49e+07  -6.0 2.73e+02  -0.8 1.18e-01 6.57e-03h  6
#  333 -9.0895538e+03 7.73e+00 5.48e+07  -6.0 3.22e+02  -1.3 3.73e-02 3.01e-03h  5
#  334 -9.0853820e+03 7.70e+00 6.36e+07  -6.0 2.84e+02  -0.8 2.62e-01 4.28e-03h  6
#  335 -9.0784567e+03 7.66e+00 6.33e+07  -6.0 3.33e+02  -1.3 1.73e-02 4.58e-03h  4
#  336 -9.0729705e+03 7.62e+00 6.40e+07  -6.0 3.03e+02  -0.9 3.64e-02 5.19e-03h  5
#  337 -9.0315109e+03 7.19e+00 6.57e+07  -6.0 2.36e+02  -0.5 1.17e-01 5.36e-02w  1
#  338 -8.9375898e+03 6.63e+00 5.96e+07  -6.0 2.48e+02  -0.9 4.41e-07 7.38e-02w  1
#  339 -8.9375897e+03 6.63e+00 6.65e+07  -6.0 1.68e+02  -0.5 1.28e-01 1.56e-07w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340 -9.0677881e+03 7.57e+00 7.23e+07  -6.0 7.83e+02  -1.0 1.17e-01 6.70e-03h  3
#  341 -9.0611639e+03 7.51e+00 9.56e+07  -6.0 2.61e+02  -0.6 3.59e-01 7.66e-03h  6
#  342 -9.0577771e+03 7.49e+00 9.54e+07  -6.0 3.48e+02  -1.0 8.87e-03 2.55e-03h  5
#  343 -9.0532299e+03 7.46e+00 1.10e+08  -6.0 2.96e+02  -0.6 2.37e-01 4.67e-03h  6
#  344 -9.0503376e+03 7.44e+00 1.10e+08  -6.0 3.52e+02  -1.1 1.14e-02 1.95e-03h  5
#  345 -9.0447971e+03 7.40e+00 1.15e+08  -6.0 3.18e+02  -0.7 8.81e-02 5.30e-03h  5
#  346 -9.0436211e+03 7.40e+00 1.14e+08  -6.0 1.08e+03  -1.1 1.22e-02 5.56e-04h  6
#  347 -9.0393104e+03 7.37e+00 1.27e+08  -6.0 3.28e+02  -0.7 2.34e-01 3.94e-03h  5
#  348 -9.0355027e+03 7.33e+00 1.41e+08  -6.0 2.55e+02  -0.3 1.02e-01 4.76e-03h  3
#  349 -9.0321517e+03 7.31e+00 1.42e+08  -6.0 3.51e+02  -0.8 3.98e-02 2.83e-03h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350 -9.0146781e+03 7.16e+00 1.72e+08  -6.0 2.74e+02  -0.3 2.57e-01 2.04e-02w  1
#  351 -8.9662226e+03 6.90e+00 1.65e+08  -6.0 3.49e+02  -0.8 5.12e-07 3.56e-02w  1
#  352 -8.8590620e+03 6.06e+00 1.71e+08  -6.0 2.72e+02  -0.4 3.42e-01 1.11e-01w  1
#  353 -9.0277833e+03 7.28e+00 1.76e+08  -6.0 1.84e+02   0.0 2.57e-01 5.10e-03h  2
#  354 -9.0242825e+03 7.25e+00 1.79e+08  -6.0 3.10e+02  -0.4 2.93e-02 3.64e-03h  6
#  355 -9.0219050e+03 7.24e+00 1.79e+08  -6.0 3.59e+02  -0.9 2.82e-02 1.57e-03h  5
#  356 -9.0169042e+03 7.20e+00 1.83e+08  -6.0 3.18e+02  -0.5 5.49e-02 5.00e-03h  5
#  357 -9.0158632e+03 7.20e+00 1.83e+08  -6.0 7.86e+02  -1.0 1.92e-02 5.20e-04h  6
#  358 -9.0121055e+03 7.17e+00 2.19e+08  -6.0 3.26e+02  -0.5 4.02e-01 3.61e-03h  5
#  359 -9.0098708e+03 7.15e+00 2.34e+08  -6.0 2.33e+02  -0.1 8.60e-02 3.26e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360 -9.0050343e+03 7.12e+00 2.33e+08  -6.0 3.36e+02  -0.6 9.23e-06 4.48e-03h  4
#  361r-9.0050343e+03 7.12e+00 1.00e+03  -0.4 0.00e+00  -0.2 0.00e+00 2.59e-07R  5
#  362r-9.0050347e+03 7.12e+00 1.10e+03  -0.4 1.79e+05    -  2.03e-03 1.15e-06f  2
#  363r-9.0036311e+03 7.21e+00 2.41e+03  -0.4 2.29e+02    -  6.11e-02 3.03e-03f  1
#  364 -9.0045218e+03 6.88e+00 1.14e+03  -6.0 2.19e+02    -  4.37e-02 4.33e-02f  1
#  365 -9.0045233e+03 6.88e+00 2.73e+04  -6.0 2.30e+02    -  1.94e-01 2.34e-05h  1
#  366 -9.0056951e+03 6.73e+00 3.19e+04  -6.0 2.34e+02    -  7.17e-02 2.02e-02f  4
#  367 -9.0063674e+03 6.68e+00 4.01e+04  -6.0 2.38e+02    -  1.14e-01 8.41e-03f  5
#  368 -9.0069790e+03 6.64e+00 4.01e+04  -6.0 2.81e+02    -  8.15e-03 4.90e-03f  4
#  369 -9.0075661e+03 6.61e+00 4.85e+04  -6.0 2.79e+02    -  1.55e-01 4.60e-03f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370 -9.0082872e+03 6.56e+00 4.95e+04  -6.0 2.63e+02    -  3.95e-02 7.43e-03f  4
#  371 -9.0133073e+03 6.20e+00 5.08e+04  -6.0 2.55e+02    -  1.53e-01 5.28e-02f  1
#  372 -9.0181814e+03 6.11e+00 4.99e+04  -6.0 5.17e+02    -  6.74e-03 1.51e-02f  1
#  373 -9.0185455e+03 6.08e+00 5.71e+04  -6.0 2.23e+02    -  2.37e-01 3.43e-03f  1
#  374 -9.0362463e+03 9.13e+00 5.09e+04  -6.0 2.62e+02    -  1.29e-01 1.34e-01f  1
#  375 -9.0828825e+03 2.52e+01 1.46e+05  -6.0 2.33e+02    -  1.79e-01 2.42e-01f  1
#  376 -9.1198046e+03 2.37e+01 1.32e+05  -6.0 3.68e+02    -  2.95e-03 6.32e-02f  1
#  377 -9.1199183e+03 2.37e+01 1.32e+05  -6.0 2.15e+02    -  1.26e-01 4.48e-04f  1
#  378 -9.1792577e+03 2.42e+01 7.00e+04  -6.0 2.16e+02    -  5.26e-02 2.37e-01f  1
#  379 -9.1792581e+03 2.42e+01 7.00e+04  -6.0 2.54e+02    -  1.18e-01 1.22e-06h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380 -9.1798369e+03 2.41e+01 7.08e+04  -6.0 4.33e+02    -  1.04e-02 2.83e-03f  1
#  381 -9.2367778e+03 2.46e+01 9.96e+04  -6.0 2.03e+02    -  1.22e-07 1.24e-01f  1
#  382 -9.2368039e+03 2.46e+01 9.96e+04  -6.0 1.45e+03    -  9.36e-05 2.27e-05f  1
#  383 -9.2542890e+03 2.50e+01 1.31e+05  -6.0 1.48e+03    -  5.12e-03 1.50e-02f  1
#  384 -9.2543981e+03 2.50e+01 1.62e+05  -6.0 1.49e+02  -0.6 2.09e-04 8.27e-04h  1
#  385 -9.2580585e+03 2.45e+01 4.45e+05  -6.0 1.42e+02  -1.1 3.37e-07 2.11e-02f  1
#  386 -9.2626992e+03 2.38e+01 5.26e+05  -6.0 1.40e+02  -1.6 4.25e-03 2.35e-02f  1
#  387 -9.2692267e+03 2.24e+01 5.91e+05  -6.0 1.44e+02  -2.1 1.86e-08 5.07e-02f  1
#  388 -9.2734309e+03 2.12e+01 5.97e+05  -6.0 1.43e+02  -2.5 1.97e-02 4.77e-02f  1
#  389 -9.2788673e+03 1.95e+01 5.55e+05  -6.0 1.41e+02  -3.0 3.19e-03 6.08e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390 -9.2853310e+03 1.70e+01 4.89e+05  -6.0 1.36e+02  -2.6 8.50e-04 9.55e-02f  1
#  391 -9.2853316e+03 1.70e+01 4.89e+05  -6.0 1.46e+02  -3.1 9.92e-02 9.85e-06h  1
#  392 -9.2861450e+03 1.66e+01 4.77e+05  -6.0 1.29e+02  -2.7 2.99e-02 2.37e-02f  1
#  393 -9.2870468e+03 1.63e+01 4.67e+05  -6.0 1.43e+02  -3.1 4.89e-02 2.04e-02f  1
#  394 -9.2873673e+03 1.62e+01 4.65e+05  -6.0 4.75e+03  -3.6 3.73e-03 3.37e-03f  1
#  395 -9.2873673e+03 1.62e+01 4.93e+05  -6.0 2.72e+03  -4.1 7.39e-04 2.31e-08h  2
#  396 -9.2901943e+03 1.54e+01 4.62e+05  -6.0 3.65e+02  -3.7 5.03e-02 5.05e-02f  1
#  397 -9.2939944e+03 1.45e+01 4.75e+05  -6.0 1.24e+03    -  4.02e-03 5.92e-02f  1
#  398 -9.3024610e+03 1.29e+01 5.19e+05  -6.0 9.64e+01    -  3.50e-02 1.16e-01f  1
#  399 -9.3176751e+03 1.12e+01 7.01e+05  -6.0 1.68e+02    -  3.64e-02 1.49e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400 -9.3288899e+03 1.00e+01 6.24e+05  -6.0 9.93e+01    -  4.76e-06 1.12e-01f  1
#  401 -9.3418337e+03 8.91e+00 5.43e+05  -6.0 9.82e+01    -  1.11e-01 1.29e-01f  1
#  402 -9.3675872e+03 7.34e+00 4.01e+05  -6.0 1.11e+02    -  2.22e-01 2.65e-01f  1
#  403 -9.3806172e+03 7.20e+00 3.71e+05  -6.0 2.82e+02    -  6.44e-02 7.58e-02f  1
#  404 -9.3806181e+03 7.20e+00 3.71e+05  -6.0 1.60e+02    -  8.57e-02 1.50e-05h  1
#  405 -9.4018991e+03 6.87e+00 2.45e+05  -6.0 1.57e+02    -  1.20e-01 3.47e-01f  1
#  406 -9.4019016e+03 6.87e+00 2.45e+05  -6.0 1.73e+02    -  4.46e-02 4.47e-05h  1
#  407 -9.4083644e+03 6.17e+00 2.17e+05  -6.0 1.69e+02    -  5.87e-02 1.19e-01f  1
#  408 -9.4237324e+03 6.12e+00 2.06e+05  -6.0 1.70e+02    -  2.75e-01 2.53e-01f  1
#  409 -9.4237325e+03 6.12e+00 2.06e+05  -6.0 1.56e+02    -  7.09e-04 3.21e-07h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410 -9.4332400e+03 5.53e+00 1.86e+05  -6.0 2.44e+02    -  7.39e-03 1.47e-01f  1
#  411 -9.4447578e+03 4.34e+00 1.94e+05  -6.0 3.28e+02    -  5.24e-02 1.67e-01f  1
#  412 -9.4481912e+03 4.06e+00 1.84e+05  -6.0 1.97e+02    -  2.39e-06 6.78e-02f  1
#  413 -9.4481913e+03 4.06e+00 1.84e+05  -6.0 3.63e+02    -  1.71e-03 1.70e-06h  1
#  414 -9.4489583e+03 3.88e+00 1.75e+05  -6.0 1.34e+02    -  1.13e-03 4.77e-02f  1
#  415 -9.4493396e+03 3.78e+00 1.71e+05  -6.0 1.21e+02    -  4.88e-02 2.73e-02h  1
#  416 -9.4521947e+03 3.22e+00 1.51e+05  -6.0 1.21e+02    -  1.20e-01 2.11e-01f  1
#  417 -9.4542074e+03 2.72e+00 1.46e+05  -6.0 1.16e+02    -  3.19e-01 1.91e-01f  1
#  418 -9.4543921e+03 2.67e+00 1.43e+05  -6.0 8.56e+01    -  5.29e-01 2.11e-02h  1
#  419 -9.4589481e+03 1.77e+00 2.38e+05  -6.0 5.78e+01    -  3.93e-01 5.71e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420 -9.4590682e+03 1.73e+00 2.33e+05  -6.0 3.69e+02    -  2.79e-01 2.16e-02h  1
#  421 -9.4615474e+03 9.75e-01 1.69e+05  -6.0 7.46e+01    -  5.94e-01 5.03e-01f  1
#  422 -9.4624097e+03 8.59e-01 1.34e+05  -6.0 1.26e+02    -  2.25e-01 2.29e-01h  1
#  423 -9.4624169e+03 8.54e-01 1.33e+05  -6.0 6.33e+01  -4.1 8.11e-01 5.61e-03h  1
#  424 -9.4624393e+03 8.48e-01 1.32e+05  -6.0 1.54e+02    -  2.18e-03 7.21e-03h  1
#  425 -9.4624435e+03 8.42e-01 1.31e+05  -6.0 6.77e+02  -4.6 8.93e-02 4.86e-03h  1
#  426 -9.4625408e+03 7.45e-01 1.17e+05  -6.0 1.82e+02    -  2.18e-02 1.12e-01h  1
#  427 -9.4626959e+03 5.24e-01 8.48e+04  -6.0 2.02e+01    -  4.50e-01 3.02e-01h  1
#  428 -9.4626975e+03 5.21e-01 8.44e+04  -6.0 3.42e+01  -4.2 2.42e-01 5.52e-03h  1
#  429 -9.4627144e+03 4.91e-01 7.95e+04  -6.0 1.97e+01  -4.7 8.31e-01 5.79e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430 -9.4627672e+03 3.97e-01 6.47e+04  -6.0 1.61e+01    -  1.46e-01 1.94e-01h  1
#  431 -9.4628030e+03 3.32e-01 5.43e+04  -6.0 1.35e+01    -  8.67e-01 1.65e-01h  1
#  432 -9.4628294e+03 2.83e-01 4.64e+04  -6.0 1.10e+01    -  3.95e-01 1.49e-01h  1
#  433 -9.4629335e+03 8.99e-02 1.84e+04  -6.0 9.48e+00    -  8.64e-01 6.94e-01h  1
#  434 -9.4629430e+03 6.97e-02 2.80e+04  -6.0 3.18e+00    -  2.34e-01 2.26e-01h  1
#  435 -9.4629616e+03 5.78e-02 5.11e+04  -6.0 6.70e+01    -  1.32e-02 1.72e-01f  1
#  436 -9.4629765e+03 4.77e-02 2.58e+04  -6.0 6.39e+01    -  2.01e-01 1.77e-01f  1
#  437 -9.4629840e+03 2.27e-02 3.83e+04  -6.0 1.02e+01    -  6.60e-01 5.25e-01f  1
#  438 -9.4629907e+03 1.39e-02 1.84e+04  -6.0 8.87e+00    -  1.00e+00 3.90e-01h  1
#  439 -9.4629951e+03 7.33e-03 7.45e+03  -6.0 4.36e+00    -  1.00e+00 4.73e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440 -9.4629984e+03 2.38e-03 1.09e+03  -6.0 2.41e+00    -  1.00e+00 6.76e-01f  1
#  441 -9.4629991e+03 1.26e-03 4.82e+02  -6.0 1.10e+00    -  1.00e+00 4.71e-01f  1
#  442 -9.4629997e+03 3.64e-04 1.32e+02  -6.0 3.28e-01    -  1.00e+00 7.11e-01f  1
#  443 -9.4629998e+03 2.01e-04 7.19e+01  -6.0 1.58e-01    -  1.00e+00 4.48e-01f  1
#  444 -9.4629999e+03 5.58e-05 2.00e+01  -6.0 8.24e-02    -  1.00e+00 7.22e-01f  1
#  445 -9.4629999e+03 3.03e-05 1.08e+01  -6.0 2.07e-02    -  1.00e+00 4.56e-01f  1
#  446 -9.4629999e+03 1.84e-05 6.58e+00  -6.0 4.14e-03    -  1.00e+00 3.94e-01f  2
#  447 -9.4629999e+03 5.80e-09 3.80e-03  -6.0 2.43e-03    -  1.00e+00 1.00e+00h  1
#  448 -9.4629999e+03 5.24e-13 4.86e-07  -6.0 3.57e-05    -  1.00e+00 1.00e+00h  1
#  449 -9.4630000e+03 2.17e-05 2.27e+00  -9.0 1.56e-01    -  9.98e-01 9.78e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450 -9.4630000e+03 1.45e-05 4.23e+00  -9.0 7.07e-02    -  1.00e+00 3.59e-01h  1
#  451 -9.4630000e+03 7.50e-06 2.63e+00  -9.0 5.94e-02    -  1.00e+00 5.54e-01f  1
#  452 -9.4630000e+03 3.01e-06 7.50e-01  -9.0 4.29e-02    -  1.00e+00 7.16e-01f  1
#  453 -9.4630000e+03 7.03e-07 8.07e-04  -9.0 2.74e-02    -  1.00e+00 1.00e+00f  1
#  454 -9.4630000e+03 1.63e-07 1.35e-04  -9.0 1.32e-02    -  1.00e+00 1.00e+00h  1
#  455 -9.4630000e+03 1.28e-08 1.76e-04  -9.0 3.70e-03    -  1.00e+00 1.00e+00h  1
#  456 -9.4630000e+03 7.67e-11 1.91e-06  -9.0 2.86e-04    -  1.00e+00 1.00e+00h  1
#  457 -9.4630000e+03 5.49e-13 2.33e-08  -9.0 2.42e-05    -  1.00e+00 1.00e+00h  1
#  458 -9.4630000e+03 3.34e-13 1.43e-13  -9.0 2.99e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 458
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -9.4630000001845419e+03   -9.4630000001845419e+03
# Dual infeasibility......:   1.4252856707364092e-13    1.4252856707364092e-13
# Constraint violation....:   1.1368683772161603e-13    3.3395508580724709e-13
# Complementarity.........:   1.0000000006154245e-09    1.0000000006154245e-09
# Overall NLP error.......:   1.0000000006154245e-09    1.0000000006154245e-09
#
#
# Number of objective function evaluations             = 1276
# Number of objective gradient evaluations             = 354
# Number of equality constraint evaluations            = 1276
# Number of inequality constraint evaluations          = 1276
# Number of equality constraint Jacobian evaluations   = 473
# Number of inequality constraint Jacobian evaluations = 473
# Number of Lagrangian Hessian evaluations             = 458
# Total CPU secs in IPOPT (w/o function evaluations)   =   1838.530
# Total CPU secs in NLP function evaluations           =     41.408
#
# EXIT: Optimal Solution Found.

# %%
beautify(pe,model)
# Out:
# Here comes the result:
# ------------------------------------------------------------------------------------------------------------
# stages		T		Q		V_out		L_out		L_P		W
# Condenser	30.00		-202.56		8.42384		0.00000		0.08186		2.98128
#
# stages		T		Q		V_out		L_out		L_P		P_VLE
# Reactive[1]	200.00		-36.25		11.48697		0.00676		0.00000		20.00001
# Reactive[2]	200.00		-36.25		10.91262		0.01353		0.00000		20.00000
# Reactive[3]	200.00		-36.25		10.33827		0.02029		0.00000		20.00000
# Reactive[4]	200.00		-36.25		9.76393		0.02705		0.00000		20.00000
# Reactive[5]	200.00		-36.25		9.18958		0.03381		0.00000		20.00000
# Reactive[6]	200.00		-36.25		8.61523		0.04058		0.00000		20.00000
# Reactive[7]	200.00		-36.25		8.04088		0.04734		0.00000		20.00000
# Reactive[8]	200.00		-36.25		7.46653		0.05410		0.00000		20.00000
# Reactive[9]	200.00		-36.25		6.89218		0.06087		0.00000		20.00000
# Reactive[10]	200.00		-36.25		6.31783		0.06763		0.00000		20.00000
# Reactive[11]	200.00		-36.25		5.74349		0.07439		0.00000		20.00000
# Reactive[12]	200.00		-36.25		5.16914		0.08115		0.00000		20.00000
# Reactive[13]	200.00		-36.25		4.59479		0.08792		0.00000		20.00000
# Reactive[14]	200.00		-36.25		4.02044		0.09468		0.00000		20.00000
# Reactive[15]	200.00		-36.25		3.44609		0.10144		0.00000		20.00000
# Reactive[16]	200.00		-36.25		2.87174		0.10821		0.00000		20.00000
# Reactive[17]	200.00		-36.25		2.29740		0.11497		0.00000		20.00000
# Reactive[18]	200.00		-36.25		1.72305		0.12173		0.00000		20.00000
# Reactive[19]	200.00		-36.25		1.14870		0.12849		0.00000		20.00000
# Reactive[20]	200.00		-36.25		0.57435		0.13526		0.00000		20.00000
# Reboiler	200.00		0.00		0.00000		0.13526				19.99766
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Construct the simulator

# %%
style = {'description_width': 'initial'}
layout1 = widgets.Layout(width='200px')


t_control = {}
for i in model.reactive:
    t_control[i] = widgets.FloatSlider(min=200+273.15,max=265+273.15,step=5,description='T {:}'.format(i),style=style)
L_P_control = {}
for i in model.reactive:
    L_P_control[i] = widgets.FloatSlider(min=0,max=0.1,step=0.01,description='Side Draw {:}'.format(i),style=style) 
cat_control = {}
for i in model.reactive:
    cat_control[i] = widgets.FloatSlider(min=0,max=5000,value=3000,step=100,description='Cat {:}'.format(i),style=style)   
feed_control = {}
for i in model.reactive:
    feed_control[i] = widgets.FloatSlider(min=0,max=2,value=1,step=0.1,description='Feed {:}'.format(i),style=style)   


reflux_control = widgets.FloatSlider(min=0,max=5,step=0.1,description='Reflux',style=style)  
reboiler_temperature_control = widgets.FloatSlider(min=200+273.15,max=350+273.15,step=0.1,description='Temperature'.format(i),style=style)
bottom_control = widgets.FloatSlider(min=0,max=0.1,step=0.01,description='Bottom Rate'.format(i),style=style)
rho_control1 = widgets.BoundedFloatText(min=1,max=10000,step=10,description='Penalty Weight Reactive'.format(i),style=style)
rho_control2 = widgets.BoundedFloatText(min=1,max=10000,step=10,description='Penalty Weight Reboiler'.format(i),style=style)

solver_control = widgets.Checkbox(
    value=True,
    description='Display IPOPT output',
    disabled=False
)

run_solve = widgets.Button(
    description='Run Solve',
    disabled=False,
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Run Solve',
    icon='check'
)

plot_button = widgets.Button(
    description='Plot Distribution',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Plot Distribution',
    icon='check'
)

clear_plot_button = widgets.Button(
    description='Clear Plots',
    disabled=False,
    button_style='danger', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Plot Distribution',
    icon='legal'
)

out1 = widgets.Output()
out2 = widgets.Output()
out3 = widgets.Output()

# %%
def button_click(event):
    out1.clear_output()
    out2.clear_output()
    
    model.condenser.L['out'].fix(reflux_control.value)
    
    for i in model.reactive:
        model.reactive[i].T.setub(t_control[i].value)
        model.reactive[i].L['P'].fix(L_P_control[i].value) 
        model.reactive[i].MPCC.rho = rho_control1.value
    
    model.reboiler.T.fix(reboiler_temperature_control.value)
    model.reboiler.MPCC.rho = rho_control2.value
    model.reactive[model.TRAY.last()].L['P'].fix(bottom_control.value)

    with out1:
        results = opt.solve(model,tee=solver_control.value)
    update_dual(pe,model)
    with out2:
        beautify(pe,model)
        
run_solve.on_click(button_click)

def plot_click(event):
    with out3:
        plot_distribution(model)

plot_button.on_click(plot_click)

def clear_plot_click(event):
    out3.clear_output()
    with out3:
        plot_distribution(model)

clear_plot_button.on_click(clear_plot_click)

# %%
cnumber_range = range(1,57)
def trans_cnumber(dic):
    molefraction = {}
    for i in cnumber_range:
        molefraction[i] = []
    for i in m.COMP_ORG:
        molefraction[cal_cnumber(i)].append(np.array(dic[i]))
    for i in cnumber_range:
        molefraction[i] = np.sum(molefraction[i],0)
    tmp = []
    for i in cnumber_range:
        tmp.append(molefraction[i])
    return tmp 
    
def plot_distribution(model):
    
    g_data = []; d_data = []; l_out_data = {}; l_P_data = {}; b_data = []
    cd_x_data = []; rf_x_data = {}; rb_x_data = []

    g_data = trans_cnumber({i:model.condenser.V['out'].value*model.condenser.y[i].value for i in m.COMP_TOTAL})
    d_data = trans_cnumber({i:model.condenser.L['P'].value*model.condenser.x[i].value for i in m.COMP_TOTAL})
    for j in model.reactive:
        l_out_data[j] = trans_cnumber({i:model.reactive[j].L['out'].value*model.reactive[j].x[i].value for i in m.COMP_TOTAL})
        l_P_data[j] = trans_cnumber({i:model.reactive[j].L['P'].value*model.reactive[j].x[i].value for i in m.COMP_TOTAL})
    b_data = trans_cnumber({i:model.reboiler.L['out'].value*model.reboiler.x[i].value for i in m.COMP_TOTAL})

    cd_x_data = trans_cnumber({i:model.condenser.x[i].value for i in m.COMP_TOTAL})
    for j in model.reactive:
        rf_x_data[j] = trans_cnumber({i:model.reactive[j].x[i].value for i in m.COMP_TOTAL})
    rb_x_data = trans_cnumber({i:model.reboiler.x[i].value for i in m.COMP_TOTAL})
                
    fig, (ax,ax2) = plt.subplots(1,2,figsize=(16,7))
    ax.plot(cnumber_range,g_data,'co-')
    ax.plot(cnumber_range,d_data,'go-')
    for j in model.reactive:
        ax.plot(cnumber_range,l_P_data[j],'bo-',alpha = (j+1)/(len(model.TRAY)+1),marker = r'${:}$'.format(j),markersize=10)
    ax.plot(cnumber_range,b_data,'ro-')
    
    ax.set_xlim(0, 40)
    ax.set_yscale("log")
    ax.set_ylim(1e-12, 1)
    # ax.legend(['Vapor','Distillate',*['P{:}'.format(i) for i in model.reactive],'Bottom'],fontsize=14,loc=1)
    ax.set_title('Product Distribution',fontsize=18)

    ax.set_ylabel('Molar Flow (kmol/s)', color='K',fontsize=18)

    ax2.plot(cnumber_range,cd_x_data,'go-')
    for j in model.reactive:
        ax2.plot(cnumber_range,rf_x_data[j],'bo-',alpha = (j+1)/(len(model.TRAY)+1),marker = r'${:}$'.format(j),markersize=10)
    ax2.plot(cnumber_range,rb_x_data,'ro-')  

    ax2.set_xlim(0, 40)
    ax2.set_ylim(0, 0.25)
    ax2.legend(['Condenser',*['Stage{:}'.format(i) for i in model.reactive],'Reboiler'],fontsize=14,loc=1)
    ax2.set_title('Liquid Composition (Mole)',fontsize=18)

    ax2.set_ylabel('Molar Fraction', color='K',fontsize=18)
    ax2.set_xlabel('Carbon Number', color='K',fontsize=18)

    ax.grid()
    ax2.grid()
    plt.show()

# %%
t_control_vbox = widgets.VBox([t_control[i] for i in model.reactive] + [cat_control[i] for i in model.reactive])
L_P_control_vbox = widgets.VBox([L_P_control[i] for i in model.reactive] + [feed_control[i] for i in model.reactive])

linebreak = widgets.Label('-'*120)

reactive_interface = widgets.HBox([t_control_vbox,L_P_control_vbox])
reboiler_interface = widgets.HBox([reboiler_temperature_control,bottom_control])
solver_interface = widgets.HBox([run_solve,plot_button,clear_plot_button,solver_control])
rho_interface = widgets.HBox([rho_control1,rho_control2])

interface = widgets.VBox([widgets.Label('Condenser'),linebreak,reflux_control,linebreak,\
                          widgets.Label('Reactive'),linebreak,reactive_interface,linebreak,\
                          widgets.Label('Reboiler'),linebreak,reboiler_interface,linebreak,\
                          rho_interface,linebreak,\
                          solver_interface])

# %%
display(interface,out2,out3)

# %%
display(out1)
